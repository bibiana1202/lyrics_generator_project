# %%
# 그래프에서 한글표현을 위해 폰트를 설치합니다.
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

# %%
import matplotlib.pyplot as plt  # 그래프 그리는 용도
import matplotlib.font_manager as fm  # 폰트 관련 용도
path = '/usr/share/fonts/truetype/nanum/NanumGothicEco.ttf'  # 설치된 나눔글꼴중 원하는 녀석의 전체 경로를 가져오자
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)

plt.rc('font', family=font_name)

fm._rebuild()
# Out:
# NanumGothic Eco

# %%
import re
import os
import unicodedata
import urllib3
import zipfile
import shutil
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Embedding, GRU, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Download the data

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/project/NLP_project/전처리/music_data_(35만_500자 제한)_re1.csv')

df
# Out:
#         Unnamed: 0        title  \
# 0                0            가
# 1                1            가
# 2                2          잘 가
# 3                3            가
# 4                4            가
# ...            ...          ...
# 341318      341318  나 사는 이유 알도록
# 341319      341319    나로부터 시작되리
# 341320      341320    나로부터 시작되리
# 341321      341321    나로부터 시작되리
# 341322      341322    나의모습 나의소유
#
#                                                     lyric
# 0        Follow me Here we go I go I go I go 난 완전히 go ...
# 1        어서와 포르쉐는 처음이지 yeah I bet that 억짜리 SUV white s...
# 2        어서 가 밤이 깊었으니까 그래 조심히 들어가 그렇게 네가 사라질 때까지 손을 흔들...
# 3        참 선명한 얘기들 깨어도 깨어지지 않는 조각들 그뿐이란 걸 알면 이제 그만해도 될...
# 4        미안하다는 사과도 잘하겠다는 네 말도 지겨워 다 Over and over agai...
# ...                                                   ...
# 341318   어린 시절 성탄 아침에 우린 많은 선물을 받았었지 하지만 몰랐었네 아기예수 탄생하...
# 341319   저 높은 하늘위로 밝은 태양 떠오르듯이 난 주저앉지 않으리 어떤 어려움에도 주의 ...
# 341320   저 높은 하늘 위로 밝은 태양 떠오르듯이 난 주저앉지 않으리 어떤 어려움에도 주의...
# 341321   저 높은 하늘위로 밝은 태양 떠오르듯이 난 주저앉지 않으리 어떤 어려움에도 주의 ...
# 341322   나의모습 나의소유 주님앞에 모두드립니다 모든아픔 모든기쁨 내모든눈물 받아주소서 나...
#
# [341323 rows x 3 columns]

# %%
df['title'].nunique(), df['lyric'].nunique()
df.drop_duplicates(subset=['lyric'], inplace=True)
df.dropna(inplace=True)
df.reset_index(drop=True,inplace=True)

df
# Out:
#         Unnamed: 0        title  \
# 0                0            가
# 1                1            가
# 2                2          잘 가
# 3                3            가
# 4                4            가
# ...            ...          ...
# 341318      341318  나 사는 이유 알도록
# 341319      341319    나로부터 시작되리
# 341320      341320    나로부터 시작되리
# 341321      341321    나로부터 시작되리
# 341322      341322    나의모습 나의소유
#
#                                                     lyric
# 0        Follow me Here we go I go I go I go 난 완전히 go ...
# 1        어서와 포르쉐는 처음이지 yeah I bet that 억짜리 SUV white s...
# 2        어서 가 밤이 깊었으니까 그래 조심히 들어가 그렇게 네가 사라질 때까지 손을 흔들...
# 3        참 선명한 얘기들 깨어도 깨어지지 않는 조각들 그뿐이란 걸 알면 이제 그만해도 될...
# 4        미안하다는 사과도 잘하겠다는 네 말도 지겨워 다 Over and over agai...
# ...                                                   ...
# 341318   어린 시절 성탄 아침에 우린 많은 선물을 받았었지 하지만 몰랐었네 아기예수 탄생하...
# 341319   저 높은 하늘위로 밝은 태양 떠오르듯이 난 주저앉지 않으리 어떤 어려움에도 주의 ...
# 341320   저 높은 하늘 위로 밝은 태양 떠오르듯이 난 주저앉지 않으리 어떤 어려움에도 주의...
# 341321   저 높은 하늘위로 밝은 태양 떠오르듯이 난 주저앉지 않으리 어떤 어려움에도 주의 ...
# 341322   나의모습 나의소유 주님앞에 모두드립니다 모든아픔 모든기쁨 내모든눈물 받아주소서 나...
#
# [341323 rows x 3 columns]

# %% [markdown]
# ## Configuration

# %%
batch_size = 32  # Batch size for training.
epochs = 100  # Number of epochs to train for.
hidden_units = 256  # Latent dimensionality of the encoding space.
embedding_dim = 100
num_samples = 341323    # Number of samples to train on.

# %% [markdown]
# ## Prepare the data

# %% [markdown]
# 데이터셋을 다운로드한 후에 데이터를 준비하고자 다음의 단계를 수행합니다.
#
# 1. 각 문장에 start와 end 토큰을 추가합니다.
# 2. 특정 문자를 제거함으로써 문장을 정리합니다.
# 3. 단어 인덱스와 아이디(ID) 인덱스를 생성합니다. (단어 → 아이디(ID), 아이디(ID) → 단어로 매핑된 딕셔너리).
# 4. 각 문장을 입력층의 최대 길이만큼 패딩(padding)을 수행합니다.

# %%
# !pip install konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 7.2 MB/s
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.21.6)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.9.1)
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.4.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (453 kB)
#      |████████████████████████████████| 453 kB 81.7 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (4.1.1)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.4.0 konlpy-0.6.0

# %%
from konlpy.tag import Okt
okt = Okt()

# %%
import re
def preprocess_kor_sentence(sent):
  # 단어와 구두점 사이에 공백을 만듭니다.
  # Ex) "he is a boy." => "he is a boy ."
  sent = re.sub(r"([?.!,¿])", r" \1", sent)

  # (a-z, A-Z, ".", "?", "!", ",") 이들을 제외하고는 전부 공백으로 변환합니다.
  sent = re.sub(r"[^a-zA-Z가-힣ㄱ-ㅎㅏ-ㅣ!.?]+", r" ", sent)

  # 다수 개의 공백을 하나의 공백으로 치환
  sent = re.sub(r"\s+", " ", sent)
  
  sent = okt.morphs(sent, stem = False)
  sent = " ".join(sent) # string으로 출력!!! 구분 " "
  return sent

# %%
from tqdm import tqdm 
def load_preprocessed_data():
    encoder_input, decoder_input, decoder_target = [], [], []

    for i in tqdm(range(len(df[:num_samples]))):
        # source 데이터와 target 데이터 분리
        tar_line = df['title'].iloc[i]
        src_line = df['lyric'].iloc[i]

        # source 데이터 전처리
        src_line = [w for w in preprocess_kor_sentence(src_line).split()]

        # target 데이터 전처리
        tar_line = preprocess_kor_sentence(tar_line)
        tar_line_in = [w for w in ("<sos> " + tar_line).split()]  # teacher forcing을 위한 정답셋 
        tar_line_out = [w for w in (tar_line + " <eos>").split()]

        encoder_input.append(src_line)
        decoder_input.append(tar_line_in)
        decoder_target.append(tar_line_out)
                
    return encoder_input, decoder_input, decoder_target

# %%
# 전처리 테스트

kr_sent = u"저녁 먹었니?"

print('전처리 전 한국어 문장 :', kr_sent)
print('전처리 후 한국어 문장 :', preprocess_kor_sentence(kr_sent))
# Out:
# 전처리 전 한국어 문장 : 저녁 먹었니?
# 전처리 후 한국어 문장 : 저녁 먹었니 ?

# %%
sents_lylic_in, sents_title_in, sents_title_out  = load_preprocessed_data()
# Out:
# 100%|██████████| 341323/341323 [5:03:25<00:00, 18.75it/s]

# %%
len(sents_lylic_in), len(sents_title_in), len(sents_title_out)
# Out:
# (341323, 341323, 341323)

# %%
print('인코더의 입력 :',sents_lylic_in[2968])
print('디코더의 입력 :',sents_title_in[2968])
print('디코더의 레이블 :',sents_title_out[2968])
# Out:
# 인코더의 입력 : ['궂', '은', '비', '내리는', '날', '그야말로', '옛날', '식', '다방', '에', '앉아', '도라지', '위스키', '한', '잔', '에다', '짙은', '색소폰', '소릴', '들어', '보렴', '새', '빨', '간', '립스틱', '에', '나름', '대로', '멋', '을', '부린', '마담', '에게', '실없이', '던지는', '농담', '사이', '로', '짙은', '색소폰', '소릴', '들어', '보렴', '이제', '와', '새삼', '이', '나이', '에', '실연', '의', '달콤함이야', '있', '겠냐만은', '왠지', '한', '곳', '이', '비어', '있는', '내', '가슴', '이', '잃어버린', '것', '에', '대하', '여', '밤', '늦은', '항구', '에서', '그야말로', '연락선', '선', '창가', '에서', '돌아올', '사람', '은', '없을지라도', '슬픈', '뱃고동', '소릴', '들어', '보렴', '첫사랑', '그', '소녀', '는', '어디', '에서', '나', '처럼', '늙어', '갈까', '가버린', '세월', '이', '서글퍼지는', '슬픈', '뱃고동', '소릴', '들어', '보렴', '이제', '와', '새삼', '이', '나이', '에', '청춘', '의', '미련', '이야', '있', '겠냐만은', '왠지', '한', '곳', '이', '비어', '있는', '내', '가슴', '에', '다시', '못', '올', '곳', '에', '대하', '여', '낭만', '에', '대하', '여', 'kia']
# 디코더의 입력 : ['<sos>', '낭만', '에', '대하', '여']
# 디코더의 레이블 : ['낭만', '에', '대하', '여', '<eos>']

# %% [markdown]
# 단어집합을 생성하겠습니다.

# %%
# 가사 input -> 제목 output 

# 가사 input

tokenizer_lylic = Tokenizer(filters="", lower=False)
tokenizer_lylic.fit_on_texts(sents_lylic_in)
encoder_input = tokenizer_lylic.texts_to_sequences(sents_lylic_in)

# %%
# 제목 output
tokenizer_title = Tokenizer(filters="", lower=False)
tokenizer_title.fit_on_texts(sents_title_in)
tokenizer_title.fit_on_texts(sents_title_out)

decoder_input = tokenizer_title.texts_to_sequences(sents_title_in)
decoder_target = tokenizer_title.texts_to_sequences(sents_title_out)

# %% [markdown]
# 각 문장을 입력층의 최대 길이만큼 패딩(padding)을 수행합니다.

# %%
encoder_input = pad_sequences(encoder_input,maxlen=1500, padding="post")
decoder_input = pad_sequences(decoder_input,maxlen=8, padding="post")
decoder_target = pad_sequences(decoder_target,maxlen=8, padding="post")

# %%
print('인코더의 입력의 크기(shape) :',encoder_input.shape)
print('디코더의 입력의 크기(shape) :',decoder_input.shape)
print('디코더의 레이블의 크기(shape) :',decoder_target.shape)
# Out:
# 인코더의 입력의 크기(shape) : (341323, 1500)
# 디코더의 입력의 크기(shape) : (341323, 8)
# 디코더의 레이블의 크기(shape) : (341323, 8)

# %% [markdown]
# 샘플은 총 3833개 존재합니다

# %%
src_vocab_size = len(tokenizer_lylic.word_index) +1
tar_vocab_size = len(tokenizer_title.word_index) +1

print(f"가사 단어 집합의 크기 : {src_vocab_size}, 제목 단어 집합의 크기 : {tar_vocab_size}")
# Out:
# 가사 단어 집합의 크기 : 420224, 제목 단어 집합의 크기 : 84752

# %%
len(tokenizer_title.word_index)
# Out:
# 84751

# %% [markdown]
# 단어로부터 정수를 얻는 딕셔너리와 정수로부터 단어를 얻는 딕셔너리를 각각 만들어줍니다. 이들은 훈련을 마치고 예측값과 실제값을 비교하는 단계에서 사용합니다.

# %%
src_to_index = tokenizer_lylic.word_index  # word : idx
index_to_src = tokenizer_lylic.index_word  # idx : word
tar_to_index = tokenizer_title.word_index # word : idx
index_to_tar = tokenizer_title.index_word # idx : word

# %%
print(len(src_to_index),len(index_to_src),len(tar_to_index),len(index_to_tar))
# Out:
# 420223 420223 84751 84751

# %% [markdown]
# 테스트 데이터를 분리하겠습니다. 인코더 input, 디코더 input, 디코더 output이 동일하게 분리되어야 하기 때문에 랜덤한 정수배열을 만들어 직접 나누겠습니다.

# %% [markdown]
# 우선 랜덤하게 시퀀스를 섞습니다.

# %%
indices = np.arange(encoder_input.shape[0])
np.random.shuffle(indices)
print('랜덤 시퀀스 :',indices)
# Out:
# 랜덤 시퀀스 : [316931 110443 338006 ... 106874 331272 248707]

# %%
encoder_input = encoder_input[indices]
decoder_input = decoder_input[indices]
decoder_target = decoder_target[indices]

# %%
decoder_input[indices[0]], decoder_target[indices[0]]
# Out:
# (array([   1, 2884, 2884,    0,    0,    0,    0,    0], dtype=int32),
#  array([2884, 2884,    2,    0,    0,    0,    0,    0], dtype=int32))

# %% [markdown]
# `<sos>` `<eos>` 토큰을 제외한 다른 단어들은 동일한 인덱스를 갖고 있어야 합니다.

# %% [markdown]
# 10%의 데이터를 test데이터로 분리하겠습니다.

# %%
n_of_val = int(num_samples*0.1)

encoder_input_train = encoder_input[:-n_of_val]
decoder_input_train = decoder_input[:-n_of_val]
decoder_target_train = decoder_target[:-n_of_val]

encoder_input_test = encoder_input[-n_of_val:]
decoder_input_test = decoder_input[-n_of_val:]
decoder_target_test = decoder_target[-n_of_val:]

# %%
print('훈련 source 데이터의 크기 :',encoder_input_train.shape)
print('훈련 target 데이터의 크기 :',decoder_input_train.shape)
print('훈련 target 레이블의 크기 :',decoder_target_train.shape)
print('테스트 source 데이터의 크기 :',encoder_input_test.shape)
print('테스트 target 데이터의 크기 :',decoder_input_test.shape)
print('테스트 target 레이블의 크기 :',decoder_target_test.shape)
# Out:
# 훈련 source 데이터의 크기 : (307191, 1500)
# 훈련 target 데이터의 크기 : (307191, 8)
# 훈련 target 레이블의 크기 : (307191, 8)
# 테스트 source 데이터의 크기 : (34132, 1500)
# 테스트 target 데이터의 크기 : (34132, 8)
# 테스트 target 레이블의 크기 : (34132, 8)

# %% [markdown]
# ## Model

# %% [markdown]
# 이제 번역기를 빌드해보겠습니다.

# %%
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Masking
from tensorflow.keras.models import Model

# %% [markdown]
# 인코더를 설계합니다. LSTM에서 state_h, state_c를 리턴받는데, 이는 각각 RNN 챕터에서 LSTM을 처음 설명할 때 언급하였던 은닉 상태와 셀 상태에 해당됩니다. 이 두 가지 상태를 encoder_states에 저장합니다. encoder_states를 디코더에 전달하므로서 이 두 가지 상태 모두를 디코더로 전달할 예정입니다. 이것이 앞서 배운 컨텍스트 벡터입니다.

# %%
# 인코더
encoder_inputs = Input(shape=(None,))
enc_emb = Embedding(src_vocab_size, embedding_dim)(encoder_inputs) # 임베딩 층
encoder_lstm1 = LSTM(hidden_units, return_sequences = True, return_state=True)
encoder_lstm2 = LSTM(hidden_units, return_sequences = True, return_state=True)
encoder_lstm3 = LSTM(hidden_units, return_sequences = True, return_state=True)
encoder_lstm4 = LSTM(hidden_units, return_sequences = True, return_state=True)

x, eh1, ec1 = encoder_lstm1(enc_emb) # 은닉 상태와 셀 상태를 리턴
x, eh2, ec2 = encoder_lstm2(x) # 은닉 상태와 셀 상태를 리턴
x, eh3, ec3 = encoder_lstm3(x) # 은닉 상태와 셀 상태를 리턴
encoder_outputs, eh4, ec4 = encoder_lstm4(x) # 은닉 상태와 셀 상태를 리턴

encoder_states = [eh1, ec1, eh2, ec2, eh3, ec3, eh4, ec4] # 인코더의 은닉 상태와 셀 상태를 저장

# %% [markdown]
# 이번에는 Attention을 추가합니다.
# - Attention 중 가장 기초적인 dot-product attention을 예제로 진행하겠습니다.
# 1. attention score 계산
# 2. softmax로 attention distribution 계산
# 3. 각 인코더의 어텐션 가중치와 은닉 상태를 가중합하여 어텐션 값 계산
# 4. 어텐션값과 디코더의 t시점의 은닉상태를 연결
# 5. 출력층 연산의 입력이 되는 st 계산

# %% [markdown]
# 디코더에서는 attention layer를 추가합니다.
# - 이때, s_는 은닉상태와 디코더의 최종 출력은 연결해야 하므로, shape을 맞춰주기 위하여 축을 추가합니다.
# - attention layer는 디코더의 은닉상태와 인코더의 은닉상태 전체를 받아 컨텍스트 벡터를 생성합니다.
# - 마지막으로 생성한 컨텍스트 벡터와 디코더의 은닉상태 전체를 softmax layer에 넣고 인덱스를 예측합니다.

# %%
from tensorflow.keras.layers import Attention

# 디코더
decoder_inputs = Input(shape=(None,))
dec_emb_layer = Embedding(tar_vocab_size, hidden_units) # 임베딩 층
dec_emb = dec_emb_layer(decoder_inputs) # 임베딩 결과

# 상태값 리턴을 위해 return_state는 True, 모든 시점에 대해서 단어를 예측하기 위해 return_sequences는 True
decoder_lstm1 = LSTM(hidden_units, return_sequences=True, return_state=True) 
decoder_lstm2 = LSTM(hidden_units, return_sequences=True, return_state=True) 
decoder_lstm3 = LSTM(hidden_units, return_sequences=True, return_state=True) 
decoder_lstm4 = LSTM(hidden_units, return_sequences=True, return_state=True) 

# 인코더의 은닉 상태를 초기 은닉 상태(initial_state)로 사용
x1, h1, c1 = decoder_lstm1(dec_emb, initial_state=encoder_states[:2])
x2, h2, c2 = decoder_lstm2(x1, initial_state=encoder_states[2:4])
x3, h3, c3 = decoder_lstm3(x2, initial_state=encoder_states[4:6])
decoder_outputs, h4 , c4 = decoder_lstm4(x3, initial_state=encoder_states[6:])

# attention
S_ = tf.concat([eh4[:, tf.newaxis, :], decoder_outputs[:, :-1, :]], axis=1) # query 

attention = Attention(hidden_units)
context_vector, _ = attention([S_, encoder_outputs], return_attention_scores = True)

concat = tf.concat([decoder_outputs, context_vector], axis=-1)

# 모든 시점의 결과에 대해서 소프트맥스 함수를 사용한 출력층을 통해 단어 예측
decoder_dense = Dense(tar_vocab_size, activation='softmax')
decoder_outputs = decoder_dense(concat)

# %%
# 모델의 입력과 출력을 정의.
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['acc'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None)]       0           []
#
#  input_2 (InputLayer)           [(None, None)]       0           []
#
#  embedding (Embedding)          (None, None, 100)    42022400    ['input_1[0][0]']
#
#  embedding_1 (Embedding)        (None, None, 256)    21696512    ['input_2[0][0]']
#
#  lstm (LSTM)                    [(None, None, 256),  365568      ['embedding[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  lstm_4 (LSTM)                  [(None, None, 256),  525312      ['embedding_1[0][0]',
#                                  (None, 256),                     'lstm[0][1]',
#                                  (None, 256)]                     'lstm[0][2]']
#
#  lstm_1 (LSTM)                  [(None, None, 256),  525312      ['lstm[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  lstm_5 (LSTM)                  [(None, None, 256),  525312      ['lstm_4[0][0]',
#                                  (None, 256),                     'lstm_1[0][1]',
#                                  (None, 256)]                     'lstm_1[0][2]']
#
#  lstm_2 (LSTM)                  [(None, None, 256),  525312      ['lstm_1[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  lstm_6 (LSTM)                  [(None, None, 256),  525312      ['lstm_5[0][0]',
#                                  (None, 256),                     'lstm_2[0][1]',
#                                  (None, 256)]                     'lstm_2[0][2]']
#
#  lstm_3 (LSTM)                  [(None, None, 256),  525312      ['lstm_2[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  lstm_7 (LSTM)                  [(None, None, 256),  525312      ['lstm_6[0][0]',
#                                  (None, 256),                     'lstm_3[0][1]',
#                                  (None, 256)]                     'lstm_3[0][2]']
#
#  tf.__operators__.getitem (Slic  (None, 1, 256)      0           ['lstm_3[0][1]']
#  ingOpLambda)
#
#  tf.__operators__.getitem_1 (Sl  (None, None, 256)   0           ['lstm_7[0][0]']
#  icingOpLambda)
#
#  tf.concat (TFOpLambda)         (None, None, 256)    0           ['tf.__operators__.getitem[0][0]'
#                                                                  , 'tf.__operators__.getitem_1[0][
#                                                                  0]']
#
#  attention (Attention)          ((None, None, 256),  1           ['tf.concat[0][0]',
#                                  (None, None, None)               'lstm_3[0][0]']
#                                 )
#
#  tf.concat_1 (TFOpLambda)       (None, None, 512)    0           ['lstm_7[0][0]',
#                                                                   'attention[0][0]']
#
#  dense (Dense)                  (None, None, 84752)  43477776    ['tf.concat_1[0][0]']
#
# ==================================================================================================
# Total params: 111,239,441
# Trainable params: 111,239,441
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, to_file='model.png', )

# %%
import tensorflow as tf

from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

EPOCH= 50
BATCH_SIZE = 64

filename = '/content/drive/MyDrive/voice_project/model/cp/checkpoint-epoch-{}-batch-{}-9/17(2)(1).h5'.format(EPOCH, BATCH_SIZE)

checkpoint = ModelCheckpoint(filename,             # file명을 지정합니다
                             monitor='val_loss',   # val_loss 값이 개선되었을때 호출됩니다
                             verbose=1,            # 로그를 출력합니다
                             save_best_only=True,  # 가장 best 값만 저장합니다
                             mode='auto'           # auto는 알아서 best를 찾습니다. min/max
                            )
earlystopping = EarlyStopping(monitor='val_loss',  # 모니터 기준 설정 (val loss) 
                              patience=4,         # ?회 Epoch동안 개선되지 않는다면 종료
                             )

# %%
model.fit(x=[encoder_input_train, decoder_input_train], y=decoder_target_train, 
          validation_data=([encoder_input_test, decoder_input_test], decoder_target_test),batch_size=BATCH_SIZE, epochs=EPOCH,callbacks=[checkpoint,earlystopping]
          )
# Out:
# Epoch 1/50
# 4800/4800 [==============================] - ETA: 0s - loss: 3.4452 - acc: 0.5967
# Epoch 1: val_loss improved from inf to 3.16031, saving model to /content/drive/MyDrive/voice_project/model/cp/checkpoint-epoch-50-batch-64-9/17(2)(1).h5
# 4800/4800 [==============================] - 3346s 689ms/step - loss: 3.4452 - acc: 0.5967 - val_loss: 3.1603 - val_acc: 0.6168
# Epoch 2/50
# 4800/4800 [==============================] - ETA: 0s - loss: 2.9293 - acc: 0.6265
# Epoch 2: val_loss improved from 3.16031 to 2.89514, saving model to /content/drive/MyDrive/voice_project/model/cp/checkpoint-epoch-50-batch-64-9/17(2)(1).h5
# 4800/4800 [==============================] - 3315s 691ms/step - loss: 2.9293 - acc: 0.6265 - val_loss: 2.8951 - val_acc: 0.6321
# Epoch 3/50
# 4800/4800 [==============================] - ETA: 0s - loss: 2.6275 - acc: 0.6415
# Epoch 3: val_loss improved from 2.89514 to 2.77243, saving model to /content/drive/MyDrive/voice_project/model/cp/checkpoint-epoch-50-batch-64-9/17(2)(1).h5
# 4800/4800 [==============================] - 3315s 691ms/step - loss: 2.6275 - acc: 0.6415 - val_loss: 2.7724 - val_acc: 0.6436
# Epoch 4/50
# 4800/4800 [==============================] - ETA: 0s - loss: 2.3970 - acc: 0.6542
# Epoch 4: val_loss improved from 2.77243 to 2.70352, saving model to /content/drive/MyDrive/voice_project/model/cp/checkpoint-epoch-50-batch-64-9/17(2)(1).h5
# 4800/4800 [==============================] - 3315s 691ms/step - loss: 2.3970 - acc: 0.6542 - val_loss: 2.7035 - val_acc: 0.6519
# Epoch 5/50
# 4800/4800 [==============================] - ETA: 0s - loss: 2.1864 - acc: 0.6661
# Epoch 5: val_loss improved from 2.70352 to 2.68654, saving model to /content/drive/MyDrive/voice_project/model/cp/checkpoint-epoch-50-batch-64-9/17(2)(1).h5
# 4800/4800 [==============================] - 3313s 690ms/step - loss: 2.1864 - acc: 0.6661 - val_loss: 2.6865 - val_acc: 0.6558
# Epoch 6/50
# 4800/4800 [==============================] - ETA: 0s - loss: 1.9856 - acc: 0.6793
# Epoch 6: val_loss did not improve from 2.68654
# 4800/4800 [==============================] - 3304s 688ms/step - loss: 1.9856 - acc: 0.6793 - val_loss: 2.7084 - val_acc: 0.6586
# Epoch 7/50
# 4800/4800 [==============================] - ETA: 0s - loss: 1.7913 - acc: 0.6945
# Epoch 7: val_loss did not improve from 2.68654
# 4800/4800 [==============================] - 3305s 689ms/step - loss: 1.7913 - acc: 0.6945 - val_loss: 2.7547 - val_acc: 0.6615
# Epoch 8/50
# 4800/4800 [==============================] - ETA: 0s - loss: 1.6705 - acc: 0.7061
# Epoch 8: val_loss did not improve from 2.68654
# 4800/4800 [==============================] - 3305s 689ms/step - loss: 1.6705 - acc: 0.7061 - val_loss: 2.8325 - val_acc: 0.6586
# Epoch 9/50
# 4800/4800 [==============================] - ETA: 0s - loss: 1.6029 - acc: 0.7131
# Epoch 9: val_loss did not improve from 2.68654
# 4800/4800 [==============================] - 3305s 689ms/step - loss: 1.6029 - acc: 0.7131 - val_loss: 2.8713 - val_acc: 0.6571

# %%
model.save('/content/drive/MyDrive/nlp_project/model/songTolyric/lstm_attention_model_9/17(2)(1).h5')

# %% [markdown]
# ## 훈련된 모델로 번역하기
#
# * 평가 함수는 여기서 *교사 강요(teacher forcing)*를 사용하기 못하는 것을 제외하고는 훈련 루프와 비슷합니다. 각 마지막 시점(time step)에서 이전 디코더 인코더의 결과와 은닉 상태(hidden state)를 가진 예측 값을 디코더에 입력합니다.
#
#     1. 번역하고자 하는 입력 문장이 인코더로 입력되어 인코더의 마지막 시점의 은닉 상태와 셀 상태를 얻습니다.
#     2. 인코더의 은닉 상태와 셀 상태, 그리고 토큰 <sos>를 디코더로 보냅니다.
#     3. 디코더가 토큰 <eos>가 나올 때까지 다음 단어를 예측하는 행동을 반복합니다.

# %%
# 인코더 - 훈련과 동일 
encoder_model = Model(encoder_inputs, [encoder_outputs, encoder_states])

# %%
tf.keras.utils.plot_model(encoder_model, to_file='model.png', )

# %%
# 디코더 

# 이전 시점의 상태를 보관할 텐서
decoder_state_input_h = Input(shape=(hidden_units,))
decoder_state_input_c = Input(shape=(hidden_units,))

decoder_state_input_h1 = Input(shape=(hidden_units,))
decoder_state_input_c1 = Input(shape=(hidden_units,))

decoder_state_input_h2 = Input(shape=(hidden_units,))
decoder_state_input_c2 = Input(shape=(hidden_units,))

decoder_state_input_h3 = Input(shape=(hidden_units,))
decoder_state_input_c3 = Input(shape=(hidden_units,))

decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c,
                         decoder_state_input_h1, decoder_state_input_c1,
                         decoder_state_input_h2, decoder_state_input_c2,
                         decoder_state_input_h3, decoder_state_input_c3]


encoder_state_h = Input(shape=(hidden_units,))
encoder_outputs2 = Input(shape =(None, hidden_units,))


# 훈련 때 사용했던 임베딩 층을 재사용
dec_emb2 = dec_emb_layer(decoder_inputs)

# 다음 단어 예측을 위해 이전 시점의 상태를 현 시점의 초기 상태로 사용
x, state_h1, state_c1 = decoder_lstm1(dec_emb2, initial_state=decoder_states_inputs[:2])
x, state_h2, state_c2 = decoder_lstm2(x, initial_state=decoder_states_inputs[2:4])
x, state_h3, state_c3 = decoder_lstm3(x, initial_state=decoder_states_inputs[4:6])
decoder_outputs2, state_h4, state_c4 = decoder_lstm4(x, initial_state=decoder_states_inputs[6:])
decoder_states2 = [state_h1, state_c1, state_h2, state_c2, state_h3, state_c3, state_h4, state_c4]


# Attention
S_ = tf.concat([encoder_state_h[:, tf.newaxis, :], decoder_outputs2[:, :-1, :]], axis=1) # query 

context_vector, att_score = attention([S_, encoder_outputs2], return_attention_scores = True)
decoder_concat = tf.concat([decoder_outputs2, context_vector], axis=-1)

# 모든 시점에 대해서 단어 예측 (Fully Connected)
decoder_outputs2 = decoder_dense(decoder_concat)

# 수정된 디코더
decoder_model = Model(
    [decoder_inputs, encoder_state_h, encoder_outputs2] + decoder_states_inputs,
    [decoder_outputs2, att_score] + decoder_states2)

# %%
tf.keras.utils.plot_model(decoder_model, to_file='model.png', )

# %% [markdown]
# 테스트 단계에서의 동작을 위한 decode_sequence 함수를 구현합니다.
# 1. 입력 문장이 들어오면 인코더는 마지막 시점까지 전개하여 마지막 시점의 은닉 상태와 셀 상태를 리턴합니다. -> `states_value`
# 2. 디코더의 초기 입력으로 <SOS>를 준비합니다. -> `target_seq`
# 3. 이 두 가지 입력을 가지고 while문 안으로 진입하여 이 두 가지를 디코더의 입력으로 사용합니다.
# 4. 이제 디코더는 현재 시점에 대해서 예측합니다.
#     - 예측 벡터로부터 현재 시점의 예측 단어인 target_seq를 얻고, h와 c 이 두 개의 값은 states_value에 저장합니다.
#     - while문의 다음 루프. 즉, 두번째 시점의 디코더의 입력으로 다시 target_seq와 states_value를 사용합니다.
#     - 이를 현재 시점의 예측 단어로 <eos>를 예측하거나 번역 문장의 길이가 50이 넘는 순간까지 반복합니다.
# 5. 각 시점마다 번역된 다어는 decoded_sentence에 누적하여 저장하였다가 최종 번역 시퀀스로 리턴합니다.

# %%
def decode_sequence(sentence):
    # 입력으로부터 인코더의 마지막 시점의 상태(은닉 상태, 셀 상태)를 얻음
    max_src_len, max_tar_len  = encoder_input.shape[1], decoder_input.shape[1]

    attention_plot = np.zeros((max_tar_len, max_src_len))

    sentence = preprocess_kor_sentence(sentence)
    tokens = sentence.split(" ")
    inputs = tokenizer_lylic.texts_to_sequences([tokens])

    inputs = tf.keras.preprocessing.sequence.pad_sequences(inputs,
                                                            maxlen=max_src_len,
                                                            padding='post')
    encoder_test, states_value = encoder_model.predict(inputs)

    # <SOS>에 해당하는 정수 생성
    target_seq = np.zeros((1,1))
    target_seq[0, 0] = tar_to_index['<sos>']
    
    stop_condition = False
    decoded_sentence = ''

    # stop_condition이 True가 될 때까지 루프 반복
    # 구현의 간소화를 위해서 이 함수는 배치 크기를 1로 가정합니다.
    for t in range(max_tar_len):
        # 이점 시점의 상태 states_value를 현 시점의 초기 상태로 사용
        output_tokens, att_score, h1, c1, h2, c2, h3, c3, h4, c4 = decoder_model.predict([target_seq, states_value[0], encoder_test] + states_value)
        # tar_to_index 2808
  

        # 어텐션 가중치 시각화를 위해 저장 
        att_score = tf.reshape(att_score, (-1, ))
        attention_plot[t] = att_score.numpy() 

        # 예측 결과를 단어로 변환
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = index_to_tar[sampled_token_index]
  
        # 현재 시점의 예측 단어를 예측 문장에 추가
        decoded_sentence += ' '+sampled_char


        # 현재 시점의 예측 결과를 다음 시점의 입력으로 사용하기 위해 저장
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # 현재 시점의 상태를 다음 시점의 상태로 사용하기 위해 저장
        states_value = [ h1, c1, h2, c2, h3, c3, h4 ,c4]

        # <eos>에 도달하거나 정해진 길이를 넘으면 중단.
        if sampled_char == '<eos>':
            break 

    return sentence, decoded_sentence, attention_plot

# %% [markdown]
# 결과 확인을 위한 함수를 만듭니다.

# %%
# 원문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq_to_src(input_seq):
  sentence = ''
  for encoded_word in input_seq:
    if(encoded_word != 0):
      sentence = sentence + index_to_src[encoded_word] + ' '
  return sentence

# 번역문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq_to_tar(input_seq):
  sentence = ''
  for encoded_word in input_seq:
    if(encoded_word != 0 and encoded_word != tar_to_index['<eos>']):
    # if(encoded_word != 0 and encoded_word != tar_to_index['<sos>'] and encoded_word != tar_to_index['<eos>']):
      sentence = sentence + index_to_tar[encoded_word] + ' '
  return sentence

# %%
from pylab import *
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

def plot_attention(attention, sentence, predicted_sentence):
    # you need to change the fname based on your system, and the Chinese can be displayed in the plot
    # font = FontProperties(fname=r"./data/TaipeiSansTCBeta-Regular.ttf", size=14)
    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(1, 1, 1)
    ax.matshow(attention, cmap='viridis')

    fontdict = {'fontsize': 14}

    # set the x-tick/y-tick labels with list of string labels
    ax.set_xticklabels([''] + sentence, fontdict=fontdict, rotation = 90)
    ax.set_yticklabels(predicted_sentence, fontdict=fontdict)

    # set tick locators
    ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
    ax.yaxis.set_major_locator(ticker.MultipleLocator(1))
    plt.show()

# %%
def translate(sentence):
  sentence, result, attention_plot = decode_sequence(sentence)

  print('Input: %s' % (sentence))
  print('Predicted translation: {}'.format(result))

"""  attention_plot = attention_plot[:len(result.split(' '))-2, :len(sentence.split(' '))]
  plot_attention(attention_plot, sentence.split(' '), result.split(' '))"""
# Out:
# "  attention_plot = attention_plot[:len(result.split(' '))-2, :len(sentence.split(' '))]\n  plot_attention(attention_plot, sentence.split(' '), result.split(' '))"

# %%
translate('번역기를 만드는 것은 재미있어.')
# Out:
# Input: 번역기 를 만드는 것 은 재미있어 .
# Predicted translation:  나 의 작은 이야기 <eos>

# %%
translate('집에 가고 싶다.')
# Out:
# Input: 집 에 가고 싶다 .
# Predicted translation:  나 는 행복한 사람 <eos>

# %%
translate('당신의 직업은 무엇입니까?')
# Out:
# Input: 당신 의 직업 은 무엇 입 니까 ?
# Predicted translation:  당신 은 누구 <eos>

# %%
def translate_train(seq_index):
  input_seq = encoder_input_train[seq_index: seq_index + 1]

  sentence = seq_to_src(encoder_input_train[seq_index]).strip()
  _, result, attention_plot = decode_sequence(sentence)

  print('Input: %s' % (sentence))
  print("Right translation :",seq_to_tar(decoder_input_train[seq_index]))
  print('Predicted translation: {}'.format(result))

"""  attention_plot = attention_plot[:len(result.split(' '))-2, :len(sentence.split(' '))]
  plot_attention(attention_plot, sentence.split(' '), result.split(' '))"""
# Out:
# "  attention_plot = attention_plot[:len(result.split(' '))-2, :len(sentence.split(' '))]\n  plot_attention(attention_plot, sentence.split(' '), result.split(' '))"

# %%
translate_train(11)
# Out:
# Input: 키세 츠하즈레 노 카제 가하 코부 계절 이 지나감에 따라 바람 이 옮기는 오 모 이 데타 치 추억 들 나쯔 카시 이 에가 오노 키 미와도 오 이마 찌 그리운 미소 의 친구 는 먼 고향 에 있고 . . . 타카라 모노 다 토 요 베루 모노 와 나니히 토쯔모 보물 이라 부를 수 있는 건 무엇 하나 도 미 쯔케 라 레나 이 마마 찾지 못 한 채 오토 나니 낫테 유쿠 어른 이 되어 가지 나니 모카 모 가 젠 부고노 마마 쟈 모든 걸 전부 이 대론 오와레 나이 끝낼 수 없어 다레모가이쯔카 코 에 루사카 미치 모두 언 젠 간 넘어갈 언덕길 소 노 사키 니 와 그 앞 에는 마루 데 아노히노 스 가 오노마 마노 마치 그 날 의 모습 그대로 인
# Right translation : <sos>
# Predicted translation:  <eos>

# %%
for seq_index in [10, 203, 500, 900, 8003]:
  translate_train(seq_index)
  print("-"*50)
# Out:
# Input: 동망봉 터널 위 자그마한 달동네 방 한 칸 따뜻한 할머니 품속 에 유치원 에서 돌아오면 내 땀 을 닦아주던 주름 있는 당신 손 에 그렇게 자라난 나 uh 내 가 태어난 곳 성북구 의 어느 병원 내 가 자라난 곳 보문동 달동네 언덕 아래 동망봉 터널 위 작은 방 한 칸 에 밝던 내 가 늘 부르던 트로트 비 내리는 호남선 어른 들 의 사랑 . 애교 가 많던 아이 넌 커서 가수 해 라 용돈 쥐 여주 며 하신 할머니 말씀 에 입 이 귀 에 걸린 철 없던 내 가 진짜 음악 을 할 줄 은 나도 물론 처음 은 서투르고 어렸지만 엄마 의 예술 감각 들이마신 공기 를 다르게 해주려 매일 밤낮 을 고생 하신 아버지 덕분 에 내 길 을 가 . 난 . 그 생각 에 쉬 지 않고 견뎠던 시간 또 방황 난 이제 재개발 된 동망봉 터널 위 에 그 곳 에 살며 뛰놀던 달동네 추억 에 잠기 네 손자 는 이제 하고 싶은 일로 돈 을 벌어요 할머니 당신 의 말씀 가슴 에 묻곤 걸어요 난 아직도 여전히도 그대
# Right translation : <sos> 동망봉 터널 Feat . 진 준왕
# Predicted translation:  동망봉 <eos>
# --------------------------------------------------
# Input: 말 없이 떠나간 그 대여 당신 의 나인 줄 만 알았더니 지 금은 홀로 남겨진 채 로 이렇게 깊은 밤 이 다르네 이 제 것 우리 들 의 사랑 이 허무한 연기 처럼 날아간 긴 하늘 속 에 흔 족도 없이 외로운 남자되 어떠도 네 한잔 의술 이라도 벗 이 되줄까 당신 밖에 없는데 너 무사 랑 했는데 남자 라는 이 유로 흘릴수 없는 눈물 이 마를길 없어 흐르네 내 품 에 안기여 흘린 눈물 이 떠나간 날 에의 미였나요 외로운 당신 을 잊고 살기 엔 늦었어요 당신 밖엔 나 없어요 한잔 의술 이라도 벗 이 되줄까 당신 밖에 없는데 너 무사 랑 했는데 남자 라는 이 유로 흘릴수 없는 눈물 이마 를 길이 없어 흐르네 내 품 에 안기여 흘린 눈물 이 떠나간 날 에의 미였나요 외로운 당신 을 잊고 살기 엔 늦었어요 당신 밖엔 나 없어요
# Right translation : <sos> 나 보다 더 외로운 당신
# Predicted translation:  당신 은 나 의 운명 <eos>
# --------------------------------------------------
# Input: 나 는 여기 있고 싶지 않아 . 물론 거기 도 마찬가지 지 . 내 가 거기 있어야 한다면 개집 으로 나를 데려가 . 나 는 여기 있고 싶지 않아 . 물론 거기 도 마찬가지 지 . 내 가 거기 있어야 한다면 개집 으로 나를 데려가 . 개집 에서 잠 을 잤어 . 개집 에서 꿈 을 꿨어 . 개집 에서 잠 을 잤어 . 개집 에서 꿈 을 꿨어 . 개집 에서 잠 을 잤어 . 개집 에서 꿈 을 꿨어 . 개집 에서 잠 을 잤어 . 개집 에서 꿈 을 꿨어 . 오글오글 오 글 터지는 생각 들 과 시선 들 속 에 너 의 썩어 버린 고정관념 은 모욕 들 을 쏟아내고 비틀비틀 비틀어지는 세상 밖에 증오 심 들 은 나 의 별수 없는 말 이 되어 한숨 만을 쏟아내지 . 나 는 여기 있고 싶지 않아 . 물론 거기 도 마찬가지 지 . 내 가 거기 있어야 한다면 개집 으로 나를 데려가 . 나 는 여기 있고 싶지 않아 . 물론 거기 도 마찬가지 지 . 내 가 거기 있어야 한다면 개집 으로 나를 데려가 . 개집 에서 잠 을 잤어 . 개집 에서 꿈 을
# Right translation : <sos> 고귀한 자식 들
# Predicted translation:  진화론 <eos>
# --------------------------------------------------
# Input: 인생 은 잔인한 연인 천사 의 얼굴 을 하고 그대 를 아프게 하죠 작은것 들이 그대 를 울릴 때 는 내 가 그 곁 에 있어줄게 내게 기대 요 인생 은 외로운 여행 찬란한 풍경 들 속 엔 굶주린 야수 가 살 죠 그대 걸음 이 힘겨워 질때 는 내 가 그 곁 에 함께 걸어가요 내게 기대 요 해줄 수 있는 일 은 많이 없겠지만 나 만은 그대 곁 에 같은 모습 으로 언제나 머물 거 예요 아무 것 도 바라지 않을 거 에요 그대 곁 에 언제나 머물 거 예요 아무 것 도 바라지 않을 거 예요 그대 곁 에 언제나 머물 거 예요 내게 기대 요 언젠가 마지막 날 엔 미소 를 짓는 얼굴 로 그대 와 같은 순간 에 조용히 눈 을 감아요 마지막 순간 까지 그대 곁 엔 내 가 있어요 내게 기대 요 내게 기대 요 hanso
# Right translation : <sos> 연인
# Predicted translation:  그대 와 함께 <eos>
# --------------------------------------------------
# Input: 사랑 하나 가 날 다시 살 게 했어 널 만나 이제 알 게 된 말 사랑 해 . . . 너 는 날 위 한 구세주 뜨거운 사랑 을 불어 준 죽어있던 내 심장 을 다시 뛰게 만든 하나 뿐 인 내 전부 니 가 있어 난 눈물 을 지웠어 니 가 있어 난 사랑 을 알았어 너 만 있다면 난 두려울 게 없어 사랑 을 배운 난 매일 같이 웃어 I wanna be with you girl I want you listen my love 내 사랑 은 죽 을 때 까지 너 야 난 니 옆 에 영원히 있을거야 너무나도 고마운 사람 이 젠 둘 로 갈라놓을 수 없는 사람 죽 을 때 까지 널 지킬게 내 목숨 을 걸고 나 약속 해 사랑 하나 가 그대 하나 가 나를 다시 웃게 했어 널 만나 이제야 알 게 된 말 사랑 한다 사랑 한다 나 의 두 눈 과 이 가슴 엔 오로지 너 하나 밖에 없는 걸 약속 할게 영원히 사랑 만을 네 게 준다고 I can t stop loving you 하늘 이 내게만 준 선물 너 라는 사람 너무 놀라운 기
# Right translation : 배운 말 . . . feat . 김동완
# Predicted translation:  사랑 이 남아 <eos>
# --------------------------------------------------

# %%
def translate_test(seq_index):
  input_seq = encoder_input_test[seq_index: seq_index + 1]

  sentence = seq_to_src(encoder_input_test[seq_index]).strip()
  _, result, attention_plot = decode_sequence(sentence)

  print('Input: %s' % (sentence))
  print("Right translation :",seq_to_tar(decoder_input_train[seq_index]))
  print('Predicted translation: {}'.format(result))

  #attention_plot = attention_plot[:len(result.split(' '))-2, :len(sentence.split(' '))]
  #plot_attention(attention_plot, sentence.split(' '), result.split(' '))

# %%
for seq_index in [10, 200, 303, 1005]:
  translate_test(seq_index)
  print("-"*50)
# Out:
# Input: 향기롭지 못 한 날 들 과 우울 속 에 빠진 날 에도 오오 어쩌면 난 그냥 이렇게 살아갈수 있을지도 모르겠어 우 이런 날 너 와같이 걷던 그 거리 우 이런 날 너 와 함께 거 님 이 거리 우후 스밥바 라 밥 바라 스밥 바라바 거울 속 에 비친 내 모습 평범하기 그 지 없는 외모 지만 어쩌면 난 그냥 이대로 살아갈수 있을지도 모르겠어 우 이런 날 바라보는 니 가 너무 고마워 우 이런 날 좋아하는 너 를 너무 사랑 해 우후 나를 위 한 사람 나와 어울리는 나를 위 한 사람 나 의 운명 의 사람 특별하진 않은 사람 내 말 들어 봐여 당 신 앞 의 누군가 를 항상 떠올려요 많은 사람 들 중 에서 당신 기다리는 평범하지 않은 사람 나타날거예요 나를 위 한 사람 나와 어울리는 나를 위 한 사람 나 의 운명 의 사람 나를 위 한 사람 내게 맡는 사람 나를 위 한 사람 나 의 운명 의 사람 bsad
# Right translation : <sos> 동망봉 터널 Feat . 진 준왕
# Predicted translation:  나 의 고백 <eos>
# --------------------------------------------------
# Input: 머 지 않아 잊겠지 내기억 내 모습 . . . 모두 다 잊어가도 괜찮아 넌 웃을테니 . . . 웃던 너 와 웃던나 널 잊어야지 . . 울던 너 와 울던나 널 보내야지 . . 이 젠 널 지워가야 하나 봐 우는 난 널 볼수가 없나 봐 흔들리는 말투 로 떠나가라고 . . 내 가 듣지 못 한말 미안하다고 . . 잊지는마 사랑 해 . . . 다 잊지는마 사랑 해 . . . 머 지 않아 잊겠지 내기억 내 모습 . . . 모두 다 잊어가도 괜찮아 넌 웃을테니 . . . bsad
# Right translation : <sos> 그래도 넌
# Predicted translation:  너 를 떠나 <eos>
# --------------------------------------------------
# Input: 행복 가득한 우리 들 의 이야기 들어 보아 요 도란도란 정답 게 친구 들 과 나누는 소리 또 각 또각 즐겁게 연 필심 땀 흘리는 소리 재잘재잘 물음표 가득해 아하 느낌표 가득해 아하 히히히 개구쟁이 가득해 알쏭쏭 호기심 이 가득해 예쁜 교실 별빛 으로 채워진 모두 가 꿈꾸는 이 밤 다시 내일 만날 친구 그려 봐요 나 의 행복 가득한 교실 그려요 행복 가득한 교실
# Right translation : <sos> domino pt .
# Predicted translation:  나 는 나 <eos>
# --------------------------------------------------
# Input: 그대 가 초 간 날 바라본 그날 난 나 에게 자격 이 생겼다고 생각 했어 그 마음 내게 주면 안 돼요 ? 천천히 내게 오면 안 돼요 ? 멍하니 내 앞 에 서있던 그대 를 등 뒤 에서 가만히 안고 싶었던 걸 알까 내 마음 그리 옮기면 안 돼요 ? 모자란 나 지만 안 될까 요 ? 애써 눈 감아도 보이는 한 사람 밀어내도 되돌아오는 커다란 마음 눈치 챘을지 몰라도 날 봐줄까 요 ? 내일 아니 오늘 지금 그 마음 속 사는 날 발견 한다면 그날 들려준 노래 함께 부르면 어때요 ? 지금 내게 보여준 미소 진심 이면 그 걸 로 충분해 이 이야기 는 시작 됐죠 그대 가 좋아한 영화 와 음악 들 모두 찾아 보고 듣고 외워 다 공부 했어 어울리는 사람 되고 싶어 조금 더 나은 나를 보여주고 싶어 아닌 척 해 보려 해도 잘 안 되고 노력 하지 않아도 그 말 다 기억 해 이 젠 도망치지 않아요 내 가 갈게요 하루 하루 조금씩 네 게 그 마음 속 사는 날 발견 한다면 그날 들려준 노래 함
# Right translation : <sos> 바다 feat . 강록
# Predicted translation:  고스 <eos>
# --------------------------------------------------

# %% [markdown]
# # test

# %%
len(encoder_input_test)
# Out:
# 34132

# %%
import numpy as np

a = np.random.randint(30000, size=1000)
print(a)
# Out:
# [ 3292 24224 24506   187 15035 21289 28418 16993 15664 24655  4707 16507
#    761 29648 20088 23263 21802  8006  1339 15615  8132  2099   258  6176
#   2101  5148 14227 15200 18388 29744  8462 24781 21910 21920 17610 25276
#  15874  3844 18075 10961 20864 18242 19304  7699 11942  1088 12317 29965
#  17556  2683 15991 22619 27666 23253 19550 20629 12730 28460  7090 18459
#   8821 17631 22213  8478  1968  4575 22377  3949 20468 26687 15608  4477
#  26431 28001 16534 20401 23727 12243  5182 11310 16730 11822 18487 18982
#   9668 27914  8535 22463 28321  3498  4037 20100 20472 20754  4811   556
#  16739 12735  4477 24544 17462  4113 20432 10381  1032  1874 13871 18008
#  17676 23186 17360 18261  6537   325 18626  2326 27882 29025 18439 14089
#   5811 20310 20805  6434 27155 20678   926 27069 26375 27119 15232 11557
#   7521 28423 10787 12062 12591  4429 19603   611 25679 10460 26451 13415
#  15704 26527  2661  9938 14292   952  3704 20685 10024  4898  5847 11265
#   6013 29527  5644 28156 20552 14632 16754  8358 24864  5973  3987  4101
#  11778 28257 22019 21808 12864 29910 29791 10619 15432 26388 25530   480
꿈 을 부르짖어 내게 묻고 또 물어 내 가 되고 싶은 거 ? 한국 힙합 대표 또 패션 의 아이콘 Like Reddy or Beenzino 언젠가 내 꿈 이 이뤄진다 믿어 What Time is it ? am 난 내 가 맞다고 믿는것을 매일 같이 해 Where Should I go ? Go Straight 오 직 직 진 오 직 직 진 What Time is it ? am 난 내 가 맞다고 믿는것을 매일 같이 해 Where Should I go ? Go Straight 오 직 직 진 오 직 직 진 생각 해보니
# Right translation : <sos> 만고 땡 Trot Ver .
# Predicted translation:  Tempo <eos>
# -------------------------------------------------- 20088
# Input: How do I look Do I look like a sleepy boy Take cup of tea There s nothing left this oken night They said to me There s no heaven in your own world I disappear To my lonely and infinite world 내게 말 을 거 는 유령 들 과 보이지 않는 웃음소리 oh Falling falling 다 떨어져라 우 우 잠 에 들지 않는 밤 우 우 마음 은 녹아내리고 붙들고 있던 정신 을 놓아 난 어디 든 날 수 있을 것 같아 우 How do they look Every night they whisper to me Steal my sleep Every night I m chased by them endlessly 오 잠들지 않는 나 의 밤 에 찾아와서 나를 데려가 줘 우 우 잠 에 들지 않는 밤 우 우 마음 은 녹아내리
# Right translation : <sos> 사랑 이 뭐길 래
# Predicted translation:  Night Night <eos>
# -------------------------------------------------- 23263
# Input: 하나님 독생자 예수 그리스도 그 분만 이 오직 길 과 진리 생명 이라 세상 다 변하고 사람 들 변해도 나 에겐 복음 십자가 뿐 이라 하나님 독생자 예수 그리스도 그 분만 이 나 의 길 과 진리 생명 이라 세상 이 비웃고 사람 들 떠나도 나 에겐 복음 십자가 뿐 이라 다시 복음 으로 다시 십자가 로 다시 하나님 께 로 나아갑니다 오직 복음 만이 오직 십자가 만이 오직 하나님 만이 나 의 전부 입니다 오직 하나님 만이 나 의 전부 입니다
# Right translation : <sos> 프로즌
# Predicted translation:  하나님 의 나팔 소리 <eos>
# -------------------------------------------------- 21802
# Input: 별거 아닌 농담 에도 왜 그렇게 화가 나는지 늘 상 혼자 먹는 밥 인데 도 문득 서럽게만 느껴져 진심 으로 사랑 했던 경우 엔 거리 위 의 평범한 표정 들 이 모두 행복해 보여 스쳐가는 낯선 사람 들 이 모두 나를 비웃는 것 같아 진심 으로 사랑 했던 경우 엔 어질러진 방 을 며칠 씩 그대로 두고 살 아 어지러운 마음 어디서 부터 추슬러 야 할지 가질 수 없는 무언가 를 꿈꿔 온 경우 엔 어질러진 방 을 며칠 씩 그대로 두고 살 아 어지러운 마음 어디서 부터 추슬러 야 할지 가질 수 없는 무언가 를 꿈꿔 온 경우 엔 진심 으로 사랑 했던 경우 엔
# Right translation : <sos> 고란초
# Predicted translation:  부끄럼 <eos>
# -------------------------------------------------- 8006
# Input: 가늘한 손가락 처럼 붉은 노을 나 의 팔 에 누워서 스미는 너 의 숨소리 그리워서 널 기다리던 골목길 이제 는 잃어버리는 너 의 향기 비처럼 흩어지네 이제 는 떠나 갈꺼야 초콜릿 달콤한 꿈속 으로 날아가 저 새 들 처럼 우리 들 기억 해 흩어져도 이 순간 유리 에 비친 내 모습 내 뿜 은 나 의 담배 연기 와 춤추는 너 의 인형 에 슬픈 눈동자 시간 속 에 묻혀 버린 다시는 후회 하지 마 힘들게 슬퍼도 울 지는 마 달려가 숨 이 차도록 지 칠 땐 쓰러져 내 품속 에 안겨 달려가 숨 이 차도록 지 칠 땐 쓰러져 내 품속 에 날아가 저 새 들 처럼 우리 들 기억 해 흩어져도 이 순간 m
# Right translation : <sos> BACK OFF
# Predicted translation:  The End <eos>
# -------------------------------------------------- 1339
# Input: 기억 해줘 I m your chaser 어제 는 몰래 I wrote all about you on paper 여기 너무 cold send again save call nobody can t listen what should I do be together all around is you than what can I do it s cannot be true 이제 받아들이는 중 all around is you than what can I do it s cannot be true 이제 받아들이는 중 넌 어때 what about when we cold 변함 없이 내 곁 을 데워 줬던 그 시간 들 이 벌써 I m afraid 다 식었어 필요해 방화 범 끝내고 자수 할게 만약 너 가 내 앞 에 서면 안 남길 거야 나무 한 그루 도 이 게 다시 너 를 부를 주문 아무 도 신경 안 써 한숨 은 도망 다니다 결국 에 뒤 에 숨는 내 가 찌질했던거지 uh 날 보는 이의 열 뻗치고 다시 올까 기회 한 번 이 뭐 그런다고 바뀔 수 있
# Right translation : <sos> 다시 그날 그대 가 With Hyunbin
# Predicted translation:  BALLOON <eos>
# -------------------------------------------------- 15615
# Input: 내 가 전 에 말 했잖아요 . 당신 을 사랑 한다고 당신 은 모르실거예요 얼마나 내 가 당신 을 사랑 하는줄 터질 거 예요 . 내 가슴 은 당신 이 내 곁 에 떠나면 나 는 그대 못 잊어 하며 날 마다 생각 할거야 꿈길 에도 당신 모습 은 언제나 변하지 않아요 당신 만을 생각 했어요 얼마나 내 가 당신 을 사랑 한다고 터질거예요 . 내 가슴 은 당신 이 내 곁 을 떠나면 나 는 그대 못 잊어 하며 날 마다 생각 할거야 날 마다 생각 할거야
# Right translation : <sos> Villain
# Predicted translation:  터질거예요 <eos>
# -------------------------------------------------- 8132
# Input: 오늘 같은 날 은 그냥 자고 싶어 아무 생각 없이 그냥 자고 싶어 창 밖 으로 빗 소리 가 아련하게 창문 을 두드리는 빗 소리 가 마치 으음 으음 나를 잠 의 세계 로 초대 하는 노크 소리 같아 두터운 구름 때문 에 햇빛 이 들지 않아 무더운 여름날 의 초저녁 같이 몽롱 해 음산한 바람 이 방안 으로 불어와 으음 으음 오늘 같은 날 은 그냥 쉬 고 싶어 무더운 여름날 의 초저녁 같이 몽롱 해 음산한 바람 이 방안 으로 불어와 오늘 같은 날 은 그냥 너 와 자고 싶어 으음 으음
# Right translation : <sos> Mozart feat . Jl
# Predicted translation:  초승달 <eos>
# -------------------------------------------------- 2099
# Input: 그니까 나를 떠나가든가 아님 날 놓아 주든가 니 가 날 떠나가든가 아님 날 놓아 주든가 니 가 다 잘 못 했다는 너 새 빨 간 거짓말 같 애 이 젠 더 바라는 거 없어 그냥 좀 돌아서 줄 래 우린 다 나쁘고 또 아픈데 누가 더 나쁜지 때문 에 서로 떠나지도 못 하게 해 지겨운 자존심 때문 에 그니까 나를 떠나가든가 아님 날 놓아 주든가 니 가 날 떠나가든가 아님 날 놓아 주든가 이별 따위 뭐 어렵다고 그냥 휙 바람 같은 게 이 젠 더 남은 것 도 없어 누가 더 아프면 어때 우린 참 다르고 안 맞는데 누가 더 착한지 때문 에 서로 괜찮은 척 지쳐있네 지겨운 자존심 때문 에 그니까 나를 떠나가든가 아님 날 놓아 주든가 니 가 날 떠나가든가 아님 날 놓아 주든가 Ou whoa ou whoa ou whoa uh uh 이제 그만 추억 까지도 Ou whoa ou whoa ou whoa uh uh 내 일 이면 안 볼 것 처럼 그니까 나를 떠나가든가 아님 날
# Right translation : <sos> 비밀결혼
# Predicted translation:  술김 에 <eos>
# -------------------------------------------------- 258
# Input: 꼭 너 를 닮아 그리움 조차도 내게는 왜 이리 고집 센 건지 . 이제 그만 가라는데 . . 쉬자는 데 들은 척도 않잖아 한번 외우면 아무리 커서 도 저절로 되 뇌질 구구 셈 처럼 니 가 새긴 그 기억 도 사는 동안 잊는 일 없을 것 같아 어느새 길어진 머리 를 자르듯 옷깃 에 먼지 를 털듯이 그렇게 나도 널 떼어 내면 좋겠어 아무런 아픔 도 눈물 도 없이 하지만 네 마음 내 심장 같아서 이제 넌 내 목숨 같아서 널 떼 내버리면 안될 것 같은데 . . 죽 을 것 같은데 . . . . . . 어떻게 해 야해 한번 배우면 한참 을 쉬어도 평생 을 간다 는 자전거 처럼 그때 배운 내 사랑 도 너 없다고 녹슬진 않을 것 같아 어느새 길어진 머리 를 자르듯 옷깃 에 먼지 를 털듯이 그렇게 나도 널 떼어 내면 좋겠어 아무런 아픔 도 눈물 도 없이 하지만 네 마음 내 심장 같아서 이제 넌 내 목숨 같아서 널 떼 내버리면 안될 것 같은데 . . . . . . 죽 을 것 같은데 . . . . . . 어떻게 해야 해 . . . . . . 그냥 아프게 살 게 . . . . . . 그
# Right translation : <sos> 안아줘 Remix feat . 동경
# Predicted translation:  그녀 의 결혼식 <eos>
# -------------------------------------------------- 6176
# Input: 푸른 밤 내 잠 을 깨운 건 검은 악마 가 아니라 꿈결 에 어렴풋 떠오른 날개 달린 천사 야 아 고마워라 내 인생 에 그토록 짧은 순간 아 나 이제 지나가리 또다시 혼자 걸어가네 떠나는 순간 을 알아도 아마 시작 은 했을 거야 서로 가 서로 를 잊어도 없던 게 되진 않을 거야 아 고마워라 내 인생 에 그토록 짧은 순간 어떤 순간 이 온대 도 날 안아주리라는 것 을 난 깨 달아요 머 지 않아 처음 으로 돌아가서 어떤 순간 이 온다면 울어 버릴 내 모습 을 아 나 는 너 의 많은 것 을 잊고 또 잃어도 그 많은 흔적 을 전부 다 지울 수 는 없다고 말 해요 아 침묵 했던 그때 우리 둘 은 두 사람 은 말 할 수 없었던 게 아닐 거야 말 할 수 없었던 게 아닐 거야 아마도 그건 사랑 이 겠지
# Right translation : <sos> 울 고 넘는 박달재
# Predicted translation:  악몽 <eos>
# -------------------------------------------------- 2101
# Input: 오늘 정말 이상해 자꾸 눈치 만 보다 눈 이 마주치면 어색해 겨우 웃는 것 같아 할 말 있는 거 겠지 어렴풋이 알 것 같아 언젠가 이런 날 이 꼭 찾아올 것 같았어 지겨워졌다고 아무 느낌 안 든다고 그런 말 은 똑바로 내 눈 보면서 말 좀 해 줄 래 행복 을 빈다고 좋은 사람 만나라고 아니야 네 가 나를 떠날 리 없어 사실 헤어지잔 말 은 다 거짓말 모든 게 전부 장난 이라 말 하며 날 품 에 안고 웃 을 거 잖아 끝 까지 다 하지 마 모진 말 그 말 에 정말 상처 받아 버리면 다시는 돌이킬 수 없을지도 몰라 그런 표정 짓지 마 너 도 느꼈었잖아 우리 사이 언제 부턴 가 아무 느낌 없던 거 사랑 이란 핑계 로 여태 까지 감춰 온 건 헤어지자 말 할 용기 가 서로 없었던 거지 Cool 하게 하자 고 원래 그런 놈 이라고 말 해야 너 라도 마음 좀 편하게 돌아설 테 지 이제 끝내자고 더 는 사랑 안 한다고 말 하는 내 맘 도 꼭 편하진 않아 후회 할지도 몰라 사실 헤어지잔 말 은 다 거짓말 모든 게 전부
# Right translation : <sos> 예수 그리스도 feat . 권준호
# Predicted translation:  말 해줘 <eos>
# -------------------------------------------------- 24781
# Input: So So So So 만남 뒤 엔 헤어지는 거지 뭐 마냥 웃 을 수 는 없으니까 멍 또 눈물 넌 토닥토닥 That s no no 그닥 그닥 어설픈 위로 는 넣어 둬 위로 해달라고 안 했으니 내려가 Don t touch me 건 들 지 마 난 진화 직전 에 찌지리 공 편식 이지 뭐 난 간식 이었고 근데 걔 욕 은 내 가 해야지 왜 네 가 해 . 어 ? 아 왜 왜 그냥 좀 가만히 내버려 둬 좀 ! 아 몰라 다 꺼져 너 네 가 나 더 초밥 만들고 있어 I m not that weak weak weak weak weak 이별 따위 위 위 위 위 Like 가랑비 비 비 비 비 젖지도 마르지 도 않은 내 감정 은 So So So So So So 그냥 그런 날 인걸 So So So So So So 그냥 그런 마음인걸 So So So So So So So So So So 그저 그런 밤 이야 야 야 So So So So So
# Right translation : <sos> 코미디언 Feat . 서 사무엘
# Predicted translation:  Do It <eos>
# -------------------------------------------------- 21910
# Input: 고기 를 먹자고 쌈 싸줄게 커피 를 먹자고 빵 사줄게 술 한잔 치자 고 얘기 나 하자 고 싫다고는 안 했어 답장 이 늦어도 겁나게 느려도 오기 는 왔었고 읽 씹은 안 했어 이 거 나 만 혼자 줄 을 당기는거 아니지 너 도 지금 줄 을 잡고 하는지 줄다리기 감정 의 시소 에 올라타 발 을 굴러 봐 카톡 으로 장문 고백 하는 찐 따는 아니지 장문 복 처럼 니 마음 을 Check 할 타이밍 이모티콘 뭐 쓸까 골 아파 만나서 물어봐 카톡 프사 보니 앞 에 남자 같던데 나도 여자 없으면서 괜히 있는 척 해 상처 받긴 싫고 너 는 가지 고파 Oh yeah 뭔 데 뭔 데 어떻게 해 어렵네 뭔가 너 는 받고 싶은 것 같아 고백 남자답게 못 먹어도 Go 하고 Goback 그땐 오 왼 같이 노래 만들어 고해 뭔 데 뭔 데 어떻게 해 어렵네 먼저 팔짱 꼈었고 나 는 팔 에 힘줬고 옷 도 벗어 줬었고 너 는 덥석 덮었고 벗은 몸 은 못 봤고 텔가자 했다 까였어 클럽 에 가서도 그 어 두운 곳 가서도 춤추는
# Right translation : <sos> 양녕대군
# Predicted translation:  예술 은 내 가 이러구 보고 <eos>
# -------------------------------------------------- 21920
# Input: 멀어져 가는 그대 가 날 아프게 하고 있죠 아무렇지도 않게 뒤 돌아 서는 모습 거짓말 같은 현실 믿을 수 없는 이 시간 그렇게 넌 나를 두고 가는구나 그래 아닐꺼야 그렇게 믿어 시간 이 지나면 깨어질 꿈 처럼 넌 나 의 숨결 이 바람 이 되고 내 눈물 이 비 가 된다 내 아픔 이 니 가 된다 지금 의 세상 은 나 에겐 꿈 이다 이 꿈 이 깨어지기 전 까지 우린 이별 한 게 아니다 하루 가 지나고 또 하루 가 지난다 그렇게 가는 시간 은 기다리지 않는다 아냐 아닐꺼야 믿을 수 없어 시간 이 지나도 변한 건 없는데 나 의 기도 가 하늘 이 되어 내 슬픔 이 내려온다 차갑게 내려온다 이별 이 아니다 그렇게 믿는다 그대 가 돌아오기 전 까지 우린 이별 한 게 아니다 그래 아닐꺼야 . . . 아닐꺼야 . . 아닐꺼야 bsad
# Right translation : <sos> 주님 볼 수 있게
# Predicted translation:  이별 의 끝 <eos>
# -------------------------------------------------- 17610
# Input: Baby u r ma only one 곧 네 가 나 의 소원 Imma be your ocean 언 젠 간 너 를 꼭 내 거 로 만들 거야 갖고 싶어 널 Please don t tell me no Baby u r ma only one 곧 네 가 나 의 소원 난 밤하늘 을 보면서 저 멀리 별 들 에게 물어봐 네 소식 을 옥상 과 네 생각 이란 나 또한 축복 받고 살 고 있단 생각 을 하게 만들어 왜 말 도 안 되는데 우리 가 만난다면 모두 가 웃 을 텐데 난 항상 완벽한 모습 의 네 가 좋아 그걸 내 가 망칠까 봐 두려워 며칠 째 잠도 안 자고 이 노랠 만들었어 어릴 땐 이런 걸 로 고민 하진 않았는데 덕분 에 내 가 꼭 어른 이 된 것 만 같아서 흉내 를 내고 있나 봐 어디서 배워와 서 어릴 적 그렸던 미래 의 내 모습 너무나 어렸던 듯 너 라는 꿈 에는 닿지도 못 하는 가위 만 눌리 는 듯 넌 내 어릴 적의 아이돌 이야 Always love ya 내 가 좋아하는 아이돌 은 너 야 Baby u r ma only
# Right translation : <sos> 약속 처럼 feat . 권영찬
# Predicted translation:  I m here Feat . Leejee Violet <eos>
# -------------------------------------------------- 25276
# Input: tell me how u feel ? 넌 눈 을 감아 내 입술 이 열릴 때 마다 넌 숨 을 참아 오늘 밤 나 의 pretty madonna mama 나를 그리워하겠지 매일 밤 마다 너 와 나 어디 든 가 why not ? 거절 은 마 이 리 로 와 그리고 eath out 비슷한 애 들 은 참 많아 하지만 내 가 나타나면 걔 들 은 다 fade out ha 뭔 말 이 그리 많아 ? 어딜 봐도 지루한 무리 뿐이잖아 새로운 자극 을 원하는거 니 몸 이 잘 알잖아 이런 style 가진 남자 는 나 뿐이잖아 그러니 겪어 거리 를 좁혀 나와 더 엮 여 hater 들은 알수 없는 after 계속 해 turn up 페친 말고 여친 을 원해 이미 내 pen 을 쥐 고 너 의 두 귀 를 범 해 ah ! 꿈 에서나 그려 온 나 의 lady 뻔한 여잔 성 에 안 차 they ain t ready 나를 위 한 그녀 가 있어 여기 에 they ain t ready reay ready and what about u
# Input: 주가 보 이신 생명 의 길 나 주님 과 함께 상한 맘 을 드리며 주님 앞 에 나아가리 나 의 의 로움 이 되신 주 그 이름 예수 나 의 길이 되신 이름 예 수 나 의 길 오직 그 가 아시나니 나를 단련하신 후 에 내 가 정금 같이 나아오리라 주가 보 이신 생명 의 길 나 주님 과 함께 상한 맘 을 드리며 주님 앞 에 나아가리 나 의 의 로움 이 되신 주 그 이름 예수 나 의 길이 되신 이름 예 수 나 의 길 오직 그 가 아시나니 나를 단련하신 후 에 내 가 정금 같이 나아오리라 나 의 길 오직 그 가 아시나니 나를 단련하신 후 에 내 가 정금 같이 나아오리라 나 의 길 오직 그 가 아시나니 나를 단련하신 후 에 내 가 정금 같이 나아오리라 나 의 길 오직 그 가 아시나니 나를 단련하신 후 에 내 가 정금 같이 나아오리라 나 의 길 오직 그 가 아시나니 나를 단련하신 후 에 내 가 정금 같이 나아오리라 thdthdms gmai
# Right translation : <sos> 하고픈 말
# Predicted translation:  주님 은 나 의 기쁨 <eos>
# -------------------------------------------------- 10961
# Input: 노래 하세 ! 춤춰 보세 ! 아름다운 세상 꿈 꿈 꿈 꾸세 우리 다 같이 만 만세 ! 우리 kimcic 만만만만 만세 점 점 점 다가오는 저 불빛 을 보면 난 겁 도 없이 되 받아서 적 을 치 지 말 해줬어 말 해줬어 두 갈래 길이 라고 두 번 다시 두 번 다시 돌이킬 수 없다는 걸 컴 컴 컴 해진 내 주위 를 둘러보면 난 겁 도 없이 졸리 졸리 도망가지 말 해줬어 말 해줬어 두 갈래 길이 라고 이제 다시 이제 다시 난 길 을 잃고 헤 메였어 내게 물어봤어 왜 이리 막혀 너 에게 물어봤지 왜 이리 막혀 여기 가 목적지 라 너 의 말 을 따러 마러 내게 물어봤어 왜 이리 막혀 너 에게 물어봤지 왜 이리 막혀 이러다가 끝 도 없는 방황 하면 어쩌냐 고 궤도 수정 그대 내 가 보고 플 때 세번 네 번 불러 볼 래 그럼 내 가 나타날께 이제야 나도 갈 길 갈래 한 번 길 을 잘못 들고 두 번 세번 반복 되고 그럼 그때 돌려 볼 래 인생 이 팍팍 뒤집히게 탁 탁 한 번 에 이 궤도 를
# Right translation : <sos> 하늘 처럼
# Predicted translation:  다마고치 <eos>
# -------------------------------------------------- 20864
# Input: 내 마음 연약할 때 주의 위로 와 사랑 으로 나 의 괴로움 나 의 나야 함 주님 게 서 만져 주시 네 주 와 동행 할 때 에 주의 성령 이 날 인도 하니 모든 아픔 과 모든 고통 이 나 는 두렵지 않네 . 나 무릎 꿇고 간절히 주 께 기도 하며 주님 의 넘치는 사랑 을 나 표현 합니다 주 를 찬양 합니다 주 를 경배 합니다 내 삶 의 이유 가 되시는 주님 찬양 받아주소서 주 를 찬양 합니다 주 를 경배 합니다 찬양 찬양 찬양 합니다 내 가 두려워 할대 주의 지혜 와 사랑 으로 나 의 피난처 되신 주님 이 나를 단련해 용기 주시 네 주 와 동행 할 때 에 강함 주시 고 승리 주시 니 모든 불안 과 걱정 속 에도 나 는 두려움 없네 나 무름꿇 고 간절히 주 께 기도 하며 사랑 과 감사 로 가득 찬 내 맘 고백 합니다 주 를 찬양 합니다 주 를 경배 합니다 내 삶 의 이유 가 되시는 주님 찬양 받아주소서 주 를 찬양 합니다 주 를 경배 합니다 찬양 찬양 찬양 합니다 찬양 합니다 찬양 찬양 찬양 주 를 찬양
그대 와 잔뜩 취해 서 춤 을 실룩 샐룩 추다 살갗 이 여기저기 에 베 여 나가도 난 지금 은 괜찮으니까 어서 내 손 을 잡아 줘요 나와 같이 춤 을 춰요 나와 같이 춤 을 춰요 나와 같이 춤 을 춰요 나와 같이 춤 을 나와 같이 춤 을 춰요 그대 를 품 에 꽉 안고선 저 아래 로 떨어져요 두 눈 을 질끈 감아서 꿈속 으로 들어가요 피 를 뒤집어 쓴 대도 우린 멈추지 말아요 몸 을 부둥켜 안고선 나와 같이 춤 을 춰요 나와 같이 춤 을 춰요 나와 같이 춤 을
# Right translation : <sos> EYESCREAM
# Predicted translation:  의식 의 법칙 <eos>
# -------------------------------------------------- 15991
# Input: 너 를 만날 때 조차 겁 이 났어 두려웠어 어지러운 내 마음 속 에선 사실 난 아직 잡은 걸 놓지 못 해 가만이 내버려 두기 가지려 애쓰지 않기 사람 들 그 속 에 울 고 있는 나 함께 가자고 우겨 보는 나 아직 부족하다고 느낀 나 어쩜 이어있는 걸 들킬까 봐 그런 나였지만 그런 나였지만 흔들림 없는 눈빛 과 목소리 에 당신 의 따뜻한 그 말 한마디 에 위로 의 위안 을 선물 을 용기 를
# Right translation : <sos> 두근거리네
# Predicted translation:  너 의 뒤 에 <eos>
# -------------------------------------------------- 22619
# Input: 그렇게 대단한 운명 까진 바란 적 없다 생각 했는데 그대 하나 떠나간 내 하룬 이제 운명 이 아님 채울 수 없소 별처럼 수 많은 사람 들 그 중 에 그대 를 만나 꿈 을 꾸듯 서 롤 알아보고 주는 것 만으로 벅찼던 내 가 또 사랑 을 받고 그 모든 건 기적 이었음 을 그렇게 어른 이 되었다고 자신 한 내 가 어제 같은데 그대 라는 인연 을 놓지 못 하는 내 모습 어린아이가 됐소 별처럼 수 많은 사람 들 그 중 에 그대 를 만나 꿈 을 꾸듯 서 롤 알아보고 주는 것 만으로 벅찼던 내 가 또 사랑 을 받고 그 모든 건 기적 이었음 을 나를 꽃처럼 불러주던 그대 입술 에 핀 내 이름 이제 수많은 이름 들 그 중 에 하나 되고 오 그대 의 이유 였던 나 의 모든 것 도 그저 그렇게 별처럼 수 많은 사람 들 그 중 에 서로 를 만나 사랑 하고 다시 멀어지고 억 겁 의 시간 이 지나도 어쩌면 또 다시 만나 우리 사랑 운명 이었다면 내 가 너 의 기적 이었다면 Bugs 님 이 등록 해 주신 가사 입니다 .
# Right translation : <sos> 사라진 계절
# Predicted translation:  너 를 향 한 나 의 사랑 <eos>
# -------------------------------------------------- 27666
# Input: 차가운 바다 모래사장 그 곳 이 내 마음 의 안식처 그래 나 의 출생지 부산 어 Macity number 해운대구 반여동 반 지수 는 기 억 안나 도 골목 골목 기억 이나 친구 없이 내 운명 의 복선 을 그려가 When I was half on me now 외동 에 철 없던 날 주변 의 시기 와 질투 에 부족함 없어도 외롭던 날 I recall ma memory 하 가슴 이 쓰리지 우연 의 상처 가 영혼 에 들어와 깊숙히 박혔던 칼 Stay my life Stay my lifeStay my life 내 가 숨 쉬는 이유 Stay my life Stay my life Stay my life 그래 난 Music for ya Music for yaMusic for 야 이야이야 It was like a jungle Fk grow up 누가 사람 이고 짐승 인지 구 분안 가던 그 곳 에서 개싸움 을 붙히는 학생 터진 걔 를 나무라는 선생 교육 없는 곳 에서 Tape 을 돌리고 이어폰 으로 귀 를 막어 피 묻은 사슴 이 사자 떼 에게 다
주머니 젖은 어깨 까지 누가 날 보더 라도 멋진 구석 없겠지만 멋진 옷차림 이 빵빵 한 주머니 가 한 번 도 부러운 적 욕심 난 적 없었잖아 만만찮 게 약해 보이지 않게 가득 내 두 눈 에 꿈 을 담은 채 당당하게 나를 향 해 밀어 닥치는 귀여운 시련 따윈 껄껄 웃어 넘기지 텅 빈 내 주머니 젖은 어깨 까지 누가 날 보더 라도 멋진 구석 없겠지만 멋진 옷차림 이 빵빵 한 주머니 가 한 번 도 부러운 적 욕심 난 적 없었잖아 bling bling 내 배짱 에 bling bling 큰 꿈앞
# Right translation : <sos> 역 마차
# Predicted translation:  <eos>
# -------------------------------------------------- 20468
# Input: 이제 와서 내 가 원한 건 하나 없을 텐데 뭐 하러 뻔 뻔하게 말 을 전하 고 뒤 돌아선 날 벗어나고 오늘 밤 은 제발 나를 죽여 아침 이 밝아 오기 전 에 주 여 하룻밤 만이라도 내 곁 에 한순간 이라도 너 의 옆 에 유난히 도 어두웠던 방 한 켠에 홀로 있다는 걸 깨달 은 후 에 이미 늦었지만 다음 말 을 건네 우리 둘 의 찢어진 조각 을 꺼내 오늘 밤 이 가기 전 에 나를 봐줄래 모든 일 을 미뤄 두고 너 를 마주 해 부디 다음 생 엔 함께 걸어줄래 많은 것 을 느껴 후회 없이 줄 게 내 가 원한 건 누구 보다 제일 잘 알 고 알면서도 외면 했지 여러 번 에 데인 상처 는 쉽게 아물지도 않고 깊은 흉터 만 남겠지 너 를 쉽게 끊어내지 못 해 난 또 많은 술 과 약 에 기대 난 하루 도 못 사네 맨 정신 은 불안 다시 돌아가긴 어렵구나 Oh please don t go away
# Right translation : <sos> Fallin down
# Predicted translation:  숨 <eos>
# -------------------------------------------------- 26687
# Input: 처음 우리 가 만난 날 을 기억 하니 내 목소리 가 너 에게 닿았을 때 조그마한 내 꿈 을 품어 준 따뜻한 너 였으니까 얼마나 지났을까 우리 가 만난 지 혹시 달라진 나를 좋아해줄까 그래도 너 의 마음 에 들었으면 좋겠어 기다리고 기다렸던 떨리는 이 순간 두근거림이 멈추지 않아 이 젠 다시 태어난 나를 바라봐줄래 너 만을 위 한 내 선물 이야 너 를 다시 만나고 싶어 설레는 맘 을 전 할 수 있을까 언제 까지나 널 위해 노래 해줄게 너 만을 위 한 달콤한 목소리 로 다시 한번 날 사랑 해줄래 조금 더 내게로 다가와 주겠니 달콤하고 포근하게 노래 해줄게 새로운 나를 지켜봐줄래 One More Lovely 오늘 하루 는 어떻게 보냈는지 혹시 나를 만나고 싶어 기다렸니 사실 은 나도 하루 종일 너 를 보고싶었어 오늘 도 너 를 만나서 행복했어 내일 도 너 와 이야기 하고싶어 언제나 하고싶은 말 이 너무나도 많은걸 기다리고 기다렸던 설레는 이 순간 을 너 와 함께하고 싶은걸 이 젠 새롭게 태어난 날 지켜봐줄
# Right translation : <sos> 주 를 앙망 함
# Predicted translation:  너 에게 <eos>
# -------------------------------------------------- 15608
# Right translation : <sos> 노래 해요
# Predicted translation:  Love Me <eos>
# -------------------------------------------------- 5182
# Input: 너무 아파서 병원 을 찾아 갔어 한참 나를 바라보다 걱정 스레 하는 말 어디가 아파요 말 을 할 수 없었어 어디가 아픈 줄 도 난 몰랐어 오늘 처음 본 사람 앞 에서 바보 처럼 난 눈물 만 흘렸어 내 가슴 에 열 이나 기억 은 멈춰 서 있고 금새 라도 내 심장 은 터질 것 같아 나 이렇게 아픈데 죽 을 것 만 같은데 나 의 병 은 이렇게 하루하루 더해만 가는 가봐 벌써 며칠 째 처방전 에 써있던 내겐 너무 쓰기 만 한 시간 이란 약 들 을 삼키고 있어요 가슴 을 도려 내고 기억 을 지워줄 수만 있다면 지금 이라도 나 의 심장 을 다시 뛸 수 있게 고쳐 주세요 눈 이 그 댈 못 보게 얼굴 조차도 모르게 나 의 귀 는 아무 것 도 듣지 못 하게 그대 이름 까지도 몰랐었던 그때 로 돌아 갈 수 있도록 추억 을 꺼내서 버리고 있죠 내 가슴 에 열 이나 기억 은 멈춰 서 있고 금새 라도 내 심장 은 터질 것 같아 나 이렇게 아픈데 죽 을 것 만 같은데 나 의 병 을 낫 게 할 사람 은 아마도 그대 인가 봐
# Right translation : <sos> 멀어져 가네 패션 모델 Live
# Predicted translation:  그랬었지 <eos>
# -------------------------------------------------- 11310
# Input: 시냇물 흘러서 가면 넓은 바다 물이 되듯이 세월 이 흘러 익 어간 사랑 가슴 속 에 메워 있었네 그토록 믿어 온 사랑 내 마음 에 믿어 온 사랑 지금 은 모두 어리석음 에 이제 너 를 떠나간다네 저녁 노을 나를 두고 가려마 어서 가려마 내 모습 감추게 밤하늘 에 찾아보는 별 들 의 사랑 이야기 들려줄꺼야 세월 이 흘러서 가면 내 사랑 찾아오겠지 모두 다 잊고 떠나가야지 보금자리 찾아가야지 저녁 노을 나를 두고 가려마 어서 가려마 내 모습 감추게 밤하늘 에 찾아보는 별 들 의 사랑 이야기 들려줄꺼야 세월 이 흘러서 가면 내 사랑 찾아오겠지 모두 다 잊고 떠나가야지 보금자리 찾아가야지
# Right translation : <sos> 하이에나
# Predicted translation:  나 의 죄 와 같이 <eos>
# -------------------------------------------------- 16730
# Input: 그대 내 곁 을 떠나가던 그날 차마 그대 를 바라볼 수 없어 아무 말 없이 아무 말 없이 보냈지 하얀 미소 를 내 가슴 에 주며 나 의 슬픔 을 만져주던 그대 이제 와 서야 사랑 인 줄 을 알았네 아름다운 추억 이 사무치게 그리워 울고싶은 마음 이슬 이 되어 슬픈 마음속 에 그대 모습 을 그리며 나 는 가슴 으로 울었지 오늘이 가도 또 내일 이 가도 언제 까지나 내 사랑 을 위해 기도 하리 라 살 아 가리라 영원히 아름다운 추억 이 사무치게 그리워 울고싶은 마음 이슬 이 되어 슬픈 마음속 에 그대 모습 을 그리며 나 는 가슴 으로 울었지 오늘이 가도 또 내일 이 가도 언제 까지나 내 사랑 을 위해 기도 하리 라 살 아 가리라 영원히
# Right translation : <sos> 세상 을 산다 는 건 Marry Me
# Predicted translation:  그대 를 사랑 합니다 <eos>
# -------------------------------------------------- 11822
# Input: 사랑 하고 싶어요 좋아하고 싶어요 가슴 이 터지도록 사랑 하고 싶어요 내 눈 을 바라봐요 견딜수 없는 기쁨 기쁨 이 사랑 되어 내 안 에 흐르네요 햇살 이 눈 이 부신 만큼이나 그대 의 얼굴 보며 가슴 이 두근거리고 별빛 에 반짝이는 만큼이나 그대 의 눈 을 보며 사랑 을 만들어가요 사랑 하고 있어요 좋아하고 있어요 가슴 에 새기도록 그대 이름 부르며 yuc
# Right translation : <sos> 무지개
# Predicted translation:  사랑 이 저 만치 가네 <eos>
# -------------------------------------------------- 18487
# ...
# Right translation : <sos> 또 넘기고 있어 With 진 준왕
# Predicted translation:  사랑 은 나 의 사랑 <eos>
# -------------------------------------------------- 24111
# Input: 숨막히는 하루 는 아니라서 I don t have any eakfast I don t take any eak 그냥 좋은 탓 에 자리 에 앉아 아침 에 바로 할게 I don t think it s not fast 나 의 집은 너무 나다운데에 있나 모든 면 이 전부 막혀 있으니깐 해 가 진다는 것 알려줄 누구 도 있지가 않아 So I go to bed again Gravity You didn t know that Gravity Until Newton told us about me Until Newton told us about it 과학 책 이 알려주기 전 까진 넌 알 수 없었을 거야 우리 가 가만히 여기 에 앉아 있는 이유 를 You don t know 내 지하세계 중력 은 시간 을 너무 느리게 흘려서 딱히 너 와 둘 이 보내고 있을 시간 은 여유 가 만만해서 안 부러워 하지만 너 너무 당 연 시 하는 건 아닐까 나 바닥 에 떨어진 컵 물 은 엎 질러진 것
# Right translation : <sos> 꿈 에 본 서귀포
# Predicted translation:  WEEKEND Feat . Benzamin Prod . mnsx <eos>
# -------------------------------------------------- 4901
# Input: 매일 지나치는 너 의 집 퇴근길 버스 안 에서 우연히 고개 를 내 밀고 빼꼼 히 창 밖 을 바라보는 너 를 봤지 그게 너무도 아파서 인지 한동안 난 그 길 을 피 했지만 그래도 아쉬움 이 미련 이 남아 서 다시 그 버스 안 으로 올랐네 가끔 은 이렇게 널 볼 수 있을까 계절 이 바뀌고 네 창 이 활짝 열릴 때 즈음 매일 난 이렇게 네 게 인사 를 하지만 보이는 건 불 꺼진 너 의 창문 앞 뜰 에 그 길가 에 앙상하게 남아 있는 우리 의 추억 들 만이 네 가 손 흔들던 정류장 반가 움 과 아쉬움 가득했던 너 와 나 의 인사 는 추억 이 되어서 결국 두 개 의 창 사이 를 맴 도 네 가끔 은 이렇게 널 볼 수 있을까 계절 이 바뀌고 네 창 이 활짝 열릴 때 즈음 매일 난 이렇게 네 게 인사 를 하지만 보이는 건 불 꺼진 너 의 창문 앞 뜰 에 그 길가 에 앙상하게 남아 있는 우리 의 추억 들 만이 가끔 은 이렇게 널 볼 수 있을까 계절 이 바뀌고 네 창 이 활짝 열릴 때 즈음 가끔 은
# Right translation : <sos> Wake Me Up
# Predicted translation:  너 의 결혼식 <eos>
# -------------------------------------------------- 17801
# Input: 산 허리 휘 돌아 흐르는 물 에 꽃잎 하나 띄우고 뜬구름 처럼 흘러 가버린 지난 세월 그려 본다 불그레 고 왔던 얼굴 에 하나 둘 씩 주름 이 지고 반 백년 을 훌쩍 넘긴 인고 의 인생 길 어디 갔나 나 의 청춘 아 아카시아 향기 피는 언덕 에 저녁 노을 붉은데 하룻밤 꿈 처럼 지나 가버린 인생 길 을 돌아본다 치마폭 감 추웠던 사연 에 구 구 절절 눈물 이 솟네 반 백년 을 더 살아도 모자란 인생 가는 세월 야속하구나
# Right translation : <sos> 오빠 랑 여행 갈래 ?
# Predicted translation:  기차 와 함께 춤 을 <eos>
# -------------------------------------------------- 15313
# Input: 그 에게 못 했던 말 이 있어요 말 하지 못 해 아쉬워서 매번 되새기죠 당신 을 언젠가 볼 수 있단 생각 에 마음속 사랑 이란 말로 간직 하고 있죠 나 만 알 수 있는 착각 에 그대 생각 하지 못 했죠 이제야 나 는 그대 에게 말 하고 있어요 당신 을 정말로 사랑 해왔어요 마음속 깊이 닿아 버린 그대 의 모습 이 이렇게 갑자기 스며 버린 그대 모습 이 참 아름다워 하루하루 를 마음 졸 이며 살 죠 나 만 알 수 있는 착각 에 그대 생각 하지 못 했죠 이제야 나 는 그대 에게 말 하고 있어요 당신 을 정말로 사랑 해왔어요 마음속 깊이 닿아 버린 그대 의 모습 이 이렇게 갑자기 스며 버린 그대 모습 이 참 아름다워 하루하루 를 마음 졸 이며 살 죠
# Right translation : <sos> Stay 머물러줘
# Predicted translation:  사랑 이 오려나 봐요 <eos>
# -------------------------------------------------- 25833
# Input: 힘들다고 하면 너무 나 힘들 거 같아 눈물 을 흘리면 내 맘 들킬 것 같아 웃는 척 하면서 괜찮다 말 하고 내 맘 을 숨겨 우두커니 앉아 온종일 창 밖 을 봐 내 머릿속 엔 너 만 남았나 봐 어딜 둘러봐도 난 네 얼굴 을 떠올리고 있어 잊혀질 만 하면 찾고 있다는 걸 아프다는 걸 나 혼자 있을 땐 참지 않고 울 어도 괜찮은데 혼자 여 도 이 젠 참는 게 버릇 됐어 내 머릿속 엔 너 만 남았나 봐 어딜 둘러봐도 난 네 얼굴 을 떠올리고 있어 잊혀질 만 하면 찾고 있다는 걸 아프다는 걸 다 알 고 있어도 내 마음대로 안 돼 잊으려 해봐도 머릿속 에 남아있어 지우고 지워도 마음속 엔 영원히 남겨질 너 내 머릿속 엔 너 만 남았나 봐 어딜 둘러봐도 난 네 얼굴 을 떠올리고 있어 잊혀질 만 하면 찾고 있다는 걸 아프다는 걸 제발
# Right translation : <sos> 꿈 에선 언제 라도
# Predicted translation:  너 의 향기 <eos>
# -------------------------------------------------- 9664
# Input: 서툰 표현 밖에 하지 못 해 전하 지 못 한 마음 많아 그래서 바람 에 실어 보냈어 네 게 도 불어 갈 테 지 하며 무심히 건넨 작은 눈송이 에 웃어주는 네 가 보여 닿으면 한순간 에 녹을지라도 소중한 마음 이었 음 을 이 바람 도 눈 을 감 을 때 마다 빛 을 잃고 어두워지겠지 그래도 내 진심 은 변하지 않고 하 룰 보탠 바람 불어 갈 테 지 무심히 건넨 작은 눈송이 에 웃어주는 네 가 보여 이른 봄 같은 서툰 나 의 고백 을 바람 에 실어 네 게 보내 내 바람 이 전해졌 기를
# Right translation : <sos> My All
# Predicted translation:  겨울 <eos>
# -------------------------------------------------- 1638
# Input: 이름 없는 꽃 이 피었던 철새 마저 떠난 그 어딘가 에 조용히 떠오르는 하늘 의 미소 또 다시 여기 에 날 돌아오게 해 바람따라 구름 따라 흐르는 세상 스쳐가는 사람 마다 변하는 환상 내 손 에 든 칼날 이 내 대신 우 네 제발 좀 나를 이제 내버려 두 오 아 ! 난 한 마리 이리 아 ! 난 한 마리 이 눈 위 에 떨어진 내 눈물 처럼 어차피 언젠가 는 스며들텐데 여인 아 ! 날 보고 매정 타 마소 그래도 우린 웃으며 만났잖소 어디 에 있나 어디 로 가나 아 ! 난 한 마리 이리 아 ! 난 한 마리 이 아 ! 난 한송이 꽃 아 ! 난 눈 속 의 꽃 눈 위 에 떨어진 내 눈물 처럼 어차피 언젠가 는 스며들텐데 내 손 에 든 칼날 이 내 대신 우 네 제발 좀 나를 이제 내버려 두 오 bsad
# Right translation : 의 Neverland Feat . P GLOO Hash Swan
# Predicted translation:  미륵 반가사유상 의 물수제비 <eos>
# -------------------------------------------------- 437
# Input: 왜 이래 시간 까지 깨있어 친구 들 이 부르고 말 하지 다 Wake up 꾸밀 필요 도 없어 No make up 그럴 때 이미 비트 를 부수 고 바꾸는 Changer base on 내 실력 과 비전 지금 까지 보낸 시간 이 너무나도 길어 눈 에 비친 Bitches 뭐 해 비키 라고 말 했잖아 넌 뭘 알 아 들었어 씨발 내 가 바랄 때 바른거 먹지 난 그래 넌 나와 조금 다르지만 그냥 제발 좀 꺼지라고 말 했지 뭘 배운거야 전혀 도움 안 돼 가르침 걔넨 그럴 때 랩 으로 백대 맞아 필요성 으로 만들어 너 의 가난 씹 새 들 이 정신 차릴 때 까지 바뀌지 않아 나 의 모습 다시 말 을 하지 Ay 인맥 빨 로 랩 해서 잘났다 그래 난 너무 부럽네 Ay ay 그럼 나도 너 따라서 랩 안 하고 그 형 들 똥꼬 나 빨래 Ay 그래놓고 래퍼 래 Fuck off 왜 그리 대들어 꺼져 너 네 여기 왜 있어 한다해 서 하는게 아니지 다 좆 빠짐 곡 만들어도 못 알아듣지 병신 들 맞아 우리 둘 은 물 과 기름 이지 한 두 번 말 하면 알
# Right translation : <sos> 천국 을 찾고 있나요
# Predicted translation:  왜 <eos>
# -------------------------------------------------- 7243
# Input: 우주 보다 더 높은 곳 에서 나를 위 한 반짝임 이란 걸 우리 거린 너무나 멀어서 아무 생각 도 하지 못 하네 구름 위 거니 는 분홍 빛 태양 에 어느 샌가 내 맘 나도 모르게 바람 위 거니 는 소중한 기억 들 담고 담아 네 게 전 할래 저 별 은 나 의 별 어디 로 갔을까 보이지 않는 밤 어디 에 있을까 어디 로 갔을까 저 별 은 나 의 별 어디서 왔을까 보이지 않는 밤 저 달 을 따라서 너 와 구름 위 거니 는 분홍 빛 태양 에 어느 샌가 내 맘 나도 모르게 바람 위 거니 는 소중한 기억 들 담고 담아 네 게 전 할래 저 별 은 나 의 별 어디 로 갔을까 보이지 않는 밤 어디 에 있을까 어디 로 갔을까 저 별 은 나 의 별 어디서 왔을까 보이지 않는 밤 저 달 을 따라서 너 와 저 별 은 나 의 별 어디 로 갔을까 보이지 않는 밤 어디 에 있을까 어디 로 갔을까 저 별 은 나 의 별 어디서 왔을까 보이지 않는 밤 저 달 을 따라서 너 와
# Right translation : <sos> 더욱 사랑
# Predicted translation:  별 <eos>
# -------------------------------------------------- 2400
# Input: 알딸딸히 눈 을 뜨니 오후 세시 이도 저 도 아닌 삶 의 중간 쯤 감흥 없이 잊혀지는 만남 들 에 무 뎌 질 청춘 의 운명 이여 오늘 은 또 누굴 만날까 어디 를 돌아다닐까 사람 들 이 지나갈 때 내 가 서있고 내 가 지나갈 때 사람 들 이 서있네 아아 아 나 는 울 고 아아 나 는 웃고 아아 아 나 는 울 고 아아 나 는 웃네 운동화 를 구겨 신고 집 에 돌아와 습관 처럼 마주 하는 거울 속 나 의 늘어가는 한숨 들 과 인사 하는 왜소한 청춘 의 운명 이여 내일 은 또 누굴 만날까 어디 를 돌아다닐까 사람 들 이 지나갈 때 내 가 서있고 내 가 지나갈 때 사람 들 이 서있네 아아 아 나 는 울 고 아아 나 는 웃고 아아 아 나 는 울 고 아아 나 는 웃네
# Right translation : <sos> Little Star
# Predicted translation:  환절기 <eos>
# -------------------------------------------------- 6734
# Input: 이상하게 느껴져 끌림 눈치 못 채게 멋 을 흘림과 동시 에 sounds turn up 우리 둘 이 있을 땐 bounce up 시간 이 마침 딱 떨어지면 나와 마르가리타 와 모히토 로 take a shower asap poppin 춤 을 추려면 탱고 와 삼바 를 let s take it shake it you wanna shoot a movie 스피커 와 party girls that s i love it 왜 같은 말 을 또 repeat 아무 도 모르게 떠날 꺼야 여기 서 district 떠날 꺼야 저기 로 저기 푸른 바 닷 속 으로 더 는 말 할 필요 도 없어 우리 둘 은 같이 말 이야 take it short oh having a good time i m glad you having a good time 나를 따라와 i m glad you like Don t you know it s our party Turn on the music like cr
# Right translation : E . P . P Endless Painful Penitence
# Predicted translation:  <eos>
# -------------------------------------------------- 18361
# Input: 날 좋아하면서도 사랑 한 단말 을 못 하는 나비 같은 남자 나비 같은 그남자 안보 면 보고싶고 못 보면 눈 멀 고마 는 나비 같은 남자 나비 같은 그남자 얼마나 보고싶어 이리 뒤척 저리 뒤척 힘들어 보일 가봐 마냥 떠돌아다녀도 난마 냥 즐겁기만 해 날 사랑 하면서도 좋아한 단말 을 못 하는 나비 같은 사람 나비 같은 그 사람
# Right translation : <sos> Rain
# Predicted translation:  쌓인 정 <eos>
# -------------------------------------------------- 26653
# Input: 십이월 의 어느 겨울 밤 하얀 첫 눈 이 올 때 쯤 내려오는 눈꽃 을 보며 걷고 싶어 너 와 함께 온통 너 로 가득 채운 밤 나 의 모든 순간 들 이 네 가 왔던 날 의 그때 처럼 다시 돌아온다면 아름다웠던 그날 의 그 순간 들 이 흩어지고 녹아 번 져 사라지는데 나 는 아직도 여전히 그 시간 속 에 세상 이 멈춘 듯 이렇게 남아 있는데 그대로 인데 이렇게 네 가 내게 줬던 모든 거 하나 도 버리질 못 하고 전부 다 내 잘못이였다고 수백 번 되 뇌 이고 소리치는데 아름다웠던 그날 의 그 순간 들 이 흩어지고 녹아 번 져 사라지는데 나 는 아직도 여전히 그 시간 속 에 세상 이 멈춘 듯 이렇게 남아 있는데 그대로 인데 이렇게 사랑 했던 너 의 모습 이 찬란했던 우리 추억 이 아직 남아 내 곁 을 맴돌아 하루 도 살 수 없는데 가득 내렸던 그날 의 모든 순간 이 흩어지고 녹아 번 져 사라지는데 바 래 져가는 그날 의 그 시간 들 이 모두 다 사라지기 전 에 돌아와 제발 돌아와 제발 나 에게 Bugs 님 이 등록 해 주신 가사
# Right translation : <sos> 참 사람 되신 말씀 With 국립합창단 장
# Predicted translation:  폴라로이드 <eos>
# -------------------------------------------------- 19142
# Input: 나 는 간다 그 곳 내 가 꿈꾼 곳 으로 이루지 못 해도 나 는 그 곳 으로 간다 힘든 기억 들 이 내 맘 에 계속 찿아 와도 찿 지 못 한 나 의 꿈 을 계속 찿아 가 내 가 꿈꾼 기억 그 기 억 속 의 나 이루어 낼거야
# Right translation : <sos> 약속
# Predicted translation:  나 는 가야 다 <eos>
# -------------------------------------------------- 7047
# Input: 차 한 잔 을 들 때 마다 눈물 이 글썽 빈 잔 속 에 추억 이 우수수 손끝 에서 마음 까지 사랑 한 사람 생각 하면 또 눈물 남자 는 모두 다 그런 거 라고 내 마음 달래 봐도 잊을 수 없어 비는 주룩주룩 천호동 의 밤 차 한 잔 을 들 때 마다 눈물 이 글썽 눈길 마다 추억 이 우수수 촛불 처럼 나를 태워 사랑 한 사람 돌아보면 또 눈물 남자 는 모두 다 그런 거 라고 내 마음 달래 봐도 지울 수 없어 비는 주룩주룩 천호동 의 밤
# Right translation : <sos> 유리 별
# Predicted translation:  사랑 의 슬픔 <eos>
# -------------------------------------------------- 15772
# Input: 아무 도 모르게 조금씩 다가온 너 의 눈빛 은 나 조차 모르던 내 안 의 흔들림 그땐 몰랐어 매일 처럼 나 의 곁 에 머물렀지만 왜 이제 서야 내 맘 알 게 된 걸까 그대 가 느껴져 날 지켜봐주던 이 모든 현실 이 다 없어질 만큼 그대 가 느껴져 날 지켜봐주던 내 모든 고통 이 다 사라질 만큼 아무런 말 없이 시간 은 멈추고 우린 그대로 매일 처럼 나 의 곁 에 머물렀지만 왜 이제 서야 내 맘 알 게 된 걸까 그대 가 느껴져 날 지켜봐주던 이 모든 현실 이 다 없어질 만큼 그대 가 느껴져 날 지켜봐주던 내 모든 고통 이 다 사라질 만큼 그대 가 느껴져 날 지켜봐주던 이 모든 현실 이 다 없어질 만큼 그대 가 느껴져 날 지켜봐주던 내 모든 고통 이 다 사라질 만큼 아무런 말 없이 시간 은 멈추고 우린 이대로 다시 bsad
# Right translation : <sos> 너 란 별
# Predicted translation:  꿈 <eos>
# -------------------------------------------------- 10142
# Input: 한번 보고 두 번 보고 세 번 보고 자꾸만 자꾸만 자꾸만 봐도 보고 싶고 잠깐 보고 훔쳐 보고 대놓고 보고 아름다운 그 모습 을 자꾸만 보고 싶네 이 거 정말 궁금해서 미치겠네 누구 를 만나 사랑 을 나눌지 궁금하네 어떤 이 가 행운 아 인지 나 는 왜 아닌지 그 누구 의 애인 인지 정말로 궁금하네 모두 사랑 하네 나도 사랑 하네 한번 쯤 은 뒤 를 돌아 나를 볼까 어쩌면 너 도 내 가 자꾸 신경 쓰일까 두 근대 는 소리 혹시 니 심장 소 릴 까 아름다운 그 모습 을 자꾸만 보고 싶네 어디 사는 누구 인지 궁금하네 뭘 먹고 사는지 뭘 하고 사는지 궁금하네 나 에게도 기회 가 있는지 궁금하네 그 누구 의 애인 인지 정말로 궁금하네 모두 사랑 하네 나도 사랑 하네 한번 보고 두 번 보고 자꾸만 보고 싶네 나나 나나 나나 그 누구 의 애인 인지 정말로 궁금하네 나나 나나 나나 bsad
# Right translation : <sos> 소주 의 요정
# Predicted translation:  사랑 은 왜 <eos>
# -------------------------------------------------- 7085
# Input: 나 향기 가 사라진 시들은 꽃처럼 버려지는 기억 너 니 안 에서 죽 어간 슬픈 내 사랑 만 지워가는 눈물 oh my love 다시는 내게 없을 기적 과 같던 너 의 눈부신 이름 하나 가슴 에 남아 아직 떠난 너 를 기억 해 Hey you my love and just my life 오랜 추억 속 에 슬픈 영화 처럼 난 그렇게 스친 기 억 속 에 잊혀져가는 너무 아름답던 너 를 기억 해 나 빈 하늘 너머 로 날아간 새 처럼 사라지는 노을 너 긴 어둠 을 거두고 서둘러 찾아온 태양 없는 하트 repeat repeat 오랜 추억 속 에 슬픈 영화 처럼 난 그렇게 스친 기 억 속 에 잊혀져가는 너무 소중했던 너 를 기억 해 내겐 전부 였던 널 기억 해 repeat 오랜 추억 속 에 슬픈 영화 처럼 난 그렇게 스친 기 억 속 에 잊혀져가는 너 정말 사랑 했던 널 기억 해 repeat 지친 하루 와 내 구걸 한 몸
# Right translation : <sos> 대 기 업
# Predicted translation:  나 의 고백 <eos>
# -------------------------------------------------- 4467
# Input: 아아 아아 You re My Love 아아 아아 You re My Life TV 를 보다 음악 을 듣다 내 가 하고 싶은 건 모두 해 요 수 많은 카메라 수 많은 기사 들 이제 는 셀 수 없을 만큼 많아 하지만 네겐 내 가 너무 소홀했어 니 가 나를 떠날 것 같은 느낌 들어 미안해 미안해 미안해 니 가 없음 이 모든 게 의미 없어 내 욕심 에 너 를 잃게 되면 나중 에 후회 할 것 만 같아 날 보던 너 의 미소 날 안던 너 의 두 손 날 어루만지던 니 입술 도 I M TOP GIRL 이제 는 내 가 TOP GIRL 누구 에게도 지지 않는 TOP GIRL 오오오오오오 니 가 없어 오오오오오오 미치겠어 but 오오오오오 내 가 가진 모든 걸 오오오오오 너 와 바꿔도 돼 난 오오오오오 난 너 만 있으면 돼 I NEED YOU I NEED YOUR LOVE 노랠 부르면 웃고 있으면 갖고 싶은 모든 걸 다 가져요 날 향 한 가쉽 들 들리는 소문 들 보고 도 싶지 않을 만큼 많아
# Input: ay ay DMC 내 정신 불 이 붙지 꿋꿋 이 느끼는 진동 힘겨운 진도 너무 잦은 빈도 대상 없는 기도 복은 새해 에 있네 매일 이 겨울 yeah yeah 싱크대 엔 접시 가득 설거지 는 내일 해 내 변화 에 칼 을 대려는 이 들 엔 예민해 날 묶었던 게 무엇 이든 그 어떤 틀 은 싫네 이제 매주 토요일 DMC 지하 중소기업 빌딩 건물 예식장 옆 정신과 난 치료 를 받으러 오는데 늘 거 긴 문전 성 시야 입구 부터 violin 다 작위 적 이야 정신 이 아득해 세상 의 많은 이 들 의 삶 속 엔 즐거움 과 웃음 들 난 고 갤 떨구네 타인 의 행복 에 못 치는 박수 이 곳 은 만 감 의 장소 입구 앞 사람 들 악수 부정 을 뿜으 며 한숨 내 안 의 야망 과 쫌생 이 공존 모두 저 질 이야 타인 을 이해 하고자 했던 마음 은 전부 거짓 일까 이런 내 자신 이 난 진짜 헛구역질 이나 이런 내 자신 이 난 진짜 헛구역질 이나 DMC 내 정신 불 이 붙지 꿋꿋 이 느끼는 진동 힘겨운 진도 너무 잦은 빈도
# Right translation : <sos> 움직이는 십자가 Feat . 최미향 김대환
# Predicted translation:  Feat . Muddyychild <eos>
# -------------------------------------------------- 10164
# Input: 똑똑 계시나요 예수님 내 마음 에 계시나요 똑똑 계시나요 언제나 나와 함께 계시나요 예수님 없으면 난 혼자 선 설 수 없죠 언제나 어디 서나 나와 함께 해주세요 똑똑 계시나요 마음 이 아플 때 도 계시나요 매일 나와 함께 해 요 예수님 나와 함께 해주세요
# Right translation : <sos> 한 잔 만 더 하면
# Predicted translation:  달 의 노래 <eos>
# -------------------------------------------------- 27450
# Input: 그래 난 꿈 이 있지 It s quite a big big dream 현실 은 후미진 뒷골목 야 햇빛 들 기를 바라는 내 가 오늘 삼 시세 끼 를 다 먹은건 행운 평소 에는 끼니 를 거르 며 버스 네 정거장 정도 는 그냥 걸으며 천원 짜리 한장 에도 후 덜덜 떠는걸 but it s okay 이 고생 은 해봐야 돼 . 꼭 내 가 아는 이 곳 에 성공한 이 들 이 그랬듯 사실 내 주머니 는 참 넉 넉 치 않지만 우리 집 이 가난 과는 좀 거리 가 있지 난 외동아들 에 부모님 은 두 분다 교사 내 가 잘 됐음 하는 마음 에 엄마 는 날 가두려고 하지 자꾸 좁다란 울타리 에 난 그게 싫어서 절대 손 은 안 벌리지 왜 내 가 엄마 성격 을 닮은 걸 엄 만 몰라 그래 난 주체 적 이고 존나 올 곧아 그래 이 곳 은 내 무대 야 니 생각 보다 힘들게 오른 무대 야 지금 내 가 무슨 대학 을 다니고 토익 점수 가 몇 이고 그런게 여기 서 문제 야 ? 흔히 말 해 인생 이란 걸 무대 에다 빗대가며 내 말 이 여긴 내 무대 야 이 무대 가 내 무대 야 내
# Right translation : <sos> It Gonna Come FKJ Remix
# Predicted translation:  I m Ok <eos>
# -------------------------------------------------- 16111
