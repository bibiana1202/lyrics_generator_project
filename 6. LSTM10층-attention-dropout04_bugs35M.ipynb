# %%
# 그래프에서 한글표현을 위해 폰트를 설치합니다.
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

# %%
import matplotlib.pyplot as plt  # 그래프 그리는 용도
import matplotlib.font_manager as fm  # 폰트 관련 용도
path = '/usr/share/fonts/truetype/nanum/NanumGothicEco.ttf'  # 설치된 나눔글꼴중 원하는 녀석의 전체 경로를 가져오자
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)

plt.rc('font', family=font_name)

fm._rebuild()
# Out:
# NanumGothic Eco

# %%
import re
import os
import unicodedata
import urllib3
import zipfile
import shutil
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Embedding, GRU, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Download the data

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/share_120293/최종전처리(문자열버전).csv')

df
# Out:
#         Unnamed: 0               title  \
# 0                0       천만 분 의 확률 의 너
# 1                1            술 이 뭐 길래
# 2                2         그때 그 순간 그대로
# 3                3             나 의 에 게
# 4                4          일 과 이분 의 일
# ...            ...                 ...
# 112325      152629    나 를 둘러싼 기막힌 환경 이
# 112326      152631    제 장 나 의 사랑 하 는 책
# 112327      152636                 난 네
# 112328      152637  제 장 주 여 나 의 병든 몸 을
# 112329      152638       너 는 아빠 나 는 엄마
#
#                                                     lyric
# 0       너 를 만나 기 위해 모든 시간 들 을 모래시계 에 다 넣 어 놓 고서 우리 둘 만...
# 1       오늘 도 이렇게 어제 처럼 잔 을 꺼내 나 혼자 서 따른 잔 에 내 입술 을 기대 ...
# 2       잘 지냈 지 조금 은 어색 해 요즘 좋 아 보여 인사 나누 며 사실 궁금 한 게 너...
# 3       우리 다시 만날래 예쁘 게 빛나 던 모든 추억 들 이 너무 그리워 너 의 품 에 안...
# 4       멀리서 널 보 았 을 때 다른 길 로 갈까 생각 했 는데 변한 듯 한 널 보 고 싶...
# ...                                                   ...
# 112325  나 를 둘러싼 기막힌 환경 이 변하 지 않 는다 해도 나 는 주 의 이름 을 영원히...
# 112326  나 의 사랑 하 는 책 비록 해 어 졌으나 어머님 의 무릎 위 에 앉 아서 재미있 ...
# 112327  나 를 원해 이리로 이리 온 유난 떨 지 마 그만 원한다면 솔직 해져 봐 와서 가져...
# 112328  주 여 나 의 병든 몸 을 지금 고쳐 주 소서 모든 병 을 고쳐 주마 주 약속 하 ...
# 112329  어릴 때 소꿉친구 너 는 아빠 나 는 엄마 각시 풀 핀 언덕 에 오손도손 정답 더니...
#
# [112330 rows x 3 columns]

# %%
df['title'].nunique(), df['lyric'].nunique()
df.drop_duplicates(subset=['lyric'], inplace=True)
df.dropna(inplace=True)
df.reset_index(drop=True,inplace=True)

df
# Out:
#         Unnamed: 0               title  \
# 0                0       천만 분 의 확률 의 너
# 1                1            술 이 뭐 길래
# 2                2         그때 그 순간 그대로
# 3                3             나 의 에 게
# 4                4          일 과 이분 의 일
# ...            ...                 ...
# 112325      152629    나 를 둘러싼 기막힌 환경 이
# 112326      152631    제 장 나 의 사랑 하 는 책
# 112327      152636                 난 네
# 112328      152637  제 장 주 여 나 의 병든 몸 을
# 112329      152638       너 는 아빠 나 는 엄마
#
#                                                     lyric
# 0       너 를 만나 기 위해 모든 시간 들 을 모래시계 에 다 넣 어 놓 고서 우리 둘 만...
# 1       오늘 도 이렇게 어제 처럼 잔 을 꺼내 나 혼자 서 따른 잔 에 내 입술 을 기대 ...
# 2       잘 지냈 지 조금 은 어색 해 요즘 좋 아 보여 인사 나누 며 사실 궁금 한 게 너...
# 3       우리 다시 만날래 예쁘 게 빛나 던 모든 추억 들 이 너무 그리워 너 의 품 에 안...
# 4       멀리서 널 보 았 을 때 다른 길 로 갈까 생각 했 는데 변한 듯 한 널 보 고 싶...
# ...                                                   ...
# 112325  나 를 둘러싼 기막힌 환경 이 변하 지 않 는다 해도 나 는 주 의 이름 을 영원히...
# 112326  나 의 사랑 하 는 책 비록 해 어 졌으나 어머님 의 무릎 위 에 앉 아서 재미있 ...
# 112327  나 를 원해 이리로 이리 온 유난 떨 지 마 그만 원한다면 솔직 해져 봐 와서 가져...
# 112328  주 여 나 의 병든 몸 을 지금 고쳐 주 소서 모든 병 을 고쳐 주마 주 약속 하 ...
# 112329  어릴 때 소꿉친구 너 는 아빠 나 는 엄마 각시 풀 핀 언덕 에 오손도손 정답 더니...
#
# [112330 rows x 3 columns]

# %% [markdown]
# ## Configuration

# %%
batch_size = 32  # Batch size for training.
epochs = 100  # Number of epochs to train for.
hidden_units = 256  # Latent dimensionality of the encoding space.
embedding_dim = 100
num_samples = 112330    # Number of samples to train on.
dropout_rate = 0.4

# %% [markdown]
# ## Prepare the data

# %% [markdown]
# 데이터셋을 다운로드한 후에 데이터를 준비하고자 다음의 단계를 수행합니다.
#
# 1. 각 문장에 start와 end 토큰을 추가합니다.
# 2. 특정 문자를 제거함으로써 문장을 정리합니다.
# 3. 단어 인덱스와 아이디(ID) 인덱스를 생성합니다. (단어 → 아이디(ID), 아이디(ID) → 단어로 매핑된 딕셔너리).
# 4. 각 문장을 입력층의 최대 길이만큼 패딩(padding)을 수행합니다.

# %%
# !pip install konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 595 kB/s
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.9.1)
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.4.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (453 kB)
#      |████████████████████████████████| 453 kB 47.3 MB/s
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.21.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (4.1.1)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.4.0 konlpy-0.6.0

# %%
from konlpy.tag import Okt
okt = Okt()

# %%
import re
def preprocess_kor_sentence(sent):
  # 단어와 구두점 사이에 공백을 만듭니다.
  # Ex) "he is a boy." => "he is a boy ."
  sent = re.sub(r"([?.!,¿])", r" \1", sent)

  # (a-z, A-Z, ".", "?", "!", ",") 이들을 제외하고는 전부 공백으로 변환합니다.
  sent = re.sub(r"[^a-zA-Z가-힣ㄱ-ㅎㅏ-ㅣ!.?]+", r" ", sent)

  # 다수 개의 공백을 하나의 공백으로 치환
  sent = re.sub(r"\s+", " ", sent)
  
  sent = okt.morphs(sent, stem = False)
  sent = " ".join(sent) # string으로 출력!!! 구분 " "
  return sent

# %%
df
# Out:
#         Unnamed: 0               title  \
# 0                0       천만 분 의 확률 의 너
# 1                1            술 이 뭐 길래
# 2                2         그때 그 순간 그대로
# 3                3             나 의 에 게
# 4                4          일 과 이분 의 일
# ...            ...                 ...
# 112325      152629    나 를 둘러싼 기막힌 환경 이
# 112326      152631    제 장 나 의 사랑 하 는 책
# 112327      152636                 난 네
# 112328      152637  제 장 주 여 나 의 병든 몸 을
# 112329      152638       너 는 아빠 나 는 엄마
#
#                                                     lyric
# 0       너 를 만나 기 위해 모든 시간 들 을 모래시계 에 다 넣 어 놓 고서 우리 둘 만...
# 1       오늘 도 이렇게 어제 처럼 잔 을 꺼내 나 혼자 서 따른 잔 에 내 입술 을 기대 ...
# 2       잘 지냈 지 조금 은 어색 해 요즘 좋 아 보여 인사 나누 며 사실 궁금 한 게 너...
# 3       우리 다시 만날래 예쁘 게 빛나 던 모든 추억 들 이 너무 그리워 너 의 품 에 안...
# 4       멀리서 널 보 았 을 때 다른 길 로 갈까 생각 했 는데 변한 듯 한 널 보 고 싶...
# ...                                                   ...
# 112325  나 를 둘러싼 기막힌 환경 이 변하 지 않 는다 해도 나 는 주 의 이름 을 영원히...
# 112326  나 의 사랑 하 는 책 비록 해 어 졌으나 어머님 의 무릎 위 에 앉 아서 재미있 ...
# 112327  나 를 원해 이리로 이리 온 유난 떨 지 마 그만 원한다면 솔직 해져 봐 와서 가져...
# 112328  주 여 나 의 병든 몸 을 지금 고쳐 주 소서 모든 병 을 고쳐 주마 주 약속 하 ...
# 112329  어릴 때 소꿉친구 너 는 아빠 나 는 엄마 각시 풀 핀 언덕 에 오손도손 정답 더니...
#
# [112330 rows x 3 columns]

# %%
from tqdm import tqdm 
def load_preprocessed_data():
    encoder_input, decoder_input, decoder_target = [], [], []

    for i in tqdm(range(len(df[:num_samples]))):
        # source 데이터와 target 데이터 분리
        tar_line = df['title'].iloc[i]
        src_line = df['lyric'].iloc[i]
        
        # source 데이터 전처리
        src_line = [w for w in preprocess_kor_sentence(src_line).split()]

        # target 데이터 전처리
        #tar_line = preprocess_kor_sentence(tar_line)
        tar_line_in = [w for w in ("<sos> " + tar_line).split()]  # teacher forcing을 위한 정답셋 
        tar_line_out = [w for w in (tar_line + " <eos>").split()]

        encoder_input.append(src_line)
        decoder_input.append(tar_line_in)
        decoder_target.append(tar_line_out)
                
    return encoder_input, decoder_input, decoder_target

# %%
# 전처리 테스트

kr_sent = u"저녁 먹었니?"

print('전처리 전 한국어 문장 :', kr_sent)
print('전처리 후 한국어 문장 :', preprocess_kor_sentence(kr_sent))
# Out:
# 전처리 전 한국어 문장 : 저녁 먹었니?
# 전처리 후 한국어 문장 : 저녁 먹었니 ?

# %%
sents_lylic_in, sents_title_in, sents_title_out  = load_preprocessed_data()
# Out:
# 100%|██████████| 112330/112330 [41:42<00:00, 44.89it/s]

# %%
len(sents_lylic_in), len(sents_title_in), len(sents_title_out)
# Out:
# (112330, 112330, 112330)

# %%
print('인코더의 입력 :',sents_lylic_in[2968])
print('디코더의 입력 :',sents_title_in[2968])
print('디코더의 레이블 :',sents_title_out[2968])
# Out:
# 인코더의 입력 : ['단념', '을', '택했', '을', '때', '내', '가', '잃어버릴', '것', '은', '너', '하나', '뿐', '이', '고', '집착', '을', '택했', '을', '때', '내', '가', '잃어버릴', '것', '은', '너', '를', '뺀', '나머지', '모든', '것', '이', '다']
# 디코더의 입력 : ['<sos>', '희망', '고문']
# 디코더의 레이블 : ['희망', '고문', '<eos>']

# %% [markdown]
# 단어집합을 생성하겠습니다.

# %%
# 가사 input -> 제목 output 

# 가사 input

tokenizer_lylic = Tokenizer(filters="", lower=False)
tokenizer_lylic.fit_on_texts(sents_lylic_in)
encoder_input = tokenizer_lylic.texts_to_sequences(sents_lylic_in)

# %%
# 제목 output
tokenizer_title = Tokenizer(filters="", lower=False)
tokenizer_title.fit_on_texts(sents_title_in)
tokenizer_title.fit_on_texts(sents_title_out)

decoder_input = tokenizer_title.texts_to_sequences(sents_title_in)
decoder_target = tokenizer_title.texts_to_sequences(sents_title_out)

# %% [markdown]
# 각 문장을 입력층의 최대 길이만큼 패딩(padding)을 수행합니다.

# %%
encoder_input = pad_sequences(encoder_input,maxlen=1500, padding="post")
decoder_input = pad_sequences(decoder_input,maxlen=8, padding="post")
decoder_target = pad_sequences(decoder_target,maxlen=8, padding="post")

# %%
print('인코더의 입력의 크기(shape) :',encoder_input.shape)
print('디코더의 입력의 크기(shape) :',decoder_input.shape)
print('디코더의 레이블의 크기(shape) :',decoder_target.shape)
# Out:
# 인코더의 입력의 크기(shape) : (112330, 1500)
# 디코더의 입력의 크기(shape) : (112330, 8)
# 디코더의 레이블의 크기(shape) : (112330, 8)

# %%
len(encoder_input[112329])
# Out:
# 1500

# %% [markdown]
# 샘플은 총 3833개 존재합니다

# %%
src_vocab_size = len(tokenizer_lylic.word_index) +1
tar_vocab_size = len(tokenizer_title.word_index) +1

print(f"가사 단어 집합의 크기 : {src_vocab_size}, 제목 단어 집합의 크기 : {tar_vocab_size}")
# Out:
# 가사 단어 집합의 크기 : 59775, 제목 단어 집합의 크기 : 25632

# %%
len(tokenizer_title.word_index)
# Out:
# 25631

# %% [markdown]
# 단어로부터 정수를 얻는 딕셔너리와 정수로부터 단어를 얻는 딕셔너리를 각각 만들어줍니다. 이들은 훈련을 마치고 예측값과 실제값을 비교하는 단계에서 사용합니다.

# %%
src_to_index = tokenizer_lylic.word_index  # word : idx
index_to_src = tokenizer_lylic.index_word  # idx : word
tar_to_index = tokenizer_title.word_index # word : idx
index_to_tar = tokenizer_title.index_word # idx : word

# %%
print(len(src_to_index),len(index_to_src),len(tar_to_index),len(index_to_tar))
# Out:
# 59774 59774 25631 25631

# %% [markdown]
# 테스트 데이터를 분리하겠습니다. 인코더 input, 디코더 input, 디코더 output이 동일하게 분리되어야 하기 때문에 랜덤한 정수배열을 만들어 직접 나누겠습니다.

# %% [markdown]
# 우선 랜덤하게 시퀀스를 섞습니다.

# %%
indices = np.arange(encoder_input.shape[0])
np.random.shuffle(indices)
print('랜덤 시퀀스 :',indices)
# Out:
# 랜덤 시퀀스 : [47088 31731 35933 ... 24454 58299  2412]

# %%
encoder_input = encoder_input[indices]
decoder_input = decoder_input[indices]
decoder_target = decoder_target[indices]

# %%
decoder_input[indices[0]], decoder_target[indices[0]]
# Out:
# (array([    1, 13221,     0,     0,     0,     0,     0,     0],
#        dtype=int32),
#  array([13221,     2,     0,     0,     0,     0,     0,     0],
#        dtype=int32))

# %% [markdown]
# `<sos>` `<eos>` 토큰을 제외한 다른 단어들은 동일한 인덱스를 갖고 있어야 합니다.

# %% [markdown]
# 10%의 데이터를 test데이터로 분리하겠습니다.

# %%
n_of_val = int(num_samples*0.1)

encoder_input_train = encoder_input[:-n_of_val]
decoder_input_train = decoder_input[:-n_of_val]
decoder_target_train = decoder_target[:-n_of_val]

encoder_input_test = encoder_input[-n_of_val:]
decoder_input_test = decoder_input[-n_of_val:]
decoder_target_test = decoder_target[-n_of_val:]

# %%
print('훈련 source 데이터의 크기 :',encoder_input_train.shape)
print('훈련 target 데이터의 크기 :',decoder_input_train.shape)
print('훈련 target 레이블의 크기 :',decoder_target_train.shape)
print('테스트 source 데이터의 크기 :',encoder_input_test.shape)
print('테스트 target 데이터의 크기 :',decoder_input_test.shape)
print('테스트 target 레이블의 크기 :',decoder_target_test.shape)
# Out:
# 훈련 source 데이터의 크기 : (101097, 1500)
# 훈련 target 데이터의 크기 : (101097, 8)
# 훈련 target 레이블의 크기 : (101097, 8)
# 테스트 source 데이터의 크기 : (11233, 1500)
# 테스트 target 데이터의 크기 : (11233, 8)
# 테스트 target 레이블의 크기 : (11233, 8)

# %% [markdown]
# ## Model

# %% [markdown]
# 이제 번역기를 빌드해보겠습니다.

# %%
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Masking
from tensorflow.keras.models import Model

# %% [markdown]
# 인코더를 설계합니다. LSTM에서 state_h, state_c를 리턴받는데, 이는 각각 RNN 챕터에서 LSTM을 처음 설명할 때 언급하였던 은닉 상태와 셀 상태에 해당됩니다. 이 두 가지 상태를 encoder_states에 저장합니다. encoder_states를 디코더에 전달하므로서 이 두 가지 상태 모두를 디코더로 전달할 예정입니다. 이것이 앞서 배운 컨텍스트 벡터입니다.

# %%
# 인코더
encoder_inputs = Input(shape=(None,))
enc_emb = Embedding(src_vocab_size, embedding_dim)(encoder_inputs) # 임베딩 층
encoder_lstm1 = LSTM(hidden_units, return_sequences = True, return_state=True, dropout = dropout_rate)
encoder_lstm2 = LSTM(hidden_units, return_sequences = True, return_state=True, dropout = dropout_rate)
encoder_lstm3 = LSTM(hidden_units, return_sequences = True, return_state=True, dropout = dropout_rate)
encoder_lstm4 = LSTM(hidden_units, return_sequences = True, return_state=True, dropout = dropout_rate)
encoder_lstm5 = LSTM(hidden_units, return_sequences = True, return_state=True, dropout = dropout_rate)
encoder_lstm6 = LSTM(hidden_units, return_sequences = True, return_state=True, dropout = dropout_rate)
encoder_lstm7 = LSTM(hidden_units, return_sequences = True, return_state=True, dropout = dropout_rate)
encoder_lstm8 = LSTM(hidden_units, return_sequences = True, return_state=True, dropout = dropout_rate)
encoder_lstm9 = LSTM(hidden_units, return_sequences = True, return_state=True, dropout = dropout_rate)
encoder_lstm10 = LSTM(hidden_units, return_sequences = True, return_state=True, dropout = dropout_rate)


x, eh1, ec1 = encoder_lstm1(enc_emb) # 은닉 상태와 셀 상태를 리턴
x, eh2, ec2 = encoder_lstm2(x) # 은닉 상태와 셀 상태를 리턴
x, eh3, ec3 = encoder_lstm3(x) # 은닉 상태와 셀 상태를 리턴
x, eh4, ec4 = encoder_lstm4(x) # 은닉 상태와 셀 상태를 리턴
x, eh5, ec5 = encoder_lstm5(x) # 은닉 상태와 셀 상태를 리턴
x, eh6, ec6 = encoder_lstm6(x) # 은닉 상태와 셀 상태를 리턴
x, eh7, ec7 = encoder_lstm7(x) # 은닉 상태와 셀 상태를 리턴
x, eh8, ec8 = encoder_lstm8(x) # 은닉 상태와 셀 상태를 리턴
x, eh9, ec9 = encoder_lstm9(x) # 은닉 상태와 셀 상태를 리턴
encoder_outputs, eh10, ec10 = encoder_lstm10(x) # 은닉 상태와 셀 상태를 리턴

encoder_states = [eh1, ec1, eh2, ec2, eh3, ec3, eh4, ec4, eh5, ec5, eh6, ec6, eh7, ec7, eh8, ec8, eh9, ec9, eh10, ec10] # 인코더의 은닉 상태와 셀 상태를 저장

# %% [markdown]
# 이번에는 Attention을 추가합니다.
# - Attention 중 가장 기초적인 dot-product attention을 예제로 진행하겠습니다.
# 1. attention score 계산
# 2. softmax로 attention distribution 계산
# 3. 각 인코더의 어텐션 가중치와 은닉 상태를 가중합하여 어텐션 값 계산
# 4. 어텐션값과 디코더의 t시점의 은닉상태를 연결
# 5. 출력층 연산의 입력이 되는 st 계산

# %% [markdown]
# 디코더에서는 attention layer를 추가합니다.
# - 이때, s_는 은닉상태와 디코더의 최종 출력은 연결해야 하므로, shape을 맞춰주기 위하여 축을 추가합니다.
# - attention layer는 디코더의 은닉상태와 인코더의 은닉상태 전체를 받아 컨텍스트 벡터를 생성합니다.
# - 마지막으로 생성한 컨텍스트 벡터와 디코더의 은닉상태 전체를 softmax layer에 넣고 인덱스를 예측합니다.

# %%
from tensorflow.keras.layers import Attention

# 디코더
decoder_inputs = Input(shape=(None,))
dec_emb_layer = Embedding(tar_vocab_size, hidden_units) # 임베딩 층
dec_emb = dec_emb_layer(decoder_inputs) # 임베딩 결과

# 상태값 리턴을 위해 return_state는 True, 모든 시점에 대해서 단어를 예측하기 위해 return_sequences는 True
decoder_lstm1 = LSTM(hidden_units, return_sequences=True, return_state=True, dropout = dropout_rate) 
decoder_lstm2 = LSTM(hidden_units, return_sequences=True, return_state=True, dropout = dropout_rate) 
decoder_lstm3 = LSTM(hidden_units, return_sequences=True, return_state=True, dropout = dropout_rate) 
decoder_lstm4 = LSTM(hidden_units, return_sequences=True, return_state=True, dropout = dropout_rate) 
decoder_lstm5 = LSTM(hidden_units, return_sequences=True, return_state=True, dropout = dropout_rate) 
decoder_lstm6 = LSTM(hidden_units, return_sequences=True, return_state=True, dropout = dropout_rate) 
decoder_lstm7 = LSTM(hidden_units, return_sequences=True, return_state=True, dropout = dropout_rate) 
decoder_lstm8 = LSTM(hidden_units, return_sequences=True, return_state=True, dropout = dropout_rate) 
decoder_lstm9 = LSTM(hidden_units, return_sequences=True, return_state=True, dropout = dropout_rate) 
decoder_lstm10 = LSTM(hidden_units, return_sequences=True, return_state=True, dropout = dropout_rate) 

# 인코더의 은닉 상태를 초기 은닉 상태(initial_state)로 사용
x1, h1, c1 = decoder_lstm1(dec_emb, initial_state=encoder_states[:2])
x2, h2, c2 = decoder_lstm2(x1, initial_state=encoder_states[2:4])
x3, h3, c3 = decoder_lstm3(x2, initial_state=encoder_states[4:6])
x4, h4, c4 = decoder_lstm4(x3, initial_state=encoder_states[6:8])
x5, h5, c5 = decoder_lstm5(x4, initial_state=encoder_states[8:10])
x6, h6, c6 = decoder_lstm6(x5, initial_state=encoder_states[10:12])
x7, h7, c7 = decoder_lstm7(x6, initial_state=encoder_states[12:14])
x8, h8, c8 = decoder_lstm8(x7, initial_state=encoder_states[14:16])
x9, h9, c9 = decoder_lstm9(x8, initial_state=encoder_states[16:18])
decoder_outputs, h10 , c10 = decoder_lstm10(x9, initial_state=encoder_states[18:])

# attention
S_ = tf.concat([eh3[:, tf.newaxis, :], decoder_outputs[:, :-1, :]], axis=1) # query 

attention = Attention(hidden_units)
context_vector, _ = attention([S_, encoder_outputs], return_attention_scores = True)

concat = tf.concat([decoder_outputs, context_vector], axis=-1)

# 모든 시점의 결과에 대해서 소프트맥스 함수를 사용한 출력층을 통해 단어 예측
decoder_dense = Dense(tar_vocab_size, activation='softmax')
decoder_outputs = decoder_dense(concat)

# %%
# 모델의 입력과 출력을 정의.
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['acc'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, None)]       0           []
#
#  input_6 (InputLayer)           [(None, None)]       0           []
#
#  embedding_3 (Embedding)        (None, None, 100)    5977500     ['input_4[0][0]']
#
#  embedding_5 (Embedding)        (None, None, 256)    6561792     ['input_6[0][0]']
#
#  lstm_30 (LSTM)                 [(None, None, 256),  365568      ['embedding_3[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  lstm_50 (LSTM)                 [(None, None, 256),  525312      ['embedding_5[0][0]',
#                                  (None, 256),                     'lstm_30[0][1]',
#                                  (None, 256)]                     'lstm_30[0][2]']
#
#  lstm_31 (LSTM)                 [(None, None, 256),  525312      ['lstm_30[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  lstm_51 (LSTM)                 [(None, None, 256),  525312      ['lstm_50[0][0]',
#                                  (None, 256),                     'lstm_31[0][1]',
#                                  (None, 256)]                     'lstm_31[0][2]']
#
#  lstm_32 (LSTM)                 [(None, None, 256),  525312      ['lstm_31[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  lstm_52 (LSTM)                 [(None, None, 256),  525312      ['lstm_51[0][0]',
#                                  (None, 256),                     'lstm_32[0][1]',
#                                  (None, 256)]                     'lstm_32[0][2]']
#
#  lstm_33 (LSTM)                 [(None, None, 256),  525312      ['lstm_32[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  lstm_53 (LSTM)                 [(None, None, 256),  525312      ['lstm_52[0][0]',
#                                  (None, 256),                     'lstm_33[0][1]',
#                                  (None, 256)]                     'lstm_33[0][2]']
#
#  lstm_34 (LSTM)                 [(None, None, 256),  525312      ['lstm_33[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  lstm_54 (LSTM)                 [(None, None, 256),  525312      ['lstm_53[0][0]',
#                                  (None, 256),                     'lstm_34[0][1]',
#                                  (None, 256)]                     'lstm_34[0][2]']
#
#  lstm_35 (LSTM)                 [(None, None, 256),  525312      ['lstm_34[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  lstm_55 (LSTM)                 [(None, None, 256),  525312      ['lstm_54[0][0]',
#                                  (None, 256),                     'lstm_35[0][1]',
#                                  (None, 256)]                     'lstm_35[0][2]']
#
#  lstm_36 (LSTM)                 [(None, None, 256),  525312      ['lstm_35[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  lstm_56 (LSTM)                 [(None, None, 256),  525312      ['lstm_55[0][0]',
#                                  (None, 256),                     'lstm_36[0][1]',
#                                  (None, 256)]                     'lstm_36[0][2]']
#
#  lstm_37 (LSTM)                 [(None, None, 256),  525312      ['lstm_36[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  lstm_57 (LSTM)                 [(None, None, 256),  525312      ['lstm_56[0][0]',
#                                  (None, 256),                     'lstm_37[0][1]',
#                                  (None, 256)]                     'lstm_37[0][2]']
#
#  lstm_38 (LSTM)                 [(None, None, 256),  525312      ['lstm_37[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  lstm_58 (LSTM)                 [(None, None, 256),  525312      ['lstm_57[0][0]',
#                                  (None, 256),                     'lstm_38[0][1]',
#                                  (None, 256)]                     'lstm_38[0][2]']
#
#  lstm_39 (LSTM)                 [(None, None, 256),  525312      ['lstm_38[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  lstm_59 (LSTM)                 [(None, None, 256),  525312      ['lstm_58[0][0]',
#                                  (None, 256),                     'lstm_39[0][1]',
#                                  (None, 256)]                     'lstm_39[0][2]']
#
#  tf.__operators__.getitem (Slic  (None, 1, 256)      0           ['lstm_32[0][1]']
#  ingOpLambda)
#
#  tf.__operators__.getitem_1 (Sl  (None, None, 256)   0           ['lstm_59[0][0]']
#  icingOpLambda)
#
#  tf.concat (TFOpLambda)         (None, None, 256)    0           ['tf.__operators__.getitem[0][0]'
#                                                                  , 'tf.__operators__.getitem_1[0][
#                                                                  0]']
#
#  attention (Attention)          ((None, None, 256),  1           ['tf.concat[0][0]',
#                                  (None, None, None)               'lstm_39[0][0]']
#                                 )
#
#  tf.concat_1 (TFOpLambda)       (None, None, 512)    0           ['lstm_59[0][0]',
#                                                                   'attention[0][0]']
#
#  dense (Dense)                  (None, None, 25632)  13149216    ['tf.concat_1[0][0]']
#
# ==================================================================================================
# Total params: 36,035,005
# Trainable params: 36,035,005
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, to_file='model.png', )

# %%
import tensorflow as tf

from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

EPOCH= 100
BATCH_SIZE = 64

filename = '/content/drive/MyDrive/share_120293/NLP모델/cp/checkpoint-epoch-{}-batch-{}-9/18_10층.h5'.format(EPOCH, BATCH_SIZE)

checkpoint = ModelCheckpoint(filename,             # file명을 지정합니다
                             monitor='val_loss',   # val_loss 값이 개선되었을때 호출됩니다
                             verbose=1,            # 로그를 출력합니다
                             save_best_only=True,  # 가장 best 값만 저장합니다
                             mode='auto'           # auto는 알아서 best를 찾습니다. min/max
                            )
earlystopping = EarlyStopping(monitor='val_loss',  # 모니터 기준 설정 (val loss) 
                              patience=5,         # ?회 Epoch동안 개선되지 않는다면 종료
                             )

# %%
model.fit(x=[encoder_input_train, decoder_input_train], y=decoder_target_train, 
          validation_data=([encoder_input_test, decoder_input_test], decoder_target_test),batch_size=BATCH_SIZE, epochs=EPOCH,callbacks=[checkpoint,earlystopping]
          )
# Out:
# Epoch 1/100
# 1580/1580 [==============================] - ETA: 0s - loss: 3.8240 - acc: 0.4473
# Epoch 1: val_loss improved from inf to 3.72491, saving model to /content/drive/MyDrive/share_120293/NLP모델/cp/checkpoint-epoch-100-batch-64-9/18_10층.h5
# 1580/1580 [==============================] - 2595s 2s/step - loss: 3.8240 - acc: 0.4473 - val_loss: 3.7249 - val_acc: 0.4550
# Epoch 2/100
# 1580/1580 [==============================] - ETA: 0s - loss: 3.6739 - acc: 0.4510
# Epoch 2: val_loss improved from 3.72491 to 3.71607, saving model to /content/drive/MyDrive/share_120293/NLP모델/cp/checkpoint-epoch-100-batch-64-9/18_10층.h5
# 1580/1580 [==============================] - 2489s 2s/step - loss: 3.6739 - acc: 0.4510 - val_loss: 3.7161 - val_acc: 0.4561
# Epoch 3/100
# 1580/1580 [==============================] - ETA: 0s - loss: 3.6354 - acc: 0.4521
# Epoch 3: val_loss did not improve from 3.71607
# 1580/1580 [==============================] - 2488s 2s/step - loss: 3.6354 - acc: 0.4521 - val_loss: 3.7191 - val_acc: 0.4578
# Epoch 4/100
# 1580/1580 [==============================] - ETA: 0s - loss: 3.5936 - acc: 0.4534
# Epoch 4: val_loss improved from 3.71607 to 3.70384, saving model to /content/drive/MyDrive/share_120293/NLP모델/cp/checkpoint-epoch-100-batch-64-9/18_10층.h5
# 1580/1580 [==============================] - 2491s 2s/step - loss: 3.5936 - acc: 0.4534 - val_loss: 3.7038 - val_acc: 0.4591
# Epoch 5/100
# 1580/1580 [==============================] - ETA: 0s - loss: 3.5631 - acc: 0.4543
# Epoch 5: val_loss did not improve from 3.70384
# 1580/1580 [==============================] - 2487s 2s/step - loss: 3.5631 - acc: 0.4543 - val_loss: 3.7134 - val_acc: 0.4580
# Epoch 6/100
# 1580/1580 [==============================] - ETA: 0s - loss: 3.5517 - acc: 0.4541
# Epoch 6: val_loss did not improve from 3.70384
# 1580/1580 [==============================] - 2486s 2s/step - loss: 3.5517 - acc: 0.4541 - val_loss: 3.7303 - val_acc: 0.4592
# Epoch 7/100
# 1580/1580 [==============================] - ETA: 0s - loss: 3.5418 - acc: 0.4540
# Epoch 7: val_loss did not improve from 3.70384
# 1580/1580 [==============================] - 2486s 2s/step - loss: 3.5418 - acc: 0.4540 - val_loss: 3.7314 - val_acc: 0.4590
# Epoch 8/100
# 1580/1580 [==============================] - ETA: 0s - loss: 3.5106 - acc: 0.4553
# Epoch 8: val_loss did not improve from 3.70384
# 1580/1580 [==============================] - 2487s 2s/step - loss: 3.5106 - acc: 0.4553 - val_loss: 3.7276 - val_acc: 0.4593
# Epoch 9/100
# 1580/1580 [==============================] - ETA: 0s - loss: 3.5060 - acc: 0.4549
# Epoch 9: val_loss did not improve from 3.70384
# 1580/1580 [==============================] - 2486s 2s/step - loss: 3.5060 - acc: 0.4549 - val_loss: 3.7705 - val_acc: 0.4579

# %%
model.save('/content/drive/MyDrive/share_120293/NLP모델/lstm_attention_model_9/18_10층.h5')

# %% [markdown]
# ## 훈련된 모델로 번역하기
#
# * 평가 함수는 여기서 *교사 강요(teacher forcing)*를 사용하기 못하는 것을 제외하고는 훈련 루프와 비슷합니다. 각 마지막 시점(time step)에서 이전 디코더 인코더의 결과와 은닉 상태(hidden state)를 가진 예측 값을 디코더에 입력합니다.
#
#     1. 번역하고자 하는 입력 문장이 인코더로 입력되어 인코더의 마지막 시점의 은닉 상태와 셀 상태를 얻습니다.
#     2. 인코더의 은닉 상태와 셀 상태, 그리고 토큰 <sos>를 디코더로 보냅니다.
#     3. 디코더가 토큰 <eos>가 나올 때까지 다음 단어를 예측하는 행동을 반복합니다.

# %%
# 인코더 - 훈련과 동일 
encoder_model = Model(encoder_inputs, [encoder_outputs, encoder_states])

# %%
tf.keras.utils.plot_model(encoder_model, to_file='model.png', )

# %%
# 디코더 

# 이전 시점의 상태를 보관할 텐서
decoder_state_input_h1 = Input(shape=(hidden_units,))
decoder_state_input_c1 = Input(shape=(hidden_units,))

decoder_state_input_h2 = Input(shape=(hidden_units,))
decoder_state_input_c2 = Input(shape=(hidden_units,))

decoder_state_input_h3 = Input(shape=(hidden_units,))
decoder_state_input_c3 = Input(shape=(hidden_units,))

decoder_state_input_h4 = Input(shape=(hidden_units,))
decoder_state_input_c4 = Input(shape=(hidden_units,))

decoder_state_input_h5 = Input(shape=(hidden_units,))
decoder_state_input_c5 = Input(shape=(hidden_units,))

decoder_state_input_h6 = Input(shape=(hidden_units,))
decoder_state_input_c6 = Input(shape=(hidden_units,))

decoder_state_input_h7 = Input(shape=(hidden_units,))
decoder_state_input_c7 = Input(shape=(hidden_units,))

decoder_state_input_h8 = Input(shape=(hidden_units,))
decoder_state_input_c8 = Input(shape=(hidden_units,))

decoder_state_input_h9 = Input(shape=(hidden_units,))
decoder_state_input_c9 = Input(shape=(hidden_units,))

decoder_state_input_h10 = Input(shape=(hidden_units,))
decoder_state_input_c10 = Input(shape=(hidden_units,))

decoder_states_inputs = [decoder_state_input_h1, decoder_state_input_c1,
                         decoder_state_input_h2, decoder_state_input_c2,
                         decoder_state_input_h3, decoder_state_input_c3,
                         decoder_state_input_h4, decoder_state_input_c4,
                         decoder_state_input_h5, decoder_state_input_c5,
                         decoder_state_input_h6, decoder_state_input_c6,
                         decoder_state_input_h7, decoder_state_input_c7,
                         decoder_state_input_h8, decoder_state_input_c8,
                         decoder_state_input_h9, decoder_state_input_c9,
                         decoder_state_input_h10, decoder_state_input_c10,
                         ]


encoder_state_h = Input(shape=(hidden_units,))
encoder_outputs2 = Input(shape =(None, hidden_units,))


# 훈련 때 사용했던 임베딩 층을 재사용
dec_emb2 = dec_emb_layer(decoder_inputs)

# 다음 단어 예측을 위해 이전 시점의 상태를 현 시점의 초기 상태로 사용
x, state_h1, state_c1 = decoder_lstm1(dec_emb2, initial_state=decoder_states_inputs[:2])
x, state_h2, state_c2 = decoder_lstm2(x, initial_state=decoder_states_inputs[2:4])
x, state_h3, state_c3 = decoder_lstm3(x, initial_state=decoder_states_inputs[4:6])
x, state_h4, state_c4 = decoder_lstm4(x, initial_state=decoder_states_inputs[6:8])
x, state_h5, state_c5 = decoder_lstm5(x, initial_state=decoder_states_inputs[8:10])
x, state_h6, state_c6 = decoder_lstm6(x, initial_state=decoder_states_inputs[10:12])
x, state_h7, state_c7 = decoder_lstm7(x, initial_state=decoder_states_inputs[12:14])
x, state_h8, state_c8 = decoder_lstm8(x, initial_state=decoder_states_inputs[14:16])
x, state_h9, state_c9 = decoder_lstm9(x, initial_state=decoder_states_inputs[16:18])
decoder_outputs2, state_h10, state_c10 = decoder_lstm10(x, initial_state=decoder_states_inputs[18:])
decoder_states2 = [state_h1, state_c1, 
                   state_h2, state_c2, 
                   state_h3, state_c3 , 
                   state_h4, state_c4 , 
                   state_h5, state_c5 , 
                   state_h6, state_c6 , 
                   state_h7, state_c7 , 
                   state_h8, state_c8 , 
                   state_h9, state_c9 , 
                   state_h10, state_c10]


# Attention
S_ = tf.concat([encoder_state_h[:, tf.newaxis, :], decoder_outputs2[:, :-1, :]], axis=1) # query 

context_vector, att_score = attention([S_, encoder_outputs2], return_attention_scores = True)
decoder_concat = tf.concat([decoder_outputs2, context_vector], axis=-1)

# 모든 시점에 대해서 단어 예측 (Fully Connected)
decoder_outputs2 = decoder_dense(decoder_concat)

# 수정된 디코더
decoder_model = Model(
    [decoder_inputs, encoder_state_h, encoder_outputs2] + decoder_states_inputs,
    [decoder_outputs2, att_score] + decoder_states2)

# %%
tf.keras.utils.plot_model(decoder_model, to_file='model.png', )

# %% [markdown]
# 테스트 단계에서의 동작을 위한 decode_sequence 함수를 구현합니다.
# 1. 입력 문장이 들어오면 인코더는 마지막 시점까지 전개하여 마지막 시점의 은닉 상태와 셀 상태를 리턴합니다. -> `states_value`
# 2. 디코더의 초기 입력으로 <SOS>를 준비합니다. -> `target_seq`
# 3. 이 두 가지 입력을 가지고 while문 안으로 진입하여 이 두 가지를 디코더의 입력으로 사용합니다.
# 4. 이제 디코더는 현재 시점에 대해서 예측합니다.
#     - 예측 벡터로부터 현재 시점의 예측 단어인 target_seq를 얻고, h와 c 이 두 개의 값은 states_value에 저장합니다.
#     - while문의 다음 루프. 즉, 두번째 시점의 디코더의 입력으로 다시 target_seq와 states_value를 사용합니다.
#     - 이를 현재 시점의 예측 단어로 <eos>를 예측하거나 번역 문장의 길이가 50이 넘는 순간까지 반복합니다.
# 5. 각 시점마다 번역된 다어는 decoded_sentence에 누적하여 저장하였다가 최종 번역 시퀀스로 리턴합니다.

# %%
def decode_sequence(sentence):
    # 입력으로부터 인코더의 마지막 시점의 상태(은닉 상태, 셀 상태)를 얻음
    max_src_len, max_tar_len  = encoder_input.shape[1], decoder_input.shape[1]

    attention_plot = np.zeros((max_tar_len, max_src_len))

    sentence = preprocess_kor_sentence(sentence)
    tokens = sentence.split(" ")
    inputs = tokenizer_lylic.texts_to_sequences([tokens])

    inputs = tf.keras.preprocessing.sequence.pad_sequences(inputs,
                                                            maxlen=max_src_len,
                                                            padding='post')
    encoder_test, states_value = encoder_model.predict(inputs)

    # <SOS>에 해당하는 정수 생성
    target_seq = np.zeros((1,1))
    target_seq[0, 0] = tar_to_index['<sos>']
    
    stop_condition = False
    decoded_sentence = ''

    # stop_condition이 True가 될 때까지 루프 반복
    # 구현의 간소화를 위해서 이 함수는 배치 크기를 1로 가정합니다.
    for t in range(max_tar_len):
        # 이점 시점의 상태 states_value를 현 시점의 초기 상태로 사용
        output_tokens, att_score, h1, c1, h2, c2, h3, c3,h4, c4,h5, c5,h6, c6,h7, c7,h8, c8,h9, c9,h10, c10 = decoder_model.predict([target_seq, states_value[0], encoder_test] + states_value)
  

        # 어텐션 가중치 시각화를 위해 저장 
        att_score = tf.reshape(att_score, (-1, ))
        attention_plot[t] = att_score.numpy() 

        # 예측 결과를 단어로 변환
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = index_to_tar[sampled_token_index]
  
        # 현재 시점의 예측 단어를 예측 문장에 추가
        decoded_sentence += ' '+sampled_char


        # 현재 시점의 예측 결과를 다음 시점의 입력으로 사용하기 위해 저장
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # 현재 시점의 상태를 다음 시점의 상태로 사용하기 위해 저장
        states_value = [ h1, c1, h2, c2, h3, c3, h4, c4, h5, c5, h6, c6, h7, c7, h8, c8, h9, c9, h10, c10]

        # <eos>에 도달하거나 정해진 길이를 넘으면 중단.
        if sampled_char == '<eos>':
            break 

    return sentence, decoded_sentence, attention_plot

# %% [markdown]
# 결과 확인을 위한 함수를 만듭니다.

# %%
# 원문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq_to_src(input_seq):
  sentence = ''
  for encoded_word in input_seq:
    if(encoded_word != 0):
      sentence = sentence + index_to_src[encoded_word] + ' '
  return sentence

# 번역문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq_to_tar(input_seq):
  sentence = ''
  for encoded_word in input_seq:
    if(encoded_word != 0 and encoded_word != tar_to_index['<eos>']):
    # if(encoded_word != 0 and encoded_word != tar_to_index['<sos>'] and encoded_word != tar_to_index['<eos>']):
      sentence = sentence + index_to_tar[encoded_word] + ' '
  return sentence

# %%
from pylab import *
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

def plot_attention(attention, sentence, predicted_sentence):
    # you need to change the fname based on your system, and the Chinese can be displayed in the plot
    # font = FontProperties(fname=r"./data/TaipeiSansTCBeta-Regular.ttf", size=14)
    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(1, 1, 1)
    ax.matshow(attention, cmap='viridis')

    fontdict = {'fontsize': 14}

    # set the x-tick/y-tick labels with list of string labels
    ax.set_xticklabels([''] + sentence, fontdict=fontdict, rotation = 90)
    ax.set_yticklabels(predicted_sentence, fontdict=fontdict)

    # set tick locators
    ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
    ax.yaxis.set_major_locator(ticker.MultipleLocator(1))
    plt.show()

# %%
def translate(sentence):
  sentence, result, attention_plot = decode_sequence(sentence)

  print('Input: %s' % (sentence))
  print('Predicted translation: {}'.format(result))

#attention_plot = attention_plot[:len(result.split(' '))-2, :len(sentence.split(' '))]
#plot_attention(attention_plot, sentence.split(' '), result.split(' '))
# Out:
# "  attention_plot = attention_plot[:len(result.split(' '))-2, :len(sentence.split(' '))]\n  plot_attention(attention_plot, sentence.split(' '), result.split(' '))"

# %%
translate('번역기를 만드는 것은 재미있어.')
# Out:
# Input: 번역기 를 만드는 것 은 재미있어 .
# Predicted translation:  나 의 <eos>

# %%
translate('집에 가고 싶다.')
# Out:
# Input: 집 에 가고 싶다 .
# Predicted translation:  <eos>

# %%
translate('당신의 직업은 무엇입니까?')
# Out:
# Input: 당신 의 직업 은 무엇 입 니까 ?
# Predicted translation:  사랑 의 <eos>

# %%
def translate_train(seq_index):
  input_seq = encoder_input_train[seq_index: seq_index + 1]

  sentence = seq_to_src(encoder_input_train[seq_index]).strip()
  _, result, attention_plot = decode_sequence(sentence)

  print('Input: %s' % (sentence))
  print("Right translation :",seq_to_tar(decoder_input_train[seq_index]))
  print('Predicted translation: {}'.format(result))

#"""  attention_plot = attention_plot[:len(result.split(' '))-2, :len(sentence.split(' '))]
# plot_attention(attention_plot, sentence.split(' '), result.split(' '))"""
# Out:
# "  attention_plot = attention_plot[:len(result.split(' '))-2, :len(sentence.split(' '))]\n  plot_attention(attention_plot, sentence.split(' '), result.split(' '))"

# %%
translate_train(11)
# Out:
# Input: 당신 은 나 에게 누구 십 니까 도대체 알 수 가 없 어요 눈꽃 처럼 녹 아 버리 는 신기루 의 환상 인가요 처음 만났 을 땐 사랑 한다고 나 만 을 사랑 한다고 이별 할 땐 무정 하 게 도 말 없이 가 버린 사람 당신 은 배신자 눈물 의 배신자 그 마음 을 모르 겠 어요 당신 은 배신자 사랑 의 배신자 내 마음 을 울리 는 사람 당신 은 나 에게 누구 십 니까 도대체 알 수 가 없 어요 불꽃 처럼 내게 다가와 바람 처럼 날아간 사랑 처음 만났 을 땐 사랑 한다고 나 만 을 사랑 한다고 이별 할 땐 무정 하 게 도 말 없이 가 버린 사람 당신 은 배신자 눈물 의 배신자 그 마음 을 모르 겠 어요 당신 은 배신자 사랑 의 배신자 내 마음 을 울리 는 사람 당신 은 배신자 눈물 의 배신자 그 마음 을 알 고 싶 어요 당신 은 배신자 사랑 의 배신자 내 마음 을 울리 는 사람 내 마음 을 울리 는 사람
# Right translation : <sos> 사랑 의 배신자
# Predicted translation:  사랑 의 <eos>

# %%
for seq_index in [10, 203, 500, 900, 8003]:
  translate_train(seq_index)
  print("-"*50)
# Out:
# Input: 아직 도 그대 를 못 잊 고 많 은 날 들 이 갔 어도 뜬 구름 같 은 기억 이 내게는 전부 였을 때 그 날 들 은 가 고 없 지만 기억 들 은 너무 짙 어 타 들 어 가 는 깊 은 밤 그 댈 꿈 속 에서 라도 만날 수 있 었 으면 하 고 나 는 기다려 사랑 그대로 를 떠올리 다가 문득 그대 가 내게 했 던 말 우린 너무나 달라 간 주 곡 그 아름다웠 던 시간 도 잊 지 못 할 그 하루 도 그림자 처럼 작아져 빛 을 잃 고 헤 메일 때 떠날 수 있 었 으면 하 고 나 는 후회 해 이 별 그 한마디 를 지워 버리 고 사랑 우리 가 주 고 받 던 말 우린 너무나 달라 사랑 이 아니 라고 하 면 나 는 좋 겠 다 혼자 라는 것 이 나 는 좋 겠 다 우리 서로 더 간절 했 던 말 우린 너무나 달라 우린 너무나 달라 우린 너무나 달라 우린 너무나 달라 우린 너무나 달라 우린 너무나 달라
# Right translation : <sos> 우린 너무나 달라
# Predicted translation:  <eos>
# --------------------------------------------------
# Input: 주 님 은 작은이 들 을 지키 시 는 분 가 여운 나 를 구해 주 셨 네 주 님 은 작은이 들 을 지키 시 는 분 가 여운 나 를 구해 주 셨 네 제 눈 에서 눈물 을 거두 시 고 제 발길 을 지켜 주 셨 네 애원 하 는 내 기도 들 어 주 셨 네 주 님 께 의지 하 리라 주 님 은 들 의 풀꽃 도 살피 시 는 분 자비 의 비 를 내려 주 시 네 높 은 데 서 나 를 끌어 올리 시 고 깊 은 물 에서 건져 주 셨 네 흔들리 는 내 영혼 잡 아 주 셨 네 주 님 께 감사 하 리라 주 님 은 들 의 풀꽃 도 살피 시 는 분 자비 의 비 를 내려 주 시 네 자비 의 비 를 내려 주 시 네
# Right translation : 은 이 들 을 지키 시 는 분
# Predicted translation:  나 의 <eos>
# --------------------------------------------------
# Input: 한 걸음 도 뗄 수 가 없 어 멍하니 떠나 는 너 의 뒷모습 만 바라볼 수 밖 에 없 는 내 자신 이 너무 초 라 해져 뒤돌 아 봐요 난 여기 서 있 을 게 그대 가 돌아올 수 있 게 너무 멀리 가지 는 말 아요 너무 빨리 내게서 멀 어 지 진 마 요 아주 잠시 발걸음 을 멈춰 나 를 돌 아 봐요 나 여기 서 꼭 기다릴게요 사랑 했잖아 왜 이 래야 만하 죠 어떻게 이럴 수 있 나요 너무 멀리 가지 는 말 아요 너무 빨리 내게서 멀 어 지 진 마 요 아주 잠시 발걸음 을 멈춰 나 를 돌 아 봐요 나 여기 서 꼭 기다릴게요 이대로 나 를 떠나 간다 면 그대 도 나 만큼 아플 지도 몰라 너무 멀리 가지 는 말 아요 너무 빨리 내게서 멀 어 지 진 마 요 아주 잠시 발걸음 을 멈춰 나 를 돌 아 봐요 나 여기 서 꼭 기다릴 게요
# Right translation : <sos> 너무 멀리 가지 는 말 아 요
# Predicted translation:  나 이 <eos>
# --------------------------------------------------
# Input: 니 가 변했 단 걸 알 아 굳이 말 안 해도 다 알 아 니 표정 니 행동 하나 하나 누구 보다 더 내 가 잘 알 아 마치 남 처럼 날 차갑 게 대해 날 왜 전 엔 하나 밖에 없 는 운명 처럼 나 를 안 고 또 안 아 또 매일 세상 에서 가장 소 중 한 것 처럼 다 줄 것 처럼 줄 것 처럼 그럼 뭐 해 으로 시작 한 날 향 한 맘 이 왜 이 젠 도 남 지 않 은 맘 보이 는 니 가 외로워 보여 끝 이 보여 난 더 커져 만 가 는데 내 가 안 보여 그래 보여 이제 어떡 하 는데 욕 만 나와 이기심 에 날 괴롭히 는 널 보 면 그래 시간 지나 추억 될 거래 다 거짓말 을 해 지난 니 가 남긴 상처 들 이 넌 왜 어딜 가 서 가끔 너 의 얘기 를 해 내 가 많이 힘들 것 만 같 대 사람 들 은 나 보고 만나 지 말 래 그럼 뭐 해 으로 시작 한 날 향 한 맘 이 왜 이 젠 도 남 지 않 은 맘 보이 는 니 가 외로워 보여 끝 이 보여 난 더 커져 만 가 는데 내 가 안 보여 그래 보여 이제 어떡 하 는데 더 이상 내 가 짜증 내 도 너 는 아무렇 지 않 아 다 환상 이 란 착각 을 해 어리석 은 내 모습 때론 구차 하 게 유치 하 게 보여 니 가 내게 그냥 그저 옛날 처럼 돌아와 주 기 만 그럼 뭐 해 으로 시작 한 날 향 한 맘 이 왜 이 젠 도 남 지 않 은 맘 보이 는 니 가 외로워 보여 끝 이 보여 난 더 커져 만 가 는데 내 가 안 보여 그래 보여 이제 어떡 하 는데
# Right translation : <sos> 그럼 뭐 해
# Predicted translation:  나 의 <eos>
# --------------------------------------------------
# Input: 어릴 적 내겐 큰 꿈 이 있 었 지 전장 을 이 끄 는 영웅 이 되 는 꿈 굴복 하 지 않 고 당당 하 게 맞서 승리 의 영광 을 누리 는 꿈 어른 이 된 오늘 내게 세상 이 란 곳 어릴 적 그리 던 꿈속 전쟁 터 구나 그 속 에서 나 는 다시 영웅 이 되 려 선포 한다 작전 명 청춘 비틀비틀 넘어갈 듯 하루하루 가 흘러갔 지만 결코 쓰러지 진 않 을 테 니 난 문제 없 어 거칠 게 몰아치 는 폭풍우 에 꿋꿋 이 견디 고는 있 지만 제 자릴 맴 도 는 기분 난 문제 없 어 어른 이 된 오늘 내게 세상 이 란 곳 어릴 적 그리 던 꿈속 전쟁 터 구나 그 속 에서 나 는 다시 영웅 이 되 려 선포 한다 작전 명 청춘 오늘 밤 우리 는 내일 부를 노랠 짓 네 친구 야 내일 도 함께 부르 자 우리 는 청춘 비 와 바람 천둥 에 소리 를 이겨 춤 을 추 겠 네 불어오 는 바람 앞 에 불꽃 들 이여 우린 모두 타오르 는 젊음 이 기 에 흔들릴 수 있 어 그래 무너질 수 있 어 일어나 라 작전 명 청춘 나 의 젊 은 날
# Right translation : <sos> 작전 명 청 춘
# Predicted translation:  <eos>
# --------------------------------------------------

# %%
def translate_test(seq_index):
  input_seq = encoder_input_test[seq_index: seq_index + 1]

  sentence = seq_to_src(encoder_input_test[seq_index]).strip()
  _, result, attention_plot = decode_sequence(sentence)

  print('Input: %s' % (sentence))
  print("Right translation :",seq_to_tar(decoder_input_train[seq_index]))
  print('Predicted translation: {}'.format(result))

  #attention_plot = attention_plot[:len(result.split(' '))-2, :len(sentence.split(' '))]
  #plot_attention(attention_plot, sentence.split(' '), result.split(' '))

# %%
for seq_index in [10, 200, 303, 1005]:
  translate_test(seq_index)
  print("-"*50)
# Out:
# Input: 당신 은 비타민 나 는 나 는 사이다 인생 살 다 보 면 음지 양지 있 지요 인생 세모 네모 힘 들 기 만 하 지요 동그라미 그리고 살아요 손 을 들 어 박수 치 면 만 병 통치 약 한 번 두 번 세 번 치 면 엔 돌핀 돌 죠 당신 은 비타민 나 는 나 는 사이다 웃 으면 복 이 와요 몸 도 맘 도 즐거워 당신 있 기 에 행복 합니다
# Right translation : <sos> 우린 너무나 달라
# Predicted translation:  사랑 의 <eos>
# --------------------------------------------------
# Input: 예수 님 을 만나 고 내 안 에 예수 님 주 신 새 생명 새 생명 이 나 에게 힘 되 어 죄 를 이길 능력 이 되 었 죠 얍 믿음 의 파워 쓩 챙 죄 와 싸워서 승리 해 모두 다 함께 외쳐요 준비 믿음 장전 발사 예 새 생명 파워 예수 님 내 게 주 신 새 생명 새 생명 파워 모든 죄 를 이기 는 믿음 의 파워
# Right translation : 는 이상 한 이야기 속 으로 가 네
# Predicted translation:  나 의 <eos>
# --------------------------------------------------
# Input: 무심코 지나 온 모든 길 을 주 님 께서 늘 인도 하 셨 네 내 주 님 날 받 아 주 소서 살아온 많 은 날 들 의 흔적 들 이 왜 그렇게 나 를 다그쳤 는지 바람 에 흘러가 듯 모든 것 들 은 헛된 꿈 이 되 어 버렸 고 어느 날 찾아온 주 님 의 은혜 가 마음 깊숙히 뿌릴 내리 고 믿음 의 소망 을 내게 허락 하 시 니 그 나라 소망 을 꿈꾸 네 무심코 지나 온 모든 길 을 주 님 께서 늘 인도 하 셨 네 영원 한 그 나라 향 하 는 연약 한 걸음 늘 지켜 주 소서 나 찬양 하 네 이 세상 끝 날 까지 도우 시 는 큰 은혜 안 에서 영원 한 그 나라 향 한 소망 을 꿈꾸 며 내 마음 주 님 께 드리 네 내 주 님 날 받 아 주 소서 귀하 신 십자가 의 그 사랑 영원 토록 나 찬양 하 리라 내 소망 나 의 위로 되 시 는 그 크 신 사랑 나 감사 하 리라 무심코 지 나 온 모든 길 을 주 님 께서 늘 인도 하 셨 네 영원 한 그 나라 향 하 는 연약 한 걸음 늘 지켜 주 소서 내 주 님 날 받 아 주 소서
# Right translation : <sos> 비 그리고 나
# Predicted translation:  나 이 <eos>
# --------------------------------------------------
# Input: 오늘 밤 그대 와 하늘하늘 걷 고 있 어 오늘 밤 그대 는 저 별빛 처럼 반짝 거려 오늘 밤 그대 는 나 의 마음 을 흔들 고 오늘 밤 그대 는 이 공간 에서 제일 아름다워 나 만 의 그대 여 그대 의 맘 을 뺏 을 수 는 없 나요 나 만 의 그대 여 그대 와 평생 함께 할 순 없 나요 오늘 밤 우리 평생토록 함께 한다 약속 해 주 면 아무 것 도 난 바라 지 않 아요 오늘 밤 그대 와 하늘하늘 걷 고 있 어 오늘 밤 그대 는 저 꽃잎 처럼 향기 로워 오늘 밤 그대 는 저기 빛나 는 달 이 고 오늘 밤 난 그대 를 포근히 안 아 줄 흰 구름 이 죠 나 만 의 그대 여 그대 의 맘 을 뺏 을 수 는 없 나요 나 만 의 그대 여 그대 와 평생 함께 할 순 없 나요 오늘 밤 우리 평생토록 함께 한다 약속 해 주 면 아무 것 도 난 바라 지 않 아요 그대 또 날 바라보 는 눈빛 이 뒤 에 있 는 가로등 보다 빛나 숨 이 막혀 나 만 의 그대 여 그대 의 맘 을 뺏 을 수 는 없 나요 나 만 의 그대 여 그대 와 평생 함께 할 순 없 나요 오늘 밤 우리 평생토록 함께 한다 약속 해 주 면 아무 것 도 난 바라 지 않 아요
# Right translation : <sos> 우산 같이 쓸까요
# Predicted translation:  나 의 <eos>
# --------------------------------------------------

# %% [markdown]
# ### Reference
#
# - https://blog.keras.io/a-ten-minute-introduction-to-sequence-to-sequence-learning-in-keras.html
# - https://wikidocs.net/86900
# - https://www.tensorflow.org/tutorials/text/nmt_with_attention?hl=ko#%ED%9B%88%EB%A0%A8%EB%90%9C_%EB%AA%A8%EB%8D%B8%EB%A1%9C_%EB%B2%88%EC%97%AD%ED%95%98%EA%B8%B0

# %% [markdown]
# # test

# %%
len(encoder_input_test)
# Out:
# 11233

# %%
import numpy as np

a = np.random.randint(100, size=1000)

# %%
for seq_index in a:
  translate_test(seq_index)
  print("-"*50,seq_index)
# Out:
# Input: 그 언젠가 별빛 에 새긴 추억 하나 가 바람 에 두 고 온 너 의 이름 을 불러와 너 의 이름 은 떠올리 기 만 해도 참 아파 아주 멀리 멀 어 진 기억 그 계절 이 또 다시 불어와 너 는 어떤지 이런 바람 이 불 면 가끔 내 가 생각나 는지 저 어딘가 노을 에 비친 추억 하나 가 그날 에 두 고 온 너 의 이름 을 불러와 너 의 이름 은 떠올리 기 만 해도 참 아파 아주 멀리 멀 어 진 기억 그 계절 이 또 다시 불어와 너 는 어떤지 이런 바람 이 불 면 가끔 내 가 생각나 는지 한참 동안 을 멀 어 진 그 날 을 다 잊 었 다고 다 잊 은 거 라고 생각 했 는데 아주 멀리 잊혀진 기억 그 계절 이 또 너 를 불러와 너 는 어떤지 오늘 같 은 밤 이 면 가끔 내 가 생각나 는지
# Right translation : <sos> 꿈 이 뛰 고 있 어요
# Predicted translation:  사랑 의 <eos>
# -------------------------------------------------- 56
# Input: 오늘 따라 많 은 여자 들 이 보여 눈 마주치 기 싫 어 색안경 을 끼 고 왔 어 사진 을 찍 을 땐 엄지 를 꽉 꼬집 는 모양 이분 들 에게 는 우리 가 그림 의 떡 일 꺼야 한때 는 내 속 에 만 볼 수 있 던 존재 였 던 너 가 이 밤 에 는 나 를 마주 보내 결론 우리 의 만남 은 단지 시간 의 문제 였 던 우리 의 운명 은 난 너 의 기둥 기분 이 돼 생각 만 해도 찡 해 한잔 씩 마셔 볼까 이 귀한 입술 몇 년 째 아껴 온 이유 해롱해롱 과연 술 에 취한 걸까 틱 대 도 왜 애교 로 느껴 지 는 걸까 떨어져 있 어도 어찌 함께 있 는 것 만 같 아 근데 이 이야긴 우리 연애 의 한편 일 뿐 한 올 나 도 그래 항상 널 원해 이 맘 다 널 위 한 거 야 너 만 있 으면 돼 그래 우리 둘 이 면 돼 요새 멀 고 도 가깝 게 느끼 는 너 의 품 내 귓가 에 맴 도 는 네 숨소리 간절 해진 우리 둘 의 만루 상황 인데 홈런 을 칠 때 된 것 같 아 여행 갈까 해서 이 시간 에 연락 했 어 이 큰 도시 도 지루 해져 벗어날 때 됐 어 지도 를 펼쳐 눈 을 감 고 찍 어 굳건 해진 우리 사인 마치 봄 에 장미 같 아 노 을 진 바다 앞 에 내게 기대 는 모습 이 마치 우리 에 미래 처럼 내 가 널 지켜줄 테 니 믿 긴 힘들 겠 지 부자 아닌 오직 래퍼 인데 계절 이 계속 변해도 우리 는 버텨 나가 겠 지 시간 이 계속 흘러도 우린 여전 하 겠 지 서로 를 놓 지 않 다면 한 올 나 도 그래 항상 널 원해 이 맘 다 널 위 한 거 야 너 만 있 으면 돼 그래 우리 둘 이 면 돼 한 올 기억 해 우리 함께 보낸 시간 아쉬움 이 많 았 던 집 으로 가 는 길 에 널 보내 고 혼자 보낸 시간 뒤 에 온종일 내 곁 에 네 가 있 어 한 올 기억 이 나 네 너 와 함께 보낸 날 위해 눈물 을 흘렸 던 그대 그때 왜 달리 한 올 나 도 그래 항상 널 원해 이 맘 다 널 위 한 거 야 너 만 있 으면 돼 그래 우리 둘 이 면 돼 한 올 기억 이 나 네 그대 함께 보낸 우리 연애 의 한편
# Right translation : <sos> 어떤 냄새
# Predicted translation:  <eos>
# -------------------------------------------------- 17
# Input: 시간 이 돌아가 네 바쁘 게 바쁘 게 바쁘 게 빨리 도 돌아가 네 겨우 일 끝냈 는데 할 일 을 또 던져 주 네 일복 많 은 나 는 전생 에 소 였 나 보 네 째깍 시간 이 멈춰 있 네 이런 하루 일 만 하 면 멈춰져 있 네 거꾸로 매달 아도 시간 가 는데 군대 갔 던 내 동생 도 예비군 인데 하루 이런 된장 야근 이 네 이 젠 더 이상 물러서 다가 늦 은 후회 다신 하 면 안 돼요 꿈 이 많 던 그때 처럼 끝 을 향 해 다시 시작 해 미친 듯이 달려 알 수 없 는 이끌 림 에 다시 올라타 세상 속 을 달려 오늘 밤 그건 너 의 또한 나 의 이 니까 시간 세상 이 달려가 네 나 는 이렇게 세상 을 배워 가 네 옆 에 있 던 입사 동기 승진 하 는데 나 는 찌그러져 로또 만 긁 네 하루 허구 한 날 물 만 먹 었 네 이 젠 더 이상 물러서 다가 늦 은 후회 다신 하 면 안 돼요 꿈 이 많 던 그때 처럼 끝 을 향 해 다시 시작 해 미친 듯이 달려 알 수 없 는 이끌 림 에 다시 올라타 세상 속 을 달려 오늘 밤 그건 너 의 또한 나 의 이 니까 세상 은 롤러코스터 오늘 도 올라 타 네 슈웅 잘 났 다고 뽐내 지 않 기 잘 했 다고 칭찬 도 하 기 한 입 으로 딴 소리 하 기 없 기 미친 듯이 달려 알 수 없 는 이끌 림 에 다시 올라타 세상 속 을 달려 오늘 밤 그건 너 의 또한 나 의 이 니까 미친 듯이 달려 알 수 없 는 이끌 림 에 다시 올라타 세상 속 을 달려 오늘 밤 그건 너 의 또한 나 의 이 니까
# Right translation : <sos> 웃 는 게 좋 아요
# Predicted translation:  나 <eos>
# -------------------------------------------------- 16
# Input: 부엉 밤 이 깊 어 가 도 나 는 잠들 지 않 아 부엉 부 부엉 깊 은 밤 을 지키 는 갈색 부엉이 아홉 시 열 한 시 자정 넘 어 아침 까지 동그란 두 눈 은 절대로 감기 지 않 아 나 는 졸리 지 않 아 부엉 밤 이 깊 어 가 도 나 는 잠들 지 않 아 부엉 부 부엉 깊 은 밤 을 지키 는 갈색 부엉이 고고 한 갈색 깃털 노란색 깊 은 두 눈 귀엽 게 보이 지만 용감 하 게 밤 을 지키 죠 나 는 잠들 지 않 아 부엉 밤 이 깊 어 가 도 나 는 잠들 지 않 아 부엉 부 부엉 깊 은 밤 을 지키 는 갈색 부엉이 잠 이 안 오 면 날 찾아와요 부엉
# Right translation : <sos> 고백 해 본다
# Predicted translation:  <eos>
# -------------------------------------------------- 38
# Input: 쉿 조용히 들 어 보 아요 활짝 마음 의 문 을 열 고 주 님 내게 하 시 는 말씀 그 말씀 따라 살아요 주 님 과 나 만 의 비밀 이야기 날 사랑 하 신다는 이야기 오늘 도 주 님 의 말씀 따라 하루 를 시작 해 요
# Right translation : <sos> 추억 이 너무 없 어
# Predicted translation:  <eos>
# -------------------------------------------------- 99
# Input: 그날 떠난 후 에 도 아직 널 생각 하 고 수 없 는 기억 속 에 내 마음 외로워 무엇 을 생각 하 며 너 는 홀로 갔 는가 차가운 바람 따라 슬픔 이 흩어지 네 긴 머리 쓰다듬 던 손끝 이 정 다 워 서 널 보 고 웃음 짓 던 내 마음 을 알 고 있 나 꿈길 깊 은 곳 에 나 의 길 이 있 으니 너 를 위해 기원 하 며 이제 나 는 떠나 리라 긴 머리 쓰다듬 던 손끝 이 정 다 워 서 널 보 고 웃음 짓 던 내 마음 을 알 고 있 나 꿈길 깊 은 곳 에 나 의 길 이 있 으니 너 를 위해 기원 하 며 이제 나 는 떠나 리라 이제 나 는 떠나 리라 이제 나 는 떠나 리라
# Right translation : <sos> 너희 를 사랑 한다
# Predicted translation:  <eos>
# -------------------------------------------------- 46
# Input: 시간 이 흐른 만큼 조금 씩 좋 아 지 다 기다린 시간 만큼 한 뼘 씩 좋 아 진다 눈앞 에 보이 는 게 전부 는 아니 듯이 지금 의 내 모습 도 전부 는 아니 지 가끔 은 힘 이 들 고 소심 해 지 고 두렵 단 생각 이 들 고 끝 까지 갈 수 있 나 걱정 되 지만 한 순간 그때 뿐 이 야 워 처음 느낌 처럼 좋 아서 하 는 거 지 조금 씩 좋 아 지 다 한 뼘 씩 좋 아 진다 시간 이 흐른 만큼 조금 씩 좋 아 지 다 기다린 시간 만큼 한 뼘 씩 좋 아 진다 나 만 의 감성 으로 나 만 의 느낌 으로 나 만 의 언어 로 이렇게 말 한다 처음 에 노래 할 때 설레 던 마음 나 만 이 아 는 그 약속 갈수록 힘 이 들 고 어렵 겠 지만 그 약속 잊 지 않 기 를 워 처음 느낌 처럼 좋 아서 하 는 거 지 조금 씩 좋 아 지 다 한 뼘 씩 좋 아 진다 처음 느낌 처럼 좋 아서 하 는 거 지 조금 씩 좋 아 지 다 한 뼘 씩 좋 아 진다 한 뼘 씩 좋 아 진다 한 뼘 씩 좋 아 진다
# Right translation : <sos> 무 탈
# Predicted translation:  나 <eos>
# -------------------------------------------------- 86
# Input: 곁 에 내 가 있 어 힘들 게 보낸 날 은 잊 어요 그대 만 위 한 맘 에 지내 면 나 는 힘들 고 아파도 괜찮 아 그대 만 행복 하 면 이 젠 내게 없이 살 아도 이 젠 괜찮 아요 그대 날 다 잊 어도 그녀 를 위 한 맘 에 그대 행복 하 면 모두 잊 은 채 로 이제 나 만 위 한 맘 에 그저 행복 하 기 만 할 수 있 어요 다시 찾 은 그대 사랑 에 힘든 일 은 없 기 를 내 다른 사랑 위 한 마음 만 원한 기도 만 하 고 난 지냈 지만 그 댈 잊 지 못 하 는 내 맘 찾 아 다시 돌아오 길 또 바라 고 있 죠 이 젠 괜찮 다고 혼자 말 해 보 지만 그대 하 고 있 는 다른 그 사랑 에 괜 한 내 마음 만 다쳐 더 힘든 날 보 는 날 위 하 는 이 사람 아프 게 할 순 없 어 또 그 댈 원해 보 는 내 욕심 만 키우 기 만 하 는 날 용서 할 자신 도 난 버리 고 날 이 젠 너 를 잊 게 기도 해 이 젠 괜찮 아요 그대 날 다 잊 어도 그녀 를 위 한 맘 에 그대 행복 하 면 모두 잊 은 채 로 이제 나 만 위 한 맘 에 그저 행복 할게요 그대 만 좋 다면 반복 이 젠 괜찮 아요
# Right translation : 이불 을 박차 고 일어나 도 소용없 어
# Predicted translation:  사랑 의 <eos>
# -------------------------------------------------- 8
# Input: 나 는 쓰러지 고 나 서 야 비로소 바람 의 노래 를 부르 네 다시 일어설 수 없 을 때 일어서 서 오만 했 던 자신 을 돌아보 네 용서 해 다 오 그러나 내 주위 엔 아무 도 없 네 다시 는 차오를 수 없 는 빈 몸 의 흐 느낌 그것 이 바람 의 노래 다 쓰러지 고 나 서 야 비로소 나 는 바람 의 노래 를 부르 네
# Right translation : <sos> 사랑 하 는 책
# Predicted translation:  나 의 <eos>
# -------------------------------------------------- 41
# Input: 나 는 그대 곁 에 있 음 에 항상 감사 하 며 지내 요 나 그대 곁 에 있 음 에 마음 평 안 해 요 당신 얼굴 바라볼 때 면 마음 이 행복 해 지 네요 내 가 곁 에 있 음 을 잊 지 마 요 그대 지켜 줄 게 요 사랑 그 하나 면 돼요 당신 위해 발 로 뛰 는 일 마음 이 불안 할 땐 쉬 어도 돼요 때 로 는 내려놓 아요 오늘 살아가 는 이유 는 당신 회복 을 위함 인 걸 요 나 그대 곁 에 있 음 에 마음 평안 해 요 당신 얼굴 바라볼 때 면 마음 이 행복 해 지 네요 내 가 곁 에 있 음 을 잊 지 마 요 그대 지켜 줄게요 가끔 힘 이 들 때 도 마음 아파 할 때 도 우린 할 수 있 어요 온 마음 다 해 바 래 요 그대 는 항상 나 의 힘 이 죠 내 가 당신 을 지켜 준다면 내 가 곁 에 있 음 을 잊 지 마 요 내 가 그대 지켜 줄 게 요 사랑 그 하나 면 돼요 당신 위해 발 로 뛰 는 일 마음 이 불안 할 땐 쉬 어도 돼요 때 로 는 내려놓 아요 항상 함께 있 어 줄 게요
# Right translation : <sos> 대박 대한민국
# Predicted translation:  나 의 <eos>
# -------------------------------------------------- 7
# Input: 나 어쩌면 이별 을 감지 했었 나 헤어지 기 싫 으면서 헤어지 길 바랬 었 나 그날 아침 에 보인 친절 함 들 은 새롭 게 마음먹 었 던 널 향 한 다짐 이 었 네 잘 하 려 했 는데 잘 대해 주 려고 잘 표현 하 려고 사랑 을 너 가 고 나 서 야 나 공부 를 했 어 이별 하 기 너 잘 알려 주 려고 그렇게 갔 나 봐 내 곁 에서
# Right translation : <sos> 널 향해 있 는 사랑
# Predicted translation:  나 의 <eos>
# -------------------------------------------------- 62
# Input: 한 여름 에 목도 릴 선물 받 은 기분 일까 요 비슷 할까 요 준다고 준 마음 이 이 것 밖에 안 되 는 걸 요 그대 에게 난 나 에게 는 용기 라 부르 겠 지만 그대 에게 는 부담 이 라 불리 겠 죠 그 댄 나 에게 한 여름 그늘 이 지만 난 그대 에게 한 겨울 바람 이 겠 죠 다 버리 고 남 은 맘 이렇게 나 많 은 걸 보 니 꽤 깊 었 나 봐요 나 에게 는 용기 라 부르 겠 지만 그대 에게 는 부담 이 라 불리 겠 죠 그 댄 나 에게 한 여름 그늘 이 지만 난 그대 에게 한 겨울 바람 이 겠 죠 보 고 싶 어요 내 이름 환히 부르 며 날 찾 아 주 는 그대 의 손짓 한 여름 에 목도 릴 선물 받 은 기분 일까 요 그런 거 겠 죠
# Right translation : <sos> 세상 을 마주 하 는 방법
# Predicted translation:  <eos>
# -------------------------------------------------- 77
# Input: 항상 웃음 가득 했 던 너 인데 요즘 은 달라졌 어 혹시 나 힘든 일 이 생긴 거 니 내 게 살짝 말 해 봐 걱정 말 라며 날 다독여 주 는 너 왜 아무렇 지 않 은 척 해 그럴 필요 없 어 내 가 왜 있 는데 나 는 니 편이 잖 아 부족 하 고 약한 나 지만 너 에게 나 힘 이 된다면 무엇 이 라도 하 고 싶 어 이 젠 누구 보다 강한 널 알 아 하 지만 니 가 힘들 때 면 가끔 은 넌 내게 기대 도 돼 항상 넓 기 만 했 던 니 어깨 가 어쩐지 힘 이 없 어 내 가 힘 이 될 수 있 는 게 있 을까 뭐 든지 해 주 고 싶 어 약속 했 었잖 아 모두 가 변해도 나 는 니 편 이 라고 부족 하 고 약한 나 지만 너 에게 나 힘 이 된다면 무엇 이 라도 하 고 싶 어 이 젠 누구 보다 강한 널 알 아 하 지만 니 가 힘들 때 면 가끔 은 넌 내게 기대 도 돼 내 가 아프 고 힘들 때 도 언제나 곁 에 있 어 준 너 이 젠 내 가 더 힘 이 돼 줄 게
# Right translation : <sos> 자동기술법
# Predicted translation:  <eos>
# -------------------------------------------------- 52
# Input: 사랑 이 란 게 원래 시간 이 지날수록 설레임 보다 는 편안 함 이 자릴 잡 나요 설레임 이 없 는 사랑 편안 함 만 남 은 사랑 도대체 뭐 냐고 물 어 보 면 그대 여 오늘 내 가 말 해 줄 게 그 댈 향 한 나 의 사랑 은 말 로 표현 할 수 없 는 사랑 허나 말 해 줘야 한다면 들 어 봐요 허어 그녀 가 곁 에 없 다면 그대 가 곁 에 없 다면 코끝 이 시려 지 는 게 그대 는 영원 한 사람 떨어져 있 어도 난 너 를 이해 하 고 믿 어 주 며 영원히 널 닮 아 가 며 너 만 을 사랑 해야지 그 댈 향 한 나 의 사랑 은 말 로 표현 할 수 없 는 사랑 허나 말 해 줘야 한다면 들 어 봐요 하아 그대 가 곁 에 없 다면 그녀 가 곁 에 없 다면 코끝 이 시려 지 는 게 그대 는 영원 한 사람 떨어져 있 어도 난 너 를 이해 하 고 믿 어 주 며 영원히 널 닮 아 가 며 너 만 을 사랑 해야지 설레임 이 없 는 사랑 편안 함 만 남 은 사랑 도대체 뭐 냐고 물 어 보 면 그대 여 오늘 내 가 말 해 줄 게 한 번 밖에 없 는 사랑 영원 함 만 남 은 사랑 그대 가 뭐 냐고 물 어 보 면 그 때 는 오늘 내 가 말 해 줄 게
# Right translation : <sos> 지 않 는 별
# Predicted translation:  사랑 의 <eos>
# -------------------------------------------------- 83
# Input: 여름 이 오 는 소리 에 넌 체중 계 를 꺼냈 어 해 마다 오 는 이벤트 라 대수롭 지 않 았 어 사실 난 지금 의 네 가 너무나 도 좋 은데 왜 너 만 몰라 왜 또 이러 는 걸까 그만 우울 한 표정 은 접 고 나와 맛있 는 것 들 을 해치우 자 널 기다리 는 이 식탁 을 외면 하 지 마 당신 의 도 사라지 지 않 게 해줘 당신 의 도 내겐 너무 소 중 해서 빛나 는 그대 가 이대로 영원히 남 아 주 기 를 변하 지 않 기 를 바 래 요 자꾸 만 네 가 기다려 지 는 밤 통화 너 를 설레 게 하 는 것 들 이 가득 한 이 밤 포기 하 면 편해질 거 야 당신 의 도 사라지 지 않 게 해줘 당신 의 도 내겐 너무 소 중 해서 빛나 는 그대 가 이대로 영원히 남 아 주 기 를 변하 지 않 기 를 바 래 요 영원 한 건 없 단 걸 그 누구 보다 잘 알 지만 내 가 너 를 사랑 하 는 단 하나 의 이유 도 달라지 지 않 기 를 바 래 당신 의 도 사라지 지 않 게 해줘 당신 의 도 내겐 너무 소 중 해서 빛나 는 그대 가 이대로 영원히 남 아 주 기 를 변하 지 않 기 를 바 래 요
# Right translation : <sos> 어떻게 그렇게 이렇 게
# Predicted translation:  <eos>
# -------------------------------------------------- 13
# Input: 아무 도 모를 거 야 어젯밤 뒤척 이 며 잠들 지 못 한 채 로 멈출 줄 모르 던 눈물 아무렇 지 않 은 척 살아가 는 게 난 너무 익숙 해 아무렇 지 않 은 척 웃 고 있 는 게 너무 쓸쓸 해질 때 내 앞 에 있 는 너 의 미소 가 너무 낯설 어 질 때 어젯밤 먼저 잠든 너 몰래 흘리 던 눈물 만 자꾸 생각 이나 아무 도 모를 거 야 어젯밤 뒤척 이 며 잠들 지 못 한 채 로 멈출 줄 모르 던 눈물 아무렇 지 않 은 척 살아가 는 게 난 너무 익숙 해 아무렇 지 않 은 척 웃 고 있 는 게 너무 쓸쓸 해질 때 내 앞 에 있 는 너 의 미소 가 너무 낯설 어 질 때 어젯밤 먼저 잠든 너 몰래 흘리 던 눈물 만 자꾸 생각 이나 생각 이 나 생각 이 나 생각 이 나 생각 이 나 생각 이 나 생각 이 나 생각 이 나 내 앞 에 있 는 너 의 미소 가 너무 낯설 어 질 때 어젯밤 먼저 잠든 너 몰래 흘리 던 눈물 만 자꾸 생각 이나
# Right translation : <sos> 하루 종일 널
# Predicted translation:  나 <eos>
# -------------------------------------------------- 29
# Input: 잠깐 그대 는 내 맘 속 서랍 에 닫 아 놓 고 나 의 시간 을 살 아 갈께요 아름답 게 내린 축복 같 은 눈빛 사이 로 흘러가 는 여름밤 따 뜻 했 던 외로움 도 멈추 고 라 닿 을 수 없 는 마음 의 달빛 의 바다 바람 같 은 우리 의 박제 된 시간 얼마나 기다려야 흘러갈 런 지 그대 눈길 에 다 이해 됐었 던 그 때 그 맘 으로 내일 을 살 아 갈께요 보이 지 않 아도 두 눈 에 보이 는 것 처럼 나 들리 지 않 아도 귓가 에 울려오 는 것 처럼 라 닿 을 수 없 는 마음 의 달빛 의 바다 바람 같 은 우리 의 박제 된 시간 얼마나 흘러 다시 흘러갈 런 지
# Right translation : <sos> 갈 생각 있 어
# Predicted translation:  나 의 <eos>
# -------------------------------------------------- 51
# Input: 쉿 조용히 들 어 보 아요 활짝 마음 의 문 을 열 고 주 님 내게 하 시 는 말씀 그 말씀 따라 살아요 주 님 과 나 만 의 비밀 이야기 날 사랑 하 신다는 이야기 오늘 도 주 님 의 말씀 따라 하루 를 시작 해 요
# Right translation : <sos> 추억 이 너무 없 어
# Predicted translation:  <eos>
# -------------------------------------------------- 99
# Input: 그녀 는 일루미나티 가 분명 해 내 마음 을 지배 하 려 하 니까 그녀 는 랩 틸 리언 분명 해 눈 도 크 고 입 도 크 니까 짧 고 많 은 인연 들 을 지나오 면서 다 부질없 다 생각 했 지만 너 를 보 고 나선 헤픈 내 맘 이 벌써 사랑 에 속 으려고 하나 봐 상상 하 지 밤새 언젠가 는 우리 둘 이 함께 삼각형 의 별 을 차 에 단 채 새로운 비밀결사 단체 차가운 네 눈 에 내 진심 은 가차 없이 살 해당 했 지 널 위해 서 아프 게 살 게 나 요즘 엔 야한 생각 도 안 해 그녀 는 일루미나티 가 분명 해 내 마음 을 지배 하 려 하 니까 그녀 는 랩 틸 리언 분명 해 눈 도 크 고 입 도 크 니까
# Right translation : <sos> 그리워 하 며
# Predicted translation:  <eos>
# -------------------------------------------------- 32
# Input: 맹세 해 난 무언가 가 있 다 믿 어 인간 이 기에 낼 수 있 는 의견 인류 의 기원 가모프 의 빅뱅 이론 운명 과 팔자 심지어 사소 한 혈액형 별자리 까지 도 그래 인간 의 머리 로 인간 의 논리 로 절대 설명 할 수 없 는 무언가 가 있 다 믿 어 난 무신론자 지만 믿 는 건 같 을지 도 근데 그걸 이용 하 려 하 는 인간 들 이 미워 죽음 그 두려움 에 대한 기도 아니 죽음 앞 에서 두렵 지 어 죽 은 뒤 에 지옥 인간 을 바치 며 기도 했 던 시절 거기 있 던 리더 는 진정 지원 자 로 나섰 을까 싶 어 이 것 또 한 인간 계 를 위 한 과연 그럼 그 는 누굴 구원 할 것 인가 광신도 살인자 와 무고 한 무신론자 인간 선택 해 봐 난 믿 어 내 자신 만 니 가 나와 다르 다면 내겐 말 을 걸 지 마 내겐 없 지 다음 삶 내겐 오직 오늘 만 나 는 무신론자 나 는 무신론자 나 는 무신론자 나 는 무신론자 믿음 을 강요 하 는 것 보다 폭력 적 인 행위 는 절대 없 다고 봐 성지 는 누구 의 힘 으로 지 어 졌 나 약자 들 의 피 눈물 로 붉 게 물들 어 가 모두 가 알 고 있 지 이건 공 공연 한 비밀 뭔가 에 의지 하 고 픈 약한 마음 을 노리 지 종교 로 인해 일어나 는 전쟁 그 들 이 바라 는 영생 의 역설 은 언 젠 간 밝혀 지 무엇 이 옳 고 그른 지 서로 의 기준 에 따라 살 기 를 두르 지 광신도 들 은 눈 에 핏대 를 세우 지 모든 수단 을 동원 해 휘두르 는 흉기 시대 에 따라 달라지 는 가르침 은 내겐 아무런 의미 를 주 지 못 해 니체 말 처럼 죽 었 지 신 은 줄어드 지 않 는 신음 늘어나 는 고통 이미 내 가 불 태워 버린 성전 난 믿 어 내 자신 만 니 가 나와 다르 다면 내겐 말 을 걸 지 마 내겐 없 지 다음 삶 내겐 오직 오늘 만 나 는 무신론자 나 는 무신론자 나 는 무신론자 나 는 무신론자
# Right translation : <sos> 주 의 은혜 라
# Predicted translation:  <eos>
# -------------------------------------------------- 3
# Input: 모든 사람 들 과 함께 한잔 을 걸치 고 돌아와 이렇게 네 게 편지 를 써 선뜻 내밀 어 줄 명함 도 번듯 한 직장 도 하나 없 지만 그렇 다고 끝 은 아니 지 너 못지않 은 내 가 있 잖아 어쨌든 나 니 가 좋 아 애절 한 너 의 그 포 근 함 이 언 젠 간 세상 도 우리 를 받 아 줄 날 이 있 을 거 야 오늘 도 예전 과 다름없이 이런 저런 수다 떨 고 추억 이 라 하 는 안주 에 우리 는 마음 흔들렸 구나 선뜻 내밀 어 줄 명함 도 번듯 한 직장 도 하나 없 지만 그렇 다고 끝 은 아니 지 너 못지않 은 내 가 있 잖아 어쨌든 나 니 가 좋 아 애절 한 너 의 그 포 근 함 이 언 젠 간 세상 도 우리 를 받 아 줄 날 이 있 을 거 야
# Right translation : <sos> 귀찮 아
# Predicted translation:  <eos>
# -------------------------------------------------- 58
# Input: 엄마 꼭 채워줄 게 루이비통 팔찌 내 가족 들 먹여 살리 려고 벌 지 사람 들 이 부르 길 아 빨 회장 님 근데 난 아직 어려서 잘 모르 지 그래도 난 달려왔 어 매일 같이 모두 닿 으면 난 그대로 번지 난 결국 멋지 게 살 아 내 겠 지 기다려 줬 음 에 난 결국 됐 지 아직 어린 나 를 생각 해 그 댄 더 많 을 일 을 겪 었 네 울 엄마 가 처음 날 봤 을 때 이뻐서 날 놓 을 수 없 었 때 햇 고마워 엄마 그대 가 없 더라면 여기 없 었 네 아직 도 그 자리 에 있 고 싶 지만 서 도 그럴 수 없 데 왜 따 뜻 했 던 기억 들 만 가득 해 그대 들 이 줬 던 추억 들 였 기 에 그걸 이 노래 의 가사 에 가 뒀 네 걱정 하지마 조만간 안동 갈 게 아무 도 못 믿 네 아직 도 여깄 네 앞 만 보 고 무조건 달려왔 기 에 깨달 았 어 내 가 매달 았 던 내 과거 아마 내 가 아빠 품 에 안 안겼 다면 평범 한 학교 가 서 평범히 살 아 당연히 엄마 가 원 하 는 대학 도 나와 과연 내 가 원 하 는 삶 일까 싶 다 죽 을 만큼 힘들 었 네 우리 가족 죽 을 만큼 일 했었 네 우리 가족 독자 아들 이 안 아 줘 안동 을 떠날 때 인사 도 못 했 네 우리 할매 내 가 다시 여기 돌아올 때 요강 이 호강 이 된다 크 게 소리쳤 네 난 미안 해 하 기 는 이르지 서울 에 와서 배고플 때 편의점 점 장 님 이 주 신 폐기 할매 생각나 서 박혔 지 쐐기 엄마 꼭 채워줄 게 루이비통 팔찌 내 가족 들 먹여 살리 려고 벌 지 사람 들 이 부르 길 아 빨 회장 님 근데 난 아직 어려서 잘 모르 지 그래도 난 달려왔 어 매일 같이 모두 닿 으면 난 그대로 번지 난 결국 멋지 게 살 아 내 겠 지 기다려 줬 음 에 난 결국 됐 지
# Right translation : <sos> 그 날 을 위해
# Predicted translation:  <eos>
# -------------------------------------------------- 19
# Input: 오 저기 버스 킹 하 네 이 노래 어서 들 어 봤 는데 뭐 여 튼 소개 를 하 네 발라드 할게요 저 원래 알 앤 비 국시 공부 만 하 다가 끝나 고 막상 취업 준비 불안 하 니 당 찬 여보 컬 얼굴 왠지 너무 힙합 같 잖아 안기 고 싶 어 져 투팍 도 잠깐 망설였 을 걸 난 너 를 닮 고 싶 어서 너 처럼 노래 불러 세상 에 모든 사랑 노래 를 네 가 저작 권 있 는 것 처럼 불러대 고 오오 맘껏 취해 서 흐느끼 네 한 이 느껴져 해 미세먼지 나쁨 이 라는 건 숨겨 도 되 겠 어 공연 이 끝나 면 친구 말 따 마 우린 급 이 다르 지만 난 안 급해 내 가 빠진 호수 들 은 물 이 넘쳐 유레카 외치 던 놈 들 많 아 우린 이웃 하 지 그럼 너 의 호수 를 알려줘 난 기본 없 는 놈 이 지만 배울 동기 도 없 었 는 걸 우리 가 확인 할 건 유머 코드 차키 를 올려 놓 고 고니 처럼 이 한 끗 에 억 을 태워도 건물 주 라도 너 같 은 여자 한텐 오히려 내 가 경쟁력 이 돼 넌 정의 할 수 없 는 것 들 에 대해 사랑 우정 행복 에 가치 를 올바르 게 추구 하 고 싶 어 해서 먹방 눕 방 가능 하 겠 어 오른손 왼손 엄지 검지 브이 칠 만들 어 사각형 거기 에 널 얼굴 을 담 는 건 얼굴 신경 이 칠 번 이 라서 가 아니 고 걍 너 가 예뻐 보이 네 오늘 유난히 도 내 박자 가 이상 한 데 좋 다고 느낀다면 우린 맞 아 이 노래 가 이상 하 게 끌린 다면 내 진심 은 통한 거 야 넌 자연 같이 통통 한 행동 과 그게 일치 하 는 품 같 은 언어 가 내게 상처 를 못 줘 내게 상처 를 못 줘 내 상처 씻겨져 사랑 으로 씻겨져 행동 으로 이어져 너 처럼 노래 불러 세상 에 모든 사랑 노래 를 네 가 저작 권 있 는 것 처럼 불러대 고 오오 맘껏 취해 서 흐느끼 네 한 이 느껴져 해 미세먼지 나쁨 이 라는 건 숨겨 도 되 겠 어 공연 이 끝나 면 친구 말 따 마 우린 급 이 다르 지만 난 안 급해
# Right translation : <sos> 놀라운 사람
# Predicted translation:  <eos>
# -------------------------------------------------- 55
# Input: 당신 이 웃 으면 온 세상 이 밝아졌 어요 당신 이 다가오 면 그 손 을 밀어 낼 수 가 없 었 죠 그만큼 나 의 모든 것 을 흔드 는 건 당신 뿐 이 에요 아직 도 기억 해 요 마지막 인사 를 그때 는 그 말 이 즐겁 게 만 들렸 는데 이렇게 그리운 말 인 줄 은 정말 몰랐 어요 일어나 웃 으며 인사 해 주 세요 어서 일어나 세요
# Right translation : <sos> 반짝이 는 마음 담 으면
# Predicted translation:  사랑 의 <eos>
# -------------------------------------------------- 94
# Input: 사랑 도둑 맞 으 신 분 넌 뭐 가 그리 잘나 서 내 맘 을 왜 이렇게 몰라 줘 널 위해 춤 을 춰 네 가 볼 때 까지 네 게 다 닿 을 때 까지 석 션 너 를 생각 하 며 하루 를 가슴 이 계속 뛰 어 완전 쿵쿵 네 게 빠져 버린 난 헤엄 쳐 도망치 다가 깊 은 곳 으로 허 우우 널 내게 뭐 냐고 묻 는다면 말 해 뭐 해 사랑 도둑 아무 말 도 없이 나타나 내 마음 을 모두 가져가 사랑 내게는 미 로 돌려줘 두 배 로 더 이상 외롭 지 는 않 게 네 가 없 는 밤 이 내겐 너무 나 도 길 어 평범 한 일상 에 내린 단비 휘파람 다가 갈수록 사랑 의 화면 은 닷지 휘파람 아무 말 도 마 바라 만 봐도 좋 잖아 난 또 우 쭈쭈 나 도 해 줘 지금 똑 딱 똑 쭈욱 들이켜 사랑 의 공기 를 사랑 하 고 싶 은 만큼 널 내게 뭐 냐고 묻 는다면 말 해 뭐 해 사랑 도둑 아무 말 도 없이 나타나 내 마음 을 모두 가져간 사랑 내게는 미 로 돌려줘 두 배 로 더 이상 외롭 지 는 않 게 네 가 없 는 밤 이 내겐 너무 나 도 길 어 거짓 된 환호 속 에 속 지 마 연극 이 꺼져도 널 지킬 테 니까 어떤 말 로 나 의 맘 을 표현 할 수 있 을까 아무 말 도 없이 나타나 내 마음 을 모두 가져간 사랑 내게는 미 로 돌려줘 두 배 로 더 이상 외롭 지 는 않 게 네 가 없 는 밤 이 내겐 너무 나 도 길 어 앵 콜 네 가 없 는 밤 이 내겐 너무 나 도 길 어
# Right translation : <sos> 토요일 은 밤 이 좋 아
# Predicted translation:  사랑 의 <eos>
# -------------------------------------------------- 90
# Input: 기억 하나 요 그대 웃음 그 목소리 까지 도 말 이 없 네요 그렇게 그대 마음 엔 나 는 더 없 네요 언제나 우리 가 걸 었 던 길 들 에 흩어진 말 은 지난 얘기 라도 뒤돌 아 보 게 돼요 사랑 은 떠나 도 그대 마음속 의 난 기억 될까 요 어떤 것 이 라도 난 기억 에 살 고 있 겠 죠 사랑 이란 너무 짧 아요 후회 되 는 난 그대 를 지워 가 는 날 살아갈 자신 없 는데 이별 이란 너무 길 어요 그 댄 느끼 나요 우리 를 꿈꾸 게 했 던 날 나 는 또 찾 겠 죠 기억 하나 요 그대 웃음 그 목소리 까지 도 마음 을 말 하 면 그대 귓가 에 도 들릴까 요 부 는 바람 에 도 나 는 눈물 이 나 요 그 댄 잊 었 나요 나 만 이렇게 혼자 걷 고 있 나요 아파한 시간 지나 결국 엔 그 댈 불러요 사랑 이란 너무 짧 아요 후회 되 는 난 그대 를 지워 가 는 날 살아갈 자신 없 는데 이별 이란 너무 길 어요 그 댄 느끼 나요 우리 를 꿈꾸 게 했 던 날 나 는 또 찾 아 눈부신 햇살 이 비추 어 주 던 나 의 마음 과 그대 마음 이 머물렀 던 기억 들 에 먼 시간 지나 모든 것 이 덮힌 다 해도 나 의 눈물 속 에 웃 고 있 을 그대 사랑 이란 너무 짧 아요 후회 되 는 난 그대 를 지워 가 는 날 살아갈 자신 없 는데 이별 이란 너무 길 어요 그 댄 느끼 나요 우리 를 꿈꾸 게 했 던 날 나 는 또 찾 겠 죠
# Right translation : <sos> 날지 못하 는 제비
# Predicted translation:  <eos>
# -------------------------------------------------- 36
# Input: 당신 이 웃 으면 온 세상 이 밝아졌 어요 당신 이 다가오 면 그 손 을 밀어 낼 수 가 없 었 죠 그만큼 나 의 모든 것 을 흔드 는 건 당신 뿐 이 에요 아직 도 기억 해 요 마지막 인사 를 그때 는 그 말 이 즐겁 게 만 들렸 는데 이렇게 그리운 말 인 줄 은 정말 몰랐 어요 일어나 웃 으며 인사 해 주 세요 어서 일어나 세요
# Right translation : <sos> 반짝이 는 마음 담 으면
# Predicted translation:  사랑 의 <eos>
# -------------------------------------------------- 94
# Input: 내 통장 에 비 온다 주룩주룩 주룩 디 룩 하늘 높 을 줄 모르 게 늘 무럭무럭 무럭 솟 아 오르 는 중 꿇 어 니 무릎 무려 이번 주 만 억 내 손금 에 재 물선 이 길 어 오늘 도 난 부처 님 께 빌 어 관세음보살 석가모니 미륵 믿음 만 이 내 유일 한 성공 의 법칙 망설임 후회 나 걱정 과 멈칫 따윈 나 의 머리 속 에 절대로 없 지 어찌나 평온 한지 구름 위 를 걷 지 난 멋지 게 싸 라 있 는 느낌 을 느끼 는 중 성공 이 든 실패 든지 뭐 든 즐기 는 중 문 두 들기 는 중 직접 나 서 다른 랩퍼 들 다 굶기 는 중 우리 는 두 배 가 아닌 세배 또 네 배 더 세 게 체계 적 인 멘붕 일 을 할 땐 확실히 된 둥 만 둥 하 지 않 네 어딜 가 든 내 이름 이 보이 지 되 고 있 단 소리 지 니 삶 엔 비 온다 주룩 난 호놀룰루 맑 은 구름 인생 에 수많 은 물음 들 에 난 답 이 뭐 든 걍 묵음 니 랩 정지 버튼 누름 내 랩 스 웩 다 두름 좋 은 생각 들 은 언제나 좋 은 일 들 만 부름 주름 쩔 게 잡힌 팬티 원 하 지 않 겠 지 보 고 싶 지 않 겠 지 내 가 돈 버 는 모습 을 보 고 싶 지 않 겠 지 그리고 선 내게 왜 순수 예술 을 안 하 냐 면서 나 를 씹 겠 지 그 동안 난 수퍼 카 들 을 사 이러 다 나중 엔 집 이나 짓 겠 지 니 들 이 그럴수록 난 오 기 가 발동 해 하 지 말 람 더 하 고 픈 그런 심리 가 내게도 작용 해 게다가 내 가 널 위해 관 둘 필욘 없 지 내 가 바보 냐 솔직히 니 가 하 는 짓 여기 와서 보 면 웃겨 바보 냐 한 번 뿐 인 인생 을 그렇게 살 다니 지노 가 말 했 지 아까워 시간 이 아까워 시간 이 아까워 시간 이
# Right translation : <sos> 나 랑 결혼 해 줄래
# Predicted translation:  나 의 <eos>
# -------------------------------------------------- 22
# Input: 전주 중 한 걸음 두 걸음 골목길 걸 을 때 들려오 는 찬양 소리 에 어깨 를 흔들 며 밤하늘 보 면은 우리 주 님 내 온 십자 가 아무리 바라보 고 바라보 아도 그 사랑 알 수 가 없 어 기쁜 날 을 주 신 나 의 예수 님 나 항상 흥 에 겨워 요 나 는 예수 님 이 정말로 좋 아요 나 항상 사랑 할래요 간주 중 아무리 바라보 고 바라 보 아도 그 사랑 알 수 가 없 어 기쁜 날 을 주 신 나 의 예수 님 나 항상 흥 에 겨워 요 나 는 예수 님 이 정말로 좋 아요 나 항상 사랑 할래요 나 는 예수 님 이 정말로 좋 아요 나 항상 사랑 할래요
# Right translation : <sos> 우리 시작 해도 괜찮 을까요
# Predicted translation:  <eos>
# -------------------------------------------------- 60
# Input: 멋대로 내 뜻대로 살아가 고도 싶 은데 왜 이리 도 힘든 게 너무 도 많 아 말 도마 차이 고 또 치이 고 오 미쳐 버릴 것 같 아 제발 나 좀 내버려 둬 웃 어라 비웃 어라 현실 에 내 몸 맡긴다 자존심 구겨 가 며 살 아 보 련다 버린다 참 는다 꼭 이룬다 나 다시 태어나 련다 나 는 혼자 가 아니 야 속이 고 또 속 는 세상 살 지만 더 이상 방황 하 지 는 않 고 살 겠 다 사랑 하 는 내 형제 가족 을 위해 행복 한 미래 를 꿈 꾼 다 모두 잊 어 버려 두려움 마저 모두 가져가 간다 다시 시작 해 나 는 오늘 도 희망 찾 는다 웃 어라 비웃 어라 현실 에 내 몸 맡긴다 자존심 구겨 가 며 살 아 보 련다 버린다 참 는다 꼭 이룬다 나 다시 태어나 련다 나 는 혼자 가 아니 야 속이 고 또 속 는 세상 살 지만 더 이상 방황 하 지 는 않 고 살 겠 다 사랑 하 는 내 형제 가족 을 위해 행복 한 미래 를 꿈 꾼 다 모두 잊 어 버려 두려움 마저 모두 가져가 간다 다시 시작 해 나 는 오늘 도 희망 찾 는다 맘 비워 미련 두 지마 쿨 하 게 살 아 보 는 거 야 누가 봐도 멋있 게 간다 모두 잊 어 버려 두려움 마저 모두 가져가 간다 오 나 는 오늘 도 희망 찾 는다 나 는 오늘 도 울 지 않 는다
# Right translation : <sos> 너 가 여자 로 보여
# Predicted translation:  <eos>
# -------------------------------------------------- 53
# Input: 다람쥐 쳇바퀴 돌아가 듯 무료 하 고 특별 할 것 없 는 바람 같이 공허 한 인생 아 나 는 지금 어디 에 눈 감 았 다 눈뜨 면 한 달 이 눈뜨 고 눈 감 으면 년 이 비바람 낙엽 지면 년 이 세월 참 무상 하 구나 뭐 하나 이룬 게 없 는 뭐 하나 가진 게 없 는 덧 없 는 시간 속 을 헤매 다 지쳐 버린 인생 아 가 자 가 자 가 자 저 멀리 떠나 자 무정 한 세월 아 비켜라 잃어버린 시간 을 찾 아서 희망 과 행복 의 그 곳 으로 떠나가 자 가난 한 나 의 사랑 도 초 라 한 나 의 모습 도 모두 다 세월 안 에 굳어져 아무 미련 도 없 어 가 자 가 자 가 자 저 멀리 떠나 자 무정 한 세월 아 비켜라 잃어버린 시간 을 찾 아서 희망 과 행복 의 그 곳 으로 떠나가 자 가 자 가 자 가 자 저 멀리 떠나 자 무정 한 세월 아 비켜라 잃어버린 시간 을 찾 아서 희망 과 행복 의 그 곳 으로 떠나가 자
# Right translation : <sos> 주 와 함께 가리
# Predicted translation:  <eos>
# -------------------------------------------------- 42
# Input: 오늘 따라 그대 의 얼굴 엔 먹구름 이 무슨 일 있 나요 하늘 도 참 맑 은데 뺨 을 스치 는 공기 다 너무 좋 은데 그 누구 도 내 그대 를 아프 게 할 순 없 어 나 는 못 봐요 꼭 내게 말 해 주 세요 나 그대 의 편 이 돼 줄 게 내 가 그 댈 안 아 줄 게 요 한 걸음 더 다가갈 게 요 아프 지 않 게 손 잡 아 줄게요 그대 눈빛 을 보 면 달 의 뒷 면 을 보 는 것 만 같 아서 내 가 더 불안 해 요 그대 의 그늘 이 돼 줄 게 내 가 그 댈 안 아 줄 게 요 한 걸음 더 다가갈 게 요 아프 지 않 게 손 잡 아 줄게요 그대 내 가 그 댈 사랑 할게요 항상 곁 에 있 을 거 예요 아프 지 마 요 우리 행복 해 봐요 그대
# Right translation : <sos> 무너져 내리 는 나
# Predicted translation:  나 의 <eos>
# -------------------------------------------------- 1
# Input: 기억나 그 어린 날 아무 것 도 없 어도 늘 행복 하 던 조그맣 던 내 손바닥 은 백 원 짜리 다섯 개 로 가득 했 어 혹시 잃어버릴까 주먹 꽉 쥐 고 걸어갔 던 내 작 은 손 하나 에 수많 은 행복 을 쥐 고 있 었 어 어느새 커버 린 걸 다섯 개 의 동전 으로 는 더 이상 내 손 은 채워 지 않 아 어떤 걸 로 채워도 그때 그 작 은 손안 에 행복 은 찾 을 수 없 다는 게 내 가 자랐 다는 게 혹시 잃어버릴까 주먹 꽉 쥐 고 걸어갔 던 내 작 은 손 하나 에 수많 은 행복 을 쥐 고 있 었 어 어느새 커버 린 걸 다섯 개 의 동전 으로 는 더 이상 내 손 은 채워 지 않 아 어떤 걸 로 채워도 그때 그 작 은 손안 에 행복 은 찾 을 수 없 다는 게 어느새 커버 린 걸 다섯 개 의 동전 으로 는 더 이상 내 손 은 채워 지 않 아 어떤 걸 로 채워도 그때 그 작 은 손안 에 행복 은 찾 을 수 없 다는 게 내 가 자랐 다는 게
# Right translation : <sos> 날 수 없 는
# Predicted translation:  나 이 <eos>
# -------------------------------------------------- 31
# Input: 시간 을 멈추 고 나 홀로 떠나 고 싶 어 잠 도 오 지 않 는 이 밤 에 두 눈 을 감 고서 조용히 숨쉬 고 싶 어 하 지만 또 생각 에 잠 못 이루 네 한 살 한 살 나이 가 들어가 면 갈수록 나 는 철 없 는 꿈 만 꾸 는구나 오예 믿 어 왔 던 친구 도 설레였 던 사랑 도 나 를 비웃 듯이 멀 어 져 가 네 사람 을 만나 고 즐기 고 맘 을 다 줘도 결국 남 는 것 은 상처 뿐 젊음 을 다 바쳐 끝없이 도전 하 지만 성공 도 내 실패 도 보이 질 않 아 한 살 한 살 나이 가 들어가 면 갈수록 나 는 철 없 는 꿈 만 꾸 는구나 오예 믿 어 왔 던 친구 도 설레였 던 사랑 도 나 를 비웃 듯이 멀 어 져 가 네 하지만 또 웃 으며 난 살아가 네
# Right translation : <sos> 누구 라도 그러 하 듯이
# Predicted translation:  <eos>
# -------------------------------------------------- 14
# Input: 사랑 이란 달콤 한 거 라고 눈물 따윈 없 어 질 거 라고 내 곁 에서 영원 할 거 라고 매일 같이 속삭였 던 너 인데 이제 와서 헤어질 거 라고 영원 이 란 건 없 다고 얼음 처럼 차갑 게 도 돌아섰 던 너 행복 했 다고 행복 했었 다고 되 뇌 어 봐도 네 가 없이 숨쉬 는 매일 이 까맣 게 물들 어 가 사랑 이 이렇게 힘든 걸 사랑 이 눈물 보다 아프 단 걸 떠난 후 에 야 알 게 되 는 멍 투성이 란 걸 그대 가 알 게 해 준 거 야 그대 가 내 기억 에 남 은 거 야 떠나가 지 말 아 다시 처음 으로 날 데려가 하루 만큼 멀 어 져 가 는데 눈물 조차 말라 져 가 는데 이제 는 꽤 괜찮 아 졌 는데 왜 지워 지 가 않 아 잘 자라 던 너 의 그 목소리 보 고 싶 다 던 그 말 도 아직 까지 선명 하 게 귓가 에 맴돌 아 널 잊 을 건데 정말 잊 을 건데 버리 고 싶 은데 왜 넌 자꾸 떠올라 또 다른 사랑 도 못 하 잖아 사랑 이 이렇게 힘든 걸 사랑 이 눈물 보다 아프 단 걸 떠난 후 에 야 알 게 되 는 멍 투성이 란 걸 그대 가 알 게 해 준 거 야 그대 가 내 기억 에 남 은 거 야 떠나가 지 말 아 다시 처음 으로 날 데려가 가 지 말 라고 눈 으로 외쳐도 돌아오 라고 맘 으로 불러도 차갑 게 뒤 돌아서 는 잔인 한 너 를 왜 난 자꾸 만 잊 지 못 해 왜 널 잡지 도 못 하 는데 날 돌아선 널 잡 고 싶 은데 돌아와 내게로 돌아와 한 번 만 내게 돌아와 이렇게 널 애원 하 고 바라 고 있 잖아 가지 마 아직 사랑 하 잖아 가지 마 아직 도 날 원 하 잖아 떠나가 지 말 아 다시 처음 으로 날 데려가
# Right translation : <sos> 비밀 키스
# Predicted translation:  사랑 의 <eos>
# -------------------------------------------------- 68
# Input: 어른 들 은 모르 잖아요 아무 것 도 모르 잖아요 엄마 아빠 부탁 할 게 어린 애 가 아니 라구요 내 방 올 땐 노크 좀 해 요 나 도 혼자 만 의 시간 이 필요 해 요 다 컸 어요 다 컸 어요 어느새 몸 도 맘 도 진짜 어른 이 됐 죠 다 컸 어요 은밀 한 혼자 만 의 비밀 도 있 죠 어리 다고 놀리 지 마 요 다 알 아요 다 알 아요 다 알 아요 자꾸 내 가 이상 해져요 설명 할 수 없 는 감정 이 하루 에 몇 번 씩 커져 만 가 는 걸 요 다 컸 어요 다 컸 어요 어느새 몸 도 맘 도 진짜 어른 이 됐 죠 다 컸 어요 은밀 한 혼자 만 의 비밀 도 있 죠 어리 다고 놀리 지 마 요 다 알 아요 다 알 아요 다 알 아요 이제 나 를 믿 어요 다 컸 어요 다 컸 어요 바람 처럼 파도 처럼 이랬 다가 저래 요 다 컸 어요 사랑 이 뭔 지 나 도 알 고 있 어요 어리 다고 놀리 지 마 요 내 맘속 에 봄 이 왔 어요 걱정 말 고 지켜 봐 줘요 다 컸 어요
# Right translation : <sos> 심 국현
# Predicted translation:  <eos>
# -------------------------------------------------- 48
# Input: 내 통장 에 비 온다 주룩주룩 주룩 디 룩 하늘 높 을 줄 모르 게 늘 무럭무럭 무럭 솟 아 오르 는 중 꿇 어 니 무릎 무려 이번 주 만 억 내 손금 에 재 물선 이 길 어 오늘 도 난 부처 님 께 빌 어 관세음보살 석가모니 미륵 믿음 만 이 내 유일 한 성공 의 법칙 망설임 후회 나 걱정 과 멈칫 따윈 나 의 머리 속 에 절대로 없 지 어찌나 평온 한지 구름 위 를 걷 지 난 멋지 게 싸 라 있 는 느낌 을 느끼 는 중 성공 이 든 실패 든지 뭐 든 즐기 는 중 문 두 들기 는 중 직접 나 서 다른 랩퍼 들 다 굶기 는 중 우리 는 두 배 가 아닌 세배 또 네 배 더 세 게 체계 적 인 멘붕 일 을 할 땐 확실히 된 둥 만 둥 하 지 않 네 어딜 가 든 내 이름 이 보이 지 되 고 있 단 소리 지 니 삶 엔 비 온다 주룩 난 호놀룰루 맑 은 구름 인생 에 수많 은 물음 들 에 난 답 이 뭐 든 걍 묵음 니 랩 정지 버튼 누름 내 랩 스 웩 다 두름 좋 은 생각 들 은 언제나 좋 은 일 들 만 부름 주름 쩔 게 잡힌 팬티 원 하 지 않 겠 지 보 고 싶 지 않 겠 지 내 가 돈 버 는 모습 을 보 고 싶 지 않 겠 지 그리고 선 내게 왜 순수 예술 을 안 하 냐 면서 나 를 씹 겠 지 그 동안 난 수퍼 카 들 을 사 이러 다 나중 엔 집 이나 짓 겠 지 니 들 이 그럴수록 난 오 기 가 발동 해 하 지 말 람 더 하 고 픈 그런 심리 가 내게도 작용 해 게다가 내 가 널 위해 관 둘 필욘 없 지 내 가 바보 냐 솔직히 니 가 하 는 짓 여기 와서 보 면 웃겨 바보 냐 한 번 뿐 인 인생 을 그렇게 살 다니 지노 가 말 했 지 아까워 시간 이 아까워 시간 이 아까워 시간 이
# Right translation : <sos> 나 랑 결혼 해 줄래
# Predicted translation:  나 의 <eos>
# -------------------------------------------------- 22
# Input: 이제 는 잘난 체 할 때 가 아닌 보여 줄 때 넌 했으니 난 보여 줄 게 젊 은 물론 이번 에 도 변화 의 핵 그 어떤 사고 도 버틴 몸 건방지 고 미련 해도 가장 높 은 성실 도 재주 도 아주 많 아 마치 서귀포 잘 생기 진 않 았 어도 난 좀 멋진 놈 솔직 한 게 문제 라고 너 는 얼씬 도 마 전국 을 소름 돋 게 해 로 반년 전 에 내 야 했 던 앨범 숙녀 가 먼저 라면 난 엄마 부터 챙길래 착함 이 부 라면 난 은 퇸 알 아서 할 게 내 가 땡길 때 내 가 켕기 는 애 들 은 욕 하 는 게 내 생김새 음악 은 귀 로 듣 는 것 근데 난 또 까 부 는 만큼 내 실력 을 매일 갱신 해 북한 애 들 도 알 아 이 동무 는 치열 해 난 이해 해 나 도 가끔 날 미워해 내 가 여기 온 이유 이제 모두 일어나 치워 도 년 전 내 가사 마음 은 돌아왔 어 진짜 를 원한다면 즉 내 집 은 니 집 난 절대 할 수 없 어 빙 의 내 가 할 수 있 는 건 오직 나대 로 하 기 나 를 욕 하 고 싶 으면 니 맘 대로 까 길 그게 너 의 삶 난 이제 내 길 을 가 지 난 약한 거 알 아 내 의 믿음 만 이 날 지탱 할지 도 몰라 한국 은 취했 어 숙취 해 손 못 해도 되 줄 게 니 콜라 아니 내 가 되 줄 게 포도당 음악 좀 찾 는 녀 되 줄 게 니 오빠 다 들 똑똑 할 때 그 멍청 한 친구 난 여름 에 도 녹 지 못 하 는 팥빙수 난 연예인 이 아냐 육 등 신 비율 만 이 내 운명 이건 질투 살 만 한 발언 누구 에겐 난 목사 누구 에겐 그 괴물 마저 도 신 을 적 으로 두 었 지 내 적 들 은 인간 아니 사실 은 그냥 두더지 내겐 하나 도 유치 하 지 않 아 이 라는 말 나와 가족 은 덕분 에 작 지 않 은 봉급 어제 내 돈 나갔 지 이 젠 생겼 어 통금 부정 적 인 모든 건 세금 이 라 생각 해 이제야 철 좀 드 나 어린이 날 인데 펜 잡지 인생 은 거품 빠지 면 밟히 는 콜라 캔 이 젠 영화배우 조폭 도 알 아 내 가사 계획 하 고 실행 하 자 내 눈 앞 엔 왕관
# Right translation : <sos> 사랑 그 이름 하나 로
# Predicted translation:  이 <eos>
# -------------------------------------------------- 12
# Input: 곁 에 내 가 있 어 힘들 게 보낸 날 은 잊 어요 그대 만 위 한 맘 에 지내 면 나 는 힘들 고 아파도 괜찮 아 그대 만 행복 하 면 이 젠 내게 없이 살 아도 이 젠 괜찮 아요 그대 날 다 잊 어도 그녀 를 위 한 맘 에 그대 행복 하 면 모두 잊 은 채 로 이제 나 만 위 한 맘 에 그저 행복 하 기 만 할 수 있 어요 다시 찾 은 그대 사랑 에 힘든 일 은 없 기 를 내 다른 사랑 위 한 마음 만 원한 기도 만 하 고 난 지냈 지만 그 댈 잊 지 못 하 는 내 맘 찾 아 다시 돌아오 길 또 바라 고 있 죠 이 젠 괜찮 다고 혼자 말 해 보 지만 그대 하 고 있 는 다른 그 사랑 에 괜 한 내 마음 만 다쳐 더 힘든 날 보 는 날 위 하 는 이 사람 아프 게 할 순 없 어 또 그 댈 원해 보 는 내 욕심 만 키우 기 만 하 는 날 용서 할 자신 도 난 버리 고 날 이 젠 너 를 잊 게 기도 해 이 젠 괜찮 아요 그대 날 다 잊 어도 그녀 를 위 한 맘 에 그대 행복 하 면 모두 잊 은 채 로 이제 나 만 위 한 맘 에 그저 행복 할게요 그대 만 좋 다면 반복 이 젠 괜찮 아요
# Right translation : 이불 을 박차 고 일어나 도 소용없 어
# Predicted translation:  사랑 의 <eos>
# -------------------------------------------------- 8
# Input: 아파하 는 너 를 가까이 다가가 너 만 의 아픔 을 찾 아 나 는 꼭 위로 해 주 고 싶 지만 저 비 가 내려오 는 너 의 슬픈 목소리 들 을 때 마다 나 는 싫 어 싫 어 비 에 흠뻑 젖 은 너 의 눈동자 를 바라보 면 나 는 아파 나 는 모르 지만 잘 은 모르 지만 너 를 위로 할 수 있 게 해줘 비 가 내려오 는 너 의 눈물 닦 아 줄 래 소 중 한 네 마음 가까이 다가가 너 만 의 아픔 을 찾 아 나 는 꼭 위로 해 주 고 싶 지만 저 비 가 내려오 는 너 의 슬픈 목소리 들 을 때 마다 나 는 싫 어 싫 어 비 에 흠뻑 젖 은 너 의 눈동자 를 바라보 면 나 는 아파 나 는 모르 지만 잘 은 모르 지만 너 를 위로 할 수 있 게 해줘 비 가 내려오 는 너 의 눈물 닦 아 줄 래 저 비 가 내려오 는 너 의 슬픈 목소리 들 을 때 마다 나 는 싫 어 싫 어 비 에 흠뻑 젖 은 너 의 눈동자 를 바라보 면 나 는 아파 나 는 모르 지만 잘 은 모르 지만 너 를 위로 할 수 있 게 해줘 비 가 내려오 는 너 의 눈물 닦 아 줄 래
# Right translation : <sos> 파스텔 시대 의 날 들
# Predicted translation:  사랑 의 <eos>
# -------------------------------------------------- 40
# Input: 따 뜻 한 햇살 구름 사이 지나 밝 게 빛나 는 그 포 근 한 바람 우리 곁 을 맴돌 던 그때 그 순간 외롭 던 나 에게 웃 어 주 며 빛 으로 나 를 감싸 주 던 내 곁 에 있 어 준 너 캄캄 한 어둠 이 가득 한 밤 속 에 갇혔 던 날 들 이 널 만나 난 변했 어 하늘 높이 날 아 걸 을래 빛나 는 너 에게 닿 을래 나 도 모르 게 어두웠 던 순간 너 로 채워 널 가득히 밤하늘 빛나 는 별 처럼 날 보 며 미소 짓 는 너 겁 이 많 아 두려웠 던 지난 순간 잊 고 모두 너 와 함께 면 날아갈 수 있 어 널 마주 하 면 온몸 이 가벼워져 하늘 높이 떠올라 가리 어 져 더 이상 보이 지 않 아 내 어지러운 세상 구름 아래 일 들 은 이제 다 잊어버리 게 돼 너 만 보이 게 돼 눈 을 마주 하 는 것 만 으로 도 밤하늘 이 느껴 지 는 건 넌 아마도 내 마음속 엔 이미 날 지키 는 힘 이 되 어 버린 것 같 아 내 바탕 에 되 어 줘 그림 이 지치 고 힘들 었 던 지난날 나 에게 웃 으며 손 내밀 던 너 에게 난 물들 어 하늘 높이 날 아 걸 을래 빛나 는 너 에게 닿 을래 나 도 모르 게 어두웠 던 순간 너 로 채워 널 가득히 밤하늘 빛나 는 별 처럼 날 보 며 미소 짓 는 너 겁 이 많 아 두려웠 던 지난 순간 잊 고 모두 너 와 함께 면 날아갈 수 있 어 나 난 나나 나 나나 나 난 나 나나 나 난 나 는 너 와 함께 면 날아갈 수 있 어
# Right translation : <sos> 당신 만 을
# Predicted translation:  <eos>
# -------------------------------------------------- 35
# Input: 우리 는 약속 했 나요 손잡 고 같이 흐르 자고 그리운 눈빛 하나 로 다가와 그렇게 약속 했 나요 함께 흐르 며 우리 가 무슨 얘기 했 나요 정녕 사랑 과 영혼 을 맹세 했 나요 비바람 이 몰아칠 때 간절 했 던 우리 의 손길 기억 하 나요 나 는 오직 그대 만 을 쳐다보 며 흘러 왔 어요 이제 와서 무엇 때문 에 두 줄기 로 흘러가 나요 언젠가 강 에 이르 면 다시 만날까 아 득 한 물결 속 에서 작 은 물방울 만들 며 기쁨 이 라고 했 나요 맑 은 아침 을 나 에게 보여준 그대 비바람 이 몰아칠 때 간절 했 던 우리 의 손길 기억 하 나요 나 는 오직 그대 만 을 쳐다보 며 흘러 왔 어요 이제 와서 무엇 때문 에 두 줄기 로 흘러가 나요 언젠가 강 에 이르 면 다시 만날까 아 득 한 물결 속 에서 물결 속
# Right translation : <sos> 오늘 이 하루 도
# Predicted translation:  <eos>
# -------------------------------------------------- 54
# Input: 무섭 지 않 아 물불 이 무서운 건 굶주림 저기 윗 동네 형 들 처럼 뜯어 먹 어 풀 뿌리 더 는 안 믿 어 주 님 내 가 믿 는 건 주식 은행 을 터 는 게 빨라 차라리 히잡 을 쓰 지 년 도 동대문 에서 옷 을 샀 지 그 다음 해 엔 용팔이 한테 컴 을 샀 지 난 한국 에 무서울게 안 남 았 지 서른 전 에 모든 겁 대가리 를 상실 우린 될 줄 알 았 어 제이지 칸 예 허나 리미 와 감자 도 못 따라가 네 들어갈 줄 알 았 어 누군가 의 꿈 을 꿨 지 현실 은 탑 텐 똥 을 쌌 던 내 바진 이 젠 배 바지 랩 하 던 배짱 이 필요 해 이력서 장 이 회사 엔 없 어 내 자리 안 메 지 넥타이 올려 내 두 다리 너 네 사장 책상 위 너무 바빠 시간 이 안 나 좀처럼 요즘 오줌 싸 고 고추 도 못 털 어 여기저기 일 을 벌려 공사 다망 하 지 거짓말 처럼 내 가 손댄 공사 는 다 망하 지 남겨 야지 마진 떨어진 동전 한 닢 까지 꽃길 만 걷 는 난 맨 발 로 가시 밭길 넌 숨 이 차 서 못 걸어가 한 번 도 쳐 본 적 없 자 나 깽판 너 에게 보여줘 갱 스타 놀러 와 내 현장 날 이 선 연장 어서 와 웰컴 체험 삶 의 현장 내 삶 을 니 오 빤 눈뜨 고 못 봐 자랑 하 지 없 는 돈 안 먹히 니 없 는 척 번데기 앞 에서 감히 얼른 너 주름 펴 난 부모 도 버린 놈 넌 내 앞 에 어린 놈 밟혀 나 한테 걸리 면 난 네 옆 에 걸리버 년 도 부터 질러 왔 던 검 은 소릿길 내 랩 은 백발 백중 평론 대중 드럼 박자 위 는 수풀 이 우 거진 오솔길 언제나 그래 왔 듯 이 리듬 은 어떻게 이런 을 발견 했 지 내 에 모두 쓰러지 는 글자 들 은 볼링 핀 들 목적 을 잃 고 헤매 는 이 땅 위 의 이 과 로 세워 가 는 나 의 삶 의 기틀 날개 를 펴 고 하늘 을 누비 는 가슴 을 적셔 오 는 아침 이슬 영혼 의 안식처 가 되 어 주 는 우리 들 의 마음 속 에 는 여전히 서태지 와 아이 들 조금 씩 제 자리 를 잡아가 고 있 는 나 에겐 날개 가 있 으니 언타이틀 처럼 하늘 을 날 수 있 어 나 는 이 노래 에 전부 실 어 날려 버릴래 힙합 으로 나 를 이끌 어 준 네 고막 을 때리 는 나 의 랩 은
# Right translation : <sos> 이렇게 저렇 게
# Predicted translation:  <eos>
# -------------------------------------------------- 85
# Input: 한 여름 에 목도 릴 선물 받 은 기분 일까 요 비슷 할까 요 준다고 준 마음 이 이 것 밖에 안 되 는 걸 요 그대 에게 난 나 에게 는 용기 라 부르 겠 지만 그대 에게 는 부담 이 라 불리 겠 죠 그 댄 나 에게 한 여름 그늘 이 지만 난 그대 에게 한 겨울 바람 이 겠 죠 다 버리 고 남 은 맘 이렇게 나 많 은 걸 보 니 꽤 깊 었 나 봐요 나 에게 는 용기 라 부르 겠 지만 그대 에게 는 부담 이 라 불리 겠 죠 그 댄 나 에게 한 여름 그늘 이 지만 난 그대 에게 한 겨울 바람 이 겠 죠 보 고 싶 어요 내 이름 환히 부르 며 날 찾 아 주 는 그대 의 손짓 한 여름 에 목도 릴 선물 받 은 기분 일까 요 그런 거 겠 죠
# Right translation : <sos> 세상 을 마주 하 는 방법
# Predicted translation:  <eos>
# -------------------------------------------------- 77
# Input: 그저 사막 을 지나 간다 덥 다 사랑 찾 아 끝없이 간다 꽤 덥 다 사막 이 끝 이 나 면 올까 내 사랑 기대 조차 버겁 다 아직 도 뜨겁 다 뜨거운 태양 을 등지 고 걷 다 보 면 끝 없 는 모래밭 언젠가 사 라 질까 희망 은 신기루 로 끝나 버리 고 무수 한 별 자 릴 의지 해 걷 다 보 면 푸른 오아시스 엔 내 사랑 있 을까 사막 이 끝 이 나 고 초원 이 나오 면 있 을까 단 한 톨 희망 도 버리 지 말 아야 지 그리움 을 떨칠 곳 을 찾 아 걷 는다 어떻게 도 표현 할 방법 이 없 어 예 예 예 나 의 몸 이 불타 오른 대 도 이 모든 게 날아가 버려도 그대 만 을 찾 는 내 마음 은 그저 사막 을 지나 간다 덥 다 사랑 찾 아 끝없이 간다 꽤 덥 다 사막 이 끝 이 나 면 올까 내 사랑 기대 조차 버겁 다 아직 도 뜨겁 다 기약 없이 걸어도 기대 는 커 지 는데 정작 내 신발 속 모래 만 쌓여 가 고 가슴 속 깊숙이 엔 무엇 도 남 질 않 는구나 어떻게 도 표현 할 방법 이 없 어 예 예 예 나 의 몸 이 불타 오른 대 도 이 모든 게 날아가 버려도 그대 만 을 찾 는 내 마음 은 그저 사막 을 지나 간다 덥 다 사랑 찾 아 끝없이 간다 꽤 덥 다 사막 이 끝 이 나 면 올까 내 사랑 기대 조차 버겁 다 아직 도 뜨겁 다 그래도 뜨거워 쓰러진 뜨거운 태양 아 지겨워 쓰러진 끝 없 는 모래밭 이 여 날아가 사라진 그대 를 향 한 내 마음 어떤 미련 도 없이 그저 걸 을 뿐 예 어떻게 도 표현 할 방법 이 없 어 예 예 예 나 의 몸 이 불타 오른 대 도 이 모든 게 날아가 버려도 그대 만 을 찾 는 내 마음 은 그저 사막 을 지나 간다 덥 다 사랑 찾 아 끝없이 간다 꽤 덥 다 사막 이 끝 이 나 면 올까 내 사랑 기대 조차 버겁 다 아직 도 뜨겁 다 그저 사막 을 지나 간다 덥 다 사랑 찾 아 끝없이 간다 꽤 덥 다 사막 이 끝 이 나 면 올까 내 사랑 기대 조차 버겁 다 아직 도 뜨겁 다
# Right translation : <sos> 나 여기 에
# Predicted translation:  나 <eos>
# -------------------------------------------------- 93
# Input: 나 는 관심 을 받 고 싶 어 너 에게 소식 이 닿 을 만큼 팔 로 비싼 옷 을 걸치 고 올려 발렌시아 가 이 거 요즘 유행 이 잖아 모든 순간 들 을 담 고 모든 순간 들 을 알려 낡 은 기억 들 의 장면 채 도 낮 은 흑백 화면 보정 을 끝낸 뒤 엔 나 는 언제 올리 지 를 고민 해 고민 하 다 보 면 잠 이 오 기 시작 졸리 네 고민 하 지 마 고민 하 지 마 좀 잘못 누른 하트 제발 보 지 마 보 지 마 멋진 신발 멋진 옷 멋진 시계 멋진 스틸 이 거 금 보다 비싼 거 너 가 알 아 줬 으면 내 가 잘 지내 는 것 을 너 가 알 아 줬 으면 연락 하 는 사람 들 이 댓글 달 아 줬 으면 너 가 뭐 해 라고 문자 남길 수 도 있 어 술 에 취한 척 하 고 너 에게 안길 수 도 있 어 돌아와 돌 아 버리 기 전 에 눈물 셀카 올리 기 전 에 난 너 와 달라 이런 모습 니 가 보 는 상상 을 해 난 이제 뭘 해 나 의 옷 나 의 삶 나 의 감성 모두 다 너무 했 지 너무 했 어 너무 해도 너무 해 술 사진 우울 사진 슬픈 영화 대사 친구 들 아 어서 빨리 나 를 위로 해 라 올린 기리보이 키 보드 내 맘 블루투스 스피커 의미 없이 찍 어 기리보이 너무 좋 아 내 마음 인 것 같이 노래 를 썼잖아 친구 들 이 공감 해 하트 눌려 하트 눌려 하트 눌려 하트 눌려 너 도 기리보이 좋 아 했잖아 질투 날 정도 로 너 때문 에 산 요 상 한 안경 들 어떡 해 기리보이 좋 아 했잖아 질투 날 정도 로 너 때문 에 변한 개 국어 나 의 언어 왜 나 를 버려 왜 나 를 울려 왜 보 란 듯이 즐거운 사진 을 올려 왜 같 은 신발 신어 왜 같 은 옷 을 입 어 발렌시아 가 요즘 유행 이 잖아 난 너 와 달라 이런 모습 니 가 보 는 상상 을 해 난 이제 뭘 해 나 의 옷 나 의 삶 나 의 감성 모두 다 해시 태그 겁나 많 은 나 는 관 종 이 지 사진 기술 플래시 터 트리 기 너 가 하트 누른 기리보이 사진 들 센 척 하 면서 안 찍 어 주 더라 사진 을 너 를 떠올리 는 건 악 플 달기 보다 쉽 고 너 를 못 잊 는 내 가 기리보이 보다 싫 어 왜 나 를 싫 어 왜 나 를 싫어해 발렌시아 가 이 거 유행 이 라 매 너 의 반응 이 어떨지 궁금 해 니 가 어떻게 나오 던 나 는 아무 관심 없 어 많 은 관심 을 받 고 싶 어 너 에게 소식 이 닿 을 만큼 팔 로 비싼 옷 을 걸치 고 올려 발렌시아 가 이 거 요즘 유행 이 잖아
# Right translation : <sos> 운명 의 친구
# Predicted translation:  나 의 <eos>
# -------------------------------------------------- 76
# Input: 오 저기 버스 킹 하 네 이 노래 어서 들 어 봤 는데 뭐 여 튼 소개 를 하 네 발라드 할게요 저 원래 알 앤 비 국시 공부 만 하 다가 끝나 고 막상 취업 준비 불안 하 니 당 찬 여보 컬 얼굴 왠지 너무 힙합 같 잖아 안기 고 싶 어 져 투팍 도 잠깐 망설였 을 걸 난 너 를 닮 고 싶 어서 너 처럼 노래 불러 세상 에 모든 사랑 노래 를 네 가 저작 권 있 는 것 처럼 불러대 고 오오 맘껏 취해 서 흐느끼 네 한 이 느껴져 해 미세먼지 나쁨 이 라는 건 숨겨 도 되 겠 어 공연 이 끝나 면 친구 말 따 마 우린 급 이 다르 지만 난 안 급해 내 가 빠진 호수 들 은 물 이 넘쳐 유레카 외치 던 놈 들 많 아 우린 이웃 하 지 그럼 너 의 호수 를 알려줘 난 기본 없 는 놈 이 지만 배울 동기 도 없 었 는 걸 우리 가 확인 할 건 유머 코드 차키 를 올려 놓 고 고니 처럼 이 한 끗 에 억 을 태워도 건물 주 라도 너 같 은 여자 한텐 오히려 내 가 경쟁력 이 돼 넌 정의 할 수 없 는 것 들 에 대해 사랑 우정 행복 에 가치 를 올바르 게 추구 하 고 싶 어 해서 먹방 눕 방 가능 하 겠 어 오른손 왼손 엄지 검지 브이 칠 만들 어 사각형 거기 에 널 얼굴 을 담 는 건 얼굴 신경 이 칠 번 이 라서 가 아니 고 걍 너 가 예뻐 보이 네 오늘 유난히 도 내 박자 가 이상 한 데 좋 다고 느낀다면 우린 맞 아 이 노래 가 이상 하 게 끌린 다면 내 진심 은 통한 거 야 넌 자연 같이 통통 한 행동 과 그게 일치 하 는 품 같 은 언어 가 내게 상처 를 못 줘 내게 상처 를 못 줘 내 상처 씻겨져 사랑 으로 씻겨져 행동 으로 이어져 너 처럼 노래 불러 세상 에 모든 사랑 노래 를 네 가 저작 권 있 는 것 처럼 불러대 고 오오 맘껏 취해 서 흐느끼 네 한 이 느껴져 해 미세먼지 나쁨 이 라는 건 숨겨 도 되 겠 어 공연 이 끝나 면 친구 말 따 마 우린 급 이 다르 지만 난 안 급해
# Right translation : <sos> 놀라운 사람
# Predicted translation:  <eos>
# -------------------------------------------------- 55
# Input: 기억나 그 어린 날 아무 것 도 없 어도 늘 행복 하 던 조그맣 던 내 손바닥 은 백 원 짜리 다섯 개 로 가득 했 어 혹시 잃어버릴까 주먹 꽉 쥐 고 걸어갔 던 내 작 은 손 하나 에 수많 은 행복 을 쥐 고 있 었 어 어느새 커버 린 걸 다섯 개 의 동전 으로 는 더 이상 내 손 은 채워 지 않 아 어떤 걸 로 채워도 그때 그 작 은 손안 에 행복 은 찾 을 수 없 다는 게 내 가 자랐 다는 게 혹시 잃어버릴까 주먹 꽉 쥐 고 걸어갔 던 내 작 은 손 하나 에 수많 은 행복 을 쥐 고 있 었 어 어느새 커버 린 걸 다섯 개 의 동전 으로 는 더 이상 내 손 은 채워 지 않 아 어떤 걸 로 채워도 그때 그 작 은 손안 에 행복 은 찾 을 수 없 다는 게 어느새 커버 린 걸 다섯 개 의 동전 으로 는 더 이상 내 손 은 채워 지 않 아 어떤 걸 로 채워도 그때 그 작 은 손안 에 행복 은 찾 을 수 없 다는 게 내 가 자랐 다는 게
# Right translation : <sos> 날 수 없 는
# Predicted translation:  나 이 <eos>
# -------------------------------------------------- 31
# Input: 잠깐 그대 는 내 맘 속 서랍 에 닫 아 놓 고 나 의 시간 을 살 아 갈께요 아름답 게 내린 축복 같 은 눈빛 사이 로 흘러가 는 여름밤 따 뜻 했 던 외로움 도 멈추 고 라 닿 을 수 없 는 마음 의 달빛 의 바다 바람 같 은 우리 의 박제 된 시간 얼마나 기다려야 흘러갈 런 지 그대 눈길 에 다 이해 됐었 던 그 때 그 맘 으로 내일 을 살 아 갈께요 보이 지 않 아도 두 눈 에 보이 는 것 처럼 나 들리 지 않 아도 귓가 에 울려오 는 것 처럼 라 닿 을 수 없 는 마음 의 달빛 의 바다 바람 같 은 우리 의 박제 된 시간 얼마나 흘러 다시 흘러갈 런 지
# Right translation : <sos> 갈 생각 있 어
# Predicted translation:  나 의 <eos>
# -------------------------------------------------- 51
# Input: 그저 앞 만 보 는 세상 너무나 삶 은 힘 이 들 어 가끔 은 하늘 의 별 을 볼 수 있 는 것 으로 우린 웃 을 수 있 어 그래 나 는 나 인 걸 하늘 을 봐 빛나 는 별 바다 를 봐 힘찬 파도 의 모습 세상 을 봐 우리 를 봐 희망 을 봐 우린 꿈 이 있 잖아 지난 날 을 후회 하 지 마 미래 를 두려워하 지 마 오늘 이 순간 만 은 즐길 수 있 는 자 만 이 세상 을 가질 수 있 어 그게 바로 너 란 걸 하늘 을 봐 빛나 는 별 바다 를 봐 힘찬 파도 의 모습 세상 을 봐 우리 를 봐 희망 을 봐 우린 꿈 이 있 잖아 나 는 나 인 걸 바로 너 란 걸 워 어 그게 나 인 걸
# Right translation : <sos> 무정 한 사람
# Predicted translation:  나 의 <eos>
# -------------------------------------------------- 66
# Input: 기억 에 갇혀 마음 을 잡혀 점차 빠져들 고 있 어 구해 줘 날 여태 지켜봐 왔 을 때 넌 좀 유별난 듯 해 왜 난 쉬운 일 이 없 어 알려줘 하나 쯤 보여 줘 하나 쯤 내게만 한 번 쯤 니 맘속 구해 줘 날 이렇 다 저렇 다 뭐 라도 말 좀 해 봐 너 만 은 놓치 기 싫 어 구해 줘 날 싱겁 게 끝낼 맘 없 어 날 쉽 게 보 지 마 할 만큼 다 해 볼 거 야 이제 시작 이 야 손 끝 에 감춰 시선 을 감춰 차차 다가가 고 있 어 안 되 겠 니 한 발 가까이 나가 면 두 발 멀 어 진 듯 해 도통 잡혀 주 질 않 아 열 어 줘 하나 쯤 풀 어 줘 하나 쯤 빈 틈 을 한 번 쯤 내 어 줘 안 되 겠 니 이렇게 저렇게 기회 를 한 번 줘 봐 너 만 은 놓치 기 싫 어 안 되 겠 니 싱겁 게 끝낼 맘 없 어 날 쉽 게 보 지 마 할 만큼 다 해 볼 거 야 이제 시작 이 야 나 에겐 기회 조차 안 주 는구나 너 도 싫 진 않 을 텐데 내 가 어떻게 해 줘야 니 가 날 받 아 줄 수 있 겠 니 뭐 가 문제 야 살짝 네 맘 찔러 보 면 너 는 깜짝 놀라 도망가 네 그래 순수 하 게 눈 딱 감 고 우리 갈 때 까지 가 보 자 막아서 지 마 날 막아서 지 마 찔러 보다 관 둘 관심 이 아냐 내 눈 을 봐 무슨 말 이 필요 해 너 느끼 는 그 대론 데 싱겁 게 끝낼 맘 없 어 날 쉽 게 보 지 마 할 만큼 다 해 볼 거 야 이제 시작 이 야
# Right translation : <sos> 나 의 이유
# Predicted translation:  <eos>
# -------------------------------------------------- 9
# Input: 분명 아까 말 한 듯 한데 왠지 모자란 듯 한 오늘 너무 예쁘 다는 말 번 째 라고 그러 면 안 한 거 야 한참 모자라 지 번 정도 는 해야지 터질 것 같 은 널 향 한 나 의 마음 이 그 래야 얌전 해 질 것 같 단 말 야 솔직히 너 도 좋 잖은 가 너무 예쁘 다는 말 자꾸 들 어 지겹 겠 지만 어쩔 수 없 어 그러 면 안 한 거 야 한참 모자라 지 번 정도 는 해야지 터질 것 같 은 널 향 한 나 의 마음 이 그 래야 얌전 해 질 것 같 단 말 야 솔직히 너 도 좋 잖은 가 너무 예쁘 다는 말 자꾸 들 어 지겹 겠 지만 어쩔 수 없 어 터질 것 같 은 널 향 한 나 의 마음 이 그 래야 얌전 해 질 것 같 단 말 야
# Right translation : <sos> 절망 의 늪
# Predicted translation:  나 이 <eos>
# -------------------------------------------------- 89
# Input: 어른 들 은 모르 잖아요 아무 것 도 모르 잖아요 엄마 아빠 부탁 할 게 어린 애 가 아니 라구요 내 방 올 땐 노크 좀 해 요 나 도 혼자 만 의 시간 이 필요 해 요 다 컸 어요 다 컸 어요 어느새 몸 도 맘 도 진짜 어른 이 됐 죠 다 컸 어요 은밀 한 혼자 만 의 비밀 도 있 죠 어리 다고 놀리 지 마 요 다 알 아요 다 알 아요 다 알 아요 자꾸 내 가 이상 해져요 설명 할 수 없 는 감정 이 하루 에 몇 번 씩 커져 만 가 는 걸 요 다 컸 어요 다 컸 어요 어느새 몸 도 맘 도 진짜 어른 이 됐 죠 다 컸 어요 은밀 한 혼자 만 의 비밀 도 있 죠 어리 다고 놀리 지 마 요 다 알 아요 다 알 아요 다 알 아요 이제 나 를 믿 어요 다 컸 어요 다 컸 어요 바람 처럼 파도 처럼 이랬 다가 저래 요 다 컸 어요 사랑 이 뭔 지 나 도 알 고 있 어요 어리 다고 놀리 지 마 요 내 맘속 에 봄 이 왔 어요 걱정 말 고 지켜 봐 줘요 다 컸 어요
# Right translation : <sos> 심 국현
# Predicted translation:  <eos>
# -------------------------------------------------- 48
# Input: 어느 날 찾아온 바람 이 말 했 어 나 와 함께 춤 을 추 자고 세상 에 수많 은 여러 춤 속 에서 너 만 의 춤 을 추 는 거 야 따따 라 밥 빠 야 이야 따따 라 밥 빠 야 이야 따따 라 밥 빠 야 이야 따따 라 밥 빠 야 이야 난 이 춤 을 멈추 지 않 아 자유 롭 게 춤 을 출 거 야 난 이 춤 을 멈추 지 않 아 자유 롭 게 춤 을 출 거 야
# Right translation : 님 에 대해 말 하 라 하 면
# Predicted translation:  <eos>
# -------------------------------------------------- 23
# Input: 잠깐 그대 는 내 맘 속 서랍 에 닫 아 놓 고 나 의 시간 을 살 아 갈께요 아름답 게 내린 축복 같 은 눈빛 사이 로 흘러가 는 여름밤 따 뜻 했 던 외로움 도 멈추 고 라 닿 을 수 없 는 마음 의 달빛 의 바다 바람 같 은 우리 의 박제 된 시간 얼마나 기다려야 흘러갈 런 지 그대 눈길 에 다 이해 됐었 던 그 때 그 맘 으로 내일 을 살 아 갈께요 보이 지 않 아도 두 눈 에 보이 는 것 처럼 나 들리 지 않 아도 귓가 에 울려오 는 것 처럼 라 닿 을 수 없 는 마음 의 달빛 의 바다 바람 같 은 우리 의 박제 된 시간 얼마나 흘러 다시 흘러갈 런 지
# Right translation : <sos> 갈 생각 있 어
# Predicted translation:  나 의 <eos>
# -------------------------------------------------- 51
# Input: 어디 서 들리 는 걸까 아득히 먼 저녁 종소리 흩어진 시간 의 흐름 속 으로 이끌려 가 는 내 모습 이대로 후회 는 없 어 우리 사랑 한 많 은 순간 들 잊 을 수 없 는 기억 들 을 애써 잊 으려 하 진 말 아요 이미 가 버린 시간 돌아온다 해도 나 는 다시 안녕 이 라 말 하 겠 지만 해 맑 은 웃음 과 그 고운 눈망울 언제 까지 잊 지 말 아 줘요 지나간 세월 에 빛나 던 우리 의 작 은 사랑 을 위 하 여 이미 가 버린 시간 돌아온다 해도 나 는 다시 안녕 이 라 말 하 겠 지만 해 맑 은 웃음 과 그 고운 눈망울 언제 까지 잊 지 말 아 줘요 지나간 세월 에 빛나 던 우리 의 작 은 사랑 을 위 하 여 일랜시아 엘 서버 아이디 변 미 선 사랑 해
# Right translation : <sos> 대박 났 네
# Predicted translation:  <eos>
# -------------------------------------------------- 44
# Input: 어른 들 은 모르 잖아요 아무 것 도 모르 잖아요 엄마 아빠 부탁 할 게 어린 애 가 아니 라구요 내 방 올 땐 노크 좀 해 요 나 도 혼자 만 의 시간 이 필요 해 요 다 컸 어요 다 컸 어요 어느새 몸 도 맘 도 진짜 어른 이 됐 죠 다 컸 어요 은밀 한 혼자 만 의 비밀 도 있 죠 어리 다고 놀리 지 마 요 다 알 아요 다 알 아요 다 알 아요 자꾸 내 가 이상 해져요 설명 할 수 없 는 감정 이 하루 에 몇 번 씩 커져 만 가 는 걸 요 다 컸 어요 다 컸 어요 어느새 몸 도 맘 도 진짜 어른 이 됐 죠 다 컸 어요 은밀 한 혼자 만 의 비밀 도 있 죠 어리 다고 놀리 지 마 요 다 알 아요 다 알 아요 다 알 아요 이제 나 를 믿 어요 다 컸 어요 다 컸 어요 바람 처럼 파도 처럼 이랬 다가 저래 요 다 컸 어요 사랑 이 뭔 지 나 도 알 고 있 어요 어리 다고 놀리 지 마 요 내 맘속 에 봄 이 왔 어요 걱정 말 고 지켜 봐 줘요 다 컸 어요
# Right translation : <sos> 심 국현
# Predicted translation:  <eos>
# -------------------------------------------------- 48
# Input: 주 의 사랑 의 빛 비취 네 어둠 가운데 비취 네 예수 세상 의 빛 비취 소서 우릴 진리 로 자유 케 하 소서 비취 소서 나 에게 비취 소서 이 땅 에 아버지 의 영광 타오르 소서 우리 맘 에 성령 넘치 소서 만방 에 주 의 은혜 긍휼 말씀 보내 비취 게 하 소서 주 님 계신 곳 에 옵니다 어둠 에서 주 의 빛 으로 예수 피 로서 들어갑니다 나 를 살펴 어둠 제하 소서 주 의 위 엄찬 광채 보 니 우리 얼굴 에 주 형상 나타나 영광 에서 영광 으로 변해 우리 삶 속 에 주 님 비 취리
# Right translation : <sos> 바라보 기 만 해도 참 좋 아요
# Predicted translation:  나 의 <eos>
# -------------------------------------------------- 72
# Input: 돌아설 걸 알 기 에 너무 도 두려웠 어 멀 어 질 걸 알 기 에 준비 를 해야 했 어 괜찮 은 척 하 기 엔 너무 도 멀리 왔 어 이렇게 눈물 만 흐른다 너 의 이름 을 부르 다 지쳐 잠든 수많 은 밤 들 이 젠 끝 이 날까 기다려 보 지만 또 같 은 자리 야 너 하나 만 보 던 나 를 알 잖아 보 고 싶 어 계속 불러 보 잖아 안녕 이 란 말 할 순 없 는 거 잖 아 이 젠 멈춰 야지 나 를 가둘 게 돌아설 걸 알 기 에 너무 도 두려웠 어 멀 어 질 걸 알 기 에 준비 를 해야 했 어 괜찮 은 척 하 기 엔 너무 도 멀리 왔 어 이렇게 눈물 만 흐른다 너 의 이름 을 부르 다 지쳐 잠든 수많 은 밤 들 이 젠 끝 이 날까 기다려 보 지만 또 같 은 자리 야 너 하나 만 보 던 나 를 알 잖아 보 고 싶 어 계속 불러 보 잖아 안녕 이 란 말 할 순 없 는 거 잖 아 이 젠 멈춰 야지 나 를 가둘 게
# Right translation : <sos> 러브 해커
# Predicted translation:  <eos>
# -------------------------------------------------- 24
# Input: 사랑 이란 달콤 한 거 라고 눈물 따윈 없 어 질 거 라고 내 곁 에서 영원 할 거 라고 매일 같이 속삭였 던 너 인데 이제 와서 헤어질 거 라고 영원 이 란 건 없 다고 얼음 처럼 차갑 게 도 돌아섰 던 너 행복 했 다고 행복 했었 다고 되 뇌 어 봐도 네 가 없이 숨쉬 는 매일 이 까맣 게 물들 어 가 사랑 이 이렇게 힘든 걸 사랑 이 눈물 보다 아프 단 걸 떠난 후 에 야 알 게 되 는 멍 투성이 란 걸 그대 가 알 게 해 준 거 야 그대 가 내 기억 에 남 은 거 야 떠나가 지 말 아 다시 처음 으로 날 데려가 하루 만큼 멀 어 져 가 는데 눈물 조차 말라 져 가 는데 이제 는 꽤 괜찮 아 졌 는데 왜 지워 지 가 않 아 잘 자라 던 너 의 그 목소리 보 고 싶 다 던 그 말 도 아직 까지 선명 하 게 귓가 에 맴돌 아 널 잊 을 건데 정말 잊 을 건데 버리 고 싶 은데 왜 넌 자꾸 떠올라 또 다른 사랑 도 못 하 잖아 사랑 이 이렇게 힘든 걸 사랑 이 눈물 보다 아프 단 걸 떠난 후 에 야 알 게 되 는 멍 투성이 란 걸 그대 가 알 게 해 준 거 야 그대 가 내 기억 에 남 은 거 야 떠나가 지 말 아 다시 처음 으로 날 데려가 가 지 말 라고 눈 으로 외쳐도 돌아오 라고 맘 으로 불러도 차갑 게 뒤 돌아서 는 잔인 한 너 를 왜 난 자꾸 만 잊 지 못 해 왜 널 잡지 도 못 하 는데 날 돌아선 널 잡 고 싶 은데 돌아와 내게로 돌아와 한 번 만 내게 돌아와 이렇게 널 애원 하 고 바라 고 있 잖아 가지 마 아직 사랑 하 잖아 가지 마 아직 도 날 원 하 잖아 떠나가 지 말 아 다시 처음 으로 날 데려가
# Right translation : <sos> 비밀 키스
# Predicted translation:  사랑 의 <eos>
# -------------------------------------------------- 68
# Input: 겨울 이 다가오 네 아픔 도 같이 오 네 마음 이 시려 오 네 겨울 만 앞서 가 네 사랑 은 뒤 쳐지 네 기억 이 떠나가 네 나 혼자 되 지 않 기 를 나 홀로 남 지 않 기 를 저 하늘 너머 로부터 내 길 을 비추 는 희망 의 빛 있 어 저 바다 끝 에서부터 내 맘 을 비추 는 희망 의 빛 있 어 한 발짝 다가가 네 그러 다 물러서 네 보이 지 않 는 앞 이 무서워서 손 을 내밀 어 보 네 머릴 흔들 어 보 네 내 가 서 있 는 길 이 아닐까 봐 나 혼자 되 지 않 기 를 나 홀로 남 지 않 기 를 저 하늘 너머 로부터 내 길 을 비추 는 희망 의 빛 있 어 저 바다 끝 에서부터 내 맘 을 비추 는 희망 의 빛 있 어 저 하늘 너머 로부터 내 길 을 비추 는 희망 의 빛 있 어 저 바다 끝 에서부터 내 맘 을 비추 는 희망 의 빛 있 어 저 하늘 너머 로부터 내 길 을 비추 는 희망 의 빛 있 어 저 바다 끝 에서부터 내 맘 을 비추 는 희망 의 빛 있 어 저 하늘 너머 로부터 내 길 을 비추 는 희망 의 빛 있 어 저 바다 끝 에서부터 내 맘 을 비추 는 희망 의 빛 있 어
# Right translation : <sos> 심야버스
# Predicted translation:  나 이 <eos>
# -------------------------------------------------- 59
# Input: 하얀 눈 이 내려 크리스마스 오 너 와 내 가 만든 크리스마스 오 서로 를 감싸안 고 걸으며 사랑 을 외쳐 봐 하얀 눈 이 내려 크리스마스 오 모두 함께 하 는 크리스마스 오 서로 를 감싸안 고 걸으며 행복 을 외쳐 봐 오 메리 크리스마스 아침 일찍 눈 을 뜨 고 설레 는 마음 으로 창문 을 열 면 꿈꿔 온 하얀 세상 에 나 도 모르 게 미소 가 져요 두 손 을 마주 잡 고 소망 을 가득 담 은 기도 그대 를 생각 하 며 사랑 을 가득 채운 내 선물 도 잊 지 마 요 하얀 눈 이 내려 크리스마스 오 너 와 내 가 만든 크리스마스 오 서로 를 감싸안 고 걸으며 사랑 을 외쳐 봐 하얀 눈 이 내려 크리스마스 오 모두 함께 하 는 크리스마스 오 서로 를 감싸안 고 걸으며 행복 을 외쳐 봐 오 메리 크리스마스 반짝 아름다운 수많 은 불빛 아래 함께 한다면 잊 었 던 따듯 한 마음 에 나 도 모르 게 미소 가 져요 두 손 을 마주 잡 고 소망 을 가득 담 은 기도 그대 를 생각 하 며 사랑 을 가득 채운 내 선물 도 잊 지 마 요 하얀 눈 이 내려 크리스마스 오 너 와 내 가 만든 크리스마스 오 서로 를 감싸안 고 걸으며 사랑 을 외쳐 봐 하얀 눈 이 내려 크리스마스 오 모두 함께 하 는 크리스마스 오 서로 를 감싸안 고 걸으며 행복 을 외쳐 봐 오 메리 크리스마스 하얀 눈 이 내려 크리스마스 오 너 와 내 가 만든 크리스마스 오 서로 를 감싸안 고 걸으며 사랑 을 외쳐 봐 하얀 눈 이 내려 크리스마스 오 모두 함께 하 는 크리스마스 오 서로 를 감싸안 고 걸으며 행복 을 외쳐 봐 오 메리 크리스마스
# Right translation : <sos> 이길 일 만 남 았 지
# Predicted translation:  나 의 <eos>
# -------------------------------------------------- 43
# Input: 여름 이 오 는 소리 에 넌 체중 계 를 꺼냈 어 해 마다 오 는 이벤트 라 대수롭 지 않 았 어 사실 난 지금 의 네 가 너무나 도 좋 은데 왜 너 만 몰라 왜 또 이러 는 걸까 그만 우울 한 표정 은 접 고 나와 맛있 는 것 들 을 해치우 자 널 기다리 는 이 식탁 을 외면 하 지 마 당신 의 도 사라지 지 않 게 해줘 당신 의 도 내겐 너무 소 중 해서 빛나 는 그대 가 이대로 영원히 남 아 주 기 를 변하 지 않 기 를 바 래 요 자꾸 만 네 가 기다려 지 는 밤 통화 너 를 설레 게 하 는 것 들 이 가득 한 이 밤 포기 하 면 편해질 거 야 당신 의 도 사라지 지 않 게 해줘 당신 의 도 내겐 너무 소 중 해서 빛나 는 그대 가 이대로 영원히 남 아 주 기 를 변하 지 않 기 를 바 래 요 영원 한 건 없 단 걸 그 누구 보다 잘 알 지만 내 가 너 를 사랑 하 는 단 하나 의 이유 도 달라지 지 않 기 를 바 래 당신 의 도 사라지 지 않 게 해줘 당신 의 도 내겐 너무 소 중 해서 빛나 는 그대 가 이대로 영원히 남 아 주 기 를 변하 지 않 기 를 바 래 요
# Right translation : <sos> 어떻게 그렇게 이렇 게
# Predicted translation:  <eos>
# -------------------------------------------------- 13
# Input: 아무 도 모를 거 야 어젯밤 뒤척 이 며 잠들 지 못 한 채 로 멈출 줄 모르 던 눈물 아무렇 지 않 은 척 살아가 는 게 난 너무 익숙 해 아무렇 지 않 은 척 웃 고 있 는 게 너무 쓸쓸 해질 때 내 앞 에 있 는 너 의 미소 가 너무 낯설 어 질 때 어젯밤 먼저 잠든 너 몰래 흘리 던 눈물 만 자꾸 생각 이나 아무 도 모를 거 야 어젯밤 뒤척 이 며 잠들 지 못 한 채 로 멈출 줄 모르 던 눈물 아무렇 지 않 은 척 살아가 는 게 난 너무 익숙 해 아무렇 지 않 은 척 웃 고 있 는 게 너무 쓸쓸 해질 때 내 앞 에 있 는 너 의 미소 가 너무 낯설 어 질 때 어젯밤 먼저 잠든 너 몰래 흘리 던 눈물 만 자꾸 생각 이나 생각 이 나 생각 이 나 생각 이 나 생각 이 나 생각 이 나 생각 이 나 생각 이 나 내 앞 에 있 는 너 의 미소 가 너무 낯설 어 질 때 어젯밤 먼저 잠든 너 몰래 흘리 던 눈물 만 자꾸 생각 이나
# Right translation : <sos> 하루 종일 널
# Predicted translation:  나 <eos>
# -------------------------------------------------- 29
# Input: 기억 에 갇혀 마음 을 잡혀 점차 빠져들 고 있 어 구해 줘 날 여태 지켜봐 왔 을 때 넌 좀 유별난 듯 해 왜 난 쉬운 일 이 없 어 알려줘 하나 쯤 보여 줘 하나 쯤 내게만 한 번 쯤 니 맘속 구해 줘 날 이렇 다 저렇 다 뭐 라도 말 좀 해 봐 너 만 은 놓치 기 싫 어 구해 줘 날 싱겁 게 끝낼 맘 없 어 날 쉽 게 보 지 마 할 만큼 다 해 볼 거 야 이제 시작 이 야 손 끝 에 감춰 시선 을 감춰 차차 다가가 고 있 어 안 되 겠 니 한 발 가까이 나가 면 두 발 멀 어 진 듯 해 도통 잡혀 주 질 않 아 열 어 줘 하나 쯤 풀 어 줘 하나 쯤 빈 틈 을 한 번 쯤 내 어 줘 안 되 겠 니 이렇게 저렇게 기회 를 한 번 줘 봐 너 만 은 놓치 기 싫 어 안 되 겠 니 싱겁 게 끝낼 맘 없 어 날 쉽 게 보 지 마 할 만큼 다 해 볼 거 야 이제 시작 이 야 나 에겐 기회 조차 안 주 는구나 너 도 싫 진 않 을 텐데 내 가 어떻게 해 줘야 니 가 날 받 아 줄 수 있 겠 니 뭐 가 문제 야 살짝 네 맘 찔러 보 면 너 는 깜짝 놀라 도망가 네 그래 순수 하 게 눈 딱 감 고 우리 갈 때 까지 가 보 자 막아서 지 마 날 막아서 지 마 찔러 보다 관 둘 관심 이 아냐 내 눈 을 봐 무슨 말 이 필요 해 너 느끼 는 그 대론 데 싱겁 게 끝낼 맘 없 어 날 쉽 게 보 지 마 할 만큼 다 해 볼 거 야 이제 시작 이 야
# Right translation : <sos> 나 의 이유
# Predicted translation:  <eos>
# -------------------------------------------------- 9
# Input: 가장 높 은 자 내게 오 셨 네 간절 한 사랑 나 를 지키 네 십자가 의 은혜 나 를 감싸 니 내 영혼 두렴 없 네 나 의 모든 삶 주 께 맡기 오니 주 여 인도 하 여 주 소서 고난 위 사랑 더 하 시 는 분 그 는 구세주 예수 하나님 이 세상 을 사랑 하사 독생자 를 주 셨으 니 저 를 믿 는 자 마다 멸망 치 않 고 영생 을 얻 게 함 이 라 귀한 생명 내 게 주 셨 네 주 님 말씀 방패 되 어 나 를 지키 고 주 의 사랑 생명 되 어 날 새롭 게 하 니 어둠 속 빛 을 찾아가 는 내 영혼 에 기쁨 의 찬양 넘치 네 선하 신 목자 내게 오 셨 네 따스 한 음성 맘 에 울리 네 그 의 사랑 안 에 내 가 거 하 니 내 영혼 평 안 얻 네 나 의 모든 삶 주 께 맡기 오니 주 여 인도 하 여 주 소서 고난 위 사랑 더 하 시 는 분 그 는 구세주 예수 하나님 이 세상 을 사랑 하사 독생자 를 주 셨으 니 저 를 믿 는 자 마다 멸망 치 않 고 영생 을 얻 게 함 이 라 귀한 생명 내 게 주 셨 네 주 의 말씀 방패 되 어 나 를 지키 고 주 의 사랑 생명 되 어 날 새롭 게 하 니 어둠 속 빛 을 찾아가 는 내 영혼 에 기쁨 의 찬양 넘치 네 기쁨 의 찬양 넘치 네
# Right translation : <sos> 화분
# Predicted translation:  나 의 <eos>
# -------------------------------------------------- 27
# Input: 그런 슬픈 표정 난 싫 었 어 미안 하 단 말 은 하 지 도 마 오 언젠가 너 도 나 를 생각 하 며 눈물 흘릴 때 가 있 을 거 야 오 그래 나 화나 는 건 사실 이 지 아직 까지 너 를 잊 지 못 한 내 가 싫 어 단 한 번 만 은 나 를 사랑 했 니 지금 까지 내게 한 말 거짓 이 었 니 오 이런 정말 가슴 이 무너져 너 를 사랑 했 던 내 가 내 가 너무 싫 어 이제 는 너 따윈 다 지워 버리 고 새로운 사랑 을 찾 겠 어 예 그래 나 화나 는 건 사실 이 지 아직 까지 너 를 잊 지 못 한 내 가 싫 어 단 한 번 만 은 나 를 사랑 했 니 지금 까지 내게 한 말 거짓 이 었 니 오 이런 정말 가슴 이 무너져 너 를 사랑 했 던 내 가 내 가 너무 싫 어 하 지만 너 내게 다시 돌아온다면 사실 은 고민 할 것 같 아 예 오오 이런 정말 가슴 이 무너져 너 를 사랑 했 던 내 가 내 가 너무 싫 어 하 지만 너 내게 다시 돌아온다면 사실 은 고민 할 것 같 아 예
# Right translation : <sos> 알 고 있 죠
# Predicted translation:  <eos>
# -------------------------------------------------- 78
# Input: 난 메이 킹 올 데 이 올 데 이 니 가 날 내버리 고 클럽 에 도장 찍 고 엉 덩일 흔들 어도 난 메이 킹 올 데 이 올 데 이 올 데 이 올 데 이 올 데 이 니 가 날 내버리 고 클럽 에 도장 찍 고 엉 덩일 흔들 어도 난 메이 킹 올 데 이 혼자 서 만 남 았 지 환기 안 되 는 방 에서 너 에 뒤 를 따랐 지 맛있 는 게 있 어 서 난 마치 강아지 니 가 귀여워 했었 지 주 는 척 안 주 는 게 얼마나 나쁜지 난 계속 괜찮 아 지 고 있 어 요즘 넌 어디 서 엉 덩일 흔들 고 있 어 몰입 해 니 가 없 는 공간 에서 또 졸리 네 또 졸리 네 난 메이 킹 올 데 이 올 데 이 니 가 날 내버리 고 클럽 에 도장 찍 고 엉 덩일 흔들 어도 난 메이 킹 올 데 이 올 데 이 올 데 이 올 데 이 올 데 이 니 가 날 내버리 고 클럽 에 도장 찍 고 엉 덩일 흔들 어도 난 메이 킹 올 데 이 만남 이 던 숙취 던 간 에 전부 지나갈 뿐 너 를 기다렸 었 던 시간 만큼 이 시원 한 밤 굳이 니 가 필요 할까 어쩌 네 저쩌 네 해도 내 가 볼 땐 오른손 만 한 게 없 기에 사실 은 조금 샘 이나 니 빵 댕 이 가 향 하 게 될 그 새끼 가 나 보다 짧 았 으면 해 그래 난 찌질 이 변태 휴지 에 너 를 뭉쳐 버려 버리 고 난 메이 킹 올 데 이 올 데 이 니 가 날 내버리 고 클럽 에 도장 찍 고 엉 덩일 흔들 어도 난 메이 킹 올 데 이 올 데 이 올 데 이 올 데 이 올 데 이 니 가 날 내버리 고 클럽 에 도장 찍 고 엉 덩일 흔들 어도 난 메이 킹 올 데이
# Right translation : <sos> 슬픈 기대
# Predicted translation:  <eos>
# -------------------------------------------------- 47
# Input: 저 달 이 우릴 밝힐 때 아무 말 없이 내 맘 을 전해 내 꿈 처럼 너 와 함께 행복 한 그림 을 그릴 래 지금 이 상황 이 힘들 어도 우린 해낼 거 야 괜히 신경 쓰 지 마 이 흐름 이 너 와 날 위해 서 감싸 안 아 줘 저 하늘 너머 무지 갤 그려서 꿈 꾸 던 곳 으로 떠나 고 싶 어 시간 이 걸려도 할 수 있 어 널 위해 선 이 젠 무섭 지 않 아 너 만 있 다면 걱정 은 내려놔 저 하늘 도 반겨 줘 가끔 내 가 바보 같 아도 지금 처럼 날 보 고 웃 어 줘 언제나 지금 처럼 힘 이 되 어 줘 보 고 싶 어서 전화 를 했 어 목소릴 들으면 기분 이 좋 아 져 보 러 갈 게 어서 끝날 때 맞춰서 비 와 눈 이 와도 갈 게 너 를 데리 러 걱정 이 된다 해도 나 만 믿 어 줄 래 아직 부족 해도 너 생각 만해 눈 을 떠도 계속 담 고 싶 어 내 눈 에 너 말 곤 어디 에 속 하 지 않 아 부를 땐 다른 사람 말 은 들리 지 않 아 다정 하 게 불러줄 사람 너 야 이런 날 사랑 해 준 너 잖 아 평생 감사 해야 할 사람 은 나 야 이 젠 무섭 지 않 아 너 만 있 다면 걱정 은 내려놔 저 하늘 도 반겨 줘 가끔 내 가 바보 같 아도 지금 처럼 날 보 고 웃 어 줘 언제나 지금 처럼 힘 이 되 어 줘 저 구름 위 에 너 와 올라가 서 그리 고 싶 어 함께 했 던 기억 들 을 모아서 이런 널 놓치 지 않 을래 네 목소리 가 내게 들릴 때 설렘 을 확인 하 게 되 우리 둘 만 알 수 있 게 이 젠 무섭 지 않 아 너 만 있 다면 둘 만 알 수 있 게 걱정 은 내려놔 저 하늘 도 반겨 줘 설렘 을 확인 하 게 되 가끔 내 가 바보 같 아도 목소리 가 네 게 들릴 때 지금 처럼 날 보 고 웃 어 줘 언제나 지금 처럼 힘 이 되 어 줘 이 젠 무섭 지 않 아 너 만 있 다면 걱정 은 내려놔 저 하늘 도 반겨 줘 가끔 내 가 바보 같 아도 지금 처럼 날 보 고 웃 어 줘 언제나 지금 처럼 힘 이 되 어 줘
# Right translation : <sos> 아마란스
# Predicted translation:  <eos>
# -------------------------------------------------- 65
# Input: 얼씨구 좋 다 지화 자 좋 다 내 사랑 당신 이 못 말리 게 좋 다 난 오직 당신 밖에 없 다 내 사랑 생각 에 덩실 춤 이 난다 잘 생기 지 않 아도 키 가 크 지 않 아도 내 눈 에 는 매력 이 철철 넘쳐 흘러요 이 세상 에 그 누가 당신 만큼 멋질 까 내 눈 에 는 당신 이 최고 넘버원 이 야 사랑 을 멈출 수 가 없 어요 내 사랑 오직 당신 뿐 인 걸 남 들 은 나 를 보 고 사랑 에 빠져 버린 바 보 라 말 들 하지만 얼씨구 좋 다 지화 자 좋 다 내 사랑 당신 이 못 말리 게 좋 다 난 오직 당신 밖에 없 다 내 사랑 생각 에 덩실 춤 이 난다 잘 생기 지 않 아도 키 가 크 지 않 아도 내 눈 에 는 당신 이 최고 넘버원 이 야 사랑 을 멈출 수 가 없 어요 내 사랑 오직 당신 뿐 인 걸 남 들 은 나 를 보 고 사랑 에 빠져 버린 바 보 라 말 들 하지만 얼씨구 좋 다 지화 자 좋 다 내 사랑 당신 이 못 말리 게 좋 다 난 오직 당신 밖에 없 다 내 사랑 생각 에 덩실 춤 이 난다 덩실 춤 이 난다 덩실 춤 이 난다
# Right translation : <sos> 넌 날 아프 게 해
# Predicted translation:  <eos>
# -------------------------------------------------- 6
# Input: 사랑 했잖아 우리 함께 한 많 은 날 동안 함께 아파 했 잖아 서로 의 일 인 줄 도 모르 고 넌 어디 있 는 거 니 나 의 목소리 들리 질 않 니 아픈 내 심장 이 너 를 찾 는다 너 를 부른다 미치 도록 가슴 이 눈물 이 또 너 의 기억 이 한 방울 한 방울 또 내 가슴 에 흘러 내 린다 울 어도 울 어도 지워 지 않 는 기억 을 따라 오늘 도 빈 내 가슴 을 또 적신 다 좋 아 했잖아 작 은 내 미소 에 웃 어 줬 잖아 함께 울 었었 잖아 나 의 눈물 에 아파 했 잖아 지금 어디 있 는 거 니 지친 내 모습 이 보이 질 않 니 아픈 내 심장 이 너 를 찾 는다 너 를 부른다 미치 도록 가슴 이 눈물 이 또 너 의 기억 이 한 방울 한 방울 또 내 가슴 에 흘러 내 린다 울 어도 울 어도 지워 지 않 는 기억 을 따라 오늘 도 빈 내 가슴 을 또 적신 다 내게로 돌아와 줄 래 매일 네 이름 부르 며 지친 기 다림 속 에 너 를 찾 아 헤매 는 나 잖 아 사랑 이 눈물 이 너 와 의 추억 이 한 방울 한 방울 또 내 가슴 에 흘러 내 린다 울 어도 울 어도 지워 지 않 는 기억 을 따라 오늘 도 빈 내 가슴 을 또 적신 다
# Right translation : <sos> 출입금 지
# Predicted translation:  사랑 의 <eos>
# -------------------------------------------------- 82
# ...
# Input: 한 여름 에 목도 릴 선물 받 은 기분 일까 요 비슷 할까 요 준다고 준 마음 이 이 것 밖에 안 되 는 걸 요 그대 에게 난 나 에게 는 용기 라 부르 겠 지만 그대 에게 는 부담 이 라 불리 겠 죠 그 댄 나 에게 한 여름 그늘 이 지만 난 그대 에게 한 겨울 바람 이 겠 죠 다 버리 고 남 은 맘 이렇게 나 많 은 걸 보 니 꽤 깊 었 나 봐요 나 에게 는 용기 라 부르 겠 지만 그대 에게 는 부담 이 라 불리 겠 죠 그 댄 나 에게 한 여름 그늘 이 지만 난 그대 에게 한 겨울 바람 이 겠 죠 보 고 싶 어요 내 이름 환히 부르 며 날 찾 아 주 는 그대 의 손짓 한 여름 에 목도 릴 선물 받 은 기분 일까 요 그런 거 겠 죠
# Right translation : <sos> 세상 을 마주 하 는 방법
# Predicted translation:  <eos>
# -------------------------------------------------- 77
# Input: 그저 사막 을 지나 간다 덥 다 사랑 찾 아 끝없이 간다 꽤 덥 다 사막 이 끝 이 나 면 올까 내 사랑 기대 조차 버겁 다 아직 도 뜨겁 다 뜨거운 태양 을 등지 고 걷 다 보 면 끝 없 는 모래밭 언젠가 사 라 질까 희망 은 신기루 로 끝나 버리 고 무수 한 별 자 릴 의지 해 걷 다 보 면 푸른 오아시스 엔 내 사랑 있 을까 사막 이 끝 이 나 고 초원 이 나오 면 있 을까 단 한 톨 희망 도 버리 지 말 아야 지 그리움 을 떨칠 곳 을 찾 아 걷 는다 어떻게 도 표현 할 방법 이 없 어 예 예 예 나 의 몸 이 불타 오른 대 도 이 모든 게 날아가 버려도 그대 만 을 찾 는 내 마음 은 그저 사막 을 지나 간다 덥 다 사랑 찾 아 끝없이 간다 꽤 덥 다 사막 이 끝 이 나 면 올까 내 사랑 기대 조차 버겁 다 아직 도 뜨겁 다 기약 없이 걸어도 기대 는 커 지 는데 정작 내 신발 속 모래 만 쌓여 가 고 가슴 속 깊숙이 엔 무엇 도 남 질 않 는구나 어떻게 도 표현 할 방법 이 없 어 예 예 예 나 의 몸 이 불타 오른 대 도 이 모든 게 날아가 버려도 그대 만 을 찾 는 내 마음 은 그저 사막 을 지나 간다 덥 다 사랑 찾 아 끝없이 간다 꽤 덥 다 사막 이 끝 이 나 면 올까 내 사랑 기대 조차 버겁 다 아직 도 뜨겁 다 그래도 뜨거워 쓰러진 뜨거운 태양 아 지겨워 쓰러진 끝 없 는 모래밭 이 여 날아가 사라진 그대 를 향 한 내 마음 어떤 미련 도 없이 그저 걸 을 뿐 예 어떻게 도 표현 할 방법 이 없 어 예 예 예 나 의 몸 이 불타 오른 대 도 이 모든 게 날아가 버려도 그대 만 을 찾 는 내 마음 은 그저 사막 을 지나 간다 덥 다 사랑 찾 아 끝없이 간다 꽤 덥 다 사막 이 끝 이 나 면 올까 내 사랑 기대 조차 버겁 다 아직 도 뜨겁 다 그저 사막 을 지나 간다 덥 다 사랑 찾 아 끝없이 간다 꽤 덥 다 사막 이 끝 이 나 면 올까 내 사랑 기대 조차 버겁 다 아직 도 뜨겁 다
# Right translation : <sos> 나 여기 에
# Predicted translation:  나 <eos>
# -------------------------------------------------- 93
# Input: 너 와 내 가 던 장소 지금 은 사라졌 어 햇살 가득 비춰 지 던 창가 쪽 그 자리 도 너 와 나 는 그 장소 들 처럼 희미 해져 만 가 네 너 와 나 는 예전 처럼 돌아갈 수 없 나 오늘 도 그 곳 엘 가 봤 지만 너 는 없 어 어디 에 도 나 는 널 기다려 쉽 지 않 아 널 놓 는 게 지우 는 게 너 와 내 가 함께 걷 던 그 길 을 걷 고 있 어 오늘 하루 어땠 는지 물 어 줄 넌 없 지만 너 와 나 는 그 대화 들 처럼 희미 해져 만 가 네 너 와 나 는 예전 처럼 돌아갈 수 없 나 오늘 도 그 곳 엘 가 봤 지만 너 는 없 어 어디 에 도 나 는 널 기다려 쉽 지 않 아 널 놓 는 게 지우 는 게 미안 해 이기 적 인 모습 보 여서 단 한 번 만 단 한 번 만 기회 를 줘 오늘 도 그 곳 엘 가 봤 지만 너 는 없 어 너 는 없 어 어디 에 도 어디 에 도 어디 서 도 찾 을 수 없 어 나 는 널 기다려 쉽 지 않 아 널 놓 는 게 널 놓 을 수 가 없 어 지우 는 게 난 너 를 지울 수 없 어
# Right translation : <sos> 바보 같 은 내게
# Predicted translation:  <eos>
# -------------------------------------------------- 2
# Input: 부엉 밤 이 깊 어 가 도 나 는 잠들 지 않 아 부엉 부 부엉 깊 은 밤 을 지키 는 갈색 부엉이 아홉 시 열 한 시 자정 넘 어 아침 까지 동그란 두 눈 은 절대로 감기 지 않 아 나 는 졸리 지 않 아 부엉 밤 이 깊 어 가 도 나 는 잠들 지 않 아 부엉 부 부엉 깊 은 밤 을 지키 는 갈색 부엉이 고고 한 갈색 깃털 노란색 깊 은 두 눈 귀엽 게 보이 지만 용감 하 게 밤 을 지키 죠 나 는 잠들 지 않 아 부엉 밤 이 깊 어 가 도 나 는 잠들 지 않 아 부엉 부 부엉 깊 은 밤 을 지키 는 갈색 부엉이 잠 이 안 오 면 날 찾아와요 부엉
# Right translation : <sos> 고백 해 본다
# Predicted translation:  <eos>
# -------------------------------------------------- 38
# Input: 소 처럼 매일 일 을 해봐도 예전 이나 지금 이나 무엇 하나 도 매번 그 자리 나아진 게 없 구나 아가 야 아가 야 이리 좀 오 너 라 애비 의 어깨 좀 주물러 다 오 싫 다며 투정 부리 던 내 모습 에 눈물 이 나 요 자식 하나 잘 되 기 만 을 바라 셨 던 울 아부지 새벽 눈 뜨 면 내 가 깰 새 라 도둑 걸음 걸 으 시 며 거친 수염 이 내 볼 찌를까 입맞춤 도 못 하 셨 네 아가 야 아가 야 이리 좀 오 너 라 애비 의 어깨 좀 주물러 다 오 싫 다며 투정 부리 던 내 모습 에 눈물 이 나 요 자식 하나 잘 되 기 만 을 바라 셨 던 울 아부지 자식 하나 잘 되 기 만 을 바라 셨 던 울 아부지
# Right translation : <sos> 친구 였 다면
# Predicted translation:  <eos>
# -------------------------------------------------- 84
# Input: 심심 해 심심 해 도깨비 는 심심 해 짝짝 심심 해 심심 해 도깨비 는 심심 해 짝짝 아이 들 도 바빠 어른 들 도 바빠 모두 다 바쁘 대 짝짝 다 바쁘 면 도깨비 는 누구 랑 놀 아 흠 흠 바쁘 대 바쁘 대 아이 들 도 바쁘 대 짝짝 바쁘 대 바쁘 대 아이 들 도 바쁘 대 짝짝 다 바쁘 면 도깨비 는 누구 랑 놀 아 음음 해 를 따라 가 볼까 강 을 따라 가 볼까 숲 속 에서 사 는 아이 들 찾 아 떠나 볼까 찾 았 대 찾 았 대 숲 친구 들 찾 았 대 짝짝 찾 았 대 찾 았 대 숲 친구 들 찾 았 대 짝짝 아이 들 도 놀 아 어른 들 도 놀 아 모두 다 즐겁 대 짝짝 다 바쁘 면 도깨비 는 누구 랑 놀 아 흠 흠 즐겁 대 즐겁 대 아이 들 도 즐겁 대 짝짝 즐겁 대 즐겁 대 아이 들 도 즐겁 대 짝짝 다 바쁘 면 도깨비 는 누구 랑 놀 아 음음 해 를 따라 가 볼까 강 을 따라 가 볼까 숲 속 에서 사 는 아이 들 찾 아 떠나 볼까
# Right translation : <sos> 낭만 의 밤
# Predicted translation:  <eos>
# -------------------------------------------------- 25
# Input: 니 가 가진 게 부러워 니 모습 이 난 부러워 나 도 너 와 같 은 색 으로 나 를 칠하 고 싶 어 난 닮 아 가려 애 를 써 빛나 보이 는 저 모습 들 이 나 완 달라 보이 는 게 부러워 이 밤 은 또 다시 찾 아 오 고 어둠 은 나 를 또 삼켜 오 고 나 는 또 내 안 에 숨 어 버리 고 내 안 에 불씨 는 작아지 네 언 젠 간 나 도 나 다운 날 보 며 웃 을 수 있 을까 나 도 언 젠 간 날 사랑 할 수 있 을까 난 나 를 다시 잃 어 가 난 내 앞 에 등 을 돌려 난 나 와 다시 멀 어 져 더 멀 어 져 뒷걸음 쳐 가끔 은 내 가 우스워 나 답 지 않 은 나 를 볼 때 마다 여전히 다른 조각 들 로 날 채워 넣 어 언 젠 간 나 도 나 다운 날 보 며 웃 을 수 있 을까 나 도 언 젠 간 날 사랑 할 수 있 을까 날 안 아 주 고 싶 지만 난 내 앞 에 등 을 돌려 난 나 와 다시 멀 어 져 더 멀 어 져 뒷걸음 쳐 어쩌면 난 항상 그랬 어 이제 난 언 젠 간 나 도 너 처럼 빛나 보일 수 있 을까 나 도 언 젠 간 진짜 날 찾 을 수 있 을까 날 안 아 주 고 싶 지만 난 내 앞 에 등 을 돌려 난 나 를 다시 밀어내 더 멀 어 져 뒷걸음 쳐
# Right translation : <sos> 맥아더
# Predicted translation:  나 이 <eos>
# -------------------------------------------------- 75
# Input: 비 가 비 가 내리 고 있 어 함께 걷 던 그 여인 은 떠나가 고 빗속 에 나 만 혼자 외로이 서 있 네 누군가 를 사랑 한다면 아낌없이 내 모든 걸 바쳐야 해 빗물 이 눈물 되 어 흐르 지 않 도록 어제 그 님 이 나 에게 는 전부 라 달빛 에 입맞춤 하 고 오늘 은 서로 돌 아서 헤어지 고 비 만 내리 면 둘 곳 없 는 마음 에 추억 을 찾 아 헤매 다 그리움 속 에 하늘 만 바라보 네 비 가 비 가 내리 고 있 어 사랑 하 던 그 여인 은 떠나가 고 빗속 에 나 만 혼자 외로이 서 있 네 어제 그 님 이 나 에게 는 전부 라 별빛 에 입맞춤 하 고 오늘 은 서로 돌 아서 남 이 되 고 비 만 내리 면 둘 곳 없 는 마음 에 추억 을 찾 아 헤매 다 그리움 속 에 하늘 만 바라보 네 비 가 비 가 내리 고 있 어 사랑 하 던 그 여인 은 떠나가 고 빗속 에 나 만 혼자 외로이 서 있 네
# Right translation : <sos> 한방
# Predicted translation:  <eos>
# -------------------------------------------------- 64
# Input: 잠깐 그대 는 내 맘 속 서랍 에 닫 아 놓 고 나 의 시간 을 살 아 갈께요 아름답 게 내린 축복 같 은 눈빛 사이 로 흘러가 는 여름밤 따 뜻 했 던 외로움 도 멈추 고 라 닿 을 수 없 는 마음 의 달빛 의 바다 바람 같 은 우리 의 박제 된 시간 얼마나 기다려야 흘러갈 런 지 그대 눈길 에 다 이해 됐었 던 그 때 그 맘 으로 내일 을 살 아 갈께요 보이 지 않 아도 두 눈 에 보이 는 것 처럼 나 들리 지 않 아도 귓가 에 울려오 는 것 처럼 라 닿 을 수 없 는 마음 의 달빛 의 바다 바람 같 은 우리 의 박제 된 시간 얼마나 흘러 다시 흘러갈 런 지
# Right translation : <sos> 갈 생각 있 어
# Predicted translation:  나 의 <eos>
# -------------------------------------------------- 51
# Input: 시간 을 멈추 고 나 홀로 떠나 고 싶 어 잠 도 오 지 않 는 이 밤 에 두 눈 을 감 고서 조용히 숨쉬 고 싶 어 하 지만 또 생각 에 잠 못 이루 네 한 살 한 살 나이 가 들어가 면 갈수록 나 는 철 없 는 꿈 만 꾸 는구나 오예 믿 어 왔 던 친구 도 설레였 던 사랑 도 나 를 비웃 듯이 멀 어 져 가 네 사람 을 만나 고 즐기 고 맘 을 다 줘도 결국 남 는 것 은 상처 뿐 젊음 을 다 바쳐 끝없이 도전 하 지만 성공 도 내 실패 도 보이 질 않 아 한 살 한 살 나이 가 들어가 면 갈수록 나 는 철 없 는 꿈 만 꾸 는구나 오예 믿 어 왔 던 친구 도 설레였 던 사랑 도 나 를 비웃 듯이 멀 어 져 가 네 하지만 또 웃 으며 난 살아가 네
# Right translation : <sos> 누구 라도 그러 하 듯이
# Predicted translation:  <eos>
# -------------------------------------------------- 14
# Input: 분명 아까 말 한 듯 한데 왠지 모자란 듯 한 오늘 너무 예쁘 다는 말 번 째 라고 그러 면 안 한 거 야 한참 모자라 지 번 정도 는 해야지 터질 것 같 은 널 향 한 나 의 마음 이 그 래야 얌전 해 질 것 같 단 말 야 솔직히 너 도 좋 잖은 가 너무 예쁘 다는 말 자꾸 들 어 지겹 겠 지만 어쩔 수 없 어 그러 면 안 한 거 야 한참 모자라 지 번 정도 는 해야지 터질 것 같 은 널 향 한 나 의 마음 이 그 래야 얌전 해 질 것 같 단 말 야 솔직히 너 도 좋 잖은 가 너무 예쁘 다는 말 자꾸 들 어 지겹 겠 지만 어쩔 수 없 어 터질 것 같 은 널 향 한 나 의 마음 이 그 래야 얌전 해 질 것 같 단 말 야
# Right translation : <sos> 절망 의 늪
# Predicted translation:  나 이 <eos>
# -------------------------------------------------- 89
# Input: 한 여름 에 목도 릴 선물 받 은 기분 일까 요 비슷 할까 요 준다고 준 마음 이 이 것 밖에 안 되 는 걸 요 그대 에게 난 나 에게 는 용기 라 부르 겠 지만 그대 에게 는 부담 이 라 불리 겠 죠 그 댄 나 에게 한 여름 그늘 이 지만 난 그대 에게 한 겨울 바람 이 겠 죠 다 버리 고 남 은 맘 이렇게 나 많 은 걸 보 니 꽤 깊 었 나 봐요 나 에게 는 용기 라 부르 겠 지만 그대 에게 는 부담 이 라 불리 겠 죠 그 댄 나 에게 한 여름 그늘 이 지만 난 그대 에게 한 겨울 바람 이 겠 죠 보 고 싶 어요 내 이름 환히 부르 며 날 찾 아 주 는 그대 의 손짓 한 여름 에 목도 릴 선물 받 은 기분 일까 요 그런 거 겠 죠
# Right translation : <sos> 세상 을 마주 하 는 방법
# Predicted translation:  <eos>
# -------------------------------------------------- 77
# Input: 당신 은 비타민 나 는 나 는 사이다 인생 살 다 보 면 음지 양지 있 지요 인생 세모 네모 힘 들 기 만 하 지요 동그라미 그리고 살아요 손 을 들 어 박수 치 면 만 병 통치 약 한 번 두 번 세 번 치 면 엔 돌핀 돌 죠 당신 은 비타민 나 는 나 는 사이다 웃 으면 복 이 와요 몸 도 맘 도 즐거워 당신 있 기 에 행복 합니다
# Right translation : <sos> 우린 너무나 달라
# Predicted translation:  사랑 의 <eos>
# -------------------------------------------------- 10
# Input: 니 가 가진 게 부러워 니 모습 이 난 부러워 나 도 너 와 같 은 색 으로 나 를 칠하 고 싶 어 난 닮 아 가려 애 를 써 빛나 보이 는 저 모습 들 이 나 완 달라 보이 는 게 부러워 이 밤 은 또 다시 찾 아 오 고 어둠 은 나 를 또 삼켜 오 고 나 는 또 내 안 에 숨 어 버리 고 내 안 에 불씨 는 작아지 네 언 젠 간 나 도 나 다운 날 보 며 웃 을 수 있 을까 나 도 언 젠 간 날 사랑 할 수 있 을까 난 나 를 다시 잃 어 가 난 내 앞 에 등 을 돌려 난 나 와 다시 멀 어 져 더 멀 어 져 뒷걸음 쳐 가끔 은 내 가 우스워 나 답 지 않 은 나 를 볼 때 마다 여전히 다른 조각 들 로 날 채워 넣 어 언 젠 간 나 도 나 다운 날 보 며 웃 을 수 있 을까 나 도 언 젠 간 날 사랑 할 수 있 을까 날 안 아 주 고 싶 지만 난 내 앞 에 등 을 돌려 난 나 와 다시 멀 어 져 더 멀 어 져 뒷걸음 쳐 어쩌면 난 항상 그랬 어 이제 난 언 젠 간 나 도 너 처럼 빛나 보일 수 있 을까 나 도 언 젠 간 진짜 날 찾 을 수 있 을까 날 안 아 주 고 싶 지만 난 내 앞 에 등 을 돌려 난 나 를 다시 밀어내 더 멀 어 져 뒷걸음 쳐
# Right translation : <sos> 맥아더
# Predicted translation:  나 이 <eos>
# -------------------------------------------------- 75
# Input: 기억 에 갇혀 마음 을 잡혀 점차 빠져들 고 있 어 구해 줘 날 여태 지켜봐 왔 을 때 넌 좀 유별난 듯 해 왜 난 쉬운 일 이 없 어 알려줘 하나 쯤 보여 줘 하나 쯤 내게만 한 번 쯤 니 맘속 구해 줘 날 이렇 다 저렇 다 뭐 라도 말 좀 해 봐 너 만 은 놓치 기 싫 어 구해 줘 날 싱겁 게 끝낼 맘 없 어 날 쉽 게 보 지 마 할 만큼 다 해 볼 거 야 이제 시작 이 야 손 끝 에 감춰 시선 을 감춰 차차 다가가 고 있 어 안 되 겠 니 한 발 가까이 나가 면 두 발 멀 어 진 듯 해 도통 잡혀 주 질 않 아 열 어 줘 하나 쯤 풀 어 줘 하나 쯤 빈 틈 을 한 번 쯤 내 어 줘 안 되 겠 니 이렇게 저렇게 기회 를 한 번 줘 봐 너 만 은 놓치 기 싫 어 안 되 겠 니 싱겁 게 끝낼 맘 없 어 날 쉽 게 보 지 마 할 만큼 다 해 볼 거 야 이제 시작 이 야 나 에겐 기회 조차 안 주 는구나 너 도 싫 진 않 을 텐데 내 가 어떻게 해 줘야 니 가 날 받 아 줄 수 있 겠 니 뭐 가 문제 야 살짝 네 맘 찔러 보 면 너 는 깜짝 놀라 도망가 네 그래 순수 하 게 눈 딱 감 고 우리 갈 때 까지 가 보 자 막아서 지 마 날 막아서 지 마 찔러 보다 관 둘 관심 이 아냐 내 눈 을 봐 무슨 말 이 필요 해 너 느끼 는 그 대론 데 싱겁 게 끝낼 맘 없 어 날 쉽 게 보 지 마 할 만큼 다 해 볼 거 야 이제 시작 이 야
# Right translation : <sos> 나 의 이유
# Predicted translation:  <eos>
# -------------------------------------------------- 9
# Input: 전주 중 한 걸음 두 걸음 골목길 걸 을 때 들려오 는 찬양 소리 에 어깨 를 흔들 며 밤하늘 보 면은 우리 주 님 내 온 십자 가 아무리 바라보 고 바라보 아도 그 사랑 알 수 가 없 어 기쁜 날 을 주 신 나 의 예수 님 나 항상 흥 에 겨워 요 나 는 예수 님 이 정말로 좋 아요 나 항상 사랑 할래요 간주 중 아무리 바라보 고 바라 보 아도 그 사랑 알 수 가 없 어 기쁜 날 을 주 신 나 의 예수 님 나 항상 흥 에 겨워 요 나 는 예수 님 이 정말로 좋 아요 나 항상 사랑 할래요 나 는 예수 님 이 정말로 좋 아요 나 항상 사랑 할래요
# Right translation : <sos> 우리 시작 해도 괜찮 을까요
# Predicted translation:  <eos>
# -------------------------------------------------- 60
# Input: 기억 에 갇혀 마음 을 잡혀 점차 빠져들 고 있 어 구해 줘 날 여태 지켜봐 왔 을 때 넌 좀 유별난 듯 해 왜 난 쉬운 일 이 없 어 알려줘 하나 쯤 보여 줘 하나 쯤 내게만 한 번 쯤 니 맘속 구해 줘 날 이렇 다 저렇 다 뭐 라도 말 좀 해 봐 너 만 은 놓치 기 싫 어 구해 줘 날 싱겁 게 끝낼 맘 없 어 날 쉽 게 보 지 마 할 만큼 다 해 볼 거 야 이제 시작 이 야 손 끝 에 감춰 시선 을 감춰 차차 다가가 고 있 어 안 되 겠 니 한 발 가까이 나가 면 두 발 멀 어 진 듯 해 도통 잡혀 주 질 않 아 열 어 줘 하나 쯤 풀 어 줘 하나 쯤 빈 틈 을 한 번 쯤 내 어 줘 안 되 겠 니 이렇게 저렇게 기회 를 한 번 줘 봐 너 만 은 놓치 기 싫 어 안 되 겠 니 싱겁 게 끝낼 맘 없 어 날 쉽 게 보 지 마 할 만큼 다 해 볼 거 야 이제 시작 이 야 나 에겐 기회 조차 안 주 는구나 너 도 싫 진 않 을 텐데 내 가 어떻게 해 줘야 니 가 날 받 아 줄 수 있 겠 니 뭐 가 문제 야 살짝 네 맘 찔러 보 면 너 는 깜짝 놀라 도망가 네 그래 순수 하 게 눈 딱 감 고 우리 갈 때 까지 가 보 자 막아서 지 마 날 막아서 지 마 찔러 보다 관 둘 관심 이 아냐 내 눈 을 봐 무슨 말 이 필요 해 너 느끼 는 그 대론 데 싱겁 게 끝낼 맘 없 어 날 쉽 게 보 지 마 할 만큼 다 해 볼 거 야 이제 시작 이 야
# Right translation : <sos> 나 의 이유
# Predicted translation:  <eos>
# -------------------------------------------------- 9
# Input: 첫 눈 에 알 았 지 내 사람 이 란 걸 날 보 고 웃 고 있 네 난 행복 해 요 첫 눈 이 내리 던 날 눈송이 처럼 내게 살포시 내 안 에 스며들 어 왔 죠 그대 와 매일 눈 감 고 또 눈 을 뜨 는 아침 꿈꿔 온 희망 을 나 에게 준 사랑 그대 를 처음 본 순간 온 몸 이 짜릿짜릿 해 티 없이 깨끗 한 아름다운 눈빛 첫 눈 에 알 았 지 내 사람 이 란 걸 날 보 고 웃 고 있 네 난 행복 해 요 첫 눈 이 내리 던 날 눈송이 처럼 내게 살포시 내 안 에 스며들 어 왔 죠 그대 와 매일 눈 감 고 또 눈 을 뜨 는 아침 꿈꿔 온 희망 을 나 에게 준 사랑 반짝 빛나 는 그대
# Right translation : <sos> 그렇게 웃 어 줘
# Predicted translation:  나 의 <eos>
# -------------------------------------------------- 61
# Input: 나 이제 너 에게 하 고 픈 말 들 은 접 은 채 내밀 은 카레 어제 의 카레 의 알 싸 한 향기 는 숨긴 채 너 에게 차갑 게 굳 었 던 어제 의 카레 차갑 게 식 었 던 어제 의 내 마음 나 이제 너 에게 하 고 픈 말 들 은 접 은 채 내밀 은 카레 어제 의 카레 의 알 싸 한 향기 는 숨긴 채 너 에게 차갑 게 굳 었 던 어제 의 카레 차갑 게 식 었 던 어제 의 내 마음
# Right translation : <sos> 아름다운 내 사랑
# Predicted translation:  나 의 <eos>
# -------------------------------------------------- 80
# Input: 오늘 따라 그대 의 얼굴 엔 먹구름 이 무슨 일 있 나요 하늘 도 참 맑 은데 뺨 을 스치 는 공기 다 너무 좋 은데 그 누구 도 내 그대 를 아프 게 할 순 없 어 나 는 못 봐요 꼭 내게 말 해 주 세요 나 그대 의 편 이 돼 줄 게 내 가 그 댈 안 아 줄 게 요 한 걸음 더 다가갈 게 요 아프 지 않 게 손 잡 아 줄게요 그대 눈빛 을 보 면 달 의 뒷 면 을 보 는 것 만 같 아서 내 가 더 불안 해 요 그대 의 그늘 이 돼 줄 게 내 가 그 댈 안 아 줄 게 요 한 걸음 더 다가갈 게 요 아프 지 않 게 손 잡 아 줄게요 그대 내 가 그 댈 사랑 할게요 항상 곁 에 있 을 거 예요 아프 지 마 요 우리 행복 해 봐요 그대
# Right translation : <sos> 무너져 내리 는 나
# Predicted translation:  나 의 <eos>
# -------------------------------------------------- 1
# Input: 항상 웃음 가득 했 던 너 인데 요즘 은 달라졌 어 혹시 나 힘든 일 이 생긴 거 니 내 게 살짝 말 해 봐 걱정 말 라며 날 다독여 주 는 너 왜 아무렇 지 않 은 척 해 그럴 필요 없 어 내 가 왜 있 는데 나 는 니 편이 잖 아 부족 하 고 약한 나 지만 너 에게 나 힘 이 된다면 무엇 이 라도 하 고 싶 어 이 젠 누구 보다 강한 널 알 아 하 지만 니 가 힘들 때 면 가끔 은 넌 내게 기대 도 돼 항상 넓 기 만 했 던 니 어깨 가 어쩐지 힘 이 없 어 내 가 힘 이 될 수 있 는 게 있 을까 뭐 든지 해 주 고 싶 어 약속 했 었잖 아 모두 가 변해도 나 는 니 편 이 라고 부족 하 고 약한 나 지만 너 에게 나 힘 이 된다면 무엇 이 라도 하 고 싶 어 이 젠 누구 보다 강한 널 알 아 하 지만 니 가 힘들 때 면 가끔 은 넌 내게 기대 도 돼 내 가 아프 고 힘들 때 도 언제나 곁 에 있 어 준 너 이 젠 내 가 더 힘 이 돼 줄 게
# Right translation : <sos> 자동기술법
# Predicted translation:  <eos>
# -------------------------------------------------- 52
# Input: 그 댄 더욱 아름다운 나 의 사람 이 죠 그 댄 나와 달라질 게 없 는 사람 그 댄 더욱 아름다운 나 의 사람 이 죠 날 바라 봐요 내 가 기도 해 요 그대 안 에 있 는 사람 너 를 기다리 는 나 의 소망 과 그 미소 속 에 눈빛 과 자라나 는 또 커져 버린 걸 알 아 버린 모습 과 그대 이별 이란 없 는 얼굴 과 또 사랑 이 란 말 내 안 에 있 는 걸 그대 가 있 는 걸 그 댄 더욱 아름다운 나 의 사람 이 죠 그 댄 나 와 같 아 변함 없 는 사람 그 댄 더욱 아름다운 나 의 사람 이 죠 날 바라 봐요 내 가 기도 해 요 그대 안 에 있 는 사람 너 를 기다리 는 나 의 소망 과 그 미소 속 에 눈빛 과 자라나 는 또 커져 버린 걸 알 아 버린 모습 과 그대 이별 이란 없 는 얼굴 과 또 사랑 이 란 말 내 맘 속 에 간직 할 꺼 야 이대로 시간 이 멈춰서 우리 혼자 였 던 기억 들 은 지워 버리 고 이제 는 그대 와 잃어버린 시간 을 함께 할께요 내 전부 인 그 사람 이 죠 나 의 그 사람 이 죠 날 알 아 버린 모습 과 그대 이별 이란 없 는 얼굴 과 또 사랑 이 란 말 내 안 에 있 는 걸 그대 가 있 는 걸 알 아
# Right translation : <sos> 날 안 아 줘
# Predicted translation:  사랑 의 <eos>
# -------------------------------------------------- 50
# Input: 당신 의 그 이름 을 잊 지 못 해 불러 보 며 나 는 당신 을 사랑 한다고 달 님 께 햇님 께 맹세 합니다 남몰래 애타 는 이내 순정 을 당신 은 아시 나 요 모르 시 나요 밤 마다 불러 보 는 당신 의 부르스 여 당신 의 그 이름 을 그리워서 불러 보 며 나 는 당신 을 믿 고 산다 고 목숨 도 죽음 도 가리 지 않 소 입술 을 깨물 며 바친 사랑 을 당신 은 아시 나 요 모르 시 나요 오늘 도 불러 보 는 당신 의 부르스
# Right translation : <sos> 새 날 이 밝 아 오 면
# Predicted translation:  사랑 의 <eos>
# -------------------------------------------------- 28
# Input: 여름 이 오 는 소리 에 넌 체중 계 를 꺼냈 어 해 마다 오 는 이벤트 라 대수롭 지 않 았 어 사실 난 지금 의 네 가 너무나 도 좋 은데 왜 너 만 몰라 왜 또 이러 는 걸까 그만 우울 한 표정 은 접 고 나와 맛있 는 것 들 을 해치우 자 널 기다리 는 이 식탁 을 외면 하 지 마 당신 의 도 사라지 지 않 게 해줘 당신 의 도 내겐 너무 소 중 해서 빛나 는 그대 가 이대로 영원히 남 아 주 기 를 변하 지 않 기 를 바 래 요 자꾸 만 네 가 기다려 지 는 밤 통화 너 를 설레 게 하 는 것 들 이 가득 한 이 밤 포기 하 면 편해질 거 야 당신 의 도 사라지 지 않 게 해줘 당신 의 도 내겐 너무 소 중 해서 빛나 는 그대 가 이대로 영원히 남 아 주 기 를 변하 지 않 기 를 바 래 요 영원 한 건 없 단 걸 그 누구 보다 잘 알 지만 내 가 너 를 사랑 하 는 단 하나 의 이유 도 달라지 지 않 기 를 바 래 당신 의 도 사라지 지 않 게 해줘 당신 의 도 내겐 너무 소 중 해서 빛나 는 그대 가 이대로 영원히 남 아 주 기 를 변하 지 않 기 를 바 래 요
# Right translation : <sos> 어떻게 그렇게 이렇 게
# Predicted translation:  <eos>
# -------------------------------------------------- 13
# Input: 나 어쩌면 이별 을 감지 했었 나 헤어지 기 싫 으면서 헤어지 길 바랬 었 나 그날 아침 에 보인 친절 함 들 은 새롭 게 마음먹 었 던 널 향 한 다짐 이 었 네 잘 하 려 했 는데 잘 대해 주 려고 잘 표현 하 려고 사랑 을 너 가 고 나 서 야 나 공부 를 했 어 이별 하 기 너 잘 알려 주 려고 그렇게 갔 나 봐 내 곁 에서
# Right translation : <sos> 널 향해 있 는 사랑
# Predicted translation:  나 의 <eos>
# -------------------------------------------------- 62
# Input: 찰랑찰랑 찰랑대 네 잔 에 담긴 위스키 처럼 그 모습 이 찰랑대 네 사랑 이 란 한잔 술 이 던가 오 그대 는 나 를 취하 게 하 는 사람 이 었 고 가까이 에서 이 마음 을 잡 고 흔들 었 어 촉촉히 젖 은 눈빛 하나 로 이 마음 을 적셔 주 었 어 그것 이 사랑 이 라면 이 순간 모든 것 다 줄 수 있 어 그것 이 거짓 없 는 진실 이 라면 나 는 나 는 그대 잔 속 에서 찰랑 찰랑대 는 술 이 되 리라 오 그대 는 나 를 취하 게 하 는 사람 이 었 고 가까이 에서 이 마음 을 잡 고 흔들 었 어 촉촉히 젖 은 눈빛 하나 로 이 마음 을 적셔 주 었 어 그것 이 사랑 이 라면 이 순간 모든 것 다 줄 수 있 어 그것 이 거짓 없 는 진실 이 라면 나 는 나 는 그대 잔 속 에서 찰랑찰랑 대 는 술 이 되 리라 나 는 나 는 그대 잔 속 에서 찰랑찰랑 대 는 술 이 되 리라 그대 위 하 여
# Right translation : <sos> 그대 뿐 인 거 겠 죠
# Predicted translation:  <eos>
# -------------------------------------------------- 69
# Input: 모든 사람 들 과 함께 한잔 을 걸치 고 돌아와 이렇게 네 게 편지 를 써 선뜻 내밀 어 줄 명함 도 번듯 한 직장 도 하나 없 지만 그렇 다고 끝 은 아니 지 너 못지않 은 내 가 있 잖아 어쨌든 나 니 가 좋 아 애절 한 너 의 그 포 근 함 이 언 젠 간 세상 도 우리 를 받 아 줄 날 이 있 을 거 야 오늘 도 예전 과 다름없이 이런 저런 수다 떨 고 추억 이 라 하 는 안주 에 우리 는 마음 흔들렸 구나 선뜻 내밀 어 줄 명함 도 번듯 한 직장 도 하나 없 지만 그렇 다고 끝 은 아니 지 너 못지않 은 내 가 있 잖아 어쨌든 나 니 가 좋 아 애절 한 너 의 그 포 근 함 이 언 젠 간 세상 도 우리 를 받 아 줄 날 이 있 을 거 야
# Right translation : <sos> 귀찮 아
# Predicted translation:  <eos>
# -------------------------------------------------- 58
# Input: 이 세상 엔 위안 이 될 기대 와 희망 이 있 을까 영원 하 게 보이 는 이 세상 의 힘 에 기대 고 싶 어 이 세상 의 화려 한 불빛 은 우리 의 빛 일까 선명 하 게 보이 는 이 세상 의 빛 은 진실 일까 나 홀로 길 을 걸 었 네 마음 둘 곳 하나 없 어 방황 할 때 에 내 곁 에 다가오 신 그 분 나 의 삶 의 나침반 이 되 신 주 보이 진 않 아도 그 분 이 보이 신 새로운 길 우릴 위해 예비 한 약속 의 길 보이 진 않 아도 그 분 이 보이 신 생명 의 길 비교 할 수 없 고 바꿀 수 도 없 는 오직 그 길 이 세상 의 화려 한 불빛 은 우리 의 빛 일까 선명 하 게 보이 는 이 세상 의 빛 은 진실 일까 나 홀로 길 을 걸 었 네 마음 둘 곳 하나 없 어 방황 할 때 에 내 곁 에 다가오 신 그 분 나 의 삶 의 나침반 이 되 신 주 보이 진 않 아도 그 분 이 보이 신 새로운 길 우릴 위해 예비 한 약속 의 길 보이 진 않 아도 그 분 이 보이 신 생명 의 길 비교 할 수 없 고 바꿀 수 도 없 는 오직 그 길 예수 가 가신 그 길 그 길 만 소망 하 네 영원히 나 와 함께 걸 으 시 네 오직 그 길 을 보이 진 않 아도 그 분 이 보이 신 새로운 길 우릴 위해 예비 한 약속 의 길 보이 진 않 아도 그 분 이 보이 신 생명 의 길 비교 할 수 없 고 바꿀 수 도 없 는 오직 그 길 오직 그 길
# Right translation : <sos> 당신 은 나 의 희망
# Predicted translation:  <eos>
# -------------------------------------------------- 5

# %%
b="오- 내가 웃고 있나요?모두 거짓이겠죠? 날 보는 이들의 눈빛 속에는 (oh!) 슬픔이 젖어있는데. 헤이- 내 이름은 광대, 내 직업은 수많은 관객, 그 앞에 웃음을 파는 일 슬퍼도 웃으며 내 모습을 감추는 게 철칙. 오- 이런 내 처질, 손가락질 하며 날 모욕해도 더 크게 웃고 난 땀으로 목욕하고 음악이 꺼지고 막이 내리고 밤이 오면 별빛에 몸을 씻고 눈부시게 광낸 구두를 신고 달에게 청혼하듯 손을 내밀어 얼음 위를 미끄러지듯 앞으로 달려 (아무도) 아무도 모르게 조용히 흐르는 이 시간에 외롭게 홀로 핀 꽃 한 송이에 난 반해 사랑을 나누려 나는 간다네 세상을 넘어 시간을 멈추고 세상을 넘어 신나게 춤을 춰봐 세상을 넘어 모두가 같은 높이에서 그래 그래 그렇게 내가 웃고있나요 모두 거짓이겠죠 날 보는 이들의 눈빛속에는 슬픔이 젖어있는데 무대 위에 서면 우린 때론 정반대 내가 관객이 돼. 사람들의 얼굴에 상상의 그림을 그려 물감을 뿌려 저 불타는 이십대의 청춘은 내일이면 이 사회의 첫 줄을 이력서 쓰며 인생을 시험보고 저 순진한 사랑의 초보 애인있는 남자와 눈 맞어 사랑에 빠져 슬픔을 기다리네 (come on baby) 너와 나 모두 왕의 옷을 입어도 신하가 되버리는 현실에 혼신에 힘을 다해 헌신에 오늘 술 한잔하면 내일은 물 한잔으로 버텨야하지만, 일단은 오늘 또 마시네 아픔이 싹 가시네 세상을 넘어 시간을 멈추고 세상을 넘어 신나게 춤을 춰봐 세상을 넘어 모두가 같은 높이에서 그래 그래 그렇게 내가 웃고있나요 모두 거짓이겠죠 날 보는 이들의 눈빛속에는 슬픔이 젖어있는데 내가 웃고있나요 모두 거짓이겠죠 날 보는 이들의 눈빛속에는 슬픔이 젖어있는데"
translate(b)
# Out:
# Input: 오 내 가 웃고 있나요 ? 모두 거짓 이 겠죠 ? 날 보는 이 들 의 눈빛 속 에는 oh ! 슬픔 이 젖어있는데 . 헤이 내 이름 은 광대 내 직업 은 수많은 관객 그 앞 에 웃음 을 파는 일 슬퍼도 웃으며 내 모습 을 감추는 게 철칙 . 오 이런 내 처질 손가락질 하며 날 모욕 해도 더 크게 웃고 난 땀 으로 목욕 하고 음악 이 꺼지고 막 이 내리고 밤 이 오면 별빛 에 몸 을 씻고 눈부시게 광 낸 구두 를 신고 달 에게 청혼 하 듯 손 을 내밀어 얼음 위 를 미끄러지듯 앞 으로 달려 아무 도 아무 도 모르게 조용히 흐르는 이 시간 에 외롭게 홀로 핀 꽃 한 송이 에 난 반해 사랑 을 나누려 나 는 간다 네 세상 을 넘어 시간 을 멈추고 세상 을 넘어 신나게 춤 을 춰 봐 세상 을 넘어 모두 가 같은 높이 에서 그래 그래 그렇게 내 가 웃고있나요 모두 거짓 이 겠죠 날 보는 이 들 의 눈빛 속 에는 슬픔 이 젖어있는데 무대 위 에 서면 우린 때론 정반대 내 가 관객 이 돼 . 사람 들 의 얼굴 에 상상 의 그림 을 그려 물감 을 뿌려 저 불타는 이십 대의 청춘 은 내 일 이면 이 사회 의 첫 줄 을 이력서 쓰며 인생 을 시험 보고 저 순진한 사랑 의 초보 애인 있는 남자 와 눈 맞어 사랑 에 빠져 슬픔 을 기다리네 come on baby 너 와 나 모두 왕 의 옷 을 입어도 신하 가 되 버리는 현실 에 혼신 에 힘 을 다해 헌신 에 오늘 술 한잔 하면 내일 은 물 한잔 으로 버텨야하지만 일단 은 오늘 또 마시네 아픔 이 싹 가시 네 세상 을 넘어 시간 을 멈추고 세상 을 넘어 신나게 춤 을 춰 봐 세상 을 넘어 모두 가 같은 높이 에서 그래 그래 그렇게 내 가 웃고있나요 모두 거짓 이 겠죠 날 보는 이 들 의 눈빛 속 에는 슬픔 이 젖어있는데 내 가 웃고있나요 모두 거짓 이 겠죠 날 보는 이 들 의 눈빛 속 에는 슬픔 이 젖어있는데
# Predicted translation:  <eos>

# %%
c='동해 물과 백두산이 마르고 닳도록 하느님이 보우하사 우리나라 만세. 무궁화 삼천리 화려 강산 대한 사람 대한으로 길이 보전하세'
translate(c)
# Out:
# Input: 동해 물 과 백두산 이 마르고 닳도록 하느님 이 보우 하사 우리나라 만세 . 무궁화 삼천리 화려 강산 대한 사람 대한 으로 길이 보전 하세
# Predicted translation:  <eos>
