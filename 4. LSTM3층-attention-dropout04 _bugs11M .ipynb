# %%
# 그래프에서 한글표현을 위해 폰트를 설치합니다.
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq
# Out:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 155569 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Selecting previously unselected package fonts-nanum-eco.
# Preparing to unpack .../fonts-nanum-eco_1.000-6_all.deb ...
# Unpacking fonts-nanum-eco (1.000-6) ...
# Selecting previously unselected package fonts-nanum-extra.
# Preparing to unpack .../fonts-nanum-extra_20170925-1_all.deb ...
# Unpacking fonts-nanum-extra (20170925-1) ...
# Selecting previously unselected package fonts-nanum-coding.
# Preparing to unpack .../fonts-nanum-coding_2.5-1_all.deb ...
# Unpacking fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-extra (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Setting up fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-eco (1.000-6) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...

# %%
import matplotlib.pyplot as plt  # 그래프 그리는 용도
import matplotlib.font_manager as fm  # 폰트 관련 용도
path = '/usr/share/fonts/truetype/nanum/NanumGothicEco.ttf'  # 설치된 나눔글꼴중 원하는 녀석의 전체 경로를 가져오자
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)

plt.rc('font', family=font_name)

fm._rebuild()
# Out:
# NanumGothic Eco

# %%
import re
import os
import unicodedata
import urllib3
import zipfile
import shutil
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Embedding, GRU, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Download the data

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/share_120293/최종전처리(문자열버전).csv')

df
# Out:
#         Unnamed: 0               title  \
# 0                0       천만 분 의 확률 의 너
# 1                1            술 이 뭐 길래
# 2                2         그때 그 순간 그대로
# 3                3             나 의 에 게
# 4                4          일 과 이분 의 일
# ...            ...                 ...
# 112325      152629    나 를 둘러싼 기막힌 환경 이
# 112326      152631    제 장 나 의 사랑 하 는 책
# 112327      152636                 난 네
# 112328      152637  제 장 주 여 나 의 병든 몸 을
# 112329      152638       너 는 아빠 나 는 엄마
#
#                                                     lyric
# 0       너 를 만나 기 위해 모든 시간 들 을 모래시계 에 다 넣 어 놓 고서 우리 둘 만...
# 1       오늘 도 이렇게 어제 처럼 잔 을 꺼내 나 혼자 서 따른 잔 에 내 입술 을 기대 ...
# 2       잘 지냈 지 조금 은 어색 해 요즘 좋 아 보여 인사 나누 며 사실 궁금 한 게 너...
# 3       우리 다시 만날래 예쁘 게 빛나 던 모든 추억 들 이 너무 그리워 너 의 품 에 안...
# 4       멀리서 널 보 았 을 때 다른 길 로 갈까 생각 했 는데 변한 듯 한 널 보 고 싶...
# ...                                                   ...
# 112325  나 를 둘러싼 기막힌 환경 이 변하 지 않 는다 해도 나 는 주 의 이름 을 영원히...
# 112326  나 의 사랑 하 는 책 비록 해 어 졌으나 어머님 의 무릎 위 에 앉 아서 재미있 ...
# 112327  나 를 원해 이리로 이리 온 유난 떨 지 마 그만 원한다면 솔직 해져 봐 와서 가져...
# 112328  주 여 나 의 병든 몸 을 지금 고쳐 주 소서 모든 병 을 고쳐 주마 주 약속 하 ...
# 112329  어릴 때 소꿉친구 너 는 아빠 나 는 엄마 각시 풀 핀 언덕 에 오손도손 정답 더니...
#
# [112330 rows x 3 columns]

# %%
df['title'].nunique(), df['lyric'].nunique()
df.drop_duplicates(subset=['lyric'], inplace=True)
df.dropna(inplace=True)
df.reset_index(drop=True,inplace=True)

df
# Out:
#         Unnamed: 0               title  \
# 0                0       천만 분 의 확률 의 너
# 1                1            술 이 뭐 길래
# 2                2         그때 그 순간 그대로
# 3                3             나 의 에 게
# 4                4          일 과 이분 의 일
# ...            ...                 ...
# 112325      152629    나 를 둘러싼 기막힌 환경 이
# 112326      152631    제 장 나 의 사랑 하 는 책
# 112327      152636                 난 네
# 112328      152637  제 장 주 여 나 의 병든 몸 을
# 112329      152638       너 는 아빠 나 는 엄마
#
#                                                     lyric
# 0       너 를 만나 기 위해 모든 시간 들 을 모래시계 에 다 넣 어 놓 고서 우리 둘 만...
# 1       오늘 도 이렇게 어제 처럼 잔 을 꺼내 나 혼자 서 따른 잔 에 내 입술 을 기대 ...
# 2       잘 지냈 지 조금 은 어색 해 요즘 좋 아 보여 인사 나누 며 사실 궁금 한 게 너...
# 3       우리 다시 만날래 예쁘 게 빛나 던 모든 추억 들 이 너무 그리워 너 의 품 에 안...
# 4       멀리서 널 보 았 을 때 다른 길 로 갈까 생각 했 는데 변한 듯 한 널 보 고 싶...
# ...                                                   ...
# 112325  나 를 둘러싼 기막힌 환경 이 변하 지 않 는다 해도 나 는 주 의 이름 을 영원히...
# 112326  나 의 사랑 하 는 책 비록 해 어 졌으나 어머님 의 무릎 위 에 앉 아서 재미있 ...
# 112327  나 를 원해 이리로 이리 온 유난 떨 지 마 그만 원한다면 솔직 해져 봐 와서 가져...
# 112328  주 여 나 의 병든 몸 을 지금 고쳐 주 소서 모든 병 을 고쳐 주마 주 약속 하 ...
# 112329  어릴 때 소꿉친구 너 는 아빠 나 는 엄마 각시 풀 핀 언덕 에 오손도손 정답 더니...
#
# [112330 rows x 3 columns]

# %% [markdown]
# ## Configuration

# %%
batch_size = 32  # Batch size for training.
epochs = 100  # Number of epochs to train for.
hidden_units = 256  # Latent dimensionality of the encoding space.
embedding_dim = 100
num_samples = 112330    # Number of samples to train on.
dropout_rate = 0.4

# %% [markdown]
# ## Prepare the data

# %% [markdown]
# 데이터셋을 다운로드한 후에 데이터를 준비하고자 다음의 단계를 수행합니다.
#
# 1. 각 문장에 start와 end 토큰을 추가합니다.
# 2. 특정 문자를 제거함으로써 문장을 정리합니다.
# 3. 단어 인덱스와 아이디(ID) 인덱스를 생성합니다. (단어 → 아이디(ID), 아이디(ID) → 단어로 매핑된 딕셔너리).
# 4. 각 문장을 입력층의 최대 길이만큼 패딩(padding)을 수행합니다.

# %%
# !pip install konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: konlpy in /usr/local/lib/python3.7/dist-packages (0.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.4.0)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.21.6)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.9.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (4.1.1)

# %%
from konlpy.tag import Okt
okt = Okt()

# %%
import re
def preprocess_kor_sentence(sent):
  # 단어와 구두점 사이에 공백을 만듭니다.
  # Ex) "he is a boy." => "he is a boy ."
  sent = re.sub(r"([?.!,¿])", r" \1", sent)

  # (a-z, A-Z, ".", "?", "!", ",") 이들을 제외하고는 전부 공백으로 변환합니다.
  sent = re.sub(r"[^a-zA-Z가-힣ㄱ-ㅎㅏ-ㅣ!.?]+", r" ", sent)

  # 다수 개의 공백을 하나의 공백으로 치환
  sent = re.sub(r"\s+", " ", sent)
  
  sent = okt.morphs(sent, stem = False)
  sent = " ".join(sent) # string으로 출력!!! 구분 " "
  return sent

# %%
df
# Out:
#         Unnamed: 0               title  \
# 0                0       천만 분 의 확률 의 너
# 1                1            술 이 뭐 길래
# 2                2         그때 그 순간 그대로
# 3                3             나 의 에 게
# 4                4          일 과 이분 의 일
# ...            ...                 ...
# 112325      152629    나 를 둘러싼 기막힌 환경 이
# 112326      152631    제 장 나 의 사랑 하 는 책
# 112327      152636                 난 네
# 112328      152637  제 장 주 여 나 의 병든 몸 을
# 112329      152638       너 는 아빠 나 는 엄마
#
#                                                     lyric
# 0       너 를 만나 기 위해 모든 시간 들 을 모래시계 에 다 넣 어 놓 고서 우리 둘 만...
# 1       오늘 도 이렇게 어제 처럼 잔 을 꺼내 나 혼자 서 따른 잔 에 내 입술 을 기대 ...
# 2       잘 지냈 지 조금 은 어색 해 요즘 좋 아 보여 인사 나누 며 사실 궁금 한 게 너...
# 3       우리 다시 만날래 예쁘 게 빛나 던 모든 추억 들 이 너무 그리워 너 의 품 에 안...
# 4       멀리서 널 보 았 을 때 다른 길 로 갈까 생각 했 는데 변한 듯 한 널 보 고 싶...
# ...                                                   ...
# 112325  나 를 둘러싼 기막힌 환경 이 변하 지 않 는다 해도 나 는 주 의 이름 을 영원히...
# 112326  나 의 사랑 하 는 책 비록 해 어 졌으나 어머님 의 무릎 위 에 앉 아서 재미있 ...
# 112327  나 를 원해 이리로 이리 온 유난 떨 지 마 그만 원한다면 솔직 해져 봐 와서 가져...
# 112328  주 여 나 의 병든 몸 을 지금 고쳐 주 소서 모든 병 을 고쳐 주마 주 약속 하 ...
# 112329  어릴 때 소꿉친구 너 는 아빠 나 는 엄마 각시 풀 핀 언덕 에 오손도손 정답 더니...
#
# [112330 rows x 3 columns]

# %%
from tqdm import tqdm 
def load_preprocessed_data():
    encoder_input, decoder_input, decoder_target = [], [], []

    for i in tqdm(range(len(df[:num_samples]))):
        # source 데이터와 target 데이터 분리
        tar_line = df['title'].iloc[i]
        src_line = df['lyric'].iloc[i]
        
        # source 데이터 전처리
        src_line = [w for w in preprocess_kor_sentence(src_line).split()]

        # target 데이터 전처리
        #tar_line = preprocess_kor_sentence(tar_line)
        tar_line_in = [w for w in ("<sos> " + tar_line).split()]  # teacher forcing을 위한 정답셋 
        tar_line_out = [w for w in (tar_line + " <eos>").split()]

        encoder_input.append(src_line)
        decoder_input.append(tar_line_in)
        decoder_target.append(tar_line_out)
                
    return encoder_input, decoder_input, decoder_target

# %%
# 전처리 테스트

kr_sent = u"저녁 먹었니?"

print('전처리 전 한국어 문장 :', kr_sent)
print('전처리 후 한국어 문장 :', preprocess_kor_sentence(kr_sent))
# Out:
# 전처리 전 한국어 문장 : 저녁 먹었니?
# 전처리 후 한국어 문장 : 저녁 먹었니 ?

# %%
sents_lylic_in, sents_title_in, sents_title_out  = load_preprocessed_data()
# Out:
# 100%|██████████| 112330/112330 [50:30<00:00, 37.07it/s]

# %%
len(sents_lylic_in), len(sents_title_in), len(sents_title_out)
# Out:
# (112330, 112330, 112330)

# %%
print('인코더의 입력 :',sents_lylic_in[2968])
print('디코더의 입력 :',sents_title_in[2968])
print('디코더의 레이블 :',sents_title_out[2968])
# Out:
# 인코더의 입력 : ['단념', '을', '택했', '을', '때', '내', '가', '잃어버릴', '것', '은', '너', '하나', '뿐', '이', '고', '집착', '을', '택했', '을', '때', '내', '가', '잃어버릴', '것', '은', '너', '를', '뺀', '나머지', '모든', '것', '이', '다']
# 디코더의 입력 : ['<sos>', '희망', '고문']
# 디코더의 레이블 : ['희망', '고문', '<eos>']

# %% [markdown]
# 단어집합을 생성하겠습니다.

# %%
# 가사 input -> 제목 output 

# 가사 input

tokenizer_lylic = Tokenizer(filters="", lower=False)
tokenizer_lylic.fit_on_texts(sents_lylic_in)
encoder_input = tokenizer_lylic.texts_to_sequences(sents_lylic_in)

# %%
# 제목 output
tokenizer_title = Tokenizer(filters="", lower=False)
tokenizer_title.fit_on_texts(sents_title_in)
tokenizer_title.fit_on_texts(sents_title_out)

decoder_input = tokenizer_title.texts_to_sequences(sents_title_in)
decoder_target = tokenizer_title.texts_to_sequences(sents_title_out)

# %% [markdown]
# 각 문장을 입력층의 최대 길이만큼 패딩(padding)을 수행합니다.

# %%
encoder_input = pad_sequences(encoder_input,maxlen=1500, padding="post")
decoder_input = pad_sequences(decoder_input,maxlen=8, padding="post")
decoder_target = pad_sequences(decoder_target,maxlen=8, padding="post")

# %%
print('인코더의 입력의 크기(shape) :',encoder_input.shape)
print('디코더의 입력의 크기(shape) :',decoder_input.shape)
print('디코더의 레이블의 크기(shape) :',decoder_target.shape)
# Out:
# 인코더의 입력의 크기(shape) : (112330, 1500)
# 디코더의 입력의 크기(shape) : (112330, 8)
# 디코더의 레이블의 크기(shape) : (112330, 8)

# %%
len(encoder_input[112329])
# Out:
# 1500

# %% [markdown]
# 샘플은 총 3833개 존재합니다

# %%
src_vocab_size = len(tokenizer_lylic.word_index) +1
tar_vocab_size = len(tokenizer_title.word_index) +1

print(f"가사 단어 집합의 크기 : {src_vocab_size}, 제목 단어 집합의 크기 : {tar_vocab_size}")
# Out:
# 가사 단어 집합의 크기 : 59775, 제목 단어 집합의 크기 : 25632

# %%
len(tokenizer_title.word_index)
# Out:
# 25631

# %% [markdown]
# 단어로부터 정수를 얻는 딕셔너리와 정수로부터 단어를 얻는 딕셔너리를 각각 만들어줍니다. 이들은 훈련을 마치고 예측값과 실제값을 비교하는 단계에서 사용합니다.

# %%
src_to_index = tokenizer_lylic.word_index  # word : idx
index_to_src = tokenizer_lylic.index_word  # idx : word
tar_to_index = tokenizer_title.word_index # word : idx
index_to_tar = tokenizer_title.index_word # idx : word

# %%
print(len(src_to_index),len(index_to_src),len(tar_to_index),len(index_to_tar))
# Out:
# 59774 59774 25631 25631

# %% [markdown]
# 테스트 데이터를 분리하겠습니다. 인코더 input, 디코더 input, 디코더 output이 동일하게 분리되어야 하기 때문에 랜덤한 정수배열을 만들어 직접 나누겠습니다.

# %% [markdown]
# 우선 랜덤하게 시퀀스를 섞습니다.

# %%
indices = np.arange(encoder_input.shape[0])
np.random.shuffle(indices)
print('랜덤 시퀀스 :',indices)
# Out:
# 랜덤 시퀀스 : [22721 59777 15344 ...   827 95311 97552]

# %%
encoder_input = encoder_input[indices]
decoder_input = decoder_input[indices]
decoder_target = decoder_target[indices]

# %%
decoder_input[indices[0]], decoder_target[indices[0]]
# Out:
# (array([  1,   6, 276,   0,   0,   0,   0,   0], dtype=int32),
#  array([  6, 276,   2,   0,   0,   0,   0,   0], dtype=int32))

# %% [markdown]
# `<sos>` `<eos>` 토큰을 제외한 다른 단어들은 동일한 인덱스를 갖고 있어야 합니다.

# %% [markdown]
# 10%의 데이터를 test데이터로 분리하겠습니다.

# %%
n_of_val = int(num_samples*0.1)

encoder_input_train = encoder_input[:-n_of_val]
decoder_input_train = decoder_input[:-n_of_val]
decoder_target_train = decoder_target[:-n_of_val]

encoder_input_test = encoder_input[-n_of_val:]
decoder_input_test = decoder_input[-n_of_val:]
decoder_target_test = decoder_target[-n_of_val:]

# %%
print('훈련 source 데이터의 크기 :',encoder_input_train.shape)
print('훈련 target 데이터의 크기 :',decoder_input_train.shape)
print('훈련 target 레이블의 크기 :',decoder_target_train.shape)
print('테스트 source 데이터의 크기 :',encoder_input_test.shape)
print('테스트 target 데이터의 크기 :',decoder_input_test.shape)
print('테스트 target 레이블의 크기 :',decoder_target_test.shape)
# Out:
# 훈련 source 데이터의 크기 : (101097, 1500)
# 훈련 target 데이터의 크기 : (101097, 8)
# 훈련 target 레이블의 크기 : (101097, 8)
# 테스트 source 데이터의 크기 : (11233, 1500)
# 테스트 target 데이터의 크기 : (11233, 8)
# 테스트 target 레이블의 크기 : (11233, 8)

# %% [markdown]
# ## Model

# %% [markdown]
# 이제 번역기를 빌드해보겠습니다.

# %%
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Masking
from tensorflow.keras.models import Model

# %% [markdown]
# 인코더를 설계합니다. LSTM에서 state_h, state_c를 리턴받는데, 이는 각각 RNN 챕터에서 LSTM을 처음 설명할 때 언급하였던 은닉 상태와 셀 상태에 해당됩니다. 이 두 가지 상태를 encoder_states에 저장합니다. encoder_states를 디코더에 전달하므로서 이 두 가지 상태 모두를 디코더로 전달할 예정입니다. 이것이 앞서 배운 컨텍스트 벡터입니다.

# %%
# 인코더
encoder_inputs = Input(shape=(None,))
enc_emb = Embedding(src_vocab_size, embedding_dim)(encoder_inputs) # 임베딩 층
encoder_lstm1 = LSTM(hidden_units, return_sequences = True, return_state=True, dropout = dropout_rate)
encoder_lstm2 = LSTM(hidden_units, return_sequences = True, return_state=True, dropout = dropout_rate)
encoder_lstm3 = LSTM(hidden_units, return_sequences = True, return_state=True, dropout = dropout_rate)

x, eh1, ec1 = encoder_lstm1(enc_emb) # 은닉 상태와 셀 상태를 리턴
x, eh2, ec2 = encoder_lstm2(x) # 은닉 상태와 셀 상태를 리턴
encoder_outputs, eh3, ec3 = encoder_lstm3(x) # 은닉 상태와 셀 상태를 리턴

encoder_states = [eh1, ec1, eh2, ec2, eh3, ec3] # 인코더의 은닉 상태와 셀 상태를 저장

# %% [markdown]
# 이번에는 Attention을 추가합니다.
# - Attention 중 가장 기초적인 dot-product attention을 예제로 진행하겠습니다.
# 1. attention score 계산
# 2. softmax로 attention distribution 계산
# 3. 각 인코더의 어텐션 가중치와 은닉 상태를 가중합하여 어텐션 값 계산
# 4. 어텐션값과 디코더의 t시점의 은닉상태를 연결
# 5. 출력층 연산의 입력이 되는 st 계산

# %% [markdown]
# 디코더에서는 attention layer를 추가합니다.
# - 이때, s_는 은닉상태와 디코더의 최종 출력은 연결해야 하므로, shape을 맞춰주기 위하여 축을 추가합니다.
# - attention layer는 디코더의 은닉상태와 인코더의 은닉상태 전체를 받아 컨텍스트 벡터를 생성합니다.
# - 마지막으로 생성한 컨텍스트 벡터와 디코더의 은닉상태 전체를 softmax layer에 넣고 인덱스를 예측합니다.

# %%
from tensorflow.keras.layers import Attention

# 디코더
decoder_inputs = Input(shape=(None,))
dec_emb_layer = Embedding(tar_vocab_size, hidden_units) # 임베딩 층
dec_emb = dec_emb_layer(decoder_inputs) # 임베딩 결과

# 상태값 리턴을 위해 return_state는 True, 모든 시점에 대해서 단어를 예측하기 위해 return_sequences는 True
decoder_lstm1 = LSTM(hidden_units, return_sequences=True, return_state=True, dropout = dropout_rate) 
decoder_lstm2 = LSTM(hidden_units, return_sequences=True, return_state=True, dropout = dropout_rate) 
decoder_lstm3 = LSTM(hidden_units, return_sequences=True, return_state=True, dropout = dropout_rate) 

# 인코더의 은닉 상태를 초기 은닉 상태(initial_state)로 사용
x1, h1, c1 = decoder_lstm1(dec_emb, initial_state=encoder_states[:2])
x2, h2, c2 = decoder_lstm2(x1, initial_state=encoder_states[2:4])
decoder_outputs, h3 , c3 = decoder_lstm3(x2, initial_state=encoder_states[4:])

# attention
S_ = tf.concat([eh3[:, tf.newaxis, :], decoder_outputs[:, :-1, :]], axis=1) # query 

attention = Attention(hidden_units)
context_vector, _ = attention([S_, encoder_outputs], return_attention_scores = True)

concat = tf.concat([decoder_outputs, context_vector], axis=-1)

# 모든 시점의 결과에 대해서 소프트맥스 함수를 사용한 출력층을 통해 단어 예측
decoder_dense = Dense(tar_vocab_size, activation='softmax')
decoder_outputs = decoder_dense(concat)

# %%
# 모델의 입력과 출력을 정의.
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['acc'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None)]       0           []
#
#  input_2 (InputLayer)           [(None, None)]       0           []
#
#  embedding (Embedding)          (None, None, 100)    5977500     ['input_1[0][0]']
#
#  embedding_1 (Embedding)        (None, None, 256)    6561792     ['input_2[0][0]']
#
#  lstm (LSTM)                    [(None, None, 256),  365568      ['embedding[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  lstm_3 (LSTM)                  [(None, None, 256),  525312      ['embedding_1[0][0]',
#                                  (None, 256),                     'lstm[0][1]',
#                                  (None, 256)]                     'lstm[0][2]']
#
#  lstm_1 (LSTM)                  [(None, None, 256),  525312      ['lstm[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  lstm_4 (LSTM)                  [(None, None, 256),  525312      ['lstm_3[0][0]',
#                                  (None, 256),                     'lstm_1[0][1]',
#                                  (None, 256)]                     'lstm_1[0][2]']
#
#  lstm_2 (LSTM)                  [(None, None, 256),  525312      ['lstm_1[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  lstm_5 (LSTM)                  [(None, None, 256),  525312      ['lstm_4[0][0]',
#                                  (None, 256),                     'lstm_2[0][1]',
#                                  (None, 256)]                     'lstm_2[0][2]']
#
#  tf.__operators__.getitem (Slic  (None, 1, 256)      0           ['lstm_2[0][1]']
#  ingOpLambda)
#
#  tf.__operators__.getitem_1 (Sl  (None, None, 256)   0           ['lstm_5[0][0]']
#  icingOpLambda)
#
#  tf.concat (TFOpLambda)         (None, None, 256)    0           ['tf.__operators__.getitem[0][0]'
#                                                                  , 'tf.__operators__.getitem_1[0][
#                                                                  0]']
#
#  attention (Attention)          ((None, None, 256),  1           ['tf.concat[0][0]',
#                                  (None, None, None)               'lstm_2[0][0]']
#                                 )
#
#  tf.concat_1 (TFOpLambda)       (None, None, 512)    0           ['lstm_5[0][0]',
#                                                                   'attention[0][0]']
#
#  dense (Dense)                  (None, None, 25632)  13149216    ['tf.concat_1[0][0]']
#
# ==================================================================================================
# Total params: 28,680,637
# Trainable params: 28,680,637
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, to_file='model.png', )

# %%
import tensorflow as tf

from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

EPOCH= 100
BATCH_SIZE = 64

filename = '/content/drive/MyDrive/share_120293/NLP모델/cp/checkpoint-epoch-{}-batch-{}-9/17(2)(1).h5'.format(EPOCH, BATCH_SIZE)

checkpoint = ModelCheckpoint(filename,             # file명을 지정합니다
                             monitor='val_loss',   # val_loss 값이 개선되었을때 호출됩니다
                             verbose=1,            # 로그를 출력합니다
                             save_best_only=True,  # 가장 best 값만 저장합니다
                             mode='auto'           # auto는 알아서 best를 찾습니다. min/max
                            )
earlystopping = EarlyStopping(monitor='val_loss',  # 모니터 기준 설정 (val loss) 
                              patience=5,         # ?회 Epoch동안 개선되지 않는다면 종료
                             )

# %%
model.fit(x=[encoder_input_train, decoder_input_train], y=decoder_target_train, 
          validation_data=([encoder_input_test, decoder_input_test], decoder_target_test),batch_size=BATCH_SIZE, epochs=EPOCH,callbacks=[checkpoint,earlystopping]
          )
# Out:
# Epoch 1/100
# 1580/1580 [==============================] - ETA: 0s - loss: 3.3246 - acc: 0.5469
# Epoch 1: val_loss improved from inf to 3.06925, saving model to /content/drive/MyDrive/share_120293/NLP모델/cp/checkpoint-epoch-100-batch-64-9/17(2)(1).h5
# 1580/1580 [==============================] - 789s 487ms/step - loss: 3.3246 - acc: 0.5469 - val_loss: 3.0693 - val_acc: 0.5696
# Epoch 2/100
# 1580/1580 [==============================] - ETA: 0s - loss: 2.9565 - acc: 0.5710
# Epoch 2: val_loss improved from 3.06925 to 2.92568, saving model to /content/drive/MyDrive/share_120293/NLP모델/cp/checkpoint-epoch-100-batch-64-9/17(2)(1).h5
# 1580/1580 [==============================] - 771s 488ms/step - loss: 2.9565 - acc: 0.5710 - val_loss: 2.9257 - val_acc: 0.5846
# Epoch 3/100
# 1580/1580 [==============================] - ETA: 0s - loss: 2.8054 - acc: 0.5814
# Epoch 3: val_loss improved from 2.92568 to 2.86536, saving model to /content/drive/MyDrive/share_120293/NLP모델/cp/checkpoint-epoch-100-batch-64-9/17(2)(1).h5
# 1580/1580 [==============================] - 767s 486ms/step - loss: 2.8054 - acc: 0.5814 - val_loss: 2.8654 - val_acc: 0.5897
# Epoch 4/100
# 1580/1580 [==============================] - ETA: 0s - loss: 2.7085 - acc: 0.5869
# Epoch 4: val_loss improved from 2.86536 to 2.83586, saving model to /content/drive/MyDrive/share_120293/NLP모델/cp/checkpoint-epoch-100-batch-64-9/17(2)(1).h5
# 1580/1580 [==============================] - 770s 487ms/step - loss: 2.7085 - acc: 0.5869 - val_loss: 2.8359 - val_acc: 0.5933
# Epoch 5/100
# 1580/1580 [==============================] - ETA: 0s - loss: 2.6141 - acc: 0.5917
# Epoch 5: val_loss improved from 2.83586 to 2.80045, saving model to /content/drive/MyDrive/share_120293/NLP모델/cp/checkpoint-epoch-100-batch-64-9/17(2)(1).h5
# 1580/1580 [==============================] - 767s 486ms/step - loss: 2.6141 - acc: 0.5917 - val_loss: 2.8005 - val_acc: 0.5975
# Epoch 6/100
# 1580/1580 [==============================] - ETA: 0s - loss: 2.5287 - acc: 0.5961
# Epoch 6: val_loss improved from 2.80045 to 2.77700, saving model to /content/drive/MyDrive/share_120293/NLP모델/cp/checkpoint-epoch-100-batch-64-9/17(2)(1).h5
# 1580/1580 [==============================] - 768s 486ms/step - loss: 2.5287 - acc: 0.5961 - val_loss: 2.7770 - val_acc: 0.6003
# Epoch 7/100
# 1580/1580 [==============================] - ETA: 0s - loss: 2.4467 - acc: 0.6001
# Epoch 7: val_loss improved from 2.77700 to 2.76970, saving model to /content/drive/MyDrive/share_120293/NLP모델/cp/checkpoint-epoch-100-batch-64-9/17(2)(1).h5
# 1580/1580 [==============================] - 767s 485ms/step - loss: 2.4467 - acc: 0.6001 - val_loss: 2.7697 - val_acc: 0.6014
# Epoch 8/100
# 1580/1580 [==============================] - ETA: 0s - loss: 2.3709 - acc: 0.6035
# Epoch 8: val_loss improved from 2.76970 to 2.76200, saving model to /content/drive/MyDrive/share_120293/NLP모델/cp/checkpoint-epoch-100-batch-64-9/17(2)(1).h5
# 1580/1580 [==============================] - 768s 486ms/step - loss: 2.3709 - acc: 0.6035 - val_loss: 2.7620 - val_acc: 0.6034
# Epoch 9/100
# 1580/1580 [==============================] - ETA: 0s - loss: 2.2935 - acc: 0.6075
# Epoch 9: val_loss improved from 2.76200 to 2.75849, saving model to /content/drive/MyDrive/share_120293/NLP모델/cp/checkpoint-epoch-100-batch-64-9/17(2)(1).h5
# 1580/1580 [==============================] - 767s 485ms/step - loss: 2.2935 - acc: 0.6075 - val_loss: 2.7585 - val_acc: 0.6063
# Epoch 10/100
# 1580/1580 [==============================] - ETA: 0s - loss: 2.2153 - acc: 0.6116
# Epoch 10: val_loss did not improve from 2.75849
# 1580/1580 [==============================] - 765s 484ms/step - loss: 2.2153 - acc: 0.6116 - val_loss: 2.7702 - val_acc: 0.6061
# Epoch 11/100
# 1580/1580 [==============================] - ETA: 0s - loss: 2.1413 - acc: 0.6160
# Epoch 11: val_loss did not improve from 2.75849
# 1580/1580 [==============================] - 764s 483ms/step - loss: 2.1413 - acc: 0.6160 - val_loss: 2.7718 - val_acc: 0.6085
# Epoch 12/100
# 1580/1580 [==============================] - ETA: 0s - loss: 2.0680 - acc: 0.6202
# Epoch 12: val_loss did not improve from 2.75849
# 1580/1580 [==============================] - 764s 483ms/step - loss: 2.0680 - acc: 0.6202 - val_loss: 2.7820 - val_acc: 0.6106
# Epoch 13/100
# 1580/1580 [==============================] - ETA: 0s - loss: 1.9989 - acc: 0.6251
# Epoch 13: val_loss did not improve from 2.75849
# 1580/1580 [==============================] - 763s 483ms/step - loss: 1.9989 - acc: 0.6251 - val_loss: 2.8010 - val_acc: 0.6101
# Epoch 14/100
# 1580/1580 [==============================] - ETA: 0s - loss: 1.9353 - acc: 0.6295
# Epoch 14: val_loss did not improve from 2.75849
# 1580/1580 [==============================] - 765s 484ms/step - loss: 1.9353 - acc: 0.6295 - val_loss: 2.8133 - val_acc: 0.6105

# %%
model.save('/content/drive/MyDrive/share_120293/NLP모델/lstm_attention_model_9/18-1.h5')

# %% [markdown]
# ## 훈련된 모델로 번역하기
#
# * 평가 함수는 여기서 *교사 강요(teacher forcing)*를 사용하기 못하는 것을 제외하고는 훈련 루프와 비슷합니다. 각 마지막 시점(time step)에서 이전 디코더 인코더의 결과와 은닉 상태(hidden state)를 가진 예측 값을 디코더에 입력합니다.
#
#     1. 번역하고자 하는 입력 문장이 인코더로 입력되어 인코더의 마지막 시점의 은닉 상태와 셀 상태를 얻습니다.
#     2. 인코더의 은닉 상태와 셀 상태, 그리고 토큰 <sos>를 디코더로 보냅니다.
#     3. 디코더가 토큰 <eos>가 나올 때까지 다음 단어를 예측하는 행동을 반복합니다.

# %%
# 인코더 - 훈련과 동일 
encoder_model = Model(encoder_inputs, [encoder_outputs, encoder_states])

# %%
tf.keras.utils.plot_model(encoder_model, to_file='model.png', )

# %%
# 디코더 

# 이전 시점의 상태를 보관할 텐서
decoder_state_input_h = Input(shape=(hidden_units,))
decoder_state_input_c = Input(shape=(hidden_units,))

decoder_state_input_h1 = Input(shape=(hidden_units,))
decoder_state_input_c1 = Input(shape=(hidden_units,))

decoder_state_input_h2 = Input(shape=(hidden_units,))
decoder_state_input_c2 = Input(shape=(hidden_units,))


decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c,
                         decoder_state_input_h1, decoder_state_input_c1,
                         decoder_state_input_h2, decoder_state_input_c2]


encoder_state_h = Input(shape=(hidden_units,))
encoder_outputs2 = Input(shape =(None, hidden_units,))


# 훈련 때 사용했던 임베딩 층을 재사용
dec_emb2 = dec_emb_layer(decoder_inputs)

# 다음 단어 예측을 위해 이전 시점의 상태를 현 시점의 초기 상태로 사용
x, state_h1, state_c1 = decoder_lstm1(dec_emb2, initial_state=decoder_states_inputs[:2])
x, state_h2, state_c2 = decoder_lstm2(x, initial_state=decoder_states_inputs[2:4])
decoder_outputs2, state_h3, state_c3 = decoder_lstm3(x, initial_state=decoder_states_inputs[4:])
decoder_states2 = [state_h1, state_c1, state_h2, state_c2, state_h3, state_c3]
# decoder_states2 = [state_h, state_c]

# Attention
S_ = tf.concat([encoder_state_h[:, tf.newaxis, :], decoder_outputs2[:, :-1, :]], axis=1) # query 

context_vector, att_score = attention([S_, encoder_outputs2], return_attention_scores = True)
decoder_concat = tf.concat([decoder_outputs2, context_vector], axis=-1)

# 모든 시점에 대해서 단어 예측 (Fully Connected)
decoder_outputs2 = decoder_dense(decoder_concat)

# 수정된 디코더
decoder_model = Model(
    [decoder_inputs, encoder_state_h, encoder_outputs2] + decoder_states_inputs,
    [decoder_outputs2, att_score] + decoder_states2)

# %%
tf.keras.utils.plot_model(decoder_model, to_file='model.png', )

# %% [markdown]
# 테스트 단계에서의 동작을 위한 decode_sequence 함수를 구현합니다.
# 1. 입력 문장이 들어오면 인코더는 마지막 시점까지 전개하여 마지막 시점의 은닉 상태와 셀 상태를 리턴합니다. -> `states_value`
# 2. 디코더의 초기 입력으로 <SOS>를 준비합니다. -> `target_seq`
# 3. 이 두 가지 입력을 가지고 while문 안으로 진입하여 이 두 가지를 디코더의 입력으로 사용합니다.
# 4. 이제 디코더는 현재 시점에 대해서 예측합니다.
#     - 예측 벡터로부터 현재 시점의 예측 단어인 target_seq를 얻고, h와 c 이 두 개의 값은 states_value에 저장합니다.
#     - while문의 다음 루프. 즉, 두번째 시점의 디코더의 입력으로 다시 target_seq와 states_value를 사용합니다.
#     - 이를 현재 시점의 예측 단어로 <eos>를 예측하거나 번역 문장의 길이가 50이 넘는 순간까지 반복합니다.
# 5. 각 시점마다 번역된 다어는 decoded_sentence에 누적하여 저장하였다가 최종 번역 시퀀스로 리턴합니다.

# %%
def decode_sequence(sentence):
    # 입력으로부터 인코더의 마지막 시점의 상태(은닉 상태, 셀 상태)를 얻음
    max_src_len, max_tar_len  = encoder_input.shape[1], decoder_input.shape[1]

    attention_plot = np.zeros((max_tar_len, max_src_len))

    sentence = preprocess_kor_sentence(sentence)
    tokens = sentence.split(" ")
    inputs = tokenizer_lylic.texts_to_sequences([tokens])

    inputs = tf.keras.preprocessing.sequence.pad_sequences(inputs,
                                                            maxlen=max_src_len,
                                                            padding='post')
    encoder_test, states_value = encoder_model.predict(inputs)

    # <SOS>에 해당하는 정수 생성
    target_seq = np.zeros((1,1))
    target_seq[0, 0] = tar_to_index['<sos>']
    
    stop_condition = False
    decoded_sentence = ''

    # stop_condition이 True가 될 때까지 루프 반복
    # 구현의 간소화를 위해서 이 함수는 배치 크기를 1로 가정합니다.
    for t in range(max_tar_len):
        # 이점 시점의 상태 states_value를 현 시점의 초기 상태로 사용
        output_tokens, att_score, h1, c1, h2, c2, h3, c3 = decoder_model.predict([target_seq, states_value[0], encoder_test] + states_value)
        # tar_to_index 2808
        # output_tokens 왜오ㅓㅐ오애ㅗ애2089??????
  

        # 어텐션 가중치 시각화를 위해 저장 
        att_score = tf.reshape(att_score, (-1, ))
        attention_plot[t] = att_score.numpy() 

        # 예측 결과를 단어로 변환
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = index_to_tar[sampled_token_index]
  
        # 현재 시점의 예측 단어를 예측 문장에 추가
        decoded_sentence += ' '+sampled_char


        # 현재 시점의 예측 결과를 다음 시점의 입력으로 사용하기 위해 저장
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # 현재 시점의 상태를 다음 시점의 상태로 사용하기 위해 저장
        states_value = [ h1, c1, h2, c2, h3, c3]

        # <eos>에 도달하거나 정해진 길이를 넘으면 중단.
        if sampled_char == '<eos>':
            break 

    return sentence, decoded_sentence, attention_plot

# %% [markdown]
# 결과 확인을 위한 함수를 만듭니다.

# %%
# 원문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq_to_src(input_seq):
  sentence = ''
  for encoded_word in input_seq:
    if(encoded_word != 0):
      sentence = sentence + index_to_src[encoded_word] + ' '
  return sentence

# 번역문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq_to_tar(input_seq):
  sentence = ''
  for encoded_word in input_seq:
    if(encoded_word != 0 and encoded_word != tar_to_index['<eos>']):
    # if(encoded_word != 0 and encoded_word != tar_to_index['<sos>'] and encoded_word != tar_to_index['<eos>']):
      sentence = sentence + index_to_tar[encoded_word] + ' '
  return sentence

# %%
from pylab import *
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

def plot_attention(attention, sentence, predicted_sentence):
    # you need to change the fname based on your system, and the Chinese can be displayed in the plot
    # font = FontProperties(fname=r"./data/TaipeiSansTCBeta-Regular.ttf", size=14)
    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(1, 1, 1)
    ax.matshow(attention, cmap='viridis')

    fontdict = {'fontsize': 14}

    # set the x-tick/y-tick labels with list of string labels
    ax.set_xticklabels([''] + sentence, fontdict=fontdict, rotation = 90)
    ax.set_yticklabels(predicted_sentence, fontdict=fontdict)

    # set tick locators
    ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
    ax.yaxis.set_major_locator(ticker.MultipleLocator(1))
    plt.show()

# %%
def translate(sentence):
  sentence, result, attention_plot = decode_sequence(sentence)

  print('Input: %s' % (sentence))
  print('Predicted translation: {}'.format(result))

"""  attention_plot = attention_plot[:len(result.split(' '))-2, :len(sentence.split(' '))]
  plot_attention(attention_plot, sentence.split(' '), result.split(' '))"""
# Out:
# "  attention_plot = attention_plot[:len(result.split(' '))-2, :len(sentence.split(' '))]\n  plot_attention(attention_plot, sentence.split(' '), result.split(' '))"

# %%
translate('번역기를 만드는 것은 재미있어.')
# Out:
# Input: 번역기 를 만드는 것 은 재미있어 .
# Predicted translation:  나 는 나 의 마지노선 <eos>

# %%
translate('집에 가고 싶다.')
# Out:
# Input: 집 에 가고 싶다 .
# Predicted translation:  나 는 야 요리사 <eos>

# %%
translate('당신의 직업은 무엇입니까?')
# Out:
# Input: 당신 의 직업 은 무엇 입 니까 ?
# Predicted translation:  나 의 사랑 어여쁜 이여 <eos>

# %%
def translate_train(seq_index):
  input_seq = encoder_input_train[seq_index: seq_index + 1]

  sentence = seq_to_src(encoder_input_train[seq_index]).strip()
  _, result, attention_plot = decode_sequence(sentence)

  print('Input: %s' % (sentence))
  print("Right translation :",seq_to_tar(decoder_input_train[seq_index]))
  print('Predicted translation: {}'.format(result))

"""  attention_plot = attention_plot[:len(result.split(' '))-2, :len(sentence.split(' '))]
  plot_attention(attention_plot, sentence.split(' '), result.split(' '))"""
# Out:
# "  attention_plot = attention_plot[:len(result.split(' '))-2, :len(sentence.split(' '))]\n  plot_attention(attention_plot, sentence.split(' '), result.split(' '))"

# %%
translate_train(11)
# Out:
# Input: 잿빛 하늘 아래 시멘트 수없이 피 흘린 놀이터 로 돌아갈 게 제일 높 은 아파트 층 중력 이 끌어내려 더 오를 수 가 없 잖아 시간 이 라는 작품 과 힘 이 라는 작품 을 함께 들 고 갈 순 없 나요 뒤 바꿀 수 있 는 작품 과 빛 이 나 는 작품 을 함께 들 고 갈 순 없 나요 지금 돌아가 기 엔 난 버스비 조차 없 어 당장 돌아가 긴 싫 어요 바쁜데 시간 이 너무나 도 헤퍼 시간 이 너무나 도 헤퍼 도 가질 수 없 을 때 도 있 어 연애 랑 같 아 철학자 들 을 만났 지만 인생 이란 무 가치 하 데 여긴 코즈믹 호러 의 장르 나 분해 난 기류 에 몸 을 던져 위험 해 걔 네 에게 형체 를 알아볼 수 없 을 정도 로 만 터지 면 족 해 어쩌면 너 의 머릴 전부 엎 어 버려 그럼 나 운석 이 지 너 에게 그럼 어서 내 피부 조각 을 주워 그게 돈 이 되 니까 어때 시간 이 라는 작품 과 힘 이 라는 작품 을 함께 들 고 갈 순 없 나요 뒤 바꿀 수 있 는 작품 과 빛 이 나 는 작품 을 함께 들 고 갈 순 없 나요 지금 돌아가 기 엔 난 버스비 조차 없 어 당장 돌아가 긴 싫 어요 잿빛 하늘 아래 시멘트 수없이 피 흘린 놀이터 로 난 넘어가 고 있 어 지평선 뒤 로 넘어가 고 있 어 지평선 뒤 로 잿빛 하늘 은 다 지 고 있 어 자동 기술법 으로 나 를 괴롭히 죠 빛 이 떠오르 게 되 면 미쳐 내겐 아직 내일 이 있 을지 도
# Right translation : <sos> 정전기 가 일어나 는 놀이터
# Predicted translation:  나 는 꼼꼼 한 테슬라 <eos>

# %%
for seq_index in [10, 203, 500, 900, 8003]:
  translate_train(seq_index)
  print("-"*50)
# Out:
# Input: 아침 시 면 새로운 하루 가 시작 돼 긴장 돼 오늘 은 어떤 하루 가 펼쳐질지 진지 한 맘 으로 오늘 하루 를 보내 려 세상 속 에서 고 됐 던 나 의 하루하루 를 매일 같이 난 시간 과 싸움 을 해 때론 피해 숨 을래 하 지만 시간 은 흘러가 그러 다 결국 하루 가 지나가 버려 아무 것 도 한 게 없 는데 그냥 지나가 이 십 사 시간 이 란 시간 은 심하 게 도 징 하 게 도 쉽사리 기다려 주 지 를 않 아 날 위 로 해 줄 수 있 는 것 이 과연 있 을까 흘러가 는 매 시간 속 내 삶 을 비춰 봐 어떻게 시간 을 보내 는지 흘러가 는 매 시간 속 내 삶 을 비춰 봐 어떻게 시간 을 보내 는지 하 고 싶 은 일 들 은 수도 없이 많 은데 그 가운데 할 수 있 는 건 정말 적 어 어서 시간 과 의 싸움 에서 이겨야 하 는데 시간 은 마치 흐르 는 강물 같 아 하루 가 딱 오 십 시간 만 된다면 오직 그렇게 만 된다면 정말 좋 을 텐데 하 지만 그것 은 한낱 꿈 일 뿐 내게 가장 두려운 적 은 바로 시간 좌우 지 간 이 것 만큼 두려운 것 은 없 어 어서 시간 의 굴레 에서 벗어나 려 하 지만 잠시 도 난 여기 서 빠져나가 지 못 해 늘리 지 못 한다면 주 어 진 것 을 아껴 써 그래 이 젠 내 삶 도 전부 다 바 꼈 어 항상 갇혀서 살 던 내 삶 도 이제 는 달라 한 번 기대 를 해 볼 만 하 게 됐 는 걸 시간 과 의 싸움 을 피 할 수 없 다면 그냥 즐겨 어차피 시간 은 참 끈 질겨 질긴 놈 을 떼 어 내 기 는 쉽 지 않 아 일어나 시간 을 너 의 삶 에 맞추 어 가 길 흘러가 는 매 시간 속 내 삶 을 비춰 봐 어떻게 시간 을 보내 는지 흘러가 는 매 시간 속 내 삶 을 비춰 봐 어떻게 시간 을 보내 는지 시간 낭비 란 세상 에서 가장 바보 같 은 짓 지난 날 이 어떠 했 는지 꼭 돌아보 길 시간 과 의 숨바꼭질 이기 려면 본질 을 이해 해 내내 끌려 다녀 선 성공 할 수 없 다는 것 시간 이란 마치 쏘 아 버린 화살 같 아 아무리 기다려 봤 자 절대로 돌아오 지 않 아 하루하루 자신 의 목표 를 설정 해 그리고 결정 해 중요 한 것 들 을 먼저 해 흘러가 는 시간 의 무상 함 속 에서 아무 것 도 하 지 못 한 채 무력 하 게 사 는 것 은 시간 을 거 스르 는 짓 이야 참 바보 같 은 일 이 야 일어나 결단 력 을 가져 앞 을 보 고 달려 시간 은 누구 에게 나 공평 한 심판 진짜 노력 하 는 자 에게 는 행복 을 선사 해 정말 내 가 제대로 하 룰 보내 는지 돌아봐 오늘 은 진짜 시간 을 제대로 이용 해 봐
# Right translation : <sos> 시간 이란
# Predicted translation:  나 의 파편 <eos>
# --------------------------------------------------
# Input: 나지막이 조용히 사라지 는 건 나 의 바람 을 이미 저 버린 듯 내 곁 에 있 어 줘 나 를 떠나 지 마 그렇게 사라지 지 마 너 만 을 바랄 게 지구 가 멈춰 도 나 는 네 곁 에 있 을 게 온 세상 이 전부 무너지 는 날 또 흔적 조차 없이 사라지 는 너 전부 다 사라지 는 걸 전부 다 사라지 려나 내 곁 에 있 어 줘 나 를 떠나 지 마 그렇게 사라지 지 마 너 만 을 바랄 게 지구 가 멈춰 도 나 는 네 곁 에 있 을 게
# Right translation : <sos> 지구
# Predicted translation:  나 의 집 에 <eos>
# --------------------------------------------------
# Input: 가까이 와도 모른 척 하 며 가 버린 내게 이렇게 큰 사랑 을 주 나 따스 한 눈 길 애써 외면 하 면서 사랑 의 기적 보 지 않 으려 했 지 매일 비치 는 햇살 과 맑 은 공기 와 하늘 처럼 그 사랑 은 너무나 당 연 해 하 지만 내 삶 은 그렇게 당 연 한 것 없이 살 수 없 다는 걸 알 아 이 젠 곁 에 있 기에 소 중 한 줄 도 모르 고 당신 의 마음 아프 게 했었 지 어디 에서 나 볼 수 있 는 꽃 처럼 흐린 눈 으로 바라보 기 만 했 지 가진 것 없 는 나 에게 믿 음 도 없 는 약한 내게 그 사랑 은 너무나 신비 해 언제나 내 삶 은 그렇게 신비 한 사랑 에 눈부시 게 빛나 는 걸 알 아 매일 비치 는 햇살 과 맑 은 공기 와 하늘 처럼 그 사랑 은 너무나 당 연 해 하 지만 내 삶 은 그렇게 당 연 한 것 없이 살 수 없 다는 걸 알 아 이 젠 언제나 내 삶 은 그렇게 신비 한 사랑 에 눈부시 게 빛나 는 걸 알 아
# Right translation : <sos> 매일 비치 는 햇살
# Predicted translation:  내 가 만든 사랑 <eos>
# --------------------------------------------------
# Input: 예 이 노래 는 당신 을 향 한 겁니다 어 어제 밤새 한 번 써 봤 는데요 예 맘 에 드 시 는지 모르 겠 는데 어쨌든 한 번 열심히 쓴 거 니까 들 어 보 시 고 아 그냥 가만히 랩 만 들으면 돼요 예 손 좀 이렇게 예 따라 하 시 고 자 하나 둘 셋 넷 하나 둘 셋 넷 햇살 이 가득 한 아침 에 너 를 봤 어 너 는 참 달랐 어 아침 해 가 나서 지 못 할 만큼 아름다웠 던 너 였 어 너 를 따라 갔 어 그리고 만났 어 시작 이 좀 되 어 가 나 무슨 말 을 해야 하나 그대 어디 를 바라보 나 뭐 가 이렇게 말 이 많 아 정신 이 없 는 나 의 마음 가운데 는 뛰 는 너 가 생각났 어 이 것 은 당신 을 향 한 노래 예요 이 걸 로 당신 의 사랑 얻 을래요 이 거릴 당신 과 함께 걸 을래요 이제 는 당신 도 나 와 함께 해 요 나 그대 를 알 게 된 후 부터 키 작 은 내 사랑 키워 가 게 됐 지 내 인생 의 가치 그대 와 같이 깨달 아 갔 지 나 그동안 갖 지 못 했 던 가치 를 얻 어 가 마치 웨딩 마치 를 마친 신부 된 것 같이 꿈꾸 며 내 인생 다시 시작 의 의미 이미 정해진 너 와 나 당신 을 향 한 나 의 마음 이 사랑 이 란 말 이 내 가슴 을 계속 두드리 니 이미 내 마음 은 당신 의 것 이 되 어 버렸 네 이 것 은 당신 을 향 한 노래 예요 이 걸 로 당신 의 사랑 얻 을래요 이 거릴 당신 과 함께 걸 을래요 이제 는 당신 도 나 와 함께 해 요 밥 을 먹 으려고 수저 를 들 을 때 도 세수 를 하 고 수건 을 만질 때 도 월화 수목 그 어느 때 도 셀 수 없 을 만큼 생각나 요 낮 술 마신 척 취한 척 다가가 말 할래요 그 댄 나 의 천사 어느 영화 대사 밥 살 돈 없 지만 사랑 만 은 장사 당신 사랑 해 요 진심 이 에요
# Right translation : <sos> 좋 아 합니다
# Predicted translation:  나 의 집 <eos>
# --------------------------------------------------
# Input: 나 는 오늘 부터 너 와 의 관계 를 다시 하 려고 해 나 는 너 의 친구 너 는 나 의 친구 이제 그만 하 려고 해 다시 하 려고 해 네 손 을 잡 고 싶 어 졌 어 네 품 에 안기 고 널 꼭 안 고 싶 어 졌 어 활짝 핀 저 꽃 이 널 향 한 내 맘 같 다는 그런 말 을 하 고 싶 었 어 전하 고 싶 었 어 얘기 가 끝나 고 눈 을 맞췄 을 땐 너 의 표정 이 어떨지 조금 걱정 도 돼 네 손 을 잡 고 싶 어 졌 어 네 품 에 안기 고 너 를 꼭 안 고 싶 어 졌 어 활짝 핀 저 꽃 이 널 향 한 내 맘 같 다는 그런 말 을 하 고 싶 었 어 너 와 나 사이 에 사랑 이 란 말 을 붙이 고 싶 어 졌 어 나 는 오늘 부터 너 와 의 관계 를 다시 하 려고 해
# Right translation : <sos> 절교
# Predicted translation:  원룸 <eos>
# --------------------------------------------------

# %%
def translate_test(seq_index):
  input_seq = encoder_input_test[seq_index: seq_index + 1]

  sentence = seq_to_src(encoder_input_test[seq_index]).strip()
  _, result, attention_plot = decode_sequence(sentence)

  print('Input: %s' % (sentence))
  print("Right translation :",seq_to_tar(decoder_input_train[seq_index]))
  print('Predicted translation: {}'.format(result))

  #attention_plot = attention_plot[:len(result.split(' '))-2, :len(sentence.split(' '))]
  #plot_attention(attention_plot, sentence.split(' '), result.split(' '))

# %%
for seq_index in [10, 200, 303, 1005]:
  translate_test(seq_index)
  print("-"*50)
# Out:
# Input: 하얀 종이 한 장 책상 에 올려다 놓 고 한참 고민 하 다 커다란 달 그렸 는데 괜히 쓸쓸 해져 작 게 그려 본 전구 를 키 고서 가만히 앉 아 아침 을 기다리 네 아직 달 은 밝 아 불 꺼진 방 을 비추 고 못 보 던 사이 에 늘어난 그림 들 속 엔 다 들 둘러앉 아 이 곳 을 바라보 고서 손짓 을 하 기 에 따라 들어갔 네 한 바퀴 를 돌아가 자 달 위 에 발자국 을 남기 자 하나 씩 떨어져 멀 어 진대 도 남겨진 발자국 을 따라가 서 다시 만나 자 그 곳 에서 기다리 던 아침 이 었 지만 이대로 는 아쉬울 것 같 아 전구 가 다 꺼져 가 고 있 을 때 망설 이 다 뒤집 은 그림 보 면 다 들 둘러앉 아 모두 한 곳 을 보 고서 달 위 를 돌아가 는데 한 바퀴 를 돌아가 자 달 위 에 발자국 을 남기 자 하나 씩 떨어져 멀 어 진대 도 남겨진 발자국 을 따라가 면 만날 수 있 을 거 야 이제 다 같이 몸 떠 오르 네 한 바퀴 를 돌아가 자 달 위 에 발 이 닿 을 수 없 다면 떠오르 는 서로 를 붙잡 고서 한 바퀴 를 더 돌 자 한 바퀴 를 더 돌 자 한 바퀴 를 돌아가 자 달 위 에 발 이 닿 을 수 없 다면 떠오르 는 서로 를 붙잡 고서 한 바퀴 를 돌아가 자 달 위 에 발 이 닿 을 수 없 다면 떠오르 는 서로 를 붙잡 고서
# Right translation : <sos> 시간 이란
# Predicted translation:  나 의 바다 <eos>
# --------------------------------------------------
# Input: 간장 게장 내 밥 을 훔쳐 간 간장 게장 간장 게장 내 몸매 훔쳐 간 간장 게장 간장 게장 꼭 품 은 주홍 빛 차오른 속 살 맘 아파 눈 질끈 감 아 봐도 한 입 에 가득히 차가운 속 살 미안 해 내 손 이 그랬 어 얄궂 은 게 딱지 에 따끈따끈 밥 을 넣 고 부비 얄미운 집게발 에 츄츄 츄 릅츄 여기 한 공기 더 간장 게장 내 밥 을 훔쳐 간 간장 게장 정말 좋 아 좋 아 간장 게장 내 몸매 훔쳐 간 간장 게장 간장 게장 좋 아 밥 을 비벼 먹 자 슥 삭 슥 삭 참기름 도 넣 고 슥 삭 슥 삭 솔솔 김 가루 도 슥 삭 슥 삭 슥 삭 간장 게장 에 나 를 맡 길래 좀 짠 듯 안 짠 듯 알쏭달쏭 해 먹 은 듯 아닌 듯 자꾸 허해 어디 로 갔 을까 벌써 세 공기 아 뿔 싸 누가 좀 말려 줘요 얄궂 은 게 딱지 에 따끈따끈 밥 을 넣 고 부비 얄미운 집게발 에 츄츄 츄 릅츄 여기 한 공기 더 간장 게장 내 밥 을 훔쳐 간 간장 게장 정말 좋 아 좋 아 간장 게장 내 몸매 훔쳐 간 간장 게장 간장 게장 좋 아 밥 을 비벼 먹 자 슥 삭 슥 삭 참기름 도 넣 고 슥 삭 슥 삭 솔솔 김 가루 도 슥 삭 슥 삭 슥 삭 간장 게장 간장 게장 간장 게장 간장 게장 내 밥 을 훔쳐 간 간장 게장 정말 좋 아 좋 아 내 맘 간장 게장 내 몸매 훔쳐 간 간장 게장 두 그릇 세 그릇 네 그릇 네 게 줄 께 간장 게장 간장 게장 정말 좋 아 좋 아 내 몸 간장 게장 내 몸매 훔쳐 간 간장 게장 에 나 를 맡 길래
# Right translation : <sos> 빗방울 소리
# Predicted translation:  나 는 야 위대 함 <eos>
# --------------------------------------------------
# Input: 무정 한 사람 카 타리 나 어찌 살 라고 그대 날 떠났 나 그대 떠 난 뒤 난 괴로워 카 타리 어여쁜 그대 잊 지 못 하 네 카 타리 그대 그리워 아 허무 한 사랑 그대 의 모습 은 아직 도 생생히 남 아 있 네 그대 의 그림자 괴로워 카 타리 그대 는 어찌 해 그대 마음 에 나 를 잊 었 나 하 홀로 만 태워도 그대 는 어이 잊 었 나 하 무정 한 마음 그대 의 모습 아직 도 생생히 남 아 있 네 그대 의 그림자 괴로워 아 허무 한 사랑 그대 의 모습 은 아직 도 생생히 남 아 있 네 그대 의 그림자 괴로워 아
# Right translation : <sos> 다른 어떤 말 로
# Predicted translation:  그대 는 나 의 푸르름 <eos>
# --------------------------------------------------
# Input: 행복 하 기 로 했잖아 어떤 어려움 이 닥쳐와 도 지금 은 힘들 어도 나중 에 추억 일 거 라 그랬었 잖아 이렇게 너 와 나 멀 어 지 면 안 되 는 거 잖 아 너 도 멀 어 지 기 싫 잖아 근데 왜 자꾸 만 멀 어 지 는 데 이겨 낼 거 라고 했었잖 아 모든 게 잘 될 거 라 그랬 잖아 조금 만 힘내 자고 조금 만 더 버텨 보 자고 그랬었잖 아 절대로 너 와 나 떨어지 지 말 자고 했었잖 아 너 도 멀 어 지 기 싫 잖아 근데 왜 자꾸 만 멀 어 지 는데 난 여전히 너 하나 만 을 사랑 하 는데 너 는 알 잖아 내 가 어떤 생각 하 는지 우리 다시 만나 게 된다면 절대로 떨어지 지 말 자 행복 하 기 로 했잖아 그 어떤 어려움 이 닥쳐와 도 지금 은 힘들 어도 나중 에 추억 일 거 라 그랬었 잖아 이렇게 너 와 나 멀 어 지 면 안 되 는 거 잖 아 너 도 멀 어 지 기 싫 잖아 근데 왜 자꾸 만 멀 어 지 는데 난 여전히 너 하나 만 을 사랑 하 는데 너 는 알 잖아 내 가 어떤 생각 하 는지 우리 다시 만나 게 된다면 절대로 떨어지 지 말 자 이렇게 끝낼 수 는 없 어 널 절대 놓 지 않 을 거 야 내 가 사랑 한 사람 은 너 하나 밖에 없 는데 이제야 알 겠 어 이렇게 되 니 알 겠 어 니 가 나 에게 얼마나 소 중 한지 를 알 겠 어 이렇게 끝낼 수 는 없 어 널 절대 놓 지 않 을 거 야 내 가 사랑 한 사람 은 너 하나 밖에 없 는데 이제야 알 겠 어 이렇게 되 니 알 겠 어 니 가 나 에게 얼마나 소 중 한지 를 알 겠 어
# Right translation : <sos> 케이크
# Predicted translation:  사랑 의 끝 <eos>
# --------------------------------------------------

# %% [markdown]
# ### Reference
#
# - https://blog.keras.io/a-ten-minute-introduction-to-sequence-to-sequence-learning-in-keras.html
# - https://wikidocs.net/86900
# - https://www.tensorflow.org/tutorials/text/nmt_with_attention?hl=ko#%ED%9B%88%EB%A0%A8%EB%90%9C_%EB%AA%A8%EB%8D%B8%EB%A1%9C_%EB%B2%88%EC%97%AD%ED%95%98%EA%B8%B0

# %% [markdown]
# # test

# %%
len(encoder_input_test)
# Out:
# 11233

# %%
import numpy as np

a = np.random.randint(100, size=1000)

# %%
for seq_index in a:
  translate_test(seq_index)
  print("-"*50,seq_index)
# Out:
# Input: 내 얼굴 알 고 있 나요 너무나 설레 요 지금 내 옆 을 지나가 는 너 일까 내 가 알 고 있 는 인연 중 에 너 인가 당신 을 위해 기다려 온 생애 최고 의 연인 이 될 준비 는 완료 평생 을 믿 고 따를게요 우리 가 만들 어 갈 새 인생 을 요 너무 기다리 게 하 지 말 아 날 아프 게 하 지 마 날 시험 에 들 게 하 지 마 천 번 의 인연 이 있 어야 만난다는 생 의 반쪽 어느 날 내 앞 에 다가와서 입 맞춰 줄 거 란 믿음 만 은 변함 없 죠 정말 잘 할 거 란 생각 밖에 말 이 필요 없 죠 생각 보다 무 뚝뚝 합니다 하찮 은 외모 보단 바다 같 은 이 해심 보 기 보다 여리 답니 다 무소 같 은 인내심 널 지킬 뱃심 할 말 이 많 아요 어디 쯤 와 있 나요 내 이름 알 고 있 나요 너무 기대 돼요 사람 많 은 거리 에서 날 보 고 소리쳐 줘 사랑 해 아무리 더워도 내 손 놓 지 말 아 줘 널 좋 아 해서 미안 한 일 은 않 을 게 내게 오 느라 힘들 었 던 발 은 내 가 씻 어 줄 게 널 기다리 느라 목 이 빠진 내 인생 너 다 줄 게 다 가져가 어쩌다 소극 적 인 성격 땜 에 화날 일 이 생겨도 표현 을 못 해 너무 답답 하 게 만들 어도 속 맘 은 안 그런 거 알 아도 이해 해도 말 처럼 쉽 지 않 을 때 가 있 어도 먼저 미안 하 다 말 할 거 예요 자존심 아닌 진실 된 뉘우침 먼저 사랑 한다 말 할 거 예요 가식 아닌 내 속 의 진심 가끔 은 두려워 혹시 않 올까 봐요 내 얼굴 알 고 있 나요 너무나 설레 요 하루 에 딱 한 번 만 싸우 고 한 달 에 속 한 번 만 썩이 고 일 년 에 나 한 번 만 울려 줘 평생 에 넌 내게 한 명 뿐 야 너 니까 참 고 너 니까 사랑 하 고 너 니까 웃 는 거 야 난 너 니까 사 는 거 야 내게 올 너 만 을 기다릴 꺼 야 분명 행복 할 꺼 야 한눈팔 지 않 고 너 만 바라볼 거 며 평생 을 바쳐 사랑 할 것 이 며 비바람 몰아쳐도 널 지킬 것 이 며 누구 의 귓속말 도 안 들 을 것 이 며 오해 가 생긴 데 도 너 를 믿 을 것 이 며 나 로 인해 행복 하 게 해 줄 것 이 며 상처 를 주 지 않 는 치료 해 주 는 그런 사람 되 줄 게 요 내 미래 반쪽 할 말 이 많 아요 어디 쯤 와 있 나요 내 이름 알 고 있 나요 너무 기대 돼요 가끔 은 두려워 혹시 않 올까 봐요 내 얼굴 알 고 있 나요 너무나 설레 요 사랑 해
# Right translation : <sos> 내 마음 이 심히 약해 졌으니
# Predicted translation:  내 가 그댈 사랑 하 는 방법 <eos>
# -------------------------------------------------- 55
# Input: 가끔 은 겁 이 나 기 도 해 요 내 가 이 길 을 끝 까지 걸 을 수 있 을까 혹시 이 길 을 걷 다가 그냥 쓰러져 버리 지 는 않 을까 가끔 은 센 척 하 기 도 해 요 누가 나 를 바라보 며 한 심 해 할까봐 사실 나 의 속마음 은 많이 아주 많이 부서져 가 는 데 하 지만 이제 더 는 숨 어서 울 지 않 아 못 난 이 모습 그대로 안 아 줘요 이렇게 약하 지만 그래도 나 는 사랑 을 믿 고 있 어 차갑 지 않 은 따 뜻 한 사랑 속 에 춤출 수 있 게 그 안 에 가둬 줘요 날 잡 아 줘요 아파도 참 고 웃 기 도 해 요 결국 세상 은 찢겨진 날 버릴 테 니까 항상 상처 를 숨기 고 매일 같 은 자리 에 서 있 었 는데 하 지만 이제 더 는 숨기 고 싶 지 않 아 찢겨진 이 모습 그대로 안 아 줘요 이렇게 약하 지만 그래도 나 는 사랑 을 믿 고 있 어 차갑 지 않 은 따 뜻 한 사랑 속 에 춤출 수 있 게 그 안 에 가둬 줘요 날 잡 아 줘요 더럽 고 찢겼 지만 그래도 나 는 당신 을 믿 고 있 어 마르 지 않 을 영원 한 사랑 속 에 춤출 수 있 게 당신 을 열 어 줘요 날 안 아 줘요
# Right translation : <sos> 자폐
# Predicted translation:  나 의 집 에 <eos>
# -------------------------------------------------- 45
# Input: 지친 내 하루 에 끝 엔 항상 그대 가 있 기 에 힘든 일 도 어려움 도 모두 이길 수 있 었 죠 아직 도 나 는 생생 해 요 우리 처음 만난 그날 이 그 댄 내 반쪽 일 거 라고 난 생각 도 못 했 는데 우리 함께 가 야 할 길 이 멀 게 만 보일지라도 서로 위 하 며 아껴 주 며 그대 와 나 영원히 변치 말 아요 힘든 시련 이 와도 지금 잡 은 두 손 을 놓 지 마 요 나 그대 의 위로 될 게 요 먼 훗날 우리 늙 고 지쳐 쓰러져도 이 맘 변치 말 아요 항상 처음 처럼 나 그 댈 지켜줄 게 요 사랑 해 요 어떤 어려움 이 온대 도 두려워 하 지 말 아요 그대 곁 에 내 가 있 음 을 언제나 기억 해 요 변치 말 아요 힘든 시련 이 와도 지금 잡 은 두 손 을 놓 지 마 요 나 그대 의 위로 될 게 요 먼 훗날 우리 늙 고 지쳐 쓰러져도 이 맘 변치 말 아요 항상 처음 처럼 나 그 댈 지켜줄 게 요 사랑 해 요 난 감사 하 죠 내 맘 을 받 아 준 그대 에게 서로 아껴 주 고 섬기 면서 평생 함께 할게요 변치 말 아요 힘든 시련 이 와도 지금 잡 은 두 손 을 놓 지 마 요 나 그대 의 위로 될 게 요 먼 훗날 우리 늙 고 지쳐 쓰러져도 이 맘 변치 말 아요 항상 처음 처럼 나 그 댈 지켜줄 게 요 사랑 해 요 나 의 사랑 그대 영원히
# Right translation : <sos> 우주 그리고 별
# Predicted translation:  나 의 뮤즈 <eos>
# -------------------------------------------------- 73
# Input: 널 좋 아 하 는 거 나 이제 그만 둘까 봐 날 좋 아 해 달 란 얘기 도 일찍 집 에 가 란 얘기 도 더 는 하 지 않 을 게 몇 날 며칠 연락 이 되 지 않 아도 괜 한 걱정 하 는 것 도 아직 도 눈 만 뜨 면 네 생각 이 난다는 얘기 도 널 좋 아 하 는 거 나 이제 그만 둘까 봐 내 가 아닌 그 사람 과 행복 하 라고 웃 으며 축하 도 해줄까 봐 널 기다리 는 거 나 이제 그만 할까 봐 너 올까 봐 기다리 는 하루 도 오늘 을 마지막 으로 널 좋 아 하 는 거 그만 할까 봐 널 좋 아 하 는 건 나 이제 힘 에 겹 나 봐 우리 처음 만난 그날 도 날 보 며 웃 어 주 던 미소 도 기억 하 지 않 을 게 하루 의 시작 하루 의 끝 에 네 목소리 잠자 는 시간 빼 고 는 아른거리 네 얼굴 이 어딜 가 나 네 가 있 고 내 귓가 에 들린단 얘기 도 널 좋 아 하 는 거 나 이제 그만 둘까 봐 내 가 아닌 그 사람 과 행복 하 라고 웃 으며 축하 도 해줄까 봐 널 기다리 는 거 나 이제 그만 할까 봐 너 올까 봐 기다리 는 하루 도 오늘 을 마지막 으로 널 좋 아 하 는 거 그만 할까 봐 더 이상 은 묻 지 않 을 거 란 그 얘기 도 널 좋 아 하 는 거 나 이제 그만 둘까 봐
# Right translation : <sos> 내게 숨 은 당신
# Predicted translation:  너 를 위한 노래 <eos>
# -------------------------------------------------- 21
# Input: 예수 님 은 나 의 왕 이 요 예수 님 은 나 의 왕 이 요 예수 님 은 나 의 왕 이 요 예수 님 은 나 의 왕 이 요 나 의 왕 이 여 예수 님 은 나 의 반석 나 의 왕 이 여 예수 님 은 나 의 반석 나 의 왕 이 여 예수 님 은 나 의 반석 나 의 왕 이 여 주 님 안 에 살 고 주 를 위해 사네 주 님 안 에 살 고 주 를 위해 사네 주 님 안 에 살 고 주 를 위해 사네 주 님 안 에 살 고 주 님 을 위해 사네 예수 나 의 주 예수 나 의 주 예수 나 의 주 예수 나 의 주 예수 나 의 주 예수 나 의 주 예수 나 의 주 예수 나 의 주 예수 나 의 주
# Right translation : <sos> 그렇게 우리 는 그렇 게
# Predicted translation:  나 의 힘 이 되 어 <eos>
# -------------------------------------------------- 4
# Input: 어떤 이 는 꿈 을 간직 하 고 살 고 어떤 이 는 꿈 을 나눠 주 고 살 며 다른 이 는 꿈 을 이루 려고 사 네 어떤 이 는 꿈 을 잊 은 채 로 살 고 어떤 이 는 남 의 꿈 을 뺏 고 살 며 다른 이 는 꿈 은 없 는 거 라 하 네 세상 에 이 처럼 많 은 사람 들 과 세상 에 이 처럼 많 은 개성 들 저 마다 자기 가 옳다 말 을 하 고 꿈 이란 이런 거 라 말 하 지만 나 는 누굴까 내일 을 꿈꾸 는가 나 는 누굴까 아무 꿈 없 질 않 나 는 누굴까 내일 을 꿈꾸 는가 나 는 누굴까 혹 아무 꿈 종진 이 는 꿈 을 간직 하 고 살 고 태관 이 는 꿈 을 나눠 주 고 살 며 여러분 은 꿈 을 이루 고 사세요 어떤 이 는 꿈 을 잊 은 채 로 살 고 어떤 이 는 남 의 꿈 을 뺏 고 살 며 다른 이 는 꿈 은 없 는 거 라 하 네 세상 에 이 처럼 많 은 사람 들 과 세상 에 이 처럼 많 은 개성 들 저 마다 자기 가 옳다 말 을 하 고 꿈 이란 이런 거 라 말 하 지만 나 는 누굴까 내일 을 꿈꾸 는가 나 는 누굴까 아무 꿈 없 질 않 나 는 누굴까 내일 을 꿈꾸 는가 나 는 누굴까 아무 꿈 나 는 누굴까 내일 을 꿈꾸 는가 나 는 누굴까 아무 꿈 없 질 않 나 는 누굴까 내일 을 꿈꾸 는가 나 는 누굴까 혹 아무 꿈
# Right translation : <sos> 자꾸 눈 이 가
# Predicted translation:  나 의 바다 <eos>
# -------------------------------------------------- 52
# Input: 니 기 리시 메테 이타 테 가 꼭 잡 고 있 던 손 이 키 가 츠 쿠토 호도 케 테 루 의식 하 면 풀 어 지 고 있 어 다레 가 키 메타 와케 데모 나 쿠 누군가 정 했 던 것 은 아니 기에 코코 로 와 츠 기노 바쇼 오 사 가스 마음 은 다음 장소 를 찾아가 오 나지 소라 오 미 나가 라 같 은 하늘 을 보 면서 보 쿠라 와 아 루이 테 키타 우리 는 걸어왔 어 츠 라이 토키 와 사사 에 앗 테 괴로울 땐 서로 의지 하 고 나 미 다오 누 굿 테 눈물 을 닦 고 히 토리 다케 데시 카 혼자 서 만 에 라베 나이 미치 모 아루 케 도 선택 해야 하 는 길 도 있 지만 소코 니 와 키 미 가 쿠 레타 그 길 에 는 네 가 줬 던 타쿠 상노 아이 가 아루 많 은 사랑 이 있 어 사 요 나라 노 무코 오 니 후리 소 소 구 작별 인사 저편 에 내리쬐 는 토 오이 히카리 가 유 메토 유우 나라 먼 빛 이 꿈 이 라고 한다면 오 모이 데 와 미라 이 오 마모루 다 로 오 추억 은 미래 를 지킬 거 야 이 츠 데모 보 쿠 와 키 미토 이루 언제나 나 는 너 와 있 어 이마 와 와카 라 나 쿠 테 모 지금 은 모르 겠 지만 신지 츠 즈 케테 이 레바 계속 믿 는다면 돈 나모 노모 카타 치 니 나 루 어떤 것 이 라도 모양 을 갖출 거 야 시아 와 세모 킷 토 행복 도 반드시 후 타리 다케 가 미타 둘 이 서 만 봤 던 아 타라 시 이 호시노 마타 타 키 새로운 별 의 반짝임 소코 카라 우마 레카 와 루 그 빛 에서 다시 태어나 는 모노 가 타리 츠 즈 이 테 쿠 이야기 는 계속 돼 사 요 나라 노 무코 오 니 후리 소 소 구 작별 인사 저편 에 내리쬐 는 아 와 이 히카리 모 유메 니 나 루 나라 희미 한 빛 도 꿈 이 된다면 카나시 미노 이 미사 에 카 에 루 다 로 오 슬픔 의 의미 까지 도 바꿀 거 야 소 오 다 요 보 쿠 와 소바 니 이루 그래 나 는 곁 에 있 어 사 아 소 노 테 니 코노 테오 카 사네 자 그 손 에 이 손 을 포개 고 타시 카 메 요 오 에이 엔 오 영 원 을 확인 하 자 사 요 나라 노 무코 오 니 후리 소 소 구 작별 인사 저편 에 내리쬐 는 토 오이 히카리 가 유 메토 유우 나라 먼 빛 이 꿈 이 라고 한다면 오 모이 데 와 미라 이 오 마모루 다 로 오 추억 은 미래 를 지킬 거 야 이 츠 데모 보 쿠 와 키 미토 이루 언제나 나 는 너 와 있 어 보 쿠 와 키 미토 이루 나 는 너 와 있 어
# Right translation : <sos> 아무것 도 아닌 나
# Predicted translation:  나 의 인생 <eos>
# -------------------------------------------------- 70
# Input: 이제 제발 좀 그만 해 모든 게 지겨워 나 를 좀 내버려 둘 래 이런 건 별것 도 아닌데 처음 도 아닌데 왜 이리 힘든 건지 그대 를 원했 던 내 마음 지워 줄 래 우리 는 너무나 다른 걸 이제야 알 았 어 아무리 원해 도 소용없 는 걸 그대 는 나 에게 불안 만 을 줄 테 니 더 이상 나 에게 강요 하 지 마 이제 내 경고 야 애절 한 눈빛 도 소용없 는 걸 그대 의 선물 도 모두 가져가 버려 이별 을 말 해도 원망 하 지 마 가슴 이 아파 와 그 댈 잊 는 걸 포기 해 그대 와 사랑 해 아니 야 이래 선 안 되 그대 는 너무나 순진 해 차라리 내 가 저 멀리 떠나 줄 게 그대 를 원했 던 내 마음 지워 줄 래 우리 는 너무나 다른 걸 이제야 알 았 어 다시 는 못 볼 거 야 나 의 착한 그대 의 기억 속 나 에게 작별 을 하 고 싶 은데 틀린 가사 알려 주 시 면 수정 하 겠 습니다
# Right translation : <sos> 우리 가 빛나 던 그 때
# Predicted translation:  나 는 어떡 하 지 않 아 <eos>
# -------------------------------------------------- 66
# Input: 잔잔 하 던 호수 위 에 파문 그대 처음 바라본 순간 놀라 움 과 두려움 에 떨 며 서로 조심 스레 가까 왔 을 때 빨려 들 던 눈동자 에 비친 외로움 에 지친 그림자 이제 는 당신 의 오 당신 만 의 사람 오 당신 만 의 사랑 이 겠 소 하얀 눈 이 온 세상 을 덮 어 진실 만 이 오 고 갔 을 때 차가와 진 손 을 어루만져 그대 마음 까지 따스 했 을 때 피곤 했 던 내 마음 의 날개 날 아 오른 느낌 이 었 소 오 그대 는 그토록 기다리 던 오 기다리 던 사람 이 었 오 젖 은 눈 을 바라보 는 순간 떠날 시간 다가온 줄 을 알 면서 도 말 못 하 는 마음 아니 보내 야 만 했 던 내 마음 헤어지 는 아픔 만 이 남 은 어느 슬픈 사랑 의 얘기 그러나 당신 은 나 하나 만 의 사람 나 하나 만 의 사랑 이 었 오 그러나 당신 은 나 하나 만 의 사람 나 하나 만 의 사랑 이 었 오
# Right translation : <sos> 주 님 이 나 를 위해
# Predicted translation:  나 의 뮤즈 <eos>
# -------------------------------------------------- 31
# Input: 법률 송 꼭꼭 지키 기 로 약속 했 더니 꼭꼭 지켜 주 는 법 이 되 었 어 법 사고뭉치 제멋대로 나쁜 짓 안 돼 엉망 진창 세상 은 법 이 지켜 줘 안 전하 게 편안 하 게 행복 한 이 세상 나 로부터 시작 해서 우리 가 되 네 꼭꼭 지키 기 로 약속 했 더니 꼭꼭 지켜 주 는 법 이 되 었 어 법 안 전하 고 편안 하 게 행복 한 세상 좋 아요 우리 모두 행복 은 법 이 지켜 줘
# Right translation : <sos> 로비 브 사랑
# Predicted translation:  나 의 집 <eos>
# -------------------------------------------------- 20
# Input: 가끔 은 겁 이 나 기 도 해 요 내 가 이 길 을 끝 까지 걸 을 수 있 을까 혹시 이 길 을 걷 다가 그냥 쓰러져 버리 지 는 않 을까 가끔 은 센 척 하 기 도 해 요 누가 나 를 바라보 며 한 심 해 할까봐 사실 나 의 속마음 은 많이 아주 많이 부서져 가 는 데 하 지만 이제 더 는 숨 어서 울 지 않 아 못 난 이 모습 그대로 안 아 줘요 이렇게 약하 지만 그래도 나 는 사랑 을 믿 고 있 어 차갑 지 않 은 따 뜻 한 사랑 속 에 춤출 수 있 게 그 안 에 가둬 줘요 날 잡 아 줘요 아파도 참 고 웃 기 도 해 요 결국 세상 은 찢겨진 날 버릴 테 니까 항상 상처 를 숨기 고 매일 같 은 자리 에 서 있 었 는데 하 지만 이제 더 는 숨기 고 싶 지 않 아 찢겨진 이 모습 그대로 안 아 줘요 이렇게 약하 지만 그래도 나 는 사랑 을 믿 고 있 어 차갑 지 않 은 따 뜻 한 사랑 속 에 춤출 수 있 게 그 안 에 가둬 줘요 날 잡 아 줘요 더럽 고 찢겼 지만 그래도 나 는 당신 을 믿 고 있 어 마르 지 않 을 영원 한 사랑 속 에 춤출 수 있 게 당신 을 열 어 줘요 날 안 아 줘요
# Right translation : <sos> 자폐
# Predicted translation:  나 의 집 에 <eos>
# -------------------------------------------------- 45
# Input: 하하 하 호호 호호 히 히 하하 하 한바탕 웃 으면은 복 이 온데 요 짜증 내 고 씩씩대 며 슬퍼 한다고 달라질 건 없 죠 랄랄라 온 집 에 웃음 소리 가득 얼굴 마다 웃음꽃 피 네 우리 모두 신나 게 웃 어 보 아요 하하 하 호호 호호 히 히 하하 하 한바탕 웃 으면은 복 이 온데 요 짜증 내 고 씩씩대 며 슬퍼 한다고 달라질 건 없 죠 랄랄라 이 곳 에 웃음 소리 가득 얼굴 마다 웃음꽃 피 네 우리 모두 신나 게 하늘 보 니 구름 아빠 있 죠 땨뜻 한 미소 로 나 를 보 네 따 뜻 한 미소 로 우릴 보네 예
# Right translation : <sos> 행복 이 쌓이 다
# Predicted translation:  나 는 꼼꼼 한 테슬라 <eos>
# -------------------------------------------------- 60
# Input: 그 는 쓰러진 나 를 일으키 며 그 의 제자 로 나 를 부르 신다 담대 하 여 라 네 가 날 알 듯 다른 사람 도 날 알 게 되 리라 너 의 증인 됨 으로 너 의 입 을 통해 서 예수 는 그리스 도 모두 외치 게 되리 예수 는 그리스 도 모두 외치 게 되리 그 는 포기 한 나 를 부르 시 며 그 의 믿음 을 내게 보이 신다 힘 을 내 어라 어서 일어나 하나님 나라 길 을 예비 하 라 너 의 증인 됨 으로 너 의 입 을 통해 서 예수 는 그리스 도 모두 외치 게 되리 예수 는 그리스 도 모두 외치 게 되리
# Right translation : <sos> 콕 찍 어 주 세요
# Predicted translation:  나 는 나 의 것 <eos>
# -------------------------------------------------- 5
# Input: 두 바퀴 돌아가 듯 세 바퀴 돌아가 듯 너 에게 가 는 길 을 알 수 가 없 어 나 에게 돌아올까 너 에게 돌아갈까 이런 저런 생각 에 잠 못 이뤘 어 너 는 나 를 떠나 고 그렇 게 도 잘 사 는지 스쳐 지나가 듯 날 바라보 며 웃 었 지만 너 를 지우 지 못 한 내 마음 이 너 에게 는 묻 지 도 궁금 하 지 도 않 은 거 야 워 우 워 워 우 워 어 야 이야 워 우 워 워 우 워 어 야 이야 날 사랑 하 던 네 가 날 좋 아 하 던 네 가 날 보 며 웃 던 네 가 다른 남자 옆 에 있 어 모든 게 거짓 같 아 믿 고 싶 지 도 않 아 이렇게 변할 줄 은 꿈 에 몰랐 어 그렇게 아무렇 지 않 은 척 을 하 면서 도 네 행복 바라 는 나 자신 이 다 비참 해도 네 가 나 에게 줬 던 그 짧 았 던 사랑 들 에 미운 짓 하 는 너 를 밀어 냈 나 봐 워 우 워 워 우 워 어 야 이야 워 우 워 워 우 워 어 야 이야 그대로 쭉 행복 해 내 생각 하 지 말 고 기억 도 하 지 말 고 모두 잊 어 줘 날 잊 고 잘 살 면 돼 그렇게 행복 하 게 멋진 여자 로 내 맘속 에 남 아 줘
# Right translation : <sos> 저절로 흐르 는 곳 낮 은
# Predicted translation:  나 의 사랑 은 <eos>
# -------------------------------------------------- 33
# Input: 사랑 한다는 그 말 더 는 못 하 는 그 말 마음 에 담 고서 자꾸 되내이 는 말 아름다웠 는데 행복 했었 어 모두 다 잊 었 니 많이 보 고 싶 어 사랑 했 던 너 를 전부 라 믿 었 던 사랑 했 던 너 를 어떡 하 나요 그 사랑 이 남 아 있 어 날 붙들 고 가지 말라 해 요 텅 빈 것 같 은 거리 혼자 거닐 고 있 죠 발길 이 닿 는 곳 마냥 걷 고 걸 었 죠 답답 한 마음 을 어떡해야 만 해야 할지 를 몰라 많이 보 고 싶 어 사랑 했 던 너 를 전부 라 믿 었 던 사랑 했 던 너 를 어떡 하 나요 그 사랑 이 남 아 있 어 날 붙들 고 가지 말라 해 요 미칠 듯이 보 고 싶 어 그대 가 어떻게 살 고 있 죠 괜찮 나요 많이 보 고 싶 어 사랑 했 던 너 를 전부 라 믿 었 던 사랑 했 던 너 를 어떡 하 나요 그 사랑 이 남 아 있 어 날 붙들 고 가지 말라 해 요 가지 말라 해 요 내 사랑 가 지 말 아요
# Right translation : <sos> 오늘 부터 행복 한 나
# Predicted translation:  사랑 이 아니 야 <eos>
# -------------------------------------------------- 67
# Input: 얼마 만큼 사랑 했 는지 나 알 고 있 어요 처음 널 만났었 던 서로 가 웃 던 내 기억 이 맞 다면 술 취해 실없이 웃 던 나 괴로웠 던 또 매일 지루 했 던 날 들 이 한 순간 에 머리 에서 사라져 버렸 던 그날 하늘 에선 비 가 오 고 세상 이 모두 씻겨 지 는 기분 이 야 대학 로 이름 모를 주점 이 라 희미 해도 그때 의 기분 나 남김없이 기억 해 기쁠 때 면 귀여운 보조 게 가 내 맘 들뜨 게 만들 었 지 가끔 슬플 때 면 서글픈 내 노래 가 싸구려 낡 은 내 통키 타 와 흐느꼈 지 년 이 지났 지만 아직 도 그대로 너 의 그 선물 들 도 여지 껏 그대로 애타 는 편지 들 도 지금껏 그대로 마지막 남겨진 일기장 도 그대로 하늘 도 우 는 걸 봤 어요 누구 도 도 와 주 질 않 아 힘 이 없 어서 미안 해 요 지키 지 못 했 어요 날 믿 고 기다려 준 당신 께 정말 사랑 했 어 너무 보 고 싶 어요 얼마 만큼 사랑 했 는지 나 알 고 있 어요 어떨 결 에 들어가 는 훈련소 내 뒤 로 울먹이 며 위병 소 앞 에서 머뭇거리 는 널 뒤 로 한 채 한 방울 굵 은 눈물 흘리 며 나 뛰어갔 지 비로소 병역 이 란 이름 아래 훈련병 생활 하루 이틀 사흘 나흘 땀 흘리 며 힘들 때 바라보 던 너 의 사진 어느새 바 래 지 고 내 눈 은 노래지고 또 희미 해 지 고 몇 통 씩 날라 오 던 편지 그리고는 몇 주 씩 걸러 오 던 편지 끊겼 지 보낼 수 없 었 단 걸 쓸 수 도 없 었 단 걸 이제야 알 았 단 걸 정말 미안 해 년 이 지났 지만 아직 도 그대로 너 의 그 선물 들 도 여지 껏 그대로 애타 는 편지 들 도 지금껏 그대로 마지막 남겨진 일기장 도 그대로 하늘 도 우 는 걸 봤 어요 누구 도 도 와 주 질 않 아 힘 이 없 어서 미안 해 요 지키 지 못 했 어요 날 믿 고 기다려 준 당신 께 정말 사랑 했 어 너무 보 고 싶 어요 얼마 만큼 사랑 했 는지 나 알 고 있 어요 꿈 만 갔 았 던 너 와 함께 했었 던 시간 다시 한 번 떠올리 며 혼자 눈물 흘리 며 앞 으로 남 은 인생 사죄 하 며 살 겠 어 하늘 위 구름 위 에 슬퍼 할 널 위해 년 이 지났 지만 아직 도 그대로 너 의 그 선물 들 도 여지 껏 그대로 애타 는 편지 들 도 지금껏 그대로 마지막 남겨진 일기장 도 그대로 년 이 지났 지만 년 이 지났 지만 년 이 지났 지만 아직 도 그대로 너 의 그 선물 들 도 여지 껏 그대로 애타 는 편지 들 도 지금껏 그대로 마지막 남겨진 일기장 도 그대로
# Right translation : <sos> 난 이곳 에서 벗어날래
# Predicted translation:  나 의 집 에 <eos>
# -------------------------------------------------- 19
# Input: 너 의 주위 에서 내 가 조용히 사라지 면 너 는 나 를 영원히 잊 어 주 면 돼 너 의 주위 에서 내 가 조용히 사라지 면 너 는 나 를 영원히 잊 어 주 면 돼 너 에 대한 감정 이 무뎌져 넌 내게서 떨어져 매일 환히 웃 으며 또 잘 해 주 면 뭐 해 끝나 면 어차피 모른 척 하 지 남 같이 험한 말 또 다시 험한 말 더러운 손짓 과 우린 헤어진다 다시 돌아갈 수 없 다 해도 후회 하 지 않 을 자신 있 어 너 의 주위 에서 내 가 조용히 사라지 면 너 는 나 를 영원히 잊 어 주 면 돼 너 의 주위 에서 내 가 조용히 사라지 면 너 는 나 를 영원히 잊 어 주 면 돼
# Right translation : <sos> 위로 해 주 세요
# Predicted translation:  나 의 곁 에 <eos>
# -------------------------------------------------- 71
# Input: 나 의 마음 은 도 미노 처럼 쓰러지 고 멈출 수 없 네 나 의 밤 을 먹 어 가 네 파랗 게 물 들 이 네 파랗 게 물들 여진 나 의 밤 을 먹 어 가 는 그대 여 나 의 마음 이 흘러가 네 저 강물 처럼 흘러가 네 멈출 수 없 네 나 의 밤 을 먹 어 가 네 파랗 게 물 들 이 네 파랗 게 물들 여진 나 의 밤 을 먹 어 가 는 나 의 밤 을 먹 어 가 네 파랗 게 물 들 이 네 파랗 게 물들 여진 나 의 밤 을 먹 어 가 는 그대 여
# Right translation : <sos> 주 예수 이름 소리 높여
# Predicted translation:  나 의 친구 <eos>
# -------------------------------------------------- 86
# Input: 내 가 그 댈 목 놓 아 부르 는데 그 댄 뒤돌 아 보 지 도 않 네요 날 좀 보소 그대 여 차가운 달빛 흩 뿌려진 이 어둠 속 에서 이 새벽 하늘 가 고 나 면 잡 지 못 할 것 을 알 기 에 차가운 이슬비 내 몸 을 적시 고 외로운 그림자 적막 을 가르 고 그대 가 남겨 둔 사랑 의 입김 을 따라 그대 를 비추 는 저 달빛 처럼 그대 가 수 놓 은 저 별빛 처럼 그대 가 어디 로 향 해 달려가 든 나 는 그저 따라가 리오 그대 를 따르 는 저 구름 처럼 그대 가 남겨 둔 저 바람 처럼 해 가 뜨 기 전 에 그 댈 만나 리라 날 좀 보소 날 좀 보소 날 좀 보소 날 좀 보소 그대 여 아무리 노력 해도 내겐 뒷 모습 만 보이 는 널 잡 지 못 해 혼자 눈물 흘리 는 이런 못 난 나 를 외면 한 체 또 가 네 너 는 어디 가 지 말 고 나 좀 봐 주 길 뒤돌 아 서 제발 나 를 쳐다 보 길 기다려 봐도 결국 엔 안 된다면 십 리 도 못 가 발병 이 나 길 스치 는 바람 에 내 몸 을 맡기 고 메 마른 입술 로 내 맘 을 여 미 고 어둠 을 밝히 는 차가운 달빛 을 따라 그대 를 비추 는 저 달빛 처럼 그대 가 수 놓 은 저 별빛 처럼 그대 가 어디 로 향 해 달려가 든 나 는 그저 따라가 리오 그대 를 따르 는 저 구름 처럼 그대 가 남겨 둔 저 바람 처럼 해 가 뜨 기 전 에 그 댈 만나 리라 구름 아 저리 비켜라 저 달빛 이 비추 도록 어찌 나 를 두 고 떠나 오 그대 없이 나 는 안 되 오 그대 를 비추 는 저 달빛 처럼 그대 가 수 놓 은 저 별빛 처럼 그대 가 어디 로 향 해 달려가 든 나 는 그저 따라가 리오 그대 를 따르 는 저 구름 처럼 그대 가 남겨 둔 저 바람 처럼 해 가 뜨 기 전 에 그 댈 만나 리라 날 좀 보소 날 좀 보소 날 좀 보소 날 좀 보소 그대 여
# Right translation : <sos> 사랑 을 지우 다
# Predicted translation:  그대 가 있 는 곳 <eos>
# -------------------------------------------------- 51
# Input: 오늘 도 표정 이 어두워 무슨 일 있 는지 물어봐도 되 는지 사실 그대 가 왜 우 는지 왜 슬퍼하 는지 눈치 를 챘 지만 일부러 모른 척 하 는 걸 도저히 용기 가 안 나 서 그 대여 세상 의 모든 연인 들 은 전부 행복 한 것 같 아 오늘 도 표정 이 어두워 그대 를 볼 수 가 없 네 그 어떤 약속 도 못 하 는 나 를 그만 용서 해 요 무슨 일 있 는 건 아닌지 그대 를 볼 수 가 없 네 일부러 모른 척 하 는 걸 도저히 용기 가 안 나 서 그 대여 세상 의 모든 연인 들 은 전부 행복 한 것 같 아 오늘 도 표정 이 어두워 그대 를 볼 수 가 없 네 그 어떤 약속 도 못 하 는 나 를 그만 용서 해 요 무슨 일 있 는 건 아닌지 그대 를 볼 수 가 없 네 집 으로 돌아오 는 길 에 나 혼자 눈물 을 흘려 신호등 불빛 사이 로 저 멀리 보이 는 너 를 집 으로 돌아오 는 길 에 나 혼자 눈물 을 흘려 신호등 불빛 사이 로 그대 를 볼 수 가 없 네 그 어떤 약속 도 못 하 는 나 를 그만 용서 해 요 무슨 일 있 는 건 아닌지 그대 를 볼 수 가 없 네
# Right translation : <sos> 청구역 로맨스
# Predicted translation:  나 의 집 에 <eos>
# -------------------------------------------------- 46
# Input: 보랏빛 어둠 이 흘러 겨울 도 지쳐 가 고 차디찬 침묵 이 꽃 이 피 면 홀로 빈 하늘 로 떠나 다 남김없이 태우 고 나 면 아 그 곳 에 는 푸른 밭 길 이 있 나요 내 머릿속 기억 속 에서 헤매 고 방황 해도 숨 쉬 고 멈추 고 다시 살 면 만날 수 있 겠 지 우리 다 남김없이 태우 고 나 면 아 그 곳 에 는 살구꽃 길 이 있 나요 저 세상 끝 에 우리 다시 만날 수 있 나요
# Right translation : <sos> 그냥 그런대로
# Predicted translation:  나 의 노래 <eos>
# -------------------------------------------------- 25
# Input: 구석 진 골목 버스 전등 속 벌레 들 빛 에 속 아 날리 네 길가 지렁이 들 물 달팽이 들 비 에 젖 어 춤추 네 비 가 온다 비 가 노래 를 한다 춤 보이 는 소리 밤 울음 소리 걸음걸이 눅눅 하 다 깨지 는 하늘 과 숨겨 둔 백수 같 은 여자 의 웃음 소리 들려온다 그런 수진 운다 수진 노래 를 한다 울음 방 한 칸 소리 밤 울음 소리 일그러진 담배 꽁초 살 아 있 는 한숨 에 여자 는 물 을 밟 을까 손 등 을 내밀 까 이유 있 는 떠도 는 그런
# Right translation : <sos> 사막 하늘 끝 에
# Predicted translation:  나 는 꼼꼼 한 테슬라 <eos>
# -------------------------------------------------- 97
# Input: 재벌 같 은 라이프 원 하 는 건 다 사 즐겨 읽 는 책 물론 널 만나 기 전 까지 의 일 네 맘 의 값어치 는 얼마 니 도 사지 는 못 하 지 비장 의 카드 꺼내 도 봐 네 환심 을 사 기 에 는 한도 초과 알 고 있 어 넌 내게 과분 해 외모 가 물론 다 는 아니 지 요즘 애 같 지 않 고 순수 해 나 오늘 너 에게 마음 을 과 소비 해 잘 빠진 네 몸매 보 면 억 소리 나 사치 네 앞 에선 명품 도 다 거품 이 야 사치 내 가 여도 너 는 사치 야 돈 으로 살 수 없 는 게 마음 이 니까 이런 나라 도 괜찮 다면 나 오늘 좀 사치 할 게 통장 잔고 는 위기 여기저기 돈 빌림 근데 왜 네 가 사 치킨 이제 는 걱정 하 지 말 라고 나라 는 그릇 에 넌 넘쳐 흐르 는 파도 자 다가 종점 까지 간 버스 에 는 비싼 차 도 태울 수 없 는 우리 둘 의 값 비싼 추억 들 이 소 중 한 순간 들 이 너 로 인해 쌓여 마일리지 알 고 있 어 넌 내게 과분 해 외모 가 물론 다 는 아니 지 요즘 애 같 지 않 고 순수 해 나 오늘 너 에게 마음 을 과 소비 해 잘 빠진 네 몸매 보 면 억 소리 나 사치 네 앞 에선 명품 도 다 거품 이 야 사치 내 가 여도 너 는 사치 야 돈 으로 살 수 없 는 게 마음 이 니까 이런 나라 도 괜찮 다면 나 오늘 좀 사치 할 게 넌 남잘 다 죽이 는 다이아 넌 내게 영원 한 갑 이 야 내 가 널 가질 수 있 을까 솔직히 좀 걱정 돼 가진 게 없 는 내 전부 인 자존심 까지 다 걸 었 어 너 는 그냥 한 마디 만 하 면 돼 잘 빠진 네 몸매 보 면 억 소리 나 사치 네 앞 에선 명품 도 다 거품 이 야 사치 내 가 여도 너 는 사치 야 돈 으로 살 수 없 는 게 마음 이 니까 이런 나라 도 괜찮 다면 나 오늘 좀 사치 할 게
# Right translation : <sos> 더 는 사랑 안 해
# Predicted translation:  나 는 야 <eos>
# -------------------------------------------------- 39
# Input: 나 행복 합니다 그대 를 만나 서 나 오랜 시간 헤맸 는데 이제 만났 네요 그대 고마워요 내게로 와줘서 아름다운 꽃 이 되 어 주 니 살며시 떨리 네요 그 댈 사랑 해 요 온 맘 다 해 사랑 할게요 우리 가 는 길 이 아무리 어렵 다 해도 그대 의 손 놓 지 않 을 게 요 그 댈 사랑 해 요 영원히 사랑 할게요 우리 하나 되 어 영원 토록 변치 않 는 그 사랑 을 함께 노래 해 요
# Right translation : <sos> 돌아봐
# Predicted translation:  당신 은 이미 <eos>
# -------------------------------------------------- 83
# Input: 니 기 리시 메테 이타 테 가 꼭 잡 고 있 던 손 이 키 가 츠 쿠토 호도 케 테 루 의식 하 면 풀 어 지 고 있 어 다레 가 키 메타 와케 데모 나 쿠 누군가 정 했 던 것 은 아니 기에 코코 로 와 츠 기노 바쇼 오 사 가스 마음 은 다음 장소 를 찾아가 오 나지 소라 오 미 나가 라 같 은 하늘 을 보 면서 보 쿠라 와 아 루이 테 키타 우리 는 걸어왔 어 츠 라이 토키 와 사사 에 앗 테 괴로울 땐 서로 의지 하 고 나 미 다오 누 굿 테 눈물 을 닦 고 히 토리 다케 데시 카 혼자 서 만 에 라베 나이 미치 모 아루 케 도 선택 해야 하 는 길 도 있 지만 소코 니 와 키 미 가 쿠 레타 그 길 에 는 네 가 줬 던 타쿠 상노 아이 가 아루 많 은 사랑 이 있 어 사 요 나라 노 무코 오 니 후리 소 소 구 작별 인사 저편 에 내리쬐 는 토 오이 히카리 가 유 메토 유우 나라 먼 빛 이 꿈 이 라고 한다면 오 모이 데 와 미라 이 오 마모루 다 로 오 추억 은 미래 를 지킬 거 야 이 츠 데모 보 쿠 와 키 미토 이루 언제나 나 는 너 와 있 어 이마 와 와카 라 나 쿠 테 모 지금 은 모르 겠 지만 신지 츠 즈 케테 이 레바 계속 믿 는다면 돈 나모 노모 카타 치 니 나 루 어떤 것 이 라도 모양 을 갖출 거 야 시아 와 세모 킷 토 행복 도 반드시 후 타리 다케 가 미타 둘 이 서 만 봤 던 아 타라 시 이 호시노 마타 타 키 새로운 별 의 반짝임 소코 카라 우마 레카 와 루 그 빛 에서 다시 태어나 는 모노 가 타리 츠 즈 이 테 쿠 이야기 는 계속 돼 사 요 나라 노 무코 오 니 후리 소 소 구 작별 인사 저편 에 내리쬐 는 아 와 이 히카리 모 유메 니 나 루 나라 희미 한 빛 도 꿈 이 된다면 카나시 미노 이 미사 에 카 에 루 다 로 오 슬픔 의 의미 까지 도 바꿀 거 야 소 오 다 요 보 쿠 와 소바 니 이루 그래 나 는 곁 에 있 어 사 아 소 노 테 니 코노 테오 카 사네 자 그 손 에 이 손 을 포개 고 타시 카 메 요 오 에이 엔 오 영 원 을 확인 하 자 사 요 나라 노 무코 오 니 후리 소 소 구 작별 인사 저편 에 내리쬐 는 토 오이 히카리 가 유 메토 유우 나라 먼 빛 이 꿈 이 라고 한다면 오 모이 데 와 미라 이 오 마모루 다 로 오 추억 은 미래 를 지킬 거 야 이 츠 데모 보 쿠 와 키 미토 이루 언제나 나 는 너 와 있 어 보 쿠 와 키 미토 이루 나 는 너 와 있 어
# Right translation : <sos> 아무것 도 아닌 나
# Predicted translation:  나 의 인생 <eos>
# -------------------------------------------------- 70
# Input: 점점 더 무거워 지 는 너 의 향 한 미움 들 점점 더 깊 어 만 가 는 너 를 향 한 그리움 얼마나 많 은 값 을 치러야 네 게 서 자유 로워질 수 있 을까 모두 가져가 줘 나 혼자 감당 하 기 엔 너무 무거운 짐 인 걸 모두 가져가 줘 나 혼자 기억 하 기 엔 너무 큰 사랑 인가 봐 제발 점점 더 무거워 지 는 너 의 향 한 미움 들 점점 더 깊 어 만 가 는 너 를 향 한 그리움 얼마나 많 은 값 을 치러야 네 게 서 자유 로워질 수 있 을까 모두 가져가 줘 나 혼자 감당 하 기 엔 너무 무거운 짐 인 걸 모두 가져가 줘 나 혼자 기억 하 기 엔 너무 큰 사랑 인가 봐 제발
# Right translation : <sos> 그대 는 그래요
# Predicted translation:  나 의 사랑 은 <eos>
# -------------------------------------------------- 79
# Input: 고마워요 그리고 사랑 해 요 나 세상 을 살아가 면서 없 어선 안 될 사람 그 어떤 말 로 도 표현 못 하 는 누구 보다 소 중 한 사람 늘 곁 에 있 는 사람 이 라고 무심 하 진 않 았 는지 툭툭 내 뱉 는 말 한마디 로 상처 주진 않 았 는지 이제 와 새삼 돌아보 니 너무 미안 해 요 이제 부터 당신 행복 위해 서 내 가 더 잘 할게요 고마워요 그리고 사랑 해 요 내 사랑 아 고마워요 그리고 사랑 해 요 영원히 말 은 안 해도 내 안 엔 언제나 든든 한 당신 뿐 이 야 나 를 만나 행복 했 다 느끼 게 내 가 더 잘 할게요 고마워요 그리고 사랑 해 요 내 사랑 아 고마워요 그리고 사랑 해 요 영원히
# Right translation : <sos> ㅁ ㅇㄹ
# Predicted translation:  사랑 의 끝 <eos>
# -------------------------------------------------- 48
# Input: 아노 지 헤이 세 카 가 야쿠 노 와 저 지평선 이 빛나 보이 는 건 도 코 카니 키 미 오 카쿠 시 테 이루카 라 어디 엔 가 너 를 숨기 고 있 는 까닭 이 야 타 쿠사 노 히 가 나 쯔 카시 이 노 와 많 은 등불 이 반가운 것 은 아노 도레 가 히 토 쯔 미 키 미 가 이루카 라 저 등불 중 한 곳 에 네 가 있 는 까닭 이 야 사 아 데 헤 카 케 요 우 히 토 키 레노 파 자 떠나 자 한 조각 의 빵 나이 푸 라 푸 카바 니 쯔 메코 데 칼 과 램프 가방 에 채워 넣 고 토우 사 가 노 코시 타 아 쯔 이 오 모이 아버지 가 남기 신 애틋 한 마음 카아 사 가 쿠 레타 아노 마나 자시 어머니 까 주 셨 던 그 눈빛 지큐 우와 마 와 루 키 미오 카쿠 시 테 지구 는 돌 고 있 어 너 를 숨기 고 카 가 야쿠 히 토 미 키 라 메 쿠 토모 시비 빛나 는 눈동자 반짝이 는 등 불 지큐 우와 마 와 루 키 미 오 노세 테 지구 는 돌 고 있 어 너 를 숨기 고 이 쯔 카 키 토 데 아우 보 쿠 라오 노세 테 언젠가 반드시 만날 우리 들 을 태우 고 토우 사 가 노코 시타 아 쯔 이 오 모이 아버지 가 남기 신 애틋 한 마음 카아 사 가 쿠 레타 아노 마나 자시 어머니 가 주 셨 던 그 눈빛 지큐 우와 마 와 루 키 미오 카쿠 시 테 지구 는 돌 고 있 어 너 를 숨기 고 카 가 야 쿠 히 토 미 키 라 메 쿠 토모 시비 빛나 는 눈동자 반짝이 는 등 불 지큐 우와 마 와 루 키 미 오 노세 테 지구 는 돌 고 있 어 너 를 숨기 고 이 쯔 카 키 토 데 아우 보 쿠 라오 노세 테 언젠가 반드시 만날 우리 들 을 태우 고
# Right translation : <sos> 좀 걸 을까요
# Predicted translation:  내 가 그린 기린 <eos>
# -------------------------------------------------- 93
# Input: 오 그대 가 나 를 떠나 버린 뒤 이제 겨우 하루 가 지났 는데 내 마음 이 이상 하 게 편안 해 오랫 만 에 자유 로움 느끼 니 오 그대 가 떠나 고 이틀 째 되 던 오늘 밤 에 내 가슴 이 답답 해 지 고 점점 불안 해져 만 가 네 안녕 이란 너 의 그 말 도무지 실감 이 안 나 하루 종일 이비 를 맞 으며 멍하니 서 있 네 사랑 해 요 사랑 해 요 나 를 사랑 한다고 말 했었 는데 바보 같이 그 말 을 믿 었 는데 그대 가 나 를 떠나 버리 고 사흘 동안 한숨 도 못 잤 는데 그대 가 다시 돌아올까봐 나 는 매일 창밖 을 바라보 네 오 그대 가 떠나 고 일 주일 이 되 던 오늘 밤 세상 이 까맣 게 변해 움직일 수 조차 없 어요 안녕 이란 너 의 그 말 도무지 실감 이 안 나 하루 종일 이비 를 맞 으며 멍하니 서 있 네 사랑 해 요 사랑 해 요 나 를 사랑 한다고 말 했었 는데 바보 같이 그 말 을 믿 었 는데 내 가 싫 어 가 버린 그대 원망 해 봤 자 다 부질없 는지 아주 많 은 세월 이 흘러 너 를 만나 면 힘들 었 던 우리 사랑 에 웃음 짖 게 되 겠 지 안녕 이란 너 의 그 말 도무지 실감 이 안 나 하루 종일 이비 를 맞 으며 멍하니 서 있 네 사랑 해 요 사랑 해 요 나 를 사랑 한다고 말 했었 는데 바보 같이 그 말 을 믿 었 는데 믿 었 는데
# Right translation : <sos> 년 동안 의 진심
# Predicted translation:  사랑 은 늘 <eos>
# -------------------------------------------------- 77
# Input: 아무 생각 도 없이 노오란 나비 를 쫓 아 올라 한 번 도 오른 적 없 던 하늘 의 가려진 작 은 언덕 그 작 은 언덕 아래 를 내려다 보 네 부 는 바람 에 하얀 햇살 이 부서지 는 데 멈춰진 시간 햇살 이 아프 도록 따가운 그런 날 에 는 나 또한 거기 엘 가 지 초록색 웃음 을 찾 아서 그 작 은 언덕 아래 를 내려다 보 네 부 는 바람 에 하얀 햇살 이 부서지 는 데 멈춰진 시간 이미 지나 온 그 시간 들 의 기억 의 기억 의 기억 눈 을 감 으면 언제나 처럼 그때 로 가네 부 는 바람 에 부 는 바람 에 하얀 햇살 이 내 두 뺨 위 로 부서지 는데 그 순간 의 나 멈춰진 시간 이미 지나 온 그 시간 들 의 기억 의 기억 의 기억 눈 을 감 으면 언제나 처럼 그때 로 가네
# Right translation : <sos> 칭찬 해 줘
# Predicted translation:  나 의 바다 <eos>
# -------------------------------------------------- 95
# Input: 내년 엔 납골 묘 를 만들 어 여기저기 흩어진 묘 들 을 이장 할 생각 이 다 그 래야 너희 들 도 편하 겠 고 나 도 죽 기 전 에 그것 만 은 하 려고 한다 아버지 납골 묘 아래 에 내 가 먼저 들어갈 건데 요
# Right translation : <sos> 비 켜 가
# Predicted translation:  나 는 꼼꼼 한 테슬라 <eos>
# -------------------------------------------------- 23
# Input: 나 행복 합니다 그대 를 만나 서 나 오랜 시간 헤맸 는데 이제 만났 네요 그대 고마워요 내게로 와줘서 아름다운 꽃 이 되 어 주 니 살며시 떨리 네요 그 댈 사랑 해 요 온 맘 다 해 사랑 할게요 우리 가 는 길 이 아무리 어렵 다 해도 그대 의 손 놓 지 않 을 게 요 그 댈 사랑 해 요 영원히 사랑 할게요 우리 하나 되 어 영원 토록 변치 않 는 그 사랑 을 함께 노래 해 요
# Right translation : <sos> 돌아봐
# Predicted translation:  당신 은 이미 <eos>
# -------------------------------------------------- 83
# Input: 널 처음 볼 때 쯤 난 세상 이 우스워 되 려면 뭐 든 될 것 같 아 그런 표정 으로 너 에게 빠져 들 때 만 해도 니 가 내게 빠진 줄 만 소리 없이 빠져든 나 그 다음 해 쯤 무서워 졌 어 사라져 버릴까봐 환상 이 될까봐 내 모든 걸 너 에게 말 했 어 내 초 라 한 기분 그 순간 까지 네 게 고백 해 버렸 지 너 에 일부 가 되 길 바랬 어 너 의 착한 귀 자상 한 눈 처럼 밝 은 날 좋 아 했 지만 슬픈 나 또한 안 아 준 그 넓 은 가슴 이 좋 아 너 에게 안겼 어 다음 해 쯤 그래도 지겹 지 않 았 어 오래 된 우리 를 배려 한 더 깊 어 진 너 그 다음 해 또 무서워 졌 어 사라져 버릴까봐 환상 이 될까봐 내 모든 걸 너 에게 말 했 어 내 초 라 한 기분 그 순간 까지 네 게 고백 해 버렸 지 너 의 일부 가 되 길 바랬 어 너 의 착한 귀 자상 한 눈 처럼 지쳤었 던 싫 어 했었 던 그 흔한 오래 된 연인 의 사랑 은 너 없 는 두려움 이 이겨 버렸 어 그 다음 해 가 이제 올해 야 최소한 그 댄 나 의 일부 가 됐 죠 일 을 잠시 쉴 때 그 댈 생각 해 그때 마다 그 댄 어디 론 가 나 를 저 멀리 보내 줘 이 젠 일부 가 아닌 하나 되 고 싶 어 우리 결국 같이 살 수 있 을까 다음 그 다음 까지
# Right translation : <sos> 서울 이야기
# Predicted translation:  너 와 나 의 마지노선 <eos>
# -------------------------------------------------- 82
# Input: 니 기 리시 메테 이타 테 가 꼭 잡 고 있 던 손 이 키 가 츠 쿠토 호도 케 테 루 의식 하 면 풀 어 지 고 있 어 다레 가 키 메타 와케 데모 나 쿠 누군가 정 했 던 것 은 아니 기에 코코 로 와 츠 기노 바쇼 오 사 가스 마음 은 다음 장소 를 찾아가 오 나지 소라 오 미 나가 라 같 은 하늘 을 보 면서 보 쿠라 와 아 루이 테 키타 우리 는 걸어왔 어 츠 라이 토키 와 사사 에 앗 테 괴로울 땐 서로 의지 하 고 나 미 다오 누 굿 테 눈물 을 닦 고 히 토리 다케 데시 카 혼자 서 만 에 라베 나이 미치 모 아루 케 도 선택 해야 하 는 길 도 있 지만 소코 니 와 키 미 가 쿠 레타 그 길 에 는 네 가 줬 던 타쿠 상노 아이 가 아루 많 은 사랑 이 있 어 사 요 나라 노 무코 오 니 후리 소 소 구 작별 인사 저편 에 내리쬐 는 토 오이 히카리 가 유 메토 유우 나라 먼 빛 이 꿈 이 라고 한다면 오 모이 데 와 미라 이 오 마모루 다 로 오 추억 은 미래 를 지킬 거 야 이 츠 데모 보 쿠 와 키 미토 이루 언제나 나 는 너 와 있 어 이마 와 와카 라 나 쿠 테 모 지금 은 모르 겠 지만 신지 츠 즈 케테 이 레바 계속 믿 는다면 돈 나모 노모 카타 치 니 나 루 어떤 것 이 라도 모양 을 갖출 거 야 시아 와 세모 킷 토 행복 도 반드시 후 타리 다케 가 미타 둘 이 서 만 봤 던 아 타라 시 이 호시노 마타 타 키 새로운 별 의 반짝임 소코 카라 우마 레카 와 루 그 빛 에서 다시 태어나 는 모노 가 타리 츠 즈 이 테 쿠 이야기 는 계속 돼 사 요 나라 노 무코 오 니 후리 소 소 구 작별 인사 저편 에 내리쬐 는 아 와 이 히카리 모 유메 니 나 루 나라 희미 한 빛 도 꿈 이 된다면 카나시 미노 이 미사 에 카 에 루 다 로 오 슬픔 의 의미 까지 도 바꿀 거 야 소 오 다 요 보 쿠 와 소바 니 이루 그래 나 는 곁 에 있 어 사 아 소 노 테 니 코노 테오 카 사네 자 그 손 에 이 손 을 포개 고 타시 카 메 요 오 에이 엔 오 영 원 을 확인 하 자 사 요 나라 노 무코 오 니 후리 소 소 구 작별 인사 저편 에 내리쬐 는 토 오이 히카리 가 유 메토 유우 나라 먼 빛 이 꿈 이 라고 한다면 오 모이 데 와 미라 이 오 마모루 다 로 오 추억 은 미래 를 지킬 거 야 이 츠 데모 보 쿠 와 키 미토 이루 언제나 나 는 너 와 있 어 보 쿠 와 키 미토 이루 나 는 너 와 있 어
# Right translation : <sos> 아무것 도 아닌 나
# Predicted translation:  나 의 인생 <eos>
# -------------------------------------------------- 70
# Input: 돈 많 은 백수 넘쳐나 는 액수 돈 많 은 백수 명품 으로 도배 해도 싫증 나 는 백수 돈 많 은 백수 돈 많 은 게 대수 돈 많 은 백수 돈 많 은 백수 돈 많 은 백수 알림 이 클럽 에서 먹 은 술 기운 은 빙빙 근데 옆 에 처음 보 는 예쁜 아가씨 는 누구 일단 나가 봐 이따 여친 오 니까 욕조 안 엔 가득 한 돈 다발 숨 만 쉬 어도 돈 이 쫓아오 니까 내 가 살 고 싶 은 데 로 살 지 원 하 는 것 사 지 간지 나 게 살 지 프랑스 에선 샤넬 을 털 고 이 테리 선 구찌 를 털 고 영국 에선 버버리 털 고 일본 에선 텐 가 를 싹 털 어 하 고 해도 따라올 수 없 는 오늘 내 가 술 쏠 테 니 강남 으로 집합 해 차 다 쏠 테 니 걱정 말 고 집합 해 남녀 노소 개 나 소나 누구 든지 집합 해 돈 많 은 백수 넘쳐나 는 액수 돈 많 은 백수 명품 으로 도배 해도 싫증 나 는 백수 돈 많 은 백수 돈 많 은 게 대수 돈 많 은 백수 돈 많 은 백수 돈 많 은 백수 뜨거운 태양 아래 사내 새끼 로 태어나 서 밥 값 하 고서 갈 게 걔 네 좀 잡 아 놓 고 기다려 설익 은 내 머리 안 에선 또 해 오늘 만 전화 긴 벽돌 이 되 고 난 클럽 안 에 불 타올라 하루 가 멀 고 내 삶 은 짧 아 잠 없이 보낸 새벽 안 에 잠긴 내 폰 의 타임 라인 에 감성 을 팔 아 돈 벌 어 만큼 내 가슴 안 은 또 빛나 목걸이 가 질릴 때 까지 나 는 계속 늘 어 만 가 가만히 놀 아도 돈 이 지쳤 어 난 돈 을 버리 는 일 이 염 따 형 을 계속 닮 아 가지 포르셰 끌 고 돈 다 버린 후 계획 은 무엇 일지 다음 해 지켜봐 나 는 걸 백수 엎 고서 난 아직 뭘 할 수 없 단 점 난 잘 알 아서 시작 은 반 이 라 하 는 걸 반 에서 반 을 더 채워 시작 은 반 이 라 하 는 걸 모르 는 것 처럼 돈 많 은 백수 넘쳐나 는 액수 돈 많 은 백수 명품 으로 도배 해도 싫증 나 는 백수 돈 많 은 백수 돈 많 은 게 대수 돈 많 은 백수 돈 많 은 백수 돈 많 은 백수
# Right translation : <sos> 어른 들 은 이상 해
# Predicted translation:  나 는 잊어버릴 아 <eos>
# -------------------------------------------------- 14
# Input: 아무런 계획 도 없이 찾아온 금요일 오후 누구 도 찾 진 않 지만 어디 든 떠나 고 싶 어 너 와 의 기억 떠올라 한동안 찾 지 못 했 던 빛 바랜 추억 의 장소 이제 는 가 보 려 해 그대 와 함께 했 던 이 곳 엔 우리 아 는 맛집 풍경 카페 너 의 미소 이제 는 내 가 아 는 너 를 볼 수 없 어도 나 조금 씩 잊 어 볼 게 걸음 이 이 끄 는 대로 걷 다 보 니 도착 한 그 곳 서로 를 바라보 았 던 우리 그 때 의 그 모습 을 다시 볼 수 는 없 을까 찾아보 려고 했 지만 너무 늦 어 버린 날 들 이제 는 놓 아야 해 그대 와 함께 했 던 이 곳 엔 우리 아 는 맛집 풍경 카페 너 의 미소 이제 는 내 가 아 는 너 를 볼 수 없 어도 나 조금 씩 잊 어 볼 게 이미 끝나 버린 한편 의 영화 처럼 더 는 기대 할 수 없 는 흔한 장면 들 에 그대 와 함께 했 던 이 곳 엔 이 곳 엔 우리 아 는 맛집 풍경 카페 나 의 미소 이제 는 기억 속 널 보내 줄 수 있 으니 나 이제 는 떠나 볼 게 그대 와 함께 했 던 이 곳 엔 이 곳 엔 우리 아 는 맛집 풍경 카페 나 의 미소 이제 는 기억 속 널 보내 줄 수 있 으니 나 이제 는 떠나 볼 게 그대 와 함께 했 던 이 곳 엔 우리 아 는 맛집 풍경 카페 나 의 미소 이제 는 기억 속 널 보내 줄 수 있 으니 나 이제 는 떠나 볼 게
# Right translation : <sos> 작 은 연주회
# Predicted translation:  나 의 바흐 오후 <eos>
# -------------------------------------------------- 61
# Input: 뜬 눈 이 어도 꿈 을 꾼 듯 해 발 끝 이 뜨거워 춤 을 춘 듯 해 어떤 의미 로 는 태몽 인 듯 해 잉태 한 건 새로운 나이 기에 이제야 나 의 천사 를 마주 심지어 이제 보 니 천사 가 둘 엇 나갈 수 없 음 에 난 그저 나 아 갈 생각 이 야 놓친 나 를 데려가 지금 껏 짊 어진 건 무거운 책임감 이 라 여겼 는데 커다란 날개 가 내 가 받 아 들여야 할 사람 은 나 였 지 너무 도 부족 해서 덮 어 버린 나 역시 가족 이 나 의 세상 인 듯 나 또한 그 들 의 세상 임 을 모순 된 듯 조화 로운 게 사랑 이 지 날 위 하 는 그 들 을 위해 날 위 해야 겠지 천사 가 날 깨우 네 드디어 너 와 마주 해 천사 가 날 깨우 네 드디어 너 와 마주 해 날 잠들 수 있 게 깨워 줬 지 다시 일어날 수 있 게 몇 번 씩 마주 한 순간 열기 는 식 어 지혜 로운 이 들 이 취해 오 던 식 조급 함 은 진심 의 허 술 한 직역 뜻 은 맞 아도 의미 는 틀려 지 며 날 원 치 않 는 곳 에 데려다 놔 지혜 와 여유 는 형제 였 나 봐 일그러진 날 인정 해 나 가 이기심 또 한 이타 적 이 란 말 발 끝 을 태우 던 처음 의 날 봐 사랑 보단 지옥 에 가까워 잠든 아이 의 이마 에 입맞춤 풀어진 잘 못 낀 첫 단추 지금 을 잊 지 말 아야 지 반복 되 지 않 을 내일 아침 천사 가 날 깨우 네 드디어 너 와 마주 해 천사 가 날 깨우 네 드디어 너 와 마주 해 왠지 어제 본 듯 해 너 의 오늘 을 난 널 이해 해 저 하늘 을 비행 했 다가 바닥 에 기댔 다가 다시 비행 하 는 너 의 마음 은 널 지치 게 해 이건 감정 의 그네 가장 높 은 곳 에 올랐 을 때 뛰 어도 못 나 는 건 너 도 알 잖아 놓치 지 않 게 줄 을 꽉 잡 아 이 놀이터 엔 밤 이 오 지 않 아 즉 나 의 은 영원 해 연결 된 나선 에서 잊혀 짐 은 이미 예정 된 일 일지 도 몰라 네 가 열쇠 를 찾 기 전 엔 허나 언제나 자물쇠 는 너 의 손 에 있 었 기 에 넌 또 다시 헤 메이 겠 지 또 다시 내일 의 지금 넌 나 를 만나 서 또 다시 되 뇌 이 겠 지 내일 은 다를 거 라고 이번 반복 에서 는 믿 어 봐 니 자신 을 날 기억 할 수 있 기 를 이제 일어나
# Right translation : <sos> 차라리 그럴 거 면
# Predicted translation:  나 의 집 에 <eos>
# -------------------------------------------------- 1
# Input: 차라리 나 를 떠나 도 돼 아예 눈치 는 보 지 말 고 그래 내 가 생각 해봐도 나 는 부족 하 더 라고 나 를 사랑 하 던가 나 를 잊 어 가 던가 나 를 응원 하 던가 나 를 저주 하 던가 나 를 알 아 가 던가 나 를 잊 어 가 던가 나 를 사랑 하 는 사람 위해 살아가 던가 나 를 사랑 하 길 바 래 날 사랑 해 달 라 말 해 야 내 가 사랑 을 바 래 이 젠 욕심 이 라 말 해 줘 대학 도 안 갔 고 또 그 나이 에 군대 도 안 간 건 뭐 가 그리 자랑 이 네 행복 한 척 하 며 사 는 게 난 재밌 길래 나 도 속 았 지 뭐 야 난 원래 병신 인데 내 가 너 여도 날 미워했 을 거 야 나 도 몰래 너 에게 기대 를 했 네 더 는 사랑 한단 말 안 믿 을 거 야 너 도 몰래 너 에게 사라져 줄 게 이 젠 익숙 한 게 지겹 고 무서워 나 는 기억 해 기억 해 너 의 심장 을 기억 해 그래 그렇게 나 를 그렇게 밀어내 차라리 나 를 떠나 도 돼 아예 눈치 는 보 지 말 고 그래 내 가 생각 해봐도 나 는 부족 하 더 라고 나 를 사랑 하 던가 나 를 잊 어 가 던가 나 를 응원 하 던가 나 를 저주 하 던가 나 를 알 아 가 던가 나 를 잊 어 가 던가 나 를 사랑 하 는 사람 위해 살아가 던가 그만 애써도 괜찮 아 그 쯤 했 으면 됐 잖아 네 가 없 어도 밤 에 잠 만 잘 와 익숙 해져 가 음 아아 아아 술 이 채워 가 음 아아 아아 아 하나 배 워 가 음 아 타오르 던 관계 도 끝 폭우 가 내린 후 엔 사랑 해도 원망 해도 바뀔 건 없 는 걸 참 아 줘 그 쯤 에서 멈춰 서 는 건 나 는 까매 너 는 희 구 나 만 맞 고 끝 난 우리 피 구 처음 부터 모르 면 더 알 필요 없 어 떠날 필요 없 어 처음 부터 모르 면 그러 면 좋 았 을 걸 차라리 나 를 떠나 도 돼 아예 눈치 는 보 지 말 고 그래 내 가 생각 해봐도 나 는 부족 하 더 라고 나 를 사랑 하 던가 나 를 잊 어 가 던가 나 를 응원 하 던가 나 를 저주 하 던가 나 를 알 아 가 던가 나 를 잊 어 가 던가 나 를 사랑 하 는 사람 위해 살아가 던가
# Right translation : <sos> 그 숲 속
# Predicted translation:  사랑 이 라 <eos>
# -------------------------------------------------- 26
# Input: 아니리 이렇 듯 세월 을 보내 는디 그때 여 사또 께서 동부 승지 당상 하 야 내직 으로 올라가 시 게 되 니 춘 향 과 이 도령 은 할 수 없이 이별 이 되 난 디 창조 도련 님 이 별 차 로 나오 난 디 중모리 왼갖 생각 두루 헌다 점 잖 허신 도련 님 이 대로 변 으로 나오 면서 울음 울리 가 없 지 만 은 옛 일 을 생각 허 니 당 명 황 은 만고 영웅 이나 양귀비 이별 에 울 어 있 고 항우 는 천하 장사 로되 우미 인 이별 에 울 었 으니 날 같 은 소 장부 야 아니 울 수 있 겠 느냐 춘 향 을 어쩌 고 갈꼬 두 고 갈 수 도 없 고 데리 고 갈 수 도 없 네 저 를 다려 간다 허 면 부모 님 이 금 할 테 요 저 를 두 고 간다 허 면 그 행실 그 기운 에 응당 자결 을 헐 것 이 니 저 못 보 면 나 못 살 고 나 를 못 보 면 저 도 응당 죽 을 테 니 사세 가 난처 로구나 질 걷 는 줄 을 모르 고 춘 향집 문전 을 당 도 허 니
# Right translation : 나 는 내일 과거 의 너 와 만난다
# Predicted translation:  나 는 꼼꼼 한 걸까요 <eos>
# -------------------------------------------------- 36
# Input: 돈 많 은 백수 넘쳐나 는 액수 돈 많 은 백수 명품 으로 도배 해도 싫증 나 는 백수 돈 많 은 백수 돈 많 은 게 대수 돈 많 은 백수 돈 많 은 백수 돈 많 은 백수 알림 이 클럽 에서 먹 은 술 기운 은 빙빙 근데 옆 에 처음 보 는 예쁜 아가씨 는 누구 일단 나가 봐 이따 여친 오 니까 욕조 안 엔 가득 한 돈 다발 숨 만 쉬 어도 돈 이 쫓아오 니까 내 가 살 고 싶 은 데 로 살 지 원 하 는 것 사 지 간지 나 게 살 지 프랑스 에선 샤넬 을 털 고 이 테리 선 구찌 를 털 고 영국 에선 버버리 털 고 일본 에선 텐 가 를 싹 털 어 하 고 해도 따라올 수 없 는 오늘 내 가 술 쏠 테 니 강남 으로 집합 해 차 다 쏠 테 니 걱정 말 고 집합 해 남녀 노소 개 나 소나 누구 든지 집합 해 돈 많 은 백수 넘쳐나 는 액수 돈 많 은 백수 명품 으로 도배 해도 싫증 나 는 백수 돈 많 은 백수 돈 많 은 게 대수 돈 많 은 백수 돈 많 은 백수 돈 많 은 백수 뜨거운 태양 아래 사내 새끼 로 태어나 서 밥 값 하 고서 갈 게 걔 네 좀 잡 아 놓 고 기다려 설익 은 내 머리 안 에선 또 해 오늘 만 전화 긴 벽돌 이 되 고 난 클럽 안 에 불 타올라 하루 가 멀 고 내 삶 은 짧 아 잠 없이 보낸 새벽 안 에 잠긴 내 폰 의 타임 라인 에 감성 을 팔 아 돈 벌 어 만큼 내 가슴 안 은 또 빛나 목걸이 가 질릴 때 까지 나 는 계속 늘 어 만 가 가만히 놀 아도 돈 이 지쳤 어 난 돈 을 버리 는 일 이 염 따 형 을 계속 닮 아 가지 포르셰 끌 고 돈 다 버린 후 계획 은 무엇 일지 다음 해 지켜봐 나 는 걸 백수 엎 고서 난 아직 뭘 할 수 없 단 점 난 잘 알 아서 시작 은 반 이 라 하 는 걸 반 에서 반 을 더 채워 시작 은 반 이 라 하 는 걸 모르 는 것 처럼 돈 많 은 백수 넘쳐나 는 액수 돈 많 은 백수 명품 으로 도배 해도 싫증 나 는 백수 돈 많 은 백수 돈 많 은 게 대수 돈 많 은 백수 돈 많 은 백수 돈 많 은 백수
# Right translation : <sos> 어른 들 은 이상 해
# Predicted translation:  나 는 잊어버릴 아 <eos>
# -------------------------------------------------- 14
# Input: 나 행복 합니다 그대 를 만나 서 나 오랜 시간 헤맸 는데 이제 만났 네요 그대 고마워요 내게로 와줘서 아름다운 꽃 이 되 어 주 니 살며시 떨리 네요 그 댈 사랑 해 요 온 맘 다 해 사랑 할게요 우리 가 는 길 이 아무리 어렵 다 해도 그대 의 손 놓 지 않 을 게 요 그 댈 사랑 해 요 영원히 사랑 할게요 우리 하나 되 어 영원 토록 변치 않 는 그 사랑 을 함께 노래 해 요
# Right translation : <sos> 돌아봐
# Predicted translation:  당신 은 이미 <eos>
# -------------------------------------------------- 83
# Input: 고마워요 그리고 사랑 해 요 나 세상 을 살아가 면서 없 어선 안 될 사람 그 어떤 말 로 도 표현 못 하 는 누구 보다 소 중 한 사람 늘 곁 에 있 는 사람 이 라고 무심 하 진 않 았 는지 툭툭 내 뱉 는 말 한마디 로 상처 주진 않 았 는지 이제 와 새삼 돌아보 니 너무 미안 해 요 이제 부터 당신 행복 위해 서 내 가 더 잘 할게요 고마워요 그리고 사랑 해 요 내 사랑 아 고마워요 그리고 사랑 해 요 영원히 말 은 안 해도 내 안 엔 언제나 든든 한 당신 뿐 이 야 나 를 만나 행복 했 다 느끼 게 내 가 더 잘 할게요 고마워요 그리고 사랑 해 요 내 사랑 아 고마워요 그리고 사랑 해 요 영원히
# Right translation : <sos> ㅁ ㅇㄹ
# Predicted translation:  사랑 의 끝 <eos>
# -------------------------------------------------- 48
# Input: 니 기 리시 메테 이타 테 가 꼭 잡 고 있 던 손 이 키 가 츠 쿠토 호도 케 테 루 의식 하 면 풀 어 지 고 있 어 다레 가 키 메타 와케 데모 나 쿠 누군가 정 했 던 것 은 아니 기에 코코 로 와 츠 기노 바쇼 오 사 가스 마음 은 다음 장소 를 찾아가 오 나지 소라 오 미 나가 라 같 은 하늘 을 보 면서 보 쿠라 와 아 루이 테 키타 우리 는 걸어왔 어 츠 라이 토키 와 사사 에 앗 테 괴로울 땐 서로 의지 하 고 나 미 다오 누 굿 테 눈물 을 닦 고 히 토리 다케 데시 카 혼자 서 만 에 라베 나이 미치 모 아루 케 도 선택 해야 하 는 길 도 있 지만 소코 니 와 키 미 가 쿠 레타 그 길 에 는 네 가 줬 던 타쿠 상노 아이 가 아루 많 은 사랑 이 있 어 사 요 나라 노 무코 오 니 후리 소 소 구 작별 인사 저편 에 내리쬐 는 토 오이 히카리 가 유 메토 유우 나라 먼 빛 이 꿈 이 라고 한다면 오 모이 데 와 미라 이 오 마모루 다 로 오 추억 은 미래 를 지킬 거 야 이 츠 데모 보 쿠 와 키 미토 이루 언제나 나 는 너 와 있 어 이마 와 와카 라 나 쿠 테 모 지금 은 모르 겠 지만 신지 츠 즈 케테 이 레바 계속 믿 는다면 돈 나모 노모 카타 치 니 나 루 어떤 것 이 라도 모양 을 갖출 거 야 시아 와 세모 킷 토 행복 도 반드시 후 타리 다케 가 미타 둘 이 서 만 봤 던 아 타라 시 이 호시노 마타 타 키 새로운 별 의 반짝임 소코 카라 우마 레카 와 루 그 빛 에서 다시 태어나 는 모노 가 타리 츠 즈 이 테 쿠 이야기 는 계속 돼 사 요 나라 노 무코 오 니 후리 소 소 구 작별 인사 저편 에 내리쬐 는 아 와 이 히카리 모 유메 니 나 루 나라 희미 한 빛 도 꿈 이 된다면 카나시 미노 이 미사 에 카 에 루 다 로 오 슬픔 의 의미 까지 도 바꿀 거 야 소 오 다 요 보 쿠 와 소바 니 이루 그래 나 는 곁 에 있 어 사 아 소 노 테 니 코노 테오 카 사네 자 그 손 에 이 손 을 포개 고 타시 카 메 요 오 에이 엔 오 영 원 을 확인 하 자 사 요 나라 노 무코 오 니 후리 소 소 구 작별 인사 저편 에 내리쬐 는 토 오이 히카리 가 유 메토 유우 나라 먼 빛 이 꿈 이 라고 한다면 오 모이 데 와 미라 이 오 마모루 다 로 오 추억 은 미래 를 지킬 거 야 이 츠 데모 보 쿠 와 키 미토 이루 언제나 나 는 너 와 있 어 보 쿠 와 키 미토 이루 나 는 너 와 있 어
# Right translation : <sos> 아무것 도 아닌 나
# Predicted translation:  나 의 인생 <eos>
# -------------------------------------------------- 70
# Input: 쉴 틈 없이 내리 던 비 는 한동안 네 곁 에 계속 머물 고 결국 엔 너 의 몸 을 적셔 버렸 네 너 의 모든 것 을 적셔 버렸 네 물기 가득 발걸음 이 무거워 보여 돌아가 도 축축 한 건 여전 할 텐데 눈치 보 며 길 을 건너 는 넌 어디 로 돌아가 도 축축 한 건 여전 할 텐데 아아 아 나 도 비 를 맞 아 이런 건지 아아 아 너 의 울음 소리 들리 지 않 아 아아 아 아아 아아 아 아아 쉴 틈 없이 내리 던 비 에 한 동안 내 곁 에 계속 머물 던 갈 곳 을 잃어버렸 던 넌 언제나 닿 기 도 전 에 먼저 흩어져 가 네 붙잡 지 않 아 젖 은 너 의 발걸음 흐르 는 비 에 흘려 보낼 내 마음 잡히 지 않 아 슬픈 너 의 목소리 흐르 는 비 에 흘려 보낼 내 마음 아아 아 나 도 비 를 맞 아 이런 건지 아아 아 너 의 울음 소리 들리 지 않 아 아아 아 아아 아아 아 아아 이 빗 소리 가 한동안 멈추 지 않 길
# Right translation : <sos> 정전기 가 일어나 는 놀이터
# Predicted translation:  나 의 뮤즈 <eos>
# -------------------------------------------------- 11
# Input: 오늘 은 우리 헤어지 는 날 마지막 으로 솔직 해 지 는 밤 나 는 그 동안 참 아 왔 는데 왜 네 가 먼저 눈물 을 흘려 그런 너 를 바라보 다가 화가 나 차갑 게 던진 한마디 울지마 그런 너 를 바라보 다가 못 참 아 난 아이 처럼 서럽 게 울 어 뚝뚝 눈물 을 흘리 고 나 를 안 아 달라 말 해 버려 내일 퉁퉁 두 눈 이 부어 서 밖 에 나갈 수 도 없 을 거 야 다시 는 울 지 않 기 를 다시 는 울 지 않 기 를 사실 은 너무 힘들 었 어 난 사랑 해 라는 가슴 속 의 그 말 나 는 한참 을 기다렸 는데 그게 그렇게 어려웠 었 니 후회 하 지 않 을까 망설이 다가 흘러내리 는 너 의 눈물 을 닦 아 약한 모습 보이 기 싫 어 참 다가 난 아이 처럼 서럽 게 울 어 또 코끝 이 시려 와 참 을래도 참 아 지 않 아 울 며 툴툴 대 는 날 안 고서 다시 사랑 하 자 말 을 해 줘 다시 는 울 지 않 기 를 다시 는 울 지 않 기 를
# Right translation : <sos> 잊혀질 그 에게
# Predicted translation:  나 의 집 에 <eos>
# -------------------------------------------------- 59
# Input: 예수 님 은 나 의 왕 이 요 예수 님 은 나 의 왕 이 요 예수 님 은 나 의 왕 이 요 예수 님 은 나 의 왕 이 요 나 의 왕 이 여 예수 님 은 나 의 반석 나 의 왕 이 여 예수 님 은 나 의 반석 나 의 왕 이 여 예수 님 은 나 의 반석 나 의 왕 이 여 주 님 안 에 살 고 주 를 위해 사네 주 님 안 에 살 고 주 를 위해 사네 주 님 안 에 살 고 주 를 위해 사네 주 님 안 에 살 고 주 님 을 위해 사네 예수 나 의 주 예수 나 의 주 예수 나 의 주 예수 나 의 주 예수 나 의 주 예수 나 의 주 예수 나 의 주 예수 나 의 주 예수 나 의 주
# Right translation : <sos> 그렇게 우리 는 그렇 게
# Predicted translation:  나 의 힘 이 되 어 <eos>
# -------------------------------------------------- 4
# Input: 평창 불어온다 거 센 바람 승리 의 함성 을 외쳐 붐 우린 하나 달려가 자 영광 의 평창 을 향 해 붐 약속 의 땅 을 딛 고 두 발 을 굴러 붐 모두 의 꿈 을 향 해 하나 로 뭉쳐 붐 두 손 을 높이 들 고 다 소리 질러 평창 누구 보다 더 높이 오 예 이겨 나 가 우리 는 하나 오 예 동쪽 하늘 태양 위 로 날아올라 붐 산 을 넘 어 정상 으로 쏘 아 올려 붐 평창 누구 보다 더 높이 오 예 이겨 나 가 우리 는 하나 오 예 워 어 워 어 워 우 예 워 어 워 어 평창 워 어 워 어 워 우 예 워 어 워 어 평창
# Right translation : <sos> 그녀 를 잡 아요
# Predicted translation:  나 는 야 몽땅 <eos>
# -------------------------------------------------- 84
# Input: 너 의 개 는 잠 이 들 고 문턱 을 곧 넘 겠 지 꿈 을 꾸며 웃 고 있 는 너 는 울 게 될 거 야 숨 을 참 고 살금살금 너 에게 로 다가가 는 나 너 의 개 는 잠 이 깨 면 너 를 찾 아 울 겠 지 꿈 을 꾸며 웃 고 있 는 너 를 보 게 될 거 야 숨 을 참 고 살 금 살 금 너 에게 로 다가가 는 나 어딘가 에 어느 날 에 나 는 네 게로 가 너 는 내게로 와 나 에게 로 잠 이 들 고 개 들 은 널 짖 겠 지 꿈 을 꾸며 웃 고 있 는 너 는 잠 이 든 거 야 숨 을 참 고 살금살금 너 를 쓰다듬 어 주 는 나 에게 로 잠 이 깨 면 너 는 이내 울 겠 지 꿈 을 꾸며 웃 고 있 던 너 를 보 게 될 거 야 눈 을 뜨 면 결국 에 는 아무 도 남 지 않 은 너
# Right translation : <sos> 불 같 은 여자
# Predicted translation:  나 의 궤도 <eos>
# -------------------------------------------------- 64
# Input: 오늘 도 표정 이 어두워 무슨 일 있 는지 물어봐도 되 는지 사실 그대 가 왜 우 는지 왜 슬퍼하 는지 눈치 를 챘 지만 일부러 모른 척 하 는 걸 도저히 용기 가 안 나 서 그 대여 세상 의 모든 연인 들 은 전부 행복 한 것 같 아 오늘 도 표정 이 어두워 그대 를 볼 수 가 없 네 그 어떤 약속 도 못 하 는 나 를 그만 용서 해 요 무슨 일 있 는 건 아닌지 그대 를 볼 수 가 없 네 일부러 모른 척 하 는 걸 도저히 용기 가 안 나 서 그 대여 세상 의 모든 연인 들 은 전부 행복 한 것 같 아 오늘 도 표정 이 어두워 그대 를 볼 수 가 없 네 그 어떤 약속 도 못 하 는 나 를 그만 용서 해 요 무슨 일 있 는 건 아닌지 그대 를 볼 수 가 없 네 집 으로 돌아오 는 길 에 나 혼자 눈물 을 흘려 신호등 불빛 사이 로 저 멀리 보이 는 너 를 집 으로 돌아오 는 길 에 나 혼자 눈물 을 흘려 신호등 불빛 사이 로 그대 를 볼 수 가 없 네 그 어떤 약속 도 못 하 는 나 를 그만 용서 해 요 무슨 일 있 는 건 아닌지 그대 를 볼 수 가 없 네
# Right translation : <sos> 청구역 로맨스
# Predicted translation:  나 의 집 에 <eos>
# -------------------------------------------------- 46
# Input: 주어진 만큼 의 생명 견뎌야 하 는 사랑 도 질기 게 날 잡 는 그림 지 가 버티 고 설 때 도 난 정말 울 지 않 았 어 팽개쳐 버렸 던 시간 이기 기 힘든 세상 에 자유 도 평화 도 다 먼 나라 얘기 되 버리 고 난 다시 돌아서 고 있 어 혼돈 을 밀치 는 바람 이 불 고 내버려졌 던 웃음 도 돌아왔 다 이제야 삶 을 찾 고 꿈 을 찾 고 다시 혼돈 을 가르 는 빛 이 비친다 볼 수 가 없 었 던 하늘 어렵 게 손 을 뻗 어도 자유 도 평화 도 다 먼 나라 얘기 되 버리 고 난 다시 떠나 야 만 했 어 한없이 붉어진 눈빛 이기 려 고개 저 어 도 마르 는 눈물 을 나 는 쉽 게 이길 수 없 었 어 모두 가 쳐다보 는 하늘 혼돈 을 밀치 는 바람 이 불 고 내버려졌 던 웃음 도 돌아왔 다 이제야 삶 을 찾 고 꿈 을 찾 고 다시 혼돈 을 가르 는 빛 이 비친다 혼돈 을 밀치 는 바람 이 불 고 내버려졌 던 웃음 도 돌아왔 다 이제야 삶 을 찾 고 꿈 을 찾 고 다시 혼돈 을 가르 는 빛 이 비친다
# Right translation : <sos> 바람 을 잡 으려 해요
# Predicted translation:  나 의 기도 <eos>
# -------------------------------------------------- 44
# Input: 혼자 밥 먹 을 때 도 나 혼자 영활 볼 때 도 언 젠 간 내게 올 그 댈 상상 했었 죠 대체 얼마나 멋진 사람 이 내게 오 려고 이렇게 날 힘들 게 할까 위로 도 했 죠 그 댈 본 순간 알 수 있 었 죠 내 가 평생 사랑 할 사람 고마워요 내사 랑 이렇게 내게 나타나 줘서 날 사랑 해 줘서 걱정 마 요 내 사랑 젤 멋진 남잔 아니 지만 나 모든 게 다 잘 될 거 예요 나 만 믿 어요 라라라 라라 대체 언제 쯤 내 맘 을 그대 가 알 아 줄까 걱정 에 난 불안 해서 난 기도 도 했 죠 그 댈 첨 본 날 잊 을 수 없 어 운명 이란 이런 거 겠 죠 고마워요 내사 랑 이렇게 내게 나타나 줘서 날 사랑 해 줘서 걱정 마 요 내 사랑 젤 멋진 남잔 아니 지만 나 모든 게 다 잘 될 거 예요 나 만 믿 어요 친구 야 니 들 이 아무리 원해도 돈 은 못 빌려줘 빚 보증 도 못 서 아홉 시 이후 엔 전화 도 하 지 마 설겆 이 해야 해 그대 를 사랑 해 요 나 그대 만 을 원해요 평생 내 곁 에서 내 손 꼭 잡 아 줘요 지금 이 순간 부터 내 삶 이 다 할 때 까지 오직 너 만 너 하나 만 평 생 너 만 너 하나 만 오직 너 만 너 하나 만 사랑 할래요 나 만 믿 어요
# Right translation : <sos> 햄 찌 햄 찌 햄 찌
# Predicted translation:  나 만 의 비밀 <eos>
# -------------------------------------------------- 17
# Input: 뜬 눈 이 어도 꿈 을 꾼 듯 해 발 끝 이 뜨거워 춤 을 춘 듯 해 어떤 의미 로 는 태몽 인 듯 해 잉태 한 건 새로운 나이 기에 이제야 나 의 천사 를 마주 심지어 이제 보 니 천사 가 둘 엇 나갈 수 없 음 에 난 그저 나 아 갈 생각 이 야 놓친 나 를 데려가 지금 껏 짊 어진 건 무거운 책임감 이 라 여겼 는데 커다란 날개 가 내 가 받 아 들여야 할 사람 은 나 였 지 너무 도 부족 해서 덮 어 버린 나 역시 가족 이 나 의 세상 인 듯 나 또한 그 들 의 세상 임 을 모순 된 듯 조화 로운 게 사랑 이 지 날 위 하 는 그 들 을 위해 날 위 해야 겠지 천사 가 날 깨우 네 드디어 너 와 마주 해 천사 가 날 깨우 네 드디어 너 와 마주 해 날 잠들 수 있 게 깨워 줬 지 다시 일어날 수 있 게 몇 번 씩 마주 한 순간 열기 는 식 어 지혜 로운 이 들 이 취해 오 던 식 조급 함 은 진심 의 허 술 한 직역 뜻 은 맞 아도 의미 는 틀려 지 며 날 원 치 않 는 곳 에 데려다 놔 지혜 와 여유 는 형제 였 나 봐 일그러진 날 인정 해 나 가 이기심 또 한 이타 적 이 란 말 발 끝 을 태우 던 처음 의 날 봐 사랑 보단 지옥 에 가까워 잠든 아이 의 이마 에 입맞춤 풀어진 잘 못 낀 첫 단추 지금 을 잊 지 말 아야 지 반복 되 지 않 을 내일 아침 천사 가 날 깨우 네 드디어 너 와 마주 해 천사 가 날 깨우 네 드디어 너 와 마주 해 왠지 어제 본 듯 해 너 의 오늘 을 난 널 이해 해 저 하늘 을 비행 했 다가 바닥 에 기댔 다가 다시 비행 하 는 너 의 마음 은 널 지치 게 해 이건 감정 의 그네 가장 높 은 곳 에 올랐 을 때 뛰 어도 못 나 는 건 너 도 알 잖아 놓치 지 않 게 줄 을 꽉 잡 아 이 놀이터 엔 밤 이 오 지 않 아 즉 나 의 은 영원 해 연결 된 나선 에서 잊혀 짐 은 이미 예정 된 일 일지 도 몰라 네 가 열쇠 를 찾 기 전 엔 허나 언제나 자물쇠 는 너 의 손 에 있 었 기 에 넌 또 다시 헤 메이 겠 지 또 다시 내일 의 지금 넌 나 를 만나 서 또 다시 되 뇌 이 겠 지 내일 은 다를 거 라고 이번 반복 에서 는 믿 어 봐 니 자신 을 날 기억 할 수 있 기 를 이제 일어나
# Right translation : <sos> 차라리 그럴 거 면
# Predicted translation:  나 의 집 에 <eos>
# -------------------------------------------------- 1
# Input: 두 바퀴 돌아가 듯 세 바퀴 돌아가 듯 너 에게 가 는 길 을 알 수 가 없 어 나 에게 돌아올까 너 에게 돌아갈까 이런 저런 생각 에 잠 못 이뤘 어 너 는 나 를 떠나 고 그렇 게 도 잘 사 는지 스쳐 지나가 듯 날 바라보 며 웃 었 지만 너 를 지우 지 못 한 내 마음 이 너 에게 는 묻 지 도 궁금 하 지 도 않 은 거 야 워 우 워 워 우 워 어 야 이야 워 우 워 워 우 워 어 야 이야 날 사랑 하 던 네 가 날 좋 아 하 던 네 가 날 보 며 웃 던 네 가 다른 남자 옆 에 있 어 모든 게 거짓 같 아 믿 고 싶 지 도 않 아 이렇게 변할 줄 은 꿈 에 몰랐 어 그렇게 아무렇 지 않 은 척 을 하 면서 도 네 행복 바라 는 나 자신 이 다 비참 해도 네 가 나 에게 줬 던 그 짧 았 던 사랑 들 에 미운 짓 하 는 너 를 밀어 냈 나 봐 워 우 워 워 우 워 어 야 이야 워 우 워 워 우 워 어 야 이야 그대로 쭉 행복 해 내 생각 하 지 말 고 기억 도 하 지 말 고 모두 잊 어 줘 날 잊 고 잘 살 면 돼 그렇게 행복 하 게 멋진 여자 로 내 맘속 에 남 아 줘
# Right translation : <sos> 저절로 흐르 는 곳 낮 은
# Predicted translation:  나 의 사랑 은 <eos>
# -------------------------------------------------- 33
# Input: 나 행복 합니다 그대 를 만나 서 나 오랜 시간 헤맸 는데 이제 만났 네요 그대 고마워요 내게로 와줘서 아름다운 꽃 이 되 어 주 니 살며시 떨리 네요 그 댈 사랑 해 요 온 맘 다 해 사랑 할게요 우리 가 는 길 이 아무리 어렵 다 해도 그대 의 손 놓 지 않 을 게 요 그 댈 사랑 해 요 영원히 사랑 할게요 우리 하나 되 어 영원 토록 변치 않 는 그 사랑 을 함께 노래 해 요
# Right translation : <sos> 돌아봐
# Predicted translation:  당신 은 이미 <eos>
# -------------------------------------------------- 83
# Input: 차 없이 도 잘 나가 는 사람 혼잡 한 도로 를 내 두 발 로 걸어왔 다 그저 되 고 싶 었었 지 난 그냥 나 다운 사람 여기 까지 왔 네 사춘기 때 불 던 바람 나 는 우리 엄마 자랑 우리 아빠 자랑 소심 했 던 안경 잡 이 는 가수 로 자라 많 은 일 들 을 경험 하 고서 변했 지 주름 이 생긴 얼굴 을 비춘 거울 에 난 서른 동경 했 던 형 님 들 의 나이 그 삶 을 살 지만 더 나 은 걸 찾 고 있 는 나 가까울수록 멀 어 지 는 친구 들 은 어디 에 수렁 에 빠진 추억 들 을 향 해 손 을 뻗 네 꽤 나 친했 던 친구 는 이제 다른 사람 같 아 아니 면 내 가 변했 거나 어떤 것 이 든 예전 처럼 할 수 는 없 는 진지 해진 세상 쉽 게 다가갈 수 없 는 나 는 먼 발치 에서 현실 을 관람 하 지 친구 들 의 변화 속 나 만 혼자 인 것 같 은 느낌 편한 척 하 며 걷 고 있 는 여긴 화려 한 불길 나 도 변했 고 세상 도 따라서 변해 늘 그래 왔 듯이 나 는 혼자 인 게 편해 난 다시 내 자리 로 처음 처럼 다시 제자리 로 모자 물감 아무 것 도 없 던 때 를 기억 하 지 그래 아무 것 도 없 던 애 가 나 지 마르 고 잘 웃 던 애 교실 구석 에서 흥얼거리 던 애 가 기 전 에 내 가 나 이 기 전 에 화면 안 의 나 는 너 를 볼 수 없 네 하루 더 한 해 더 한 해 더 지나가 고 나 면 널 내 가 나 였을 때 로 다시 돌아가 그때 로 세상 이 변해 가 도 아직 어린아이 같이 웃 고 떠들 면서 우리 둘 마지막 을 장식 우리 가 우리 였을 때 로 다시 돌아가 그때 로 너무 멀리 왔 지 두 발 로 걸어서 대체 뭘 얻 었 을까 내 순간 을 걸어서 난 내 자리 를 지켜 가끔 새 치 기 도 하 지만 내 가 밉 다고 판단 하 고 내게서 도망가 지 마 이건 잠깐 일 뿐 이 야 우리 미래 를 위 한 언 젠 간 깨 질 거 야 얄팍 한 성공 에 취한 우리 모습 소 중 한 걸 버려 가 면서 까지 우리 가 쫓 은 그 길 었 던 술자리 를 정리 하 고 다시 숙취 에 깨어나 서 다시 돌아가 내 자리
# Right translation : <sos> 깊 은 물
# Predicted translation:  나 의 친구 사여 <eos>
# -------------------------------------------------- 50
# Input: 너 의 포 근 한 살결 위 에 누워 너 의 손 이 새싹 처럼 내게 돋아나 머리 맡 으로 나비 들 이 모여 도 내게로 만 속삭여 주 는 따 뜻 한 바람 품 에 가득 안 고 벅차 오르 는 바다 만큼 하늘 만큼 우주 만큼 너 탐스런 널 한 입 베 어 물 어 유유 히 흐르 는 네 게 빠져들 어 드리 워진 너 의 아래 서 쉴 때 세상 은 너 이 하늘 아래 가 모두 너 잔잔 하 게 반짝이 는 너 목 소린 진한 생기 로 물들 어 가벼운 걸음 이 색색 으로 피어 나 내게로 만 내리쬐 주 는 눈빛 은 햇살 품 에 가득 안 고 벅차 오르 는 바다 만큼 하늘 만큼 우주 만큼 너 탐스런 널 한 입 베 어 물 어 유유 히 흐르 는 네 게 빠져들 어 드리 워진 너 의 아래 서 쉴 때 세상 은 너 이 하늘 아래 가 모두 너 탐스런 널 한 입 베 어 물 면 내 안 엔 한가득 봄 두 볼 을 맞대 고 살며시 고 갤 돌리 면 수줍 은 듯 눈웃음 을 내게 흩날리 는 너 탐스런 널 한 입 베 어 물 어 유유 히 흐르 는 네 게 빠져들 어 드리 워진 너 의 아래 서 쉴 때 세상 은 너 이 하늘 아래 가 모두 탐 스럽 게 내게로 성큼 다가온 네 게 서 유유 하 게 들리 는 숨소리 드리워진 너 의 아래 서 쉴 때 세상 은 너 이 하늘 아래 가 너 내 눈 엔 온통 다 너 이 하늘 아래 가 모두 너
# Right translation : <sos> 역해
# Predicted translation:  나 의 궤도 <eos>
# -------------------------------------------------- 56
# Input: 점점 더 무거워 지 는 너 의 향 한 미움 들 점점 더 깊 어 만 가 는 너 를 향 한 그리움 얼마나 많 은 값 을 치러야 네 게 서 자유 로워질 수 있 을까 모두 가져가 줘 나 혼자 감당 하 기 엔 너무 무거운 짐 인 걸 모두 가져가 줘 나 혼자 기억 하 기 엔 너무 큰 사랑 인가 봐 제발 점점 더 무거워 지 는 너 의 향 한 미움 들 점점 더 깊 어 만 가 는 너 를 향 한 그리움 얼마나 많 은 값 을 치러야 네 게 서 자유 로워질 수 있 을까 모두 가져가 줘 나 혼자 감당 하 기 엔 너무 무거운 짐 인 걸 모두 가져가 줘 나 혼자 기억 하 기 엔 너무 큰 사랑 인가 봐 제발
# Right translation : <sos> 그대 는 그래요
# Predicted translation:  나 의 사랑 은 <eos>
# -------------------------------------------------- 79
# Input: 그래 세월 이 흐른 거 야 나 는 여기 있 는 데 빛바랜 사진 속 에 낡 은 사랑 얘기 도 지금 내게는 소 중 한 첫 사랑 꿈 이 었 지 나 도 잊혀졌 겠 지 내 가 잊 고 살 듯이 슬픔 인 채 잊혀 지 는 거 야 두 고 두 고 그리운 거 야 언젠가 는 기억 조차 희미 해진 그런 타인 되 는 거 야 추억 이 라고 묻 어 둔 젊 은 날 의 내 모습 나 는 혼자 웃 었 어 어제 나 를 보 면서 레몬 향기 로 가득 한 첫 사랑 느낌 으로 레몬 향기 로 가득 한 첫 사랑 느낌 으로 슬픔 인 채 잊혀 지 는 거 야 두고두고 그리운 거 야 언젠가 는 기억 조차 희미 해진 그런 타인 되 는 거 야 추억 이 라고 묻 어 둔 젊 은 날 의 내 모습 나 는 혼자 웃 었 어 어제 나 를 보 면서 레몬 향기 로 가득 한 첫 사랑 느낌 으로 레몬 향기 로 가득 한 첫 사랑 느낌 으로
# Right translation : <sos> 어사또 거짓 사연 충비 향단
# Predicted translation:  사랑 은 직진 <eos>
# -------------------------------------------------- 91
# Input: 너 의 주위 에서 내 가 조용히 사라지 면 너 는 나 를 영원히 잊 어 주 면 돼 너 의 주위 에서 내 가 조용히 사라지 면 너 는 나 를 영원히 잊 어 주 면 돼 너 에 대한 감정 이 무뎌져 넌 내게서 떨어져 매일 환히 웃 으며 또 잘 해 주 면 뭐 해 끝나 면 어차피 모른 척 하 지 남 같이 험한 말 또 다시 험한 말 더러운 손짓 과 우린 헤어진다 다시 돌아갈 수 없 다 해도 후회 하 지 않 을 자신 있 어 너 의 주위 에서 내 가 조용히 사라지 면 너 는 나 를 영원히 잊 어 주 면 돼 너 의 주위 에서 내 가 조용히 사라지 면 너 는 나 를 영원히 잊 어 주 면 돼
# Right translation : <sos> 위로 해 주 세요
# Predicted translation:  나 의 곁 에 <eos>
# -------------------------------------------------- 71
# Input: 멍 때리 다가 집 앞 도 지나쳤 어 이런 내 가 익숙 해져 가 딱히 누군가 생각나 서 가 아니 야 내 마음 이 허전 해서 그래 아무 도 없 는 카페 에 들어가 늘 마시 던 아메리카노 대신 레몬 티 그냥 새롭 고 싶 어서 나 도 잘 몰라 오늘 은 특별 해 지 고 싶 어 뭐 색다른 거 어디 없 나 뭘 해도 즐겁 지 가 않 아 하루하루 다 달랐 으면 좋 겠 어 오늘 은 특별 해 지 고 싶 어
# Right translation : <sos> 광안리 연가
# Predicted translation:  나 의 집 <eos>
# -------------------------------------------------- 80
# Input: 지나간 나 의 추억 들 생각 할 때 면 소 중 한 마음 으로 피어 난 미소 가 떠오르 고 보이 지 않 는 곳 의 그 분 의 사랑 의 손길 내 인생 어루만지 시 면서 갈 길 을 인도 하시 네 절망 의 골짜기 에 나 홀로 지쳐서 외로울 때 친구 로 내 곁 에 다가와 등불 을 밝혀 주 시 네 거친 세월 의 길목 에서 함께 하 셨 던 그 사랑 노래 로 접 어 하늘 로 띄우 고파 절망 의 골짜기 에 나 홀로 지쳐서 외로울 때 친구 로 내 곁 에 다가와 등불 을 밝혀 주 시 네 거친 세월 의 길목 에서 함께 하 셨 던 그 사랑 노래 로 접 어 하늘 로 띄우 고파
# Right translation : <sos> 시간 을 되돌릴 수 없 어서
# Predicted translation:  나 의 마음 <eos>
# -------------------------------------------------- 13
# Input: 매일 꿈 을 꾸 나요 나 와 함께 하 는 꿈 그대 도 나 처럼 잠 을 못 이루 나요 내 가 없 는 모습 이 어색 하 진 않 나요 내 사진 을 보 며 미소 를 짓 나요 이렇게 그대 생각 하 면은 웃음 이 나 요 나 만 표현 못 하 고 언제나 그대 주위 를 맴돌 기 만 했 죠 그때 는 그대 향 한 마음 이 사랑 이 란 걸 알 지 못 했 나 봐요 그대 다시 오 면 그 땐 말 할 수 있 죠 이렇게 비 가 오 면 그대 생각 이 나 죠 비오 는 거리 를 그대 는 좋 아 했 죠 조용 한 밤 이 오 면 귀 를 기울여 봐요 나 의 목소리 가 들리 지 않 나요 이렇게 그대 생각 하 면은 웃음 이 나 요 나 만 표현 못 하 고 언제나 그대 주위 를 맴돌 기 만 했 죠 그때 는 그대 향 한 마음 이 사랑 이 란 걸 알 지 못 했 나 봐요 그대 다시 오 면 그 땐 말 할 수 있 죠 우리 함께 하 는 모습 은 내 가 그려 왔 던 아름다운 풍경 이 죠 그때 는 그대 향 한 마음 이 사랑 이 란 걸 알 지 못 했 나 봐요 그대 다시 오 면 그 땐 말 할 수 있 죠 내 손 을 잡 아 주 세요 오직 제 가 올린 것 만 수정 이 됩니다
# Right translation : <sos> 검 은 생각
# Predicted translation:  사랑 의 역류 <eos>
# -------------------------------------------------- 62
# Input: 아니리 이렇 듯 세월 을 보내 는디 그때 여 사또 께서 동부 승지 당상 하 야 내직 으로 올라가 시 게 되 니 춘 향 과 이 도령 은 할 수 없이 이별 이 되 난 디 창조 도련 님 이 별 차 로 나오 난 디 중모리 왼갖 생각 두루 헌다 점 잖 허신 도련 님 이 대로 변 으로 나오 면서 울음 울리 가 없 지 만 은 옛 일 을 생각 허 니 당 명 황 은 만고 영웅 이나 양귀비 이별 에 울 어 있 고 항우 는 천하 장사 로되 우미 인 이별 에 울 었 으니 날 같 은 소 장부 야 아니 울 수 있 겠 느냐 춘 향 을 어쩌 고 갈꼬 두 고 갈 수 도 없 고 데리 고 갈 수 도 없 네 저 를 다려 간다 허 면 부모 님 이 금 할 테 요 저 를 두 고 간다 허 면 그 행실 그 기운 에 응당 자결 을 헐 것 이 니 저 못 보 면 나 못 살 고 나 를 못 보 면 저 도 응당 죽 을 테 니 사세 가 난처 로구나 질 걷 는 줄 을 모르 고 춘 향집 문전 을 당 도 허 니
# Right translation : 나 는 내일 과거 의 너 와 만난다
# Predicted translation:  나 는 꼼꼼 한 걸까요 <eos>
# -------------------------------------------------- 36
# Input: 너 의 포 근 한 살결 위 에 누워 너 의 손 이 새싹 처럼 내게 돋아나 머리 맡 으로 나비 들 이 모여 도 내게로 만 속삭여 주 는 따 뜻 한 바람 품 에 가득 안 고 벅차 오르 는 바다 만큼 하늘 만큼 우주 만큼 너 탐스런 널 한 입 베 어 물 어 유유 히 흐르 는 네 게 빠져들 어 드리 워진 너 의 아래 서 쉴 때 세상 은 너 이 하늘 아래 가 모두 너 잔잔 하 게 반짝이 는 너 목 소린 진한 생기 로 물들 어 가벼운 걸음 이 색색 으로 피어 나 내게로 만 내리쬐 주 는 눈빛 은 햇살 품 에 가득 안 고 벅차 오르 는 바다 만큼 하늘 만큼 우주 만큼 너 탐스런 널 한 입 베 어 물 어 유유 히 흐르 는 네 게 빠져들 어 드리 워진 너 의 아래 서 쉴 때 세상 은 너 이 하늘 아래 가 모두 너 탐스런 널 한 입 베 어 물 면 내 안 엔 한가득 봄 두 볼 을 맞대 고 살며시 고 갤 돌리 면 수줍 은 듯 눈웃음 을 내게 흩날리 는 너 탐스런 널 한 입 베 어 물 어 유유 히 흐르 는 네 게 빠져들 어 드리 워진 너 의 아래 서 쉴 때 세상 은 너 이 하늘 아래 가 모두 탐 스럽 게 내게로 성큼 다가온 네 게 서 유유 하 게 들리 는 숨소리 드리워진 너 의 아래 서 쉴 때 세상 은 너 이 하늘 아래 가 너 내 눈 엔 온통 다 너 이 하늘 아래 가 모두 너
# Right translation : <sos> 역해
# Predicted translation:  나 의 궤도 <eos>
# -------------------------------------------------- 56
# Input: 홀로 남 은 잎새 하나 너무 애처로워 젖 어 드 는 노을 빛 에 외로움 만 쌓이 네 너 를 보낸 내 마음 은 이 토록 쓰리 고 아파 너 를 잃 은 내 가슴 엔 언제나 슬픔 뿐 이 네 나 이제 가리 라 사랑 찾 아 떠나 가리 라 내 모든 슬픔 잊어버리 고 사랑 찾 아 떠나가 리 너 없 는 이 세상 난 누굴 위해 사나 가슴 의 아픔 은 모두 잊 고 님 찾 아 떠나가 리 나 이제 가리 라 사랑 찾 아 떠나 가리 라 내 모든 아픔 묻 어 버리 고 사랑 찾 아 떠나가 리 너 없 는 이 세상 난 살 아서 무엇 하나 가슴 의 상처 모두 묻 고 님 찾 아 떠나 가리 가슴 의 상처 모두 묻 고 님 찾 아 떠나가 리
# Right translation : 하 면 널 잊 을 수 있 을까
# Predicted translation:  사랑 의 전설 <eos>
# -------------------------------------------------- 89
# Input: 아무런 계획 도 없이 찾아온 금요일 오후 누구 도 찾 진 않 지만 어디 든 떠나 고 싶 어 너 와 의 기억 떠올라 한동안 찾 지 못 했 던 빛 바랜 추억 의 장소 이제 는 가 보 려 해 그대 와 함께 했 던 이 곳 엔 우리 아 는 맛집 풍경 카페 너 의 미소 이제 는 내 가 아 는 너 를 볼 수 없 어도 나 조금 씩 잊 어 볼 게 걸음 이 이 끄 는 대로 걷 다 보 니 도착 한 그 곳 서로 를 바라보 았 던 우리 그 때 의 그 모습 을 다시 볼 수 는 없 을까 찾아보 려고 했 지만 너무 늦 어 버린 날 들 이제 는 놓 아야 해 그대 와 함께 했 던 이 곳 엔 우리 아 는 맛집 풍경 카페 너 의 미소 이제 는 내 가 아 는 너 를 볼 수 없 어도 나 조금 씩 잊 어 볼 게 이미 끝나 버린 한편 의 영화 처럼 더 는 기대 할 수 없 는 흔한 장면 들 에 그대 와 함께 했 던 이 곳 엔 이 곳 엔 우리 아 는 맛집 풍경 카페 나 의 미소 이제 는 기억 속 널 보내 줄 수 있 으니 나 이제 는 떠나 볼 게 그대 와 함께 했 던 이 곳 엔 이 곳 엔 우리 아 는 맛집 풍경 카페 나 의 미소 이제 는 기억 속 널 보내 줄 수 있 으니 나 이제 는 떠나 볼 게 그대 와 함께 했 던 이 곳 엔 우리 아 는 맛집 풍경 카페 나 의 미소 이제 는 기억 속 널 보내 줄 수 있 으니 나 이제 는 떠나 볼 게
# Right translation : <sos> 작 은 연주회
# Predicted translation:  나 의 바흐 오후 <eos>
# -------------------------------------------------- 61
# Input: 어떤 이 는 꿈 을 간직 하 고 살 고 어떤 이 는 꿈 을 나눠 주 고 살 며 다른 이 는 꿈 을 이루 려고 사 네 어떤 이 는 꿈 을 잊 은 채 로 살 고 어떤 이 는 남 의 꿈 을 뺏 고 살 며 다른 이 는 꿈 은 없 는 거 라 하 네 세상 에 이 처럼 많 은 사람 들 과 세상 에 이 처럼 많 은 개성 들 저 마다 자기 가 옳다 말 을 하 고 꿈 이란 이런 거 라 말 하 지만 나 는 누굴까 내일 을 꿈꾸 는가 나 는 누굴까 아무 꿈 없 질 않 나 는 누굴까 내일 을 꿈꾸 는가 나 는 누굴까 혹 아무 꿈 종진 이 는 꿈 을 간직 하 고 살 고 태관 이 는 꿈 을 나눠 주 고 살 며 여러분 은 꿈 을 이루 고 사세요 어떤 이 는 꿈 을 잊 은 채 로 살 고 어떤 이 는 남 의 꿈 을 뺏 고 살 며 다른 이 는 꿈 은 없 는 거 라 하 네 세상 에 이 처럼 많 은 사람 들 과 세상 에 이 처럼 많 은 개성 들 저 마다 자기 가 옳다 말 을 하 고 꿈 이란 이런 거 라 말 하 지만 나 는 누굴까 내일 을 꿈꾸 는가 나 는 누굴까 아무 꿈 없 질 않 나 는 누굴까 내일 을 꿈꾸 는가 나 는 누굴까 아무 꿈 나 는 누굴까 내일 을 꿈꾸 는가 나 는 누굴까 아무 꿈 없 질 않 나 는 누굴까 내일 을 꿈꾸 는가 나 는 누굴까 혹 아무 꿈
# Right translation : <sos> 자꾸 눈 이 가
# Predicted translation:  나 의 바다 <eos>
# -------------------------------------------------- 52
# Input: 이제 제발 좀 그만 해 모든 게 지겨워 나 를 좀 내버려 둘 래 이런 건 별것 도 아닌데 처음 도 아닌데 왜 이리 힘든 건지 그대 를 원했 던 내 마음 지워 줄 래 우리 는 너무나 다른 걸 이제야 알 았 어 아무리 원해 도 소용없 는 걸 그대 는 나 에게 불안 만 을 줄 테 니 더 이상 나 에게 강요 하 지 마 이제 내 경고 야 애절 한 눈빛 도 소용없 는 걸 그대 의 선물 도 모두 가져가 버려 이별 을 말 해도 원망 하 지 마 가슴 이 아파 와 그 댈 잊 는 걸 포기 해 그대 와 사랑 해 아니 야 이래 선 안 되 그대 는 너무나 순진 해 차라리 내 가 저 멀리 떠나 줄 게 그대 를 원했 던 내 마음 지워 줄 래 우리 는 너무나 다른 걸 이제야 알 았 어 다시 는 못 볼 거 야 나 의 착한 그대 의 기억 속 나 에게 작별 을 하 고 싶 은데 틀린 가사 알려 주 시 면 수정 하 겠 습니다
# Right translation : <sos> 우리 가 빛나 던 그 때
# Predicted translation:  나 는 어떡 하 지 않 아 <eos>
# ...
# Right translation : <sos> 감겨
# Predicted translation:  무채색 의 밤 <eos>
# -------------------------------------------------- 69
# Input: 오늘 은 우리 헤어지 는 날 마지막 으로 솔직 해 지 는 밤 나 는 그 동안 참 아 왔 는데 왜 네 가 먼저 눈물 을 흘려 그런 너 를 바라보 다가 화가 나 차갑 게 던진 한마디 울지마 그런 너 를 바라보 다가 못 참 아 난 아이 처럼 서럽 게 울 어 뚝뚝 눈물 을 흘리 고 나 를 안 아 달라 말 해 버려 내일 퉁퉁 두 눈 이 부어 서 밖 에 나갈 수 도 없 을 거 야 다시 는 울 지 않 기 를 다시 는 울 지 않 기 를 사실 은 너무 힘들 었 어 난 사랑 해 라는 가슴 속 의 그 말 나 는 한참 을 기다렸 는데 그게 그렇게 어려웠 었 니 후회 하 지 않 을까 망설이 다가 흘러내리 는 너 의 눈물 을 닦 아 약한 모습 보이 기 싫 어 참 다가 난 아이 처럼 서럽 게 울 어 또 코끝 이 시려 와 참 을래도 참 아 지 않 아 울 며 툴툴 대 는 날 안 고서 다시 사랑 하 자 말 을 해 줘 다시 는 울 지 않 기 를 다시 는 울 지 않 기 를
# Right translation : <sos> 잊혀질 그 에게
# Predicted translation:  나 의 집 에 <eos>
# -------------------------------------------------- 59
# Input: 매일 똑같 은 하루 똑같 은 일상 에 매일 지겨운 날 들 에 가끔 웃 을 수 있 는 일 아 지금 이 곳 에서 누가 날 좀 꺼내 줘 아 지금 여기 서 누가 날 좀 꺼내 줘 집 에서 뒹굴 기 집 에서 밥 먹 기 영화 보 기 드라마 보 기 어디 선 가 누구 라도 만나 술 이나 퍼마시 기 집 에서 뒹굴 기 집 에서 밥 먹 기 영화 보 기 드라마 보 기 언제나 처럼 오늘 도 매일 똑같 은 하루 매일 지겹 지만 뭔갈 해 보 려고 했 는데 지금 여기 서 누가 날 나 뜯 는 중 이 니까 사랑 은 개 풀 뜯 는 감정 손실 취침 먹 기 반복 이 일 과 다 피부 에 양보 하 는 태도 와 착한 재료 가 쓰인 입욕 제 를 풀 고 늘어지 는 중 이 시 지 집 에서 뒹굴 기 집 에서 밥 먹 기 영화 보 기 드라마 보 기 어디 선 가 누구 라도 만나 술 이나 퍼마시 기 집 에서 뒹굴 기 집 에서 밥 먹 기 영화 보 기 드라마 보 기 언제나 처럼 오늘 도
# Right translation : <sos> 우리 집 으로
# Predicted translation:  나 는 꼼꼼 해 <eos>
# -------------------------------------------------- 40
# Input: 차가운 바람 숨 고 싶 던 그날 들 기나긴 계절 끝날 것 같 지 않 아 간절히 기다려도 오 지 않 을 것 같 아 쓸쓸 한 거리 울 고 싶 던 그날 들 기나긴 한숨 멈출 것 같 지 않 아 나지막이 불러도 듣 지 못 할 것 같 아 그대 바람 이 지나 는 길목 에서 가만히 기다리 면 따스 한 봄 이 오 겠 지 지나 는 바람 잊 고 싶 던 그날 들 오래 된 기억 머물 것 같 지 않 아 가만히 바라봐 도 이 젠 볼 수 없 을 것 같 아 그대 바람 이 지나 는 길목 에서 가만히 기다리 면 따스 한 봄 이 오 겠 지 그 길 에서 가만히 널 부르 면 따스 한 봄 이 오 겠 지
# Right translation : <sos> 봄 의 아지랑이 처럼
# Predicted translation:  바람 이 오 는 날 <eos>
# -------------------------------------------------- 0
# Input: 널 좋 아 하 는 거 나 이제 그만 둘까 봐 날 좋 아 해 달 란 얘기 도 일찍 집 에 가 란 얘기 도 더 는 하 지 않 을 게 몇 날 며칠 연락 이 되 지 않 아도 괜 한 걱정 하 는 것 도 아직 도 눈 만 뜨 면 네 생각 이 난다는 얘기 도 널 좋 아 하 는 거 나 이제 그만 둘까 봐 내 가 아닌 그 사람 과 행복 하 라고 웃 으며 축하 도 해줄까 봐 널 기다리 는 거 나 이제 그만 할까 봐 너 올까 봐 기다리 는 하루 도 오늘 을 마지막 으로 널 좋 아 하 는 거 그만 할까 봐 널 좋 아 하 는 건 나 이제 힘 에 겹 나 봐 우리 처음 만난 그날 도 날 보 며 웃 어 주 던 미소 도 기억 하 지 않 을 게 하루 의 시작 하루 의 끝 에 네 목소리 잠자 는 시간 빼 고 는 아른거리 네 얼굴 이 어딜 가 나 네 가 있 고 내 귓가 에 들린단 얘기 도 널 좋 아 하 는 거 나 이제 그만 둘까 봐 내 가 아닌 그 사람 과 행복 하 라고 웃 으며 축하 도 해줄까 봐 널 기다리 는 거 나 이제 그만 할까 봐 너 올까 봐 기다리 는 하루 도 오늘 을 마지막 으로 널 좋 아 하 는 거 그만 할까 봐 더 이상 은 묻 지 않 을 거 란 그 얘기 도 널 좋 아 하 는 거 나 이제 그만 둘까 봐
# Right translation : <sos> 내게 숨 은 당신
# Predicted translation:  너 를 위한 노래 <eos>
# -------------------------------------------------- 21
# Input: 매일 꿈 을 꾸 나요 나 와 함께 하 는 꿈 그대 도 나 처럼 잠 을 못 이루 나요 내 가 없 는 모습 이 어색 하 진 않 나요 내 사진 을 보 며 미소 를 짓 나요 이렇게 그대 생각 하 면은 웃음 이 나 요 나 만 표현 못 하 고 언제나 그대 주위 를 맴돌 기 만 했 죠 그때 는 그대 향 한 마음 이 사랑 이 란 걸 알 지 못 했 나 봐요 그대 다시 오 면 그 땐 말 할 수 있 죠 이렇게 비 가 오 면 그대 생각 이 나 죠 비오 는 거리 를 그대 는 좋 아 했 죠 조용 한 밤 이 오 면 귀 를 기울여 봐요 나 의 목소리 가 들리 지 않 나요 이렇게 그대 생각 하 면은 웃음 이 나 요 나 만 표현 못 하 고 언제나 그대 주위 를 맴돌 기 만 했 죠 그때 는 그대 향 한 마음 이 사랑 이 란 걸 알 지 못 했 나 봐요 그대 다시 오 면 그 땐 말 할 수 있 죠 우리 함께 하 는 모습 은 내 가 그려 왔 던 아름다운 풍경 이 죠 그때 는 그대 향 한 마음 이 사랑 이 란 걸 알 지 못 했 나 봐요 그대 다시 오 면 그 땐 말 할 수 있 죠 내 손 을 잡 아 주 세요 오직 제 가 올린 것 만 수정 이 됩니다
# Right translation : <sos> 검 은 생각
# Predicted translation:  사랑 의 역류 <eos>
# -------------------------------------------------- 62
# Input: 내년 엔 납골 묘 를 만들 어 여기저기 흩어진 묘 들 을 이장 할 생각 이 다 그 래야 너희 들 도 편하 겠 고 나 도 죽 기 전 에 그것 만 은 하 려고 한다 아버지 납골 묘 아래 에 내 가 먼저 들어갈 건데 요
# Right translation : <sos> 비 켜 가
# Predicted translation:  나 는 꼼꼼 한 테슬라 <eos>
# -------------------------------------------------- 23
# Input: 너 의 포 근 한 살결 위 에 누워 너 의 손 이 새싹 처럼 내게 돋아나 머리 맡 으로 나비 들 이 모여 도 내게로 만 속삭여 주 는 따 뜻 한 바람 품 에 가득 안 고 벅차 오르 는 바다 만큼 하늘 만큼 우주 만큼 너 탐스런 널 한 입 베 어 물 어 유유 히 흐르 는 네 게 빠져들 어 드리 워진 너 의 아래 서 쉴 때 세상 은 너 이 하늘 아래 가 모두 너 잔잔 하 게 반짝이 는 너 목 소린 진한 생기 로 물들 어 가벼운 걸음 이 색색 으로 피어 나 내게로 만 내리쬐 주 는 눈빛 은 햇살 품 에 가득 안 고 벅차 오르 는 바다 만큼 하늘 만큼 우주 만큼 너 탐스런 널 한 입 베 어 물 어 유유 히 흐르 는 네 게 빠져들 어 드리 워진 너 의 아래 서 쉴 때 세상 은 너 이 하늘 아래 가 모두 너 탐스런 널 한 입 베 어 물 면 내 안 엔 한가득 봄 두 볼 을 맞대 고 살며시 고 갤 돌리 면 수줍 은 듯 눈웃음 을 내게 흩날리 는 너 탐스런 널 한 입 베 어 물 어 유유 히 흐르 는 네 게 빠져들 어 드리 워진 너 의 아래 서 쉴 때 세상 은 너 이 하늘 아래 가 모두 탐 스럽 게 내게로 성큼 다가온 네 게 서 유유 하 게 들리 는 숨소리 드리워진 너 의 아래 서 쉴 때 세상 은 너 이 하늘 아래 가 너 내 눈 엔 온통 다 너 이 하늘 아래 가 모두 너
# Right translation : <sos> 역해
# Predicted translation:  나 의 궤도 <eos>
# -------------------------------------------------- 56
# Input: 너 라고 확신 해 너 는 내 여자 라는 걸 나 는 분명 해 확실 해 이 게 사랑 이 란 걸 어떻게 이렇게 좋 을 수 가 있 어 한 번 도 이런 적 없 었 어 잠시 라도 떨어지 면 나 미칠 것 같 아 조금 전 에 봤 는데 나 는 왜 또 네 가 생각나 이따가 또 볼 건데 나 는 왜 또 네 가 보 고파 꿈 에서 도 봤 는데 계속 너 를 볼 건데 하루 종일 옆 에 있 어 주 면 정말 좋 겠 네 봐도 나 는 네 가 보 고파 보 고파 천년 만년 나 는 너 만 보 고파 보 고파 계속 그렇 게 있 어 줘 언제나 웃 을 수 있 게 시간 이 흘러도 내 눈 엔 너 하나 만 보 고파 매번 봐도 보 고 파지 는 마법 에 걸렸 나 봐 빠져드 는 마력 에 작대기 한 줄 더 보태 매력 갑 매일 너 다 움 엿볼 수 있 는 기회 내 사랑 은 시간 에 정비례 편안 해 과학 적 으론 설명 이 안 돼 콧노래 가 절로 나오 고 입 꼬리 가 귀 에 걸리 고 너 니까 그래 너 여야 가능 해 내 선택 은 어제 도 오늘 도 내일 도 조금 전 에 봤 는데 나 는 왜 또 네 가 생각나 이따가 또 볼 건데 나 는 왜 또 네 가 보 고파 꿈 에서 도 봤 는데 계속 너 를 볼 건데 하루 종일 옆 에 있 어 주 면 정말 좋 겠 네 봐도 나 는 네 가 보 고파 보 고파 천년 만년 나 는 너 만 보 고파 보 고파 계속 그렇 게 있 어 줘 언제나 웃 을 수 있 게 시간 이 흘러도 내 눈 엔 너 하나 만 보 고파 시간 이 흘러서 우리 가 조금 익숙 해져도 지금 이 느낌 을 잊 지 말 자 난 네 가 보 고파 내 맘 은 변하 지 않 아 넌 지금 처럼 있 으면 돼 봐도 나 는 네 가 보 고파 보 고파 천년 만년 나 는 너 만 보 고파 보 고파 계속 그렇 게 있 어 줘 언제나 웃 을 수 있 게 시간 이 흘러도 내 눈 엔 너 하나 만 보 고파
# Right translation : 는 밤새 홀로 앉 아 있 었 다
# Predicted translation:  나 의 친구 <eos>
# -------------------------------------------------- 6
# Input: 오 그대 가 나 를 떠나 버린 뒤 이제 겨우 하루 가 지났 는데 내 마음 이 이상 하 게 편안 해 오랫 만 에 자유 로움 느끼 니 오 그대 가 떠나 고 이틀 째 되 던 오늘 밤 에 내 가슴 이 답답 해 지 고 점점 불안 해져 만 가 네 안녕 이란 너 의 그 말 도무지 실감 이 안 나 하루 종일 이비 를 맞 으며 멍하니 서 있 네 사랑 해 요 사랑 해 요 나 를 사랑 한다고 말 했었 는데 바보 같이 그 말 을 믿 었 는데 그대 가 나 를 떠나 버리 고 사흘 동안 한숨 도 못 잤 는데 그대 가 다시 돌아올까봐 나 는 매일 창밖 을 바라보 네 오 그대 가 떠나 고 일 주일 이 되 던 오늘 밤 세상 이 까맣 게 변해 움직일 수 조차 없 어요 안녕 이란 너 의 그 말 도무지 실감 이 안 나 하루 종일 이비 를 맞 으며 멍하니 서 있 네 사랑 해 요 사랑 해 요 나 를 사랑 한다고 말 했었 는데 바보 같이 그 말 을 믿 었 는데 내 가 싫 어 가 버린 그대 원망 해 봤 자 다 부질없 는지 아주 많 은 세월 이 흘러 너 를 만나 면 힘들 었 던 우리 사랑 에 웃음 짖 게 되 겠 지 안녕 이란 너 의 그 말 도무지 실감 이 안 나 하루 종일 이비 를 맞 으며 멍하니 서 있 네 사랑 해 요 사랑 해 요 나 를 사랑 한다고 말 했었 는데 바보 같이 그 말 을 믿 었 는데 믿 었 는데
# Right translation : <sos> 년 동안 의 진심
# Predicted translation:  사랑 은 늘 <eos>
# -------------------------------------------------- 77
# Input: 늦 은 아침 단잠 빠진 너 를 깨 우 며 일어나 출근 하 자 눈 을 뜨 라고 꿈결 인가 생시 인가 눈꼽 찬 눈 을 뜨 며 어리둥절 세수 하 러 끌려가 는 너 늦 은 식사 허둥지둥 입 엔 한가득 가득 어서 씹 어 빨리 씹 어 그래도 꼭꼭 씹 어 카시트 에 꽁꽁 묶여 답답 해 짜증 내 지만 짜증 낸다 쥐어박 는 날 위해 웃 는 너 걸음 마 도 떼 기 전 에 우린 함께 이 길 을 걸 었 지 세상 은 걸음 멈춰 있 지만 우린 노래 불렀 지 아둥바둥 허둥지둥 연습 실 도착 해 모든 방 이 자기 세상 여기 기웃 저기 기웃 노 느라 정신 팔려 실수 연발 하 지만 모든 노래 따라 불러 작 은 꼬마 가수 더운 여름 추운 겨울 거리 에서 무대 에 선 나 를 기다리 는 너 의 모습 잘 있 을까 걱정 돼서 자꾸 쳐다보 지만 노래 따라 흥 에 겨워 춤추 고 있 는 너 하루하루 네 가 커 갈수록 많 은 세상 을 보 았 지 거리 에서 만난 사람 들 과 마음 을 함께 나눴 지 늦 은 저녁 꾸벅꾸벅 조 는 널 깨 우 며 일어나 집 에 가 자 눈 을 뜨 라고 잠 에 취해 울 어 버린 너 를 감싸 안 으니 어린 마음 힘 이 들 까 마음 이 찡하 네 너 에게 보여 주 고 싶 은 널 닮 은 세상 있 지만 우리 함께 걸어가 는 이 길 이 더 소 중 한 일 이 아닐까
# Right translation : <sos> 자기 전 에 드 는 생각
# Predicted translation:  나 의 여름 <eos>
# -------------------------------------------------- 30
# Input: 나 행복 합니다 그대 를 만나 서 나 오랜 시간 헤맸 는데 이제 만났 네요 그대 고마워요 내게로 와줘서 아름다운 꽃 이 되 어 주 니 살며시 떨리 네요 그 댈 사랑 해 요 온 맘 다 해 사랑 할게요 우리 가 는 길 이 아무리 어렵 다 해도 그대 의 손 놓 지 않 을 게 요 그 댈 사랑 해 요 영원히 사랑 할게요 우리 하나 되 어 영원 토록 변치 않 는 그 사랑 을 함께 노래 해 요
# Right translation : <sos> 돌아봐
# Predicted translation:  당신 은 이미 <eos>
# -------------------------------------------------- 83
# Input: 구석 진 골목 버스 전등 속 벌레 들 빛 에 속 아 날리 네 길가 지렁이 들 물 달팽이 들 비 에 젖 어 춤추 네 비 가 온다 비 가 노래 를 한다 춤 보이 는 소리 밤 울음 소리 걸음걸이 눅눅 하 다 깨지 는 하늘 과 숨겨 둔 백수 같 은 여자 의 웃음 소리 들려온다 그런 수진 운다 수진 노래 를 한다 울음 방 한 칸 소리 밤 울음 소리 일그러진 담배 꽁초 살 아 있 는 한숨 에 여자 는 물 을 밟 을까 손 등 을 내밀 까 이유 있 는 떠도 는 그런
# Right translation : <sos> 사막 하늘 끝 에
# Predicted translation:  나 는 꼼꼼 한 테슬라 <eos>
# -------------------------------------------------- 97
# Input: 어떤 이 는 꿈 을 간직 하 고 살 고 어떤 이 는 꿈 을 나눠 주 고 살 며 다른 이 는 꿈 을 이루 려고 사 네 어떤 이 는 꿈 을 잊 은 채 로 살 고 어떤 이 는 남 의 꿈 을 뺏 고 살 며 다른 이 는 꿈 은 없 는 거 라 하 네 세상 에 이 처럼 많 은 사람 들 과 세상 에 이 처럼 많 은 개성 들 저 마다 자기 가 옳다 말 을 하 고 꿈 이란 이런 거 라 말 하 지만 나 는 누굴까 내일 을 꿈꾸 는가 나 는 누굴까 아무 꿈 없 질 않 나 는 누굴까 내일 을 꿈꾸 는가 나 는 누굴까 혹 아무 꿈 종진 이 는 꿈 을 간직 하 고 살 고 태관 이 는 꿈 을 나눠 주 고 살 며 여러분 은 꿈 을 이루 고 사세요 어떤 이 는 꿈 을 잊 은 채 로 살 고 어떤 이 는 남 의 꿈 을 뺏 고 살 며 다른 이 는 꿈 은 없 는 거 라 하 네 세상 에 이 처럼 많 은 사람 들 과 세상 에 이 처럼 많 은 개성 들 저 마다 자기 가 옳다 말 을 하 고 꿈 이란 이런 거 라 말 하 지만 나 는 누굴까 내일 을 꿈꾸 는가 나 는 누굴까 아무 꿈 없 질 않 나 는 누굴까 내일 을 꿈꾸 는가 나 는 누굴까 아무 꿈 나 는 누굴까 내일 을 꿈꾸 는가 나 는 누굴까 아무 꿈 없 질 않 나 는 누굴까 내일 을 꿈꾸 는가 나 는 누굴까 혹 아무 꿈
# Right translation : <sos> 자꾸 눈 이 가
# Predicted translation:  나 의 바다 <eos>
# -------------------------------------------------- 52
# Input: 기 찻길 옆 오막살이 아기 잘 도 잔다 칙 폭 칙칙폭폭 기차 소리 요란 해도 아기 잘 도 잔다 기 찻길 옆 옥수수 밭 옥수수 는 잘 도 큰다 칙 폭 칙칙폭폭 기차 소리 요란 해도 옥수수 는 잘 도 큰다
# Right translation : <sos> 세상 의 날개
# Predicted translation:  나 는 야 요리사 <eos>
# -------------------------------------------------- 38
# Input: 널 좋 아 하 는 거 나 이제 그만 둘까 봐 날 좋 아 해 달 란 얘기 도 일찍 집 에 가 란 얘기 도 더 는 하 지 않 을 게 몇 날 며칠 연락 이 되 지 않 아도 괜 한 걱정 하 는 것 도 아직 도 눈 만 뜨 면 네 생각 이 난다는 얘기 도 널 좋 아 하 는 거 나 이제 그만 둘까 봐 내 가 아닌 그 사람 과 행복 하 라고 웃 으며 축하 도 해줄까 봐 널 기다리 는 거 나 이제 그만 할까 봐 너 올까 봐 기다리 는 하루 도 오늘 을 마지막 으로 널 좋 아 하 는 거 그만 할까 봐 널 좋 아 하 는 건 나 이제 힘 에 겹 나 봐 우리 처음 만난 그날 도 날 보 며 웃 어 주 던 미소 도 기억 하 지 않 을 게 하루 의 시작 하루 의 끝 에 네 목소리 잠자 는 시간 빼 고 는 아른거리 네 얼굴 이 어딜 가 나 네 가 있 고 내 귓가 에 들린단 얘기 도 널 좋 아 하 는 거 나 이제 그만 둘까 봐 내 가 아닌 그 사람 과 행복 하 라고 웃 으며 축하 도 해줄까 봐 널 기다리 는 거 나 이제 그만 할까 봐 너 올까 봐 기다리 는 하루 도 오늘 을 마지막 으로 널 좋 아 하 는 거 그만 할까 봐 더 이상 은 묻 지 않 을 거 란 그 얘기 도 널 좋 아 하 는 거 나 이제 그만 둘까 봐
# Right translation : <sos> 내게 숨 은 당신
# Predicted translation:  너 를 위한 노래 <eos>
# -------------------------------------------------- 21
# Input: 지나간 나 의 추억 들 생각 할 때 면 소 중 한 마음 으로 피어 난 미소 가 떠오르 고 보이 지 않 는 곳 의 그 분 의 사랑 의 손길 내 인생 어루만지 시 면서 갈 길 을 인도 하시 네 절망 의 골짜기 에 나 홀로 지쳐서 외로울 때 친구 로 내 곁 에 다가와 등불 을 밝혀 주 시 네 거친 세월 의 길목 에서 함께 하 셨 던 그 사랑 노래 로 접 어 하늘 로 띄우 고파 절망 의 골짜기 에 나 홀로 지쳐서 외로울 때 친구 로 내 곁 에 다가와 등불 을 밝혀 주 시 네 거친 세월 의 길목 에서 함께 하 셨 던 그 사랑 노래 로 접 어 하늘 로 띄우 고파
# Right translation : <sos> 시간 을 되돌릴 수 없 어서
# Predicted translation:  나 의 마음 <eos>
# -------------------------------------------------- 13
# Input: 차 분 하 게 나 의 마음 을 가라앉힌 다음 에 조용 하 게 너 의 뒤 로 다가가 서 너 를 포 근 하 게 너 를 나 의 품 으로 당겨 안 아 나직 하 게 너 의 귓가 에 속삭일 거 야 너 가 나 의 곁 에 있 었 으면 좋 겠 어 너 가 나 의 품안 에 안겼 음 좋 겠 어 너 와 내 가 손 을 맞 잡 고 너 와 내 가 입 을 맞추 고 너 와 내 가 평생 함께 였 음 좋 겠 어 너 가 나 의 너 가 나 의 곁 에 있 었 으면 좋 겠 어 너 가 나 의 품안 에 안겼 음 좋 겠 어 너 와 내 가 손 을 맞 잡 고 너 와 내 가 입 을 맞추 고 너 와 내 가 평생 함께 였 음 좋 겠 어 우리 함께 같이
# Right translation : 하 지 음악 듣 기 싫 을 때
# Predicted translation:  나 의 세상 <eos>
# -------------------------------------------------- 96
# Input: 마음속 안개 가 걷혀질 때 쯤 에 넌 나 를 불러 술 한잔 에 잊 자고 앞 으로 가 다 보 면 해 는 또 떠올라 고양이 수염 에 이슬 이 맺혀 잠자 던 도시 에 오로라 를 뿌려 줘 너 의 눈동자 반짝이 던 그날 난 이제 너 뿐 이 야 참살 이 새벽 시 너 와 나 단 둘 이 서 참살 이 새벽 시 너 와 난 단 둘 이 서 잠자 던 도시 에 오로라 를 뿌려 줘 너 의 눈동자 반짝이 던 그날 난 이제 너 뿐 이 야 참살 이 새벽 시 너 와 나 단 둘 이 서 참살 이 새벽 시 너 와 난 단 둘 이 서
# Right translation : <sos> 네발자전거
# Predicted translation:  나 의 민낯 <eos>
# -------------------------------------------------- 22
# Input: 내 얼굴 알 고 있 나요 너무나 설레 요 지금 내 옆 을 지나가 는 너 일까 내 가 알 고 있 는 인연 중 에 너 인가 당신 을 위해 기다려 온 생애 최고 의 연인 이 될 준비 는 완료 평생 을 믿 고 따를게요 우리 가 만들 어 갈 새 인생 을 요 너무 기다리 게 하 지 말 아 날 아프 게 하 지 마 날 시험 에 들 게 하 지 마 천 번 의 인연 이 있 어야 만난다는 생 의 반쪽 어느 날 내 앞 에 다가와서 입 맞춰 줄 거 란 믿음 만 은 변함 없 죠 정말 잘 할 거 란 생각 밖에 말 이 필요 없 죠 생각 보다 무 뚝뚝 합니다 하찮 은 외모 보단 바다 같 은 이 해심 보 기 보다 여리 답니 다 무소 같 은 인내심 널 지킬 뱃심 할 말 이 많 아요 어디 쯤 와 있 나요 내 이름 알 고 있 나요 너무 기대 돼요 사람 많 은 거리 에서 날 보 고 소리쳐 줘 사랑 해 아무리 더워도 내 손 놓 지 말 아 줘 널 좋 아 해서 미안 한 일 은 않 을 게 내게 오 느라 힘들 었 던 발 은 내 가 씻 어 줄 게 널 기다리 느라 목 이 빠진 내 인생 너 다 줄 게 다 가져가 어쩌다 소극 적 인 성격 땜 에 화날 일 이 생겨도 표현 을 못 해 너무 답답 하 게 만들 어도 속 맘 은 안 그런 거 알 아도 이해 해도 말 처럼 쉽 지 않 을 때 가 있 어도 먼저 미안 하 다 말 할 거 예요 자존심 아닌 진실 된 뉘우침 먼저 사랑 한다 말 할 거 예요 가식 아닌 내 속 의 진심 가끔 은 두려워 혹시 않 올까 봐요 내 얼굴 알 고 있 나요 너무나 설레 요 하루 에 딱 한 번 만 싸우 고 한 달 에 속 한 번 만 썩이 고 일 년 에 나 한 번 만 울려 줘 평생 에 넌 내게 한 명 뿐 야 너 니까 참 고 너 니까 사랑 하 고 너 니까 웃 는 거 야 난 너 니까 사 는 거 야 내게 올 너 만 을 기다릴 꺼 야 분명 행복 할 꺼 야 한눈팔 지 않 고 너 만 바라볼 거 며 평생 을 바쳐 사랑 할 것 이 며 비바람 몰아쳐도 널 지킬 것 이 며 누구 의 귓속말 도 안 들 을 것 이 며 오해 가 생긴 데 도 너 를 믿 을 것 이 며 나 로 인해 행복 하 게 해 줄 것 이 며 상처 를 주 지 않 는 치료 해 주 는 그런 사람 되 줄 게 요 내 미래 반쪽 할 말 이 많 아요 어디 쯤 와 있 나요 내 이름 알 고 있 나요 너무 기대 돼요 가끔 은 두려워 혹시 않 올까 봐요 내 얼굴 알 고 있 나요 너무나 설레 요 사랑 해
# Right translation : <sos> 내 마음 이 심히 약해 졌으니
# Predicted translation:  내 가 그댈 사랑 하 는 방법 <eos>
# -------------------------------------------------- 55
# Input: 홀로 남 은 잎새 하나 너무 애처로워 젖 어 드 는 노을 빛 에 외로움 만 쌓이 네 너 를 보낸 내 마음 은 이 토록 쓰리 고 아파 너 를 잃 은 내 가슴 엔 언제나 슬픔 뿐 이 네 나 이제 가리 라 사랑 찾 아 떠나 가리 라 내 모든 슬픔 잊어버리 고 사랑 찾 아 떠나가 리 너 없 는 이 세상 난 누굴 위해 사나 가슴 의 아픔 은 모두 잊 고 님 찾 아 떠나가 리 나 이제 가리 라 사랑 찾 아 떠나 가리 라 내 모든 아픔 묻 어 버리 고 사랑 찾 아 떠나가 리 너 없 는 이 세상 난 살 아서 무엇 하나 가슴 의 상처 모두 묻 고 님 찾 아 떠나 가리 가슴 의 상처 모두 묻 고 님 찾 아 떠나가 리
# Right translation : 하 면 널 잊 을 수 있 을까
# Predicted translation:  사랑 의 전설 <eos>
# -------------------------------------------------- 89
# Input: 참 아 봤 지만 이겨 내 긴 힘든가 봐 피 가 흘러야 그 제 서야 아픈가 봐 그래 나 는 바보 야 그래 나 는 바보 야 밤하늘 별 들 뒤지 다 잠 이 든다 별 이 지워 진다 지워 진다 지워진다 거울 이 나 를 본다 애처 롭 게 바라본다 마음 에 눈 을 둔다 아무리 애써 찾아봐도 나 를 비추 던 넌 떠났 구나 하루하루 가 불안 한 꿈 인 것 같 아 잠 을 청 하 면 아픔 이 더 또렷 해져 그래 나 는 바보 야 나 는 정말 바보 야 이런 날 놀리 진 마 이런 날 욕 하 진 마 쉽 게 말 하 지 마 니 가 뭘 안다 그래 별 이 지워 진다 지워 진다 지워진다 거울 이 나 를 본다 애처 롭 게 쳐다본다 날 빛내 주 던 너 를 잃어버린 내 얼굴 매일 보 자니 눈엣 가시 구나 내 가 지워진다 질끈 눈 감 는다 잠시 도 널 참 지 못 하 니 힘 이 드 누나 별 없 는 밤 어찌 버텨 낼까 별 이 이 울 고 모두 함께 스러진 밤
# Right translation : <sos> 이대로 좋 다
# Predicted translation:  나 의 친굴 는 남자 <eos>
# -------------------------------------------------- 9
# Input: 가끔 은 겁 이 나 기 도 해 요 내 가 이 길 을 끝 까지 걸 을 수 있 을까 혹시 이 길 을 걷 다가 그냥 쓰러져 버리 지 는 않 을까 가끔 은 센 척 하 기 도 해 요 누가 나 를 바라보 며 한 심 해 할까봐 사실 나 의 속마음 은 많이 아주 많이 부서져 가 는 데 하 지만 이제 더 는 숨 어서 울 지 않 아 못 난 이 모습 그대로 안 아 줘요 이렇게 약하 지만 그래도 나 는 사랑 을 믿 고 있 어 차갑 지 않 은 따 뜻 한 사랑 속 에 춤출 수 있 게 그 안 에 가둬 줘요 날 잡 아 줘요 아파도 참 고 웃 기 도 해 요 결국 세상 은 찢겨진 날 버릴 테 니까 항상 상처 를 숨기 고 매일 같 은 자리 에 서 있 었 는데 하 지만 이제 더 는 숨기 고 싶 지 않 아 찢겨진 이 모습 그대로 안 아 줘요 이렇게 약하 지만 그래도 나 는 사랑 을 믿 고 있 어 차갑 지 않 은 따 뜻 한 사랑 속 에 춤출 수 있 게 그 안 에 가둬 줘요 날 잡 아 줘요 더럽 고 찢겼 지만 그래도 나 는 당신 을 믿 고 있 어 마르 지 않 을 영원 한 사랑 속 에 춤출 수 있 게 당신 을 열 어 줘요 날 안 아 줘요
# Right translation : <sos> 자폐
# Predicted translation:  나 의 집 에 <eos>
# -------------------------------------------------- 45
# Input: 어떤 이 는 꿈 을 간직 하 고 살 고 어떤 이 는 꿈 을 나눠 주 고 살 며 다른 이 는 꿈 을 이루 려고 사 네 어떤 이 는 꿈 을 잊 은 채 로 살 고 어떤 이 는 남 의 꿈 을 뺏 고 살 며 다른 이 는 꿈 은 없 는 거 라 하 네 세상 에 이 처럼 많 은 사람 들 과 세상 에 이 처럼 많 은 개성 들 저 마다 자기 가 옳다 말 을 하 고 꿈 이란 이런 거 라 말 하 지만 나 는 누굴까 내일 을 꿈꾸 는가 나 는 누굴까 아무 꿈 없 질 않 나 는 누굴까 내일 을 꿈꾸 는가 나 는 누굴까 혹 아무 꿈 종진 이 는 꿈 을 간직 하 고 살 고 태관 이 는 꿈 을 나눠 주 고 살 며 여러분 은 꿈 을 이루 고 사세요 어떤 이 는 꿈 을 잊 은 채 로 살 고 어떤 이 는 남 의 꿈 을 뺏 고 살 며 다른 이 는 꿈 은 없 는 거 라 하 네 세상 에 이 처럼 많 은 사람 들 과 세상 에 이 처럼 많 은 개성 들 저 마다 자기 가 옳다 말 을 하 고 꿈 이란 이런 거 라 말 하 지만 나 는 누굴까 내일 을 꿈꾸 는가 나 는 누굴까 아무 꿈 없 질 않 나 는 누굴까 내일 을 꿈꾸 는가 나 는 누굴까 아무 꿈 나 는 누굴까 내일 을 꿈꾸 는가 나 는 누굴까 아무 꿈 없 질 않 나 는 누굴까 내일 을 꿈꾸 는가 나 는 누굴까 혹 아무 꿈
# Right translation : <sos> 자꾸 눈 이 가
# Predicted translation:  나 의 바다 <eos>
# -------------------------------------------------- 52
# Input: 사랑 하 는 사람 이 생겼 다 말 로 는 표현 하 기 어렵 지만 마치 떨어지 는 별똥별 같 은 내 사람 아 부디 사라지 지 말 아다 오 아프 고 쓰라린 감정 을 정리 하 던 와중 에 어 두운 가로등 밑 을 환하 게 밝혀 주 었 던 그대 의 고운 손 은 거칠 게 더럽힐 수 도 있 는 이 곳 에 먼지 투성이 인 나 만 을 평생 사랑 해 줄 사람 이 생겼 다 말 로 는 표현 하 기 어렵 지만 마치 떨어지 는 별똥별 같 은 내 사람 아 부디 사라지 지 말 아 다오
# Right translation : <sos> 창 의 도시
# Predicted translation:  사랑 은 늘 <eos>
# -------------------------------------------------- 18
# Input: 보랏빛 어둠 이 흘러 겨울 도 지쳐 가 고 차디찬 침묵 이 꽃 이 피 면 홀로 빈 하늘 로 떠나 다 남김없이 태우 고 나 면 아 그 곳 에 는 푸른 밭 길 이 있 나요 내 머릿속 기억 속 에서 헤매 고 방황 해도 숨 쉬 고 멈추 고 다시 살 면 만날 수 있 겠 지 우리 다 남김없이 태우 고 나 면 아 그 곳 에 는 살구꽃 길 이 있 나요 저 세상 끝 에 우리 다시 만날 수 있 나요
# Right translation : <sos> 그냥 그런대로
# Predicted translation:  나 의 노래 <eos>
# -------------------------------------------------- 25

# %%
b="오- 내가 웃고 있나요?모두 거짓이겠죠? 날 보는 이들의 눈빛 속에는 (oh!) 슬픔이 젖어있는데. 헤이- 내 이름은 광대, 내 직업은 수많은 관객, 그 앞에 웃음을 파는 일 슬퍼도 웃으며 내 모습을 감추는 게 철칙. 오- 이런 내 처질, 손가락질 하며 날 모욕해도 더 크게 웃고 난 땀으로 목욕하고 음악이 꺼지고 막이 내리고 밤이 오면 별빛에 몸을 씻고 눈부시게 광낸 구두를 신고 달에게 청혼하듯 손을 내밀어 얼음 위를 미끄러지듯 앞으로 달려 (아무도) 아무도 모르게 조용히 흐르는 이 시간에 외롭게 홀로 핀 꽃 한 송이에 난 반해 사랑을 나누려 나는 간다네 세상을 넘어 시간을 멈추고 세상을 넘어 신나게 춤을 춰봐 세상을 넘어 모두가 같은 높이에서 그래 그래 그렇게 내가 웃고있나요 모두 거짓이겠죠 날 보는 이들의 눈빛속에는 슬픔이 젖어있는데 무대 위에 서면 우린 때론 정반대 내가 관객이 돼. 사람들의 얼굴에 상상의 그림을 그려 물감을 뿌려 저 불타는 이십대의 청춘은 내일이면 이 사회의 첫 줄을 이력서 쓰며 인생을 시험보고 저 순진한 사랑의 초보 애인있는 남자와 눈 맞어 사랑에 빠져 슬픔을 기다리네 (come on baby) 너와 나 모두 왕의 옷을 입어도 신하가 되버리는 현실에 혼신에 힘을 다해 헌신에 오늘 술 한잔하면 내일은 물 한잔으로 버텨야하지만, 일단은 오늘 또 마시네 아픔이 싹 가시네 세상을 넘어 시간을 멈추고 세상을 넘어 신나게 춤을 춰봐 세상을 넘어 모두가 같은 높이에서 그래 그래 그렇게 내가 웃고있나요 모두 거짓이겠죠 날 보는 이들의 눈빛속에는 슬픔이 젖어있는데 내가 웃고있나요 모두 거짓이겠죠 날 보는 이들의 눈빛속에는 슬픔이 젖어있는데"
translate(b)
# Out:
# Input: 오 내 가 웃고 있나요 ? 모두 거짓 이 겠죠 ? 날 보는 이 들 의 눈빛 속 에는 oh ! 슬픔 이 젖어있는데 . 헤이 내 이름 은 광대 내 직업 은 수많은 관객 그 앞 에 웃음 을 파는 일 슬퍼도 웃으며 내 모습 을 감추는 게 철칙 . 오 이런 내 처질 손가락질 하며 날 모욕 해도 더 크게 웃고 난 땀 으로 목욕 하고 음악 이 꺼지고 막 이 내리고 밤 이 오면 별빛 에 몸 을 씻고 눈부시게 광 낸 구두 를 신고 달 에게 청혼 하 듯 손 을 내밀어 얼음 위 를 미끄러지듯 앞 으로 달려 아무 도 아무 도 모르게 조용히 흐르는 이 시간 에 외롭게 홀로 핀 꽃 한 송이 에 난 반해 사랑 을 나누려 나 는 간다 네 세상 을 넘어 시간 을 멈추고 세상 을 넘어 신나게 춤 을 춰 봐 세상 을 넘어 모두 가 같은 높이 에서 그래 그래 그렇게 내 가 웃고있나요 모두 거짓 이 겠죠 날 보는 이 들 의 눈빛 속 에는 슬픔 이 젖어있는데 무대 위 에 서면 우린 때론 정반대 내 가 관객 이 돼 . 사람 들 의 얼굴 에 상상 의 그림 을 그려 물감 을 뿌려 저 불타는 이십 대의 청춘 은 내 일 이면 이 사회 의 첫 줄 을 이력서 쓰며 인생 을 시험 보고 저 순진한 사랑 의 초보 애인 있는 남자 와 눈 맞어 사랑 에 빠져 슬픔 을 기다리네 come on baby 너 와 나 모두 왕 의 옷 을 입어도 신하 가 되 버리는 현실 에 혼신 에 힘 을 다해 헌신 에 오늘 술 한잔 하면 내일 은 물 한잔 으로 버텨야하지만 일단 은 오늘 또 마시네 아픔 이 싹 가시 네 세상 을 넘어 시간 을 멈추고 세상 을 넘어 신나게 춤 을 춰 봐 세상 을 넘어 모두 가 같은 높이 에서 그래 그래 그렇게 내 가 웃고있나요 모두 거짓 이 겠죠 날 보는 이 들 의 눈빛 속 에는 슬픔 이 젖어있는데 내 가 웃고있나요 모두 거짓 이 겠죠 날 보는 이 들 의 눈빛 속 에는 슬픔 이 젖어있는데
# Predicted translation:  내 가 자릴 비운 <eos>

# %%
c='동해 물과 백두산이 마르고 닳도록 하느님이 보우하사 우리나라 만세. 무궁화 삼천리 화려 강산 대한 사람 대한으로 길이 보전하세'
translate(c)
# Out:
# Input: 동해 물 과 백두산 이 마르고 닳도록 하느님 이 보우 하사 우리나라 만세 . 무궁화 삼천리 화려 강산 대한 사람 대한 으로 길이 보전 하세
# Predicted translation:  고갈 다래 <eos>
